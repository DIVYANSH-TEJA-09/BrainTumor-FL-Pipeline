# %% [markdown]
# # Phase 3 / Setup 2: Moderate Label Skew — SimpleCNN + Dynamic-β QPSO
# **Phase 3 — Lightweight Model Experiment**
# - **Model:** SimpleCNN (~120K params) — 100× smaller than ResNet-18
# - **Image Size:** 112×112 (reduced from 224×224)
# - **Local Epochs:** 1 (reduced from 5) — forces reliance on aggregation
# - **Learning Rate:** 0.01 (increased from 0.001) — more client drift
# - **QPSO β:** 1.0 → 0.5 (dynamic linear decay, was static 0.7)
# - **QPSO perturbation clamp:** ±0.5 (relaxed from ±0.1)
# - **QPSO u clamp:** [0.1, 1.0] (relaxed from [0.3, 1.0])
#
# **Hypothesis:** With a capacity-limited model and minimal local training, QPSO's memory-based
# exploration (pbest/gbest) should clearly outperform FedAvg's stateless averaging.
#
# **Settings:** GPU P100 · Persistence: Files only · Internet: ON
# **Add Inputs:** Brain Tumor MRI Dataset (masoudnickparvar) + BRISC 2025 (briscdataset)

# %%
import os, sys, copy, time, random, json, shutil
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import stats
try:
    from tqdm.notebook import tqdm
except ImportError:
    from tqdm import tqdm

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42); device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu"); print("CPU only")
torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False

NUM_CLASSES = 4
CLASS_NAMES = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
VALID_CLASSES = {"glioma": 0, "meningioma": 1, "notumor": 2, "no_tumor": 2, "pituitary": 3}

# ╔══════════════════════════════════════════════════════╗
# ║  Phase 3 Hyperparameters — Tunable Knobs            ║
# ╚══════════════════════════════════════════════════════╝
IMG_SIZE = 112        # Reduced from 224 — less spatial info → harder task
LOCAL_EPOCHS = 1      # Reduced from 5 — forces reliance on aggregation
LR = 0.01             # Increased from 0.001 — faster local steps → more client drift
BATCH_SIZE = 64       # Increased from 32 — noisier per-step gradients
NUM_ROUNDS = 100
BETA_START = 1.0      # QPSO β decay: explore broadly early
BETA_END = 0.5        # QPSO β decay: exploit late
FEDPROX_MU = 0.01

print(f"Phase 3 Config: SimpleCNN | img={IMG_SIZE} | E={LOCAL_EPOCHS} | lr={LR} | bs={BATCH_SIZE} | rounds={NUM_ROUNDS}")
print(f"QPSO β: {BETA_START} → {BETA_END} (linear decay) | FedProx μ={FEDPROX_MU}")

for d in ['data/processed/client1','data/processed/client2','data/processed/client3',
          'data/test_set','models','results/fedavg','results/fedprox','results/qpso','results/plots','logs']:
    os.makedirs(f'/kaggle/working/{d}', exist_ok=True)
print("Directories created")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Phase 3 Config: SimpleCNN | img=112 | E=1 | lr=0.01 | bs=64 | rounds=100
# QPSO β: 1.0 → 0.5 (linear decay) | FedProx μ=0.01
# Directories created

# %% [markdown]
# ## Preprocessor (112×112)

# %%
class Preprocessor:
    def __init__(self, size=None):
        self.size = size or (IMG_SIZE, IMG_SIZE)
    def load_image(self, path):
        try:
            img = Image.open(path)
            if img.mode != "RGB": img = img.convert("RGB")
            return np.array(img.resize(self.size, Image.LANCZOS), dtype=np.float32) / 255.0
        except: return None

    def process_dataset(self, dataset_path, client_name, save_dir="/kaggle/working/data/processed",
                        train_r=0.70, val_r=0.15):
        print(f"\n{'='*60}\nProcessing {client_name} <- {dataset_path}\n{'='*60}")
        images, labels = [], []
        for cls_name in sorted(os.listdir(dataset_path)):
            cls_path = os.path.join(dataset_path, cls_name)
            if not os.path.isdir(cls_path): continue
            key = cls_name.lower().replace(" ","")
            if key not in VALID_CLASSES: print(f"  Skipping: {cls_name}"); continue
            label = VALID_CLASSES[key]
            files = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))]
            print(f"  {cls_name}: {len(files)} images (label={label})")
            for fname in tqdm(files, desc=f"    {cls_name}", leave=False):
                arr = self.load_image(os.path.join(cls_path, fname))
                if arr is not None: images.append(arr); labels.append(label)
        X, y = np.array(images), np.array(labels)
        print(f"  Total: {len(X)} | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
        test_r = 1.0 - train_r - val_r
        X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=test_r, stratify=y, random_state=42)
        val_adj = val_r / (train_r + val_r)
        X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=val_adj, stratify=y_tmp, random_state=42)
        print(f"  Train:{len(X_train)} Val:{len(X_val)} Test:{len(X_test)}")
        out = os.path.join(save_dir, client_name); os.makedirs(out, exist_ok=True)
        for name, arr in [("X_train",X_train),("y_train",y_train),("X_val",X_val),("y_val",y_val),("X_test",X_test),("y_test",y_test)]:
            np.save(os.path.join(out, f"{name}.npy"), arr)
        print(f"  Saved -> {out}")

    @staticmethod
    def create_global_test(pdir="/kaggle/working/data/processed", sdir="/kaggle/working/data/test_set"):
        Xs, ys = [], []
        for i in range(1, 4):
            d = os.path.join(pdir, f"client{i}")
            Xs.append(np.load(os.path.join(d, "X_test.npy")))
            ys.append(np.load(os.path.join(d, "y_test.npy")))
        X, y = np.concatenate(Xs), np.concatenate(ys)
        os.makedirs(sdir, exist_ok=True)
        np.save(os.path.join(sdir, "X_test.npy"), X)
        np.save(os.path.join(sdir, "y_test.npy"), y)
        print(f"Global test: {len(X)} images | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
print("Preprocessor ready (112x112)")
# Out:
# Preprocessor ready (112x112)

# %% [markdown]
# ## SimpleCNN Model & FL Components

# %%
class BrainTumorDataset(Dataset):
    _DEFAULT = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
    def __init__(self, X, y, transform=None):
        self.X, self.y = X, y; self.transform = transform or self._DEFAULT
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        img = Image.fromarray((self.X[idx]*255).astype(np.uint8))
        return self.transform(img), torch.tensor(self.y[idx], dtype=torch.long)

TRAIN_TF = transforms.Compose([transforms.RandomHorizontalFlip(0.5),
    transforms.RandomRotation(15), transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
TEST_TF = transforms.Compose([transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

def create_data_loaders(pdir="/kaggle/working/data/processed", tdir="/kaggle/working/data/test_set", bs=None, nw=2):
    bs = bs or BATCH_SIZE
    loaders = {}
    for i in range(1, 4):
        d = f"{pdir}/client{i}"
        ds_tr = BrainTumorDataset(np.load(f"{d}/X_train.npy"), np.load(f"{d}/y_train.npy"), TRAIN_TF)
        ds_va = BrainTumorDataset(np.load(f"{d}/X_val.npy"), np.load(f"{d}/y_val.npy"), TEST_TF)
        ds_te = BrainTumorDataset(np.load(f"{d}/X_test.npy"), np.load(f"{d}/y_test.npy"), TEST_TF)
        loaders[f"client{i}"] = {"train": DataLoader(ds_tr, bs, shuffle=True, num_workers=nw, pin_memory=True),
            "val": DataLoader(ds_va, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "test": DataLoader(ds_te, bs, shuffle=False, num_workers=nw, pin_memory=True), "train_size": len(ds_tr)}
        print(f"client{i}: Train={len(ds_tr)} Val={len(ds_va)} Test={len(ds_te)}")
    gds = BrainTumorDataset(np.load(f"{tdir}/X_test.npy"), np.load(f"{tdir}/y_test.npy"), TEST_TF)
    loaders["global_test"] = DataLoader(gds, bs, shuffle=False, num_workers=nw, pin_memory=True)
    print(f"Global test: {len(gds)}"); return loaders

# ═══════════════════════════════════════════════════════════════
# SimpleCNN — ~120K params (vs ResNet-18's 11.18M)
# ═══════════════════════════════════════════════════════════════
# SimpleCNN: Lightweight 3-layer CNN for Phase 3 experiments.
# ~120K params — designed to be capacity-limited so that
# the aggregation strategy (FedAvg vs QPSO) actually matters.
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16), nn.ReLU(), nn.MaxPool2d(2),           # -> 16 x 56 x 56
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(2),           # -> 32 x 28 x 28
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64), nn.ReLU(),
            nn.AdaptiveAvgPool2d(4),                                   # -> 64 x 4 x 4
        )
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(64 * 4 * 4, 128), nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes),
        )
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

def create_model(n=4, device="cuda"):
    m = SimpleCNN(n).to(device)
    total = sum(p.numel() for p in m.parameters())
    train = sum(p.numel() for p in m.parameters() if p.requires_grad)
    print(f"Model: SimpleCNN | Params: {total:,} (trainable {train:,}) | Classes: {n}")
    print(f"  ~{total * 4 / 1024**2:.2f} MB — {11_178_051 / total:.0f}x smaller than ResNet-18")
    return m

class FederatedClient:
    def __init__(self, cid, train_loader, val_loader, device="cuda"):
        self.client_id = cid; self.train_loader = train_loader
        self.val_loader = val_loader; self.device = device
        self.model = None; self.optimizer = None
        self.criterion = nn.CrossEntropyLoss(); self.dataset_size = len(train_loader.dataset)
    def set_model(self, gm): self.model = copy.deepcopy(gm).to(self.device)
    def set_optimizer(self, lr=None): self.optimizer = optim.Adam(self.model.parameters(), lr=lr or LR)
    def train_local(self, epochs=None, verbose=False):
        epochs = epochs or LOCAL_EPOCHS
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs); loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea
    def validate(self):
        self.model.eval(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.model(imgs); ls += self.criterion(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return ls/len(self.val_loader), 100.*c/t
    def get_dataset_size(self): return self.dataset_size

class FedProxClient(FederatedClient):
    def train_local(self, epochs=None, verbose=False, mu=None, global_params=None):
        epochs = epochs or LOCAL_EPOCHS; mu = mu or FEDPROX_MU
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs)
                if global_params is not None:
                    prox = sum(torch.norm(pl - pg.detach())**2 for pl, pg in zip(self.model.parameters(), global_params))
                    loss = loss + (mu / 2.0) * prox
                loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea

class FedAvgServer:
    def __init__(self, gm, clients, device="cuda"):
        self.global_model = gm; self.clients = clients; self.device = device
        self.total_samples = sum(c.get_dataset_size() for c in clients)
        print(f"FedAvg Server | clients={len(clients)} total={self.total_samples}")
    def aggregate_weights(self, cw):
        first = cw[0][0]; agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for sd, nk in cw: acc = acc + sd[k].float() * (nk / self.total_samples)
                agg[k] = acc.to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)

# ═══════════════════════════════════════════════════════════════
# QPSOServer with Dynamic Beta + Relaxed Clamps
# ═══════════════════════════════════════════════════════════════
# QPSOServer with Phase 3 improvements:
# - Dynamic beta decay (BETA_START -> BETA_END over rounds)
# - Relaxed perturbation clamps (+-0.5 instead of +-0.1)
# - Relaxed u clamp ([0.1, 1.0] instead of [0.3, 1.0])
class QPSOServer:
    def __init__(self, gm, clients, device="cuda", beta_start=None, beta_end=None, num_rounds=None):
        self.global_model = gm; self.clients = clients; self.device = device
        self.beta_start = beta_start or BETA_START
        self.beta_end = beta_end or BETA_END
        self.num_rounds = num_rounds or NUM_ROUNDS
        self.current_beta = self.beta_start
        self.personal_best = {}; self.personal_best_scores = {}
        self.global_best = None; self.global_best_score = 0.0; self.mean_best = None
        print(f"QPSO Server (Phase 3) | clients={len(clients)} β={self.beta_start}→{self.beta_end}")
    def initialize_particles(self):
        s = copy.deepcopy(self.global_model.state_dict())
        for c in self.clients: self.personal_best[c.client_id] = copy.deepcopy(s); self.personal_best_scores[c.client_id] = 0.0
        self.global_best = copy.deepcopy(s); self.global_best_score = 0.0; print("QPSO particles initialised")
    def update_beta(self, rnd):
        # Linear decay: beta_start at round 1 -> beta_end at final round
        self.current_beta = self.beta_start - (self.beta_start - self.beta_end) * (rnd / self.num_rounds)
        return self.current_beta
    def update_personal_best(self, cid, w, acc):
        if acc > self.personal_best_scores[cid]: self.personal_best[cid] = copy.deepcopy(w); self.personal_best_scores[cid] = acc; return True
        return False
    def update_global_best(self, cid, acc):
        if acc > self.global_best_score: self.global_best = copy.deepcopy(self.personal_best[cid]); self.global_best_score = acc; return True
        return False
    def calculate_mean_best(self):
        fid = self.clients[0].client_id
        self.mean_best = {k: torch.zeros_like(v, dtype=torch.float32) for k, v in self.personal_best[fid].items()}
        for c in self.clients:
            for k in self.mean_best: self.mean_best[k] += self.personal_best[c.client_id][k].float()
        for k in self.mean_best: self.mean_best[k] /= len(self.clients)
    def qpso_aggregate(self, cwl, rnd=1):
        beta = self.update_beta(rnd)
        for cid, w, acc in cwl:
            pb = self.update_personal_best(cid, w, acc); gb = self.update_global_best(cid, acc)
            if pb: print(f"  {cid}: pbest {acc:.2f}%")
            if gb: print(f"  {cid}: gbest {acc:.2f}%")
        self.calculate_mean_best(); agg = copy.deepcopy(self.global_best)
        for k in agg:
            if not agg[k].is_floating_point(): continue
            ps = torch.zeros_like(agg[k], dtype=torch.float32)
            for c in self.clients: ps += self.personal_best[c.client_id][k].float()
            phi = torch.rand_like(agg[k].float())
            u = torch.rand_like(agg[k].float()).clamp(min=0.1, max=1.0)     # relaxed from 0.3
            p = phi*(ps/len(self.clients)) + (1-phi)*self.global_best[k].float()
            sign = torch.where(torch.rand_like(agg[k].float())<0.5, torch.ones_like(agg[k].float()), -torch.ones_like(agg[k].float()))
            pert = beta * torch.abs(self.mean_best[k].float() - agg[k].float()) * torch.log(1.0/u)
            pert = pert.clamp(-0.5, 0.5)                                     # relaxed from ±0.1
            agg[k] = (p + sign * pert).to(self.global_best[k].dtype)
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)
print("All Phase 3 classes loaded (SimpleCNN + Dynamic-β QPSO)")
# Out:
# All Phase 3 classes loaded (SimpleCNN + Dynamic-β QPSO)

# %% [markdown]
# ## Data Preparation

# %%
# Setup 2: Moderate Label Skew (70/10/10/10)
# Each client keeps its OWN data but we subsample to create class imbalance
# Then augment back to original size

CLIENT1_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
CLIENT2_PATH = '/kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train'
CLIENT3_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

# First, process normally to get all images
prep = Preprocessor()
prep.process_dataset(CLIENT1_PATH, 'client1')
prep.process_dataset(CLIENT2_PATH, 'client2')
prep.process_dataset(CLIENT3_PATH, 'client3')

# Now apply label skew: Client1->Glioma dominant, Client2->Meningioma, Client3->NoTumor
DOMINANT = {1: 0, 2: 1, 3: 2}  # client_id -> dominant class label
DOMINANT_RATIO = 0.70
MINORITY_RATIO = 0.10

def augment_image(img):
    from PIL import ImageEnhance, ImageFilter
    pil = Image.fromarray((img*255).astype(np.uint8))
    if random.random() < 0.5: pil = pil.transpose(Image.FLIP_LEFT_RIGHT)
    if random.random() < 0.5: pil = pil.rotate(random.uniform(-30, 30), fillcolor=(0,0,0))
    if random.random() < 0.3: pil = ImageEnhance.Brightness(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.3: pil = ImageEnhance.Contrast(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.2: pil = pil.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1.5)))
    return np.array(pil, dtype=np.float32) / 255.0

for cid in range(1, 4):
    d = f"/kaggle/working/data/processed/client{cid}"
    X_train = np.load(f"{d}/X_train.npy"); y_train = np.load(f"{d}/y_train.npy")
    dom_cls = DOMINANT[cid]
    total = len(X_train)
    target_dom = int(total * DOMINANT_RATIO)
    target_min = int(total * MINORITY_RATIO)

    new_X, new_y = [], []
    for cls in range(NUM_CLASSES):
        mask = y_train == cls
        X_cls = X_train[mask]
        target = target_dom if cls == dom_cls else target_min
        if len(X_cls) >= target:
            idx = np.random.choice(len(X_cls), target, replace=False)
            new_X.append(X_cls[idx]); new_y.extend([cls]*target)
        else:
            new_X.append(X_cls); new_y.extend([cls]*len(X_cls))
            need = target - len(X_cls)
            for _ in range(need):
                src = X_cls[random.randint(0, len(X_cls)-1)]
                new_X.append(augment_image(src)[np.newaxis]); new_y.append(cls)

    X_new = np.concatenate(new_X); y_new = np.array(new_y)
    perm = np.random.permutation(len(X_new)); X_new = X_new[perm]; y_new = y_new[perm]
    np.save(f"{d}/X_train.npy", X_new); np.save(f"{d}/y_train.npy", y_new)
    print(f"client{cid}: dominant=class{dom_cls} | dist={np.bincount(y_new, minlength=NUM_CLASSES)} | total={len(X_new)}")

Preprocessor.create_global_test()
data_loaders = create_data_loaders()
print("\nSetup 2 data ready!")
# Out:
# ============================================================
# Processing client1 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
# ============================================================
#   glioma: 400 images (label=0)
#     glioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   meningioma: 400 images (label=1)
#     meningioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   notumor: 400 images (label=2)
#     notumor:   0%|          | 0/400 [00:00<?, ?it/s]
#   pituitary: 400 images (label=3)
#     pituitary:   0%|          | 0/400 [00:00<?, ?it/s]
#   Total: 1600 | Classes: [400 400 400 400]
#   Train:1119 Val:240 Test:241
#   Saved -> /kaggle/working/data/processed/client1
#
# ============================================================
# Processing client2 <- /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
# ============================================================
#   glioma: 1147 images (label=0)
#     glioma:   0%|          | 0/1147 [00:00<?, ?it/s]
#   meningioma: 1329 images (label=1)
#     meningioma:   0%|          | 0/1329 [00:00<?, ?it/s]
#   no_tumor: 1067 images (label=2)
#     no_tumor:   0%|          | 0/1067 [00:00<?, ?it/s]
#   pituitary: 1457 images (label=3)
#     pituitary:   0%|          | 0/1457 [00:00<?, ?it/s]
#   Total: 5000 | Classes: [1147 1329 1067 1457]
#   Train:3499 Val:750 Test:751
#   Saved -> /kaggle/working/data/processed/client2
#
# ============================================================
# Processing client3 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# ============================================================
#   glioma: 1400 images (label=0)
#     glioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   meningioma: 1400 images (label=1)
#     meningioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   notumor: 1400 images (label=2)
#     notumor:   0%|          | 0/1400 [00:00<?, ?it/s]
#   pituitary: 1400 images (label=3)
#     pituitary:   0%|          | 0/1400 [00:00<?, ?it/s]
#   Total: 5600 | Classes: [1400 1400 1400 1400]
#   Train:3919 Val:840 Test:841
#   Saved -> /kaggle/working/data/processed/client3
# client1: dominant=class0 | dist=[783 111 111 111] | total=1116
# client2: dominant=class1 | dist=[ 349 2449  349  349] | total=3496
# client3: dominant=class2 | dist=[ 391  391 2743  391] | total=3916
# Global test: 1833 images | Classes: [442 470 432 489]
# client1: Train=1116 Val=240 Test=241
# client2: Train=3496 Val=750 Test=751
# client3: Train=3916 Val=840 Test=841
# Global test: 1833
#
# Setup 2 data ready!

# %% [markdown]
# ## Phase 3 Training Functions

# %%
def train_fedavg(server, clients, gtl, nr=None, le=None, lr=None, se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR
    print("="*80+"\n  FEDAVG TRAINING START (Phase 3: SimpleCNN)\n"+"="*80)
    print(f"  Rounds={nr} | Local epochs={le} | LR={lr}")
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedavg/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDAVG DONE best {best:.2f}%\n{'='*80}"); return h

def train_fedprox(server, clients, gtl, nr=None, le=None, lr=None, mu=None, se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR; mu = mu or FEDPROX_MU
    print("="*80+"\n  FEDPROX TRAINING START (Phase 3, mu="+str(mu)+")\n"+"="*80)
    print(f"  Rounds={nr} | Local epochs={le} | LR={lr}")
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        gp = list(server.global_model.parameters())
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose, mu=mu, global_params=gp)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedprox/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDPROX DONE best {best:.2f}%\n{'='*80}"); return h

def train_qpso(server, clients, gtl, nr=None, le=None, lr=None, se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR
    print("="*80+"\n  QPSO-FL TRAINING START (Phase 3: Dynamic β)\n"+"="*80)
    print(f"  Rounds={nr} | Local epochs={le} | LR={lr} | β: {server.beta_start}→{server.beta_end}")
    server.initialize_particles()
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"global_best_score":[],"current_beta":[],
         "client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],
         "client1_pbest":[],"client2_pbest":[],"client3_pbest":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); beta = server.update_beta(rnd)
        print(f"\n{'='*60} ROUND {rnd}/{nr} (β={beta:.3f})"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((cl.client_id, w, va))
        print(f"  QPSO aggregating (β={beta:.3f})..."); agg = server.qpso_aggregate(cw, rnd)
        server.global_model.load_state_dict(agg)
        for c in clients: h[f"{c.client_id}_pbest"].append(server.personal_best_scores[c.client_id])
        h["global_best_score"].append(server.global_best_score); h["current_beta"].append(beta)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} gbest={server.global_best_score:.2f}% ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/qpso/metrics.csv", index=False)
    print(f"\n{'='*80}\n  QPSO-FL DONE best {best:.2f}% gbest {server.global_best_score:.2f}%\n{'='*80}"); return h
print("Phase 3 trainers loaded")
# Out:
# Phase 3 trainers loaded

# %% [markdown]
# ## FedAvg Training (SimpleCNN, E=1, lr=0.01)

# %%
fedavg_model = create_model(NUM_CLASSES, device)
fedavg_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                  data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedavg_server = FedAvgServer(fedavg_model, fedavg_clients, device=device)
fedavg_history = train_fedavg(fedavg_server, fedavg_clients, data_loaders['global_test'],
    nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, se=10, verbose=False)
# Out:
# Model: SimpleCNN | Params: 155,524 (trainable 155,524) | Classes: 4
#   ~0.59 MB — 72x smaller than ResNet-18
# FedAvg Server | clients=3 total=8528
# ================================================================================
#   FEDAVG TRAINING START (Phase 3: SimpleCNN)
# ================================================================================
#   Rounds=100 | Local epochs=1 | LR=0.01
#
# ============================================================ ROUND 1/100
#   client1 training... val=30.00%
#   client2 training... val=45.33%
#   client3 training... val=40.95%
#   Global: acc=23.24% loss=1.3777 (8.8s)
#   New best! 23.24%
#
# ============================================================ ROUND 2/100
#   client1 training... val=28.33%
#   client2 training... val=26.53%
#   client3 training... val=45.24%
#   Global: acc=26.57% loss=1.3049 (8.2s)
#   New best! 26.57%
#
# ============================================================ ROUND 3/100
#   client1 training... val=25.00%
#   client2 training... val=26.53%
#   client3 training... val=46.90%
#   Global: acc=35.62% loss=1.2247 (8.0s)
#   New best! 35.62%
#
# ============================================================ ROUND 4/100
#   client1 training... val=28.33%
#   client2 training... val=26.53%
#   client3 training... val=25.00%
#   Global: acc=46.43% loss=1.1734 (7.7s)
#   New best! 46.43%
#
# ============================================================ ROUND 5/100
#   client1 training... val=25.00%
#   client2 training... val=35.07%
#   client3 training... val=64.76%
#   Global: acc=57.72% loss=1.1046 (7.8s)
#   New best! 57.72%
#
# ============================================================ ROUND 6/100
#   client1 training... val=25.00%
#   client2 training... val=32.40%
#   client3 training... val=63.21%
#   Global: acc=54.39% loss=1.1086 (7.9s)
#
# ============================================================ ROUND 7/100
#   client1 training... val=25.00%
#   client2 training... val=39.87%
#   client3 training... val=68.33%
#   Global: acc=53.41% loss=1.1406 (7.8s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=27.08%
#   client2 training... val=38.13%
#   client3 training... val=72.14%
#   Global: acc=57.94% loss=1.0364 (7.7s)
#   New best! 57.94%
#
# ============================================================ ROUND 9/100
#   client1 training... val=32.08%
#   client2 training... val=59.60%
#   client3 training... val=65.83%
#   Global: acc=57.72% loss=0.9451 (7.7s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=34.17%
#   client2 training... val=58.53%
#   client3 training... val=70.00%
#   Global: acc=68.96% loss=0.8695 (7.8s)
#   New best! 68.96%
#
# ============================================================ ROUND 11/100
#   client1 training... val=25.00%
#   client2 training... val=54.67%
#   client3 training... val=72.38%
#   Global: acc=64.43% loss=0.8449 (7.9s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=32.08%
#   client2 training... val=48.53%
#   client3 training... val=70.12%
#   Global: acc=59.74% loss=0.9066 (7.8s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=27.92%
#   client2 training... val=46.67%
#   client3 training... val=73.45%
#   Global: acc=64.70% loss=0.8414 (8.0s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=26.25%
#   client2 training... val=59.60%
#   client3 training... val=70.95%
#   Global: acc=62.36% loss=0.7970 (7.7s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=50.00%
#   client2 training... val=58.53%
#   client3 training... val=65.95%
#   Global: acc=60.67% loss=0.8218 (7.8s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=44.17%
#   client2 training... val=64.00%
#   client3 training... val=67.86%
#   Global: acc=67.48% loss=0.7267 (7.8s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=41.67%
#   client2 training... val=65.73%
#   client3 training... val=75.60%
#   Global: acc=68.30% loss=0.7243 (7.8s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=47.08%
#   client2 training... val=58.00%
#   client3 training... val=74.76%
#   Global: acc=61.87% loss=0.7753 (7.9s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=45.83%
#   client2 training... val=33.87%
#   client3 training... val=72.98%
#   Global: acc=65.25% loss=0.7728 (7.9s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=44.58%
#   client2 training... val=64.67%
#   client3 training... val=74.52%
#   Global: acc=69.39% loss=0.7664 (8.0s)
#   New best! 69.39%
#
# ============================================================ ROUND 21/100
#   client1 training... val=55.42%
#   client2 training... val=60.67%
#   client3 training... val=71.79%
#   Global: acc=73.00% loss=0.6874 (8.1s)
#   New best! 73.00%
#
# ============================================================ ROUND 22/100
#   client1 training... val=45.00%
#   client2 training... val=60.80%
#   client3 training... val=75.12%
#   Global: acc=65.85% loss=0.6883 (8.1s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=56.25%
#   client2 training... val=49.73%
#   client3 training... val=66.31%
#   Global: acc=67.70% loss=0.7035 (7.9s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=42.50%
#   client2 training... val=67.20%
#   client3 training... val=77.38%
#   Global: acc=65.41% loss=0.6871 (8.0s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=34.17%
#   client2 training... val=65.60%
#   client3 training... val=77.86%
#   Global: acc=75.29% loss=0.6714 (8.0s)
#   New best! 75.29%
#
# ============================================================ ROUND 26/100
#   client1 training... val=42.92%
#   client2 training... val=63.47%
#   client3 training... val=75.24%
#   Global: acc=70.27% loss=0.7338 (8.0s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=47.50%
#   client2 training... val=33.73%
#   client3 training... val=73.69%
#   Global: acc=74.74% loss=0.7219 (8.0s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=49.58%
#   client2 training... val=67.07%
#   client3 training... val=71.90%
#   Global: acc=71.47% loss=0.6961 (7.9s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=45.00%
#   client2 training... val=57.47%
#   client3 training... val=61.55%
#   Global: acc=75.61% loss=0.6654 (7.9s)
#   New best! 75.61%
#
# ============================================================ ROUND 30/100
#   client1 training... val=50.00%
#   client2 training... val=60.13%
#   client3 training... val=67.98%
#   Global: acc=79.49% loss=0.5971 (7.9s)
#   New best! 79.49%
#
# ============================================================ ROUND 31/100
#   client1 training... val=41.25%
#   client2 training... val=62.93%
#   client3 training... val=76.43%
#   Global: acc=73.76% loss=0.6954 (8.0s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=43.33%
#   client2 training... val=67.33%
#   client3 training... val=77.50%
#   Global: acc=77.03% loss=0.6277 (8.0s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=49.17%
#   client2 training... val=65.73%
#   client3 training... val=73.10%
#   Global: acc=75.40% loss=0.6195 (8.0s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=52.08%
#   client2 training... val=65.60%
#   client3 training... val=73.21%
#   Global: acc=78.45% loss=0.5979 (8.0s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=52.08%
#   client2 training... val=68.53%
#   client3 training... val=79.88%
#   Global: acc=80.03% loss=0.5712 (8.0s)
#   New best! 80.03%
#
# ============================================================ ROUND 36/100
#   client1 training... val=38.75%
#   client2 training... val=64.80%
#   client3 training... val=66.55%
#   Global: acc=76.81% loss=0.6299 (8.0s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=42.08%
#   client2 training... val=68.13%
#   client3 training... val=77.62%
#   Global: acc=79.92% loss=0.5780 (8.1s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=54.58%
#   client2 training... val=68.13%
#   client3 training... val=79.05%
#   Global: acc=81.94% loss=0.5741 (7.9s)
#   New best! 81.94%
#
# ============================================================ ROUND 39/100
#   client1 training... val=40.83%
#   client2 training... val=69.20%
#   client3 training... val=74.17%
#   Global: acc=79.81% loss=0.5646 (8.0s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=46.25%
#   client2 training... val=68.00%
#   client3 training... val=77.50%
#   Global: acc=75.29% loss=0.6168 (7.9s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=47.92%
#   client2 training... val=65.60%
#   client3 training... val=81.07%
#   Global: acc=80.63% loss=0.5466 (7.8s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=31.25%
#   client2 training... val=62.13%
#   client3 training... val=85.60%
#   Global: acc=79.81% loss=0.6025 (7.8s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=49.58%
#   client2 training... val=67.87%
#   client3 training... val=72.50%
#   Global: acc=76.98% loss=0.6405 (8.4s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=60.00%
#   client2 training... val=67.47%
#   client3 training... val=80.60%
#   Global: acc=84.02% loss=0.5274 (8.2s)
#   New best! 84.02%
#
# ============================================================ ROUND 45/100
#   client1 training... val=52.92%
#   client2 training... val=69.60%
#   client3 training... val=79.17%
#   Global: acc=82.43% loss=0.5146 (8.0s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=53.33%
#   client2 training... val=67.87%
#   client3 training... val=81.55%
#   Global: acc=80.69% loss=0.6067 (7.7s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=43.75%
#   client2 training... val=66.40%
#   client3 training... val=84.88%
#   Global: acc=82.21% loss=0.5536 (7.9s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=58.33%
#   client2 training... val=67.73%
#   client3 training... val=49.17%
#   Global: acc=67.43% loss=0.7211 (7.7s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=42.50%
#   client2 training... val=70.53%
#   client3 training... val=73.69%
#   Global: acc=77.58% loss=0.5901 (7.9s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=61.67%
#   client2 training... val=72.67%
#   client3 training... val=84.64%
#   Global: acc=83.74% loss=0.5144 (7.8s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=51.25%
#   client2 training... val=69.33%
#   client3 training... val=82.74%
#   Global: acc=83.36% loss=0.5184 (7.9s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=39.58%
#   client2 training... val=70.27%
#   client3 training... val=81.31%
#   Global: acc=83.31% loss=0.5144 (7.8s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=46.67%
#   client2 training... val=72.67%
#   client3 training... val=74.40%
#   Global: acc=84.72% loss=0.4903 (7.8s)
#   New best! 84.72%
#
# ============================================================ ROUND 54/100
#   client1 training... val=59.17%
#   client2 training... val=67.33%
#   client3 training... val=78.33%
#   Global: acc=80.14% loss=0.5514 (7.8s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=51.25%
#   client2 training... val=72.00%
#   client3 training... val=86.55%
#   Global: acc=86.09% loss=0.4773 (7.9s)
#   New best! 86.09%
#
# ============================================================ ROUND 56/100
#   client1 training... val=54.17%
#   client2 training... val=77.33%
#   client3 training... val=86.07%
#   Global: acc=85.82% loss=0.4902 (7.9s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=58.33%
#   client2 training... val=72.53%
#   client3 training... val=85.71%
#   Global: acc=84.40% loss=0.4949 (7.9s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=52.92%
#   client2 training... val=76.00%
#   client3 training... val=85.12%
#   Global: acc=85.16% loss=0.4581 (7.9s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=60.00%
#   client2 training... val=77.33%
#   client3 training... val=81.90%
#   Global: acc=86.58% loss=0.4745 (8.0s)
#   New best! 86.58%
#
# ============================================================ ROUND 60/100
#   client1 training... val=60.83%
#   client2 training... val=84.00%
#   client3 training... val=85.12%
#   Global: acc=85.11% loss=0.4680 (8.1s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=52.50%
#   client2 training... val=72.93%
#   client3 training... val=80.60%
#   Global: acc=84.34% loss=0.4819 (7.9s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=52.92%
#   client2 training... val=77.07%
#   client3 training... val=85.24%
#   Global: acc=85.32% loss=0.4581 (7.8s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=56.25%
#   client2 training... val=80.80%
#   client3 training... val=80.83%
#   Global: acc=86.63% loss=0.4694 (7.9s)
#   New best! 86.63%
#
# ============================================================ ROUND 64/100
#   client1 training... val=54.58%
#   client2 training... val=74.00%
#   client3 training... val=84.88%
#   Global: acc=85.38% loss=0.4783 (7.9s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=58.33%
#   client2 training... val=79.47%
#   client3 training... val=87.14%
#   Global: acc=85.38% loss=0.4655 (7.9s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=55.83%
#   client2 training... val=76.40%
#   client3 training... val=80.48%
#   Global: acc=84.67% loss=0.4597 (7.9s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=58.75%
#   client2 training... val=81.33%
#   client3 training... val=88.21%
#   Global: acc=85.60% loss=0.4594 (7.8s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=47.92%
#   client2 training... val=82.40%
#   client3 training... val=77.98%
#   Global: acc=86.31% loss=0.4500 (7.8s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=46.67%
#   client2 training... val=78.80%
#   client3 training... val=83.45%
#   Global: acc=85.60% loss=0.4512 (7.9s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=52.92%
#   client2 training... val=77.73%
#   client3 training... val=86.43%
#   Global: acc=85.82% loss=0.4724 (7.9s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=47.92%
#   client2 training... val=75.60%
#   client3 training... val=86.55%
#   Global: acc=88.22% loss=0.4497 (7.9s)
#   New best! 88.22%
#
# ============================================================ ROUND 72/100
#   client1 training... val=59.17%
#   client2 training... val=80.00%
#   client3 training... val=80.60%
#   Global: acc=87.67% loss=0.4275 (7.8s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=55.00%
#   client2 training... val=80.93%
#   client3 training... val=82.38%
#   Global: acc=86.52% loss=0.4161 (7.9s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=55.00%
#   client2 training... val=81.33%
#   client3 training... val=87.02%
#   Global: acc=87.56% loss=0.4261 (7.8s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=52.08%
#   client2 training... val=80.40%
#   client3 training... val=86.19%
#   Global: acc=87.83% loss=0.4113 (7.9s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=50.42%
#   client2 training... val=83.33%
#   client3 training... val=77.26%
#   Global: acc=87.07% loss=0.4264 (7.8s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=63.33%
#   client2 training... val=79.20%
#   client3 training... val=86.79%
#   Global: acc=86.80% loss=0.4207 (7.9s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=39.17%
#   client2 training... val=82.13%
#   client3 training... val=77.86%
#   Global: acc=86.47% loss=0.4054 (7.8s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=58.33%
#   client2 training... val=80.27%
#   client3 training... val=66.07%
#   Global: acc=87.40% loss=0.3807 (7.9s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=55.42%
#   client2 training... val=79.73%
#   client3 training... val=85.71%
#   Global: acc=87.67% loss=0.4133 (7.9s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=55.83%
#   client2 training... val=85.73%
#   client3 training... val=87.62%
#   Global: acc=88.16% loss=0.3865 (7.9s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=51.25%
#   client2 training... val=78.13%
#   client3 training... val=88.57%
#   Global: acc=88.71% loss=0.3838 (7.9s)
#   New best! 88.71%
#
# ============================================================ ROUND 83/100
#   client1 training... val=50.42%
#   client2 training... val=78.80%
#   client3 training... val=83.81%
#   Global: acc=89.96% loss=0.3902 (7.9s)
#   New best! 89.96%
#
# ============================================================ ROUND 84/100
#   client1 training... val=62.08%
#   client2 training... val=85.47%
#   client3 training... val=88.69%
#   Global: acc=88.71% loss=0.3682 (7.8s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=55.83%
#   client2 training... val=77.87%
#   client3 training... val=68.21%
#   Global: acc=86.58% loss=0.4148 (7.8s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=53.75%
#   client2 training... val=78.53%
#   client3 training... val=81.90%
#   Global: acc=87.94% loss=0.3668 (7.8s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=58.33%
#   client2 training... val=75.87%
#   client3 training... val=86.43%
#   Global: acc=87.07% loss=0.4172 (7.8s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=57.92%
#   client2 training... val=86.40%
#   client3 training... val=87.86%
#   Global: acc=88.98% loss=0.3577 (7.9s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=55.42%
#   client2 training... val=85.60%
#   client3 training... val=88.10%
#   Global: acc=88.87% loss=0.3793 (7.8s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=54.58%
#   client2 training... val=81.60%
#   client3 training... val=88.21%
#   Global: acc=87.83% loss=0.4054 (7.8s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=40.42%
#   client2 training... val=88.40%
#   client3 training... val=88.45%
#   Global: acc=90.18% loss=0.3476 (7.9s)
#   New best! 90.18%
#
# ============================================================ ROUND 92/100
#   client1 training... val=52.08%
#   client2 training... val=79.33%
#   client3 training... val=87.14%
#   Global: acc=88.71% loss=0.3672 (7.8s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=50.00%
#   client2 training... val=83.60%
#   client3 training... val=86.19%
#   Global: acc=88.05% loss=0.3650 (7.9s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=52.92%
#   client2 training... val=85.07%
#   client3 training... val=74.52%
#   Global: acc=90.56% loss=0.3006 (7.9s)
#   New best! 90.56%
#
# ============================================================ ROUND 95/100
#   client1 training... val=59.58%
#   client2 training... val=77.47%
#   client3 training... val=83.69%
#   Global: acc=85.92% loss=0.4073 (7.8s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=57.08%
#   client2 training... val=86.40%
#   client3 training... val=88.33%
#   Global: acc=89.47% loss=0.3439 (7.9s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=66.67%
#   client2 training... val=84.80%
#   client3 training... val=77.50%
#   Global: acc=87.02% loss=0.3694 (7.9s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=64.17%
#   client2 training... val=87.60%
#   client3 training... val=86.55%
#   Global: acc=89.80% loss=0.3233 (7.8s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=60.42%
#   client2 training... val=84.67%
#   client3 training... val=88.81%
#   Global: acc=90.13% loss=0.3406 (7.7s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=60.42%
#   client2 training... val=85.73%
#   client3 training... val=89.17%
#   Global: acc=88.16% loss=0.3624 (7.9s)
#
# ================================================================================
#   FEDAVG DONE best 90.56%
# ================================================================================

# %% [markdown]
# ## FedProx Training (SimpleCNN, E=1, lr=0.01, μ=0.01)

# %%
torch.cuda.empty_cache()
fedprox_model = create_model(NUM_CLASSES, device)
fedprox_clients = [FedProxClient(f'client{i}', data_loaders[f'client{i}']['train'],
                   data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedprox_server = FedAvgServer(fedprox_model, fedprox_clients, device=device)
fedprox_history = train_fedprox(fedprox_server, fedprox_clients, data_loaders['global_test'],
    nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, mu=FEDPROX_MU, se=10, verbose=False)
# Out:
# Model: SimpleCNN | Params: 155,524 (trainable 155,524) | Classes: 4
#   ~0.59 MB — 72x smaller than ResNet-18
# FedAvg Server | clients=3 total=8528
# ================================================================================
#   FEDPROX TRAINING START (Phase 3, mu=0.01)
# ================================================================================
#   Rounds=100 | Local epochs=1 | LR=0.01
#
# ============================================================ ROUND 1/100
#   client1 training... val=35.42%
#   client2 training... val=26.53%
#   client3 training... val=31.07%
#   Global: acc=23.02% loss=1.3901 (8.0s)
#   New best! 23.02%
#
# ============================================================ ROUND 2/100
#   client1 training... val=25.00%
#   client2 training... val=52.27%
#   client3 training... val=56.67%
#   Global: acc=55.21% loss=1.1548 (7.9s)
#   New best! 55.21%
#
# ============================================================ ROUND 3/100
#   client1 training... val=31.25%
#   client2 training... val=34.27%
#   client3 training... val=49.76%
#   Global: acc=60.07% loss=1.0164 (8.0s)
#   New best! 60.07%
#
# ============================================================ ROUND 4/100
#   client1 training... val=38.75%
#   client2 training... val=57.33%
#   client3 training... val=48.10%
#   Global: acc=68.36% loss=0.8732 (8.0s)
#   New best! 68.36%
#
# ============================================================ ROUND 5/100
#   client1 training... val=34.17%
#   client2 training... val=37.07%
#   client3 training... val=74.40%
#   Global: acc=68.47% loss=0.7901 (8.0s)
#   New best! 68.47%
#
# ============================================================ ROUND 6/100
#   client1 training... val=38.75%
#   client2 training... val=64.67%
#   client3 training... val=39.64%
#   Global: acc=71.96% loss=0.7483 (8.0s)
#   New best! 71.96%
#
# ============================================================ ROUND 7/100
#   client1 training... val=43.33%
#   client2 training... val=58.00%
#   client3 training... val=71.55%
#   Global: acc=70.65% loss=0.6912 (8.0s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=56.67%
#   client2 training... val=64.13%
#   client3 training... val=52.26%
#   Global: acc=75.01% loss=0.6412 (8.0s)
#   New best! 75.01%
#
# ============================================================ ROUND 9/100
#   client1 training... val=40.42%
#   client2 training... val=57.60%
#   client3 training... val=67.38%
#   Global: acc=69.12% loss=0.7039 (8.0s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=58.33%
#   client2 training... val=62.13%
#   client3 training... val=72.74%
#   Global: acc=71.30% loss=0.6650 (7.9s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=58.75%
#   client2 training... val=64.93%
#   client3 training... val=63.45%
#   Global: acc=72.01% loss=0.6632 (8.0s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=37.08%
#   client2 training... val=66.00%
#   client3 training... val=76.43%
#   Global: acc=76.32% loss=0.6202 (7.9s)
#   New best! 76.32%
#
# ============================================================ ROUND 13/100
#   client1 training... val=32.50%
#   client2 training... val=56.67%
#   client3 training... val=50.95%
#   Global: acc=73.98% loss=0.6285 (7.9s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=55.00%
#   client2 training... val=67.47%
#   client3 training... val=75.60%
#   Global: acc=79.98% loss=0.5554 (8.0s)
#   New best! 79.98%
#
# ============================================================ ROUND 15/100
#   client1 training... val=51.67%
#   client2 training... val=74.93%
#   client3 training... val=75.95%
#   Global: acc=78.83% loss=0.5570 (7.9s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=42.92%
#   client2 training... val=53.73%
#   client3 training... val=76.67%
#   Global: acc=79.81% loss=0.5625 (7.9s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=54.17%
#   client2 training... val=77.60%
#   client3 training... val=80.36%
#   Global: acc=83.03% loss=0.4571 (8.0s)
#   New best! 83.03%
#
# ============================================================ ROUND 18/100
#   client1 training... val=46.67%
#   client2 training... val=62.00%
#   client3 training... val=66.55%
#   Global: acc=82.27% loss=0.5048 (7.9s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=60.83%
#   client2 training... val=70.27%
#   client3 training... val=68.81%
#   Global: acc=72.34% loss=0.5919 (7.9s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=45.42%
#   client2 training... val=80.13%
#   client3 training... val=63.21%
#   Global: acc=81.51% loss=0.4731 (8.0s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=50.42%
#   client2 training... val=64.80%
#   client3 training... val=75.95%
#   Global: acc=85.32% loss=0.4616 (8.0s)
#   New best! 85.32%
#
# ============================================================ ROUND 22/100
#   client1 training... val=43.33%
#   client2 training... val=75.07%
#   client3 training... val=62.14%
#   Global: acc=80.80% loss=0.4790 (8.0s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=61.25%
#   client2 training... val=66.13%
#   client3 training... val=76.90%
#   Global: acc=79.92% loss=0.4959 (8.0s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=39.58%
#   client2 training... val=63.33%
#   client3 training... val=85.00%
#   Global: acc=85.65% loss=0.4304 (8.0s)
#   New best! 85.65%
#
# ============================================================ ROUND 25/100
#   client1 training... val=63.75%
#   client2 training... val=74.27%
#   client3 training... val=68.57%
#   Global: acc=84.94% loss=0.4122 (8.0s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=62.08%
#   client2 training... val=84.67%
#   client3 training... val=83.57%
#   Global: acc=84.67% loss=0.4240 (8.1s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=58.75%
#   client2 training... val=82.40%
#   client3 training... val=85.36%
#   Global: acc=86.69% loss=0.3808 (8.0s)
#   New best! 86.69%
#
# ============================================================ ROUND 28/100
#   client1 training... val=58.33%
#   client2 training... val=76.80%
#   client3 training... val=85.00%
#   Global: acc=83.03% loss=0.4357 (8.1s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=70.42%
#   client2 training... val=83.87%
#   client3 training... val=76.90%
#   Global: acc=84.40% loss=0.4077 (8.0s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=58.33%
#   client2 training... val=63.87%
#   client3 training... val=85.83%
#   Global: acc=84.40% loss=0.4206 (8.0s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=61.25%
#   client2 training... val=71.87%
#   client3 training... val=76.90%
#   Global: acc=83.63% loss=0.4232 (8.1s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=47.08%
#   client2 training... val=82.13%
#   client3 training... val=87.14%
#   Global: acc=85.92% loss=0.3845 (8.0s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=66.67%
#   client2 training... val=73.47%
#   client3 training... val=81.90%
#   Global: acc=84.56% loss=0.4019 (8.0s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=53.75%
#   client2 training... val=80.67%
#   client3 training... val=86.67%
#   Global: acc=87.02% loss=0.3458 (8.0s)
#   New best! 87.02%
#
# ============================================================ ROUND 35/100
#   client1 training... val=68.75%
#   client2 training... val=84.13%
#   client3 training... val=79.52%
#   Global: acc=83.85% loss=0.4170 (8.0s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=68.33%
#   client2 training... val=83.20%
#   client3 training... val=88.10%
#   Global: acc=86.25% loss=0.3515 (8.0s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=64.17%
#   client2 training... val=71.47%
#   client3 training... val=85.60%
#   Global: acc=85.22% loss=0.3764 (8.1s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=59.17%
#   client2 training... val=81.87%
#   client3 training... val=76.79%
#   Global: acc=87.51% loss=0.3501 (8.1s)
#   New best! 87.51%
#
# ============================================================ ROUND 39/100
#   client1 training... val=56.67%
#   client2 training... val=85.60%
#   client3 training... val=85.24%
#   Global: acc=87.34% loss=0.3297 (8.1s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=67.08%
#   client2 training... val=86.13%
#   client3 training... val=88.69%
#   Global: acc=88.16% loss=0.3193 (8.0s)
#   New best! 88.16%
#
# ============================================================ ROUND 41/100
#   client1 training... val=70.00%
#   client2 training... val=88.93%
#   client3 training... val=86.43%
#   Global: acc=88.33% loss=0.3062 (8.0s)
#   New best! 88.33%
#
# ============================================================ ROUND 42/100
#   client1 training... val=68.75%
#   client2 training... val=85.73%
#   client3 training... val=79.05%
#   Global: acc=84.78% loss=0.4009 (8.0s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=61.25%
#   client2 training... val=87.73%
#   client3 training... val=81.79%
#   Global: acc=88.60% loss=0.3125 (8.0s)
#   New best! 88.60%
#
# ============================================================ ROUND 44/100
#   client1 training... val=63.75%
#   client2 training... val=69.20%
#   client3 training... val=87.26%
#   Global: acc=85.54% loss=0.3921 (7.9s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=64.58%
#   client2 training... val=73.47%
#   client3 training... val=77.62%
#   Global: acc=90.02% loss=0.3006 (7.9s)
#   New best! 90.02%
#
# ============================================================ ROUND 46/100
#   client1 training... val=55.00%
#   client2 training... val=70.40%
#   client3 training... val=84.05%
#   Global: acc=88.98% loss=0.3158 (8.1s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=52.92%
#   client2 training... val=84.67%
#   client3 training... val=81.43%
#   Global: acc=89.69% loss=0.3010 (8.1s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=73.75%
#   client2 training... val=83.20%
#   client3 training... val=88.81%
#   Global: acc=89.03% loss=0.2998 (8.1s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=70.42%
#   client2 training... val=86.67%
#   client3 training... val=85.71%
#   Global: acc=87.67% loss=0.3291 (8.0s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=68.75%
#   client2 training... val=86.67%
#   client3 training... val=67.02%
#   Global: acc=86.74% loss=0.3692 (8.0s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=71.67%
#   client2 training... val=84.53%
#   client3 training... val=88.93%
#   Global: acc=89.96% loss=0.3094 (8.1s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=70.42%
#   client2 training... val=86.80%
#   client3 training... val=88.69%
#   Global: acc=89.80% loss=0.2839 (8.1s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=69.17%
#   client2 training... val=86.53%
#   client3 training... val=76.79%
#   Global: acc=87.73% loss=0.3223 (8.0s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=63.33%
#   client2 training... val=90.00%
#   client3 training... val=79.52%
#   Global: acc=88.87% loss=0.3007 (8.0s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=62.50%
#   client2 training... val=78.13%
#   client3 training... val=74.29%
#   Global: acc=86.03% loss=0.3573 (7.9s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=66.25%
#   client2 training... val=87.33%
#   client3 training... val=90.24%
#   Global: acc=89.74% loss=0.2865 (8.0s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=70.00%
#   client2 training... val=89.20%
#   client3 training... val=88.21%
#   Global: acc=90.56% loss=0.2723 (8.0s)
#   New best! 90.56%
#
# ============================================================ ROUND 58/100
#   client1 training... val=65.83%
#   client2 training... val=82.80%
#   client3 training... val=81.90%
#   Global: acc=89.91% loss=0.2790 (8.0s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=58.75%
#   client2 training... val=85.20%
#   client3 training... val=90.24%
#   Global: acc=91.27% loss=0.2685 (7.9s)
#   New best! 91.27%
#
# ============================================================ ROUND 60/100
#   client1 training... val=63.33%
#   client2 training... val=82.80%
#   client3 training... val=89.05%
#   Global: acc=89.03% loss=0.3083 (8.1s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=67.50%
#   client2 training... val=74.13%
#   client3 training... val=91.31%
#   Global: acc=88.82% loss=0.3002 (8.0s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=50.00%
#   client2 training... val=86.67%
#   client3 training... val=87.38%
#   Global: acc=90.34% loss=0.2667 (8.0s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=70.00%
#   client2 training... val=83.47%
#   client3 training... val=88.57%
#   Global: acc=89.36% loss=0.2792 (8.0s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=65.83%
#   client2 training... val=85.47%
#   client3 training... val=90.60%
#   Global: acc=91.87% loss=0.2574 (8.0s)
#   New best! 91.87%
#
# ============================================================ ROUND 65/100
#   client1 training... val=72.92%
#   client2 training... val=85.47%
#   client3 training... val=89.29%
#   Global: acc=88.65% loss=0.2924 (8.0s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=58.33%
#   client2 training... val=84.67%
#   client3 training... val=83.93%
#   Global: acc=91.22% loss=0.2680 (8.1s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=67.50%
#   client2 training... val=86.67%
#   client3 training... val=91.19%
#   Global: acc=90.94% loss=0.2711 (8.0s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=63.75%
#   client2 training... val=80.93%
#   client3 training... val=90.60%
#   Global: acc=89.74% loss=0.2940 (8.0s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=69.17%
#   client2 training... val=79.33%
#   client3 training... val=91.31%
#   Global: acc=91.05% loss=0.2634 (8.0s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=67.50%
#   client2 training... val=85.60%
#   client3 training... val=89.40%
#   Global: acc=90.83% loss=0.2577 (8.1s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=64.58%
#   client2 training... val=86.27%
#   client3 training... val=89.76%
#   Global: acc=91.76% loss=0.2312 (8.1s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=67.92%
#   client2 training... val=87.73%
#   client3 training... val=79.17%
#   Global: acc=89.03% loss=0.2885 (7.9s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=76.67%
#   client2 training... val=87.33%
#   client3 training... val=91.31%
#   Global: acc=92.09% loss=0.2356 (8.1s)
#   New best! 92.09%
#
# ============================================================ ROUND 74/100
#   client1 training... val=70.00%
#   client2 training... val=81.07%
#   client3 training... val=87.26%
#   Global: acc=87.02% loss=0.3556 (8.0s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=67.08%
#   client2 training... val=87.60%
#   client3 training... val=85.24%
#   Global: acc=91.49% loss=0.2520 (8.1s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=74.58%
#   client2 training... val=88.93%
#   client3 training... val=91.31%
#   Global: acc=92.20% loss=0.2393 (8.1s)
#   New best! 92.20%
#
# ============================================================ ROUND 77/100
#   client1 training... val=70.83%
#   client2 training... val=88.40%
#   client3 training... val=90.83%
#   Global: acc=92.64% loss=0.2289 (8.0s)
#   New best! 92.64%
#
# ============================================================ ROUND 78/100
#   client1 training... val=67.92%
#   client2 training... val=88.40%
#   client3 training... val=90.48%
#   Global: acc=92.42% loss=0.2420 (8.2s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=75.83%
#   client2 training... val=89.33%
#   client3 training... val=89.52%
#   Global: acc=92.20% loss=0.2344 (8.1s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=63.75%
#   client2 training... val=85.47%
#   client3 training... val=92.50%
#   Global: acc=90.73% loss=0.2601 (8.0s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=67.50%
#   client2 training... val=87.73%
#   client3 training... val=92.74%
#   Global: acc=91.65% loss=0.2504 (8.0s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=76.25%
#   client2 training... val=89.47%
#   client3 training... val=89.17%
#   Global: acc=90.18% loss=0.2680 (8.1s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=50.42%
#   client2 training... val=79.20%
#   client3 training... val=93.10%
#   Global: acc=92.91% loss=0.2309 (8.1s)
#   New best! 92.91%
#
# ============================================================ ROUND 84/100
#   client1 training... val=52.92%
#   client2 training... val=88.27%
#   client3 training... val=86.67%
#   Global: acc=92.53% loss=0.2345 (8.1s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=57.92%
#   client2 training... val=88.13%
#   client3 training... val=85.12%
#   Global: acc=91.38% loss=0.2633 (7.9s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=65.00%
#   client2 training... val=88.80%
#   client3 training... val=92.26%
#   Global: acc=91.98% loss=0.2262 (8.0s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=74.17%
#   client2 training... val=91.87%
#   client3 training... val=84.29%
#   Global: acc=90.51% loss=0.2731 (8.2s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=65.00%
#   client2 training... val=87.60%
#   client3 training... val=91.90%
#   Global: acc=92.74% loss=0.2208 (8.0s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=62.92%
#   client2 training... val=83.60%
#   client3 training... val=91.55%
#   Global: acc=93.02% loss=0.2155 (8.0s)
#   New best! 93.02%
#
# ============================================================ ROUND 90/100
#   client1 training... val=62.50%
#   client2 training... val=86.93%
#   client3 training... val=86.19%
#   Global: acc=91.87% loss=0.2471 (8.0s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=67.92%
#   client2 training... val=89.20%
#   client3 training... val=88.81%
#   Global: acc=92.25% loss=0.2355 (8.1s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=77.50%
#   client2 training... val=87.07%
#   client3 training... val=86.31%
#   Global: acc=92.14% loss=0.2219 (8.1s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=76.25%
#   client2 training... val=92.67%
#   client3 training... val=76.19%
#   Global: acc=90.94% loss=0.2403 (8.0s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=65.42%
#   client2 training... val=91.73%
#   client3 training... val=93.33%
#   Global: acc=92.91% loss=0.2223 (8.0s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=75.83%
#   client2 training... val=88.40%
#   client3 training... val=91.67%
#   Global: acc=92.74% loss=0.2189 (8.0s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=72.08%
#   client2 training... val=88.93%
#   client3 training... val=91.67%
#   Global: acc=92.80% loss=0.2181 (8.1s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=71.67%
#   client2 training... val=86.93%
#   client3 training... val=91.55%
#   Global: acc=91.93% loss=0.2326 (8.1s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=70.83%
#   client2 training... val=91.87%
#   client3 training... val=92.98%
#   Global: acc=92.42% loss=0.2165 (8.1s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=78.33%
#   client2 training... val=91.20%
#   client3 training... val=94.88%
#   Global: acc=92.74% loss=0.2130 (8.0s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=77.50%
#   client2 training... val=86.80%
#   client3 training... val=92.14%
#   Global: acc=91.82% loss=0.2264 (8.0s)
#
# ================================================================================
#   FEDPROX DONE best 93.02%
# ================================================================================

# %% [markdown]
# ## QPSO Training (SimpleCNN, Dynamic β: 1.0→0.5)

# %%
torch.cuda.empty_cache()
qpso_model = create_model(NUM_CLASSES, device)
qpso_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
qpso_server = QPSOServer(qpso_model, qpso_clients, device=device,
                         beta_start=BETA_START, beta_end=BETA_END, num_rounds=NUM_ROUNDS)
qpso_history = train_qpso(qpso_server, qpso_clients, data_loaders['global_test'],
    nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, se=10, verbose=False)
print("\nAll Phase 3 training complete!")
# Out:
# Model: SimpleCNN | Params: 155,524 (trainable 155,524) | Classes: 4
#   ~0.59 MB — 72x smaller than ResNet-18
# QPSO Server (Phase 3) | clients=3 β=1.0→0.5
# ================================================================================
#   QPSO-FL TRAINING START (Phase 3: Dynamic β)
# ================================================================================
#   Rounds=100 | Local epochs=1 | LR=0.01 | β: 1.0→0.5
# QPSO particles initialised
#
# ============================================================ ROUND 1/100 (β=0.995)
#   client1 training... val=25.00%
#   client2 training... val=51.60%
#   client3 training... val=25.00%
#   QPSO aggregating (β=0.995)...
#   client1: pbest 25.00%
#   client1: gbest 25.00%
#   client2: pbest 51.60%
#   client2: gbest 51.60%
#   client3: pbest 25.00%
#   Global: acc=24.11% loss=nan gbest=51.60% (8.1s)
#   New best! 24.11%
#
# ============================================================ ROUND 2/100 (β=0.990)
#   client1 training... val=25.00%
#   client2 training... val=50.80%
#   client3 training... val=62.14%
#   QPSO aggregating (β=0.990)...
#   client3: pbest 62.14%
#   client3: gbest 62.14%
#   Global: acc=48.17% loss=1.2974 gbest=62.14% (7.9s)
#   New best! 48.17%
#
# ============================================================ ROUND 3/100 (β=0.985)
#   client1 training... val=25.83%
#   client2 training... val=54.80%
#   client3 training... val=67.74%
#   QPSO aggregating (β=0.985)...
#   client1: pbest 25.83%
#   client2: pbest 54.80%
#   client3: pbest 67.74%
#   client3: gbest 67.74%
#   Global: acc=62.25% loss=0.9803 gbest=67.74% (7.9s)
#   New best! 62.25%
#
# ============================================================ ROUND 4/100 (β=0.980)
#   client1 training... val=45.83%
#   client2 training... val=53.33%
#   client3 training... val=78.45%
#   QPSO aggregating (β=0.980)...
#   client1: pbest 45.83%
#   client3: pbest 78.45%
#   client3: gbest 78.45%
#   Global: acc=54.56% loss=0.9424 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 5/100 (β=0.975)
#   client1 training... val=52.92%
#   client2 training... val=55.73%
#   client3 training... val=65.71%
#   QPSO aggregating (β=0.975)...
#   client1: pbest 52.92%
#   client2: pbest 55.73%
#   Global: acc=45.66% loss=1.5322 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 6/100 (β=0.970)
#   client1 training... val=41.25%
#   client2 training... val=63.07%
#   client3 training... val=70.24%
#   QPSO aggregating (β=0.970)...
#   client2: pbest 63.07%
#   Global: acc=74.52% loss=0.6815 gbest=78.45% (8.0s)
#   New best! 74.52%
#
# ============================================================ ROUND 7/100 (β=0.965)
#   client1 training... val=37.08%
#   client2 training... val=46.93%
#   client3 training... val=78.33%
#   QPSO aggregating (β=0.965)...
#   Global: acc=68.69% loss=0.7259 gbest=78.45% (8.0s)
#
# ============================================================ ROUND 8/100 (β=0.960)
#   client1 training... val=37.08%
#   client2 training... val=59.73%
#   client3 training... val=72.14%
#   QPSO aggregating (β=0.960)...
#   Global: acc=50.25% loss=1.2250 gbest=78.45% (8.0s)
#
# ============================================================ ROUND 9/100 (β=0.955)
#   client1 training... val=30.83%
#   client2 training... val=51.60%
#   client3 training... val=71.79%
#   QPSO aggregating (β=0.955)...
#   Global: acc=71.41% loss=0.7556 gbest=78.45% (8.0s)
#
# ============================================================ ROUND 10/100 (β=0.950)
#   client1 training... val=44.17%
#   client2 training... val=52.80%
#   client3 training... val=57.98%
#   QPSO aggregating (β=0.950)...
#   Global: acc=63.23% loss=0.7978 gbest=78.45% (8.1s)
#
# ============================================================ ROUND 11/100 (β=0.945)
#   client1 training... val=38.33%
#   client2 training... val=58.53%
#   client3 training... val=69.88%
#   QPSO aggregating (β=0.945)...
#   Global: acc=60.39% loss=0.9344 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 12/100 (β=0.940)
#   client1 training... val=46.25%
#   client2 training... val=61.87%
#   client3 training... val=76.67%
#   QPSO aggregating (β=0.940)...
#   Global: acc=63.94% loss=0.8955 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 13/100 (β=0.935)
#   client1 training... val=45.42%
#   client2 training... val=70.80%
#   client3 training... val=69.17%
#   QPSO aggregating (β=0.935)...
#   client2: pbest 70.80%
#   Global: acc=62.19% loss=0.9530 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 14/100 (β=0.930)
#   client1 training... val=27.92%
#   client2 training... val=52.93%
#   client3 training... val=72.26%
#   QPSO aggregating (β=0.930)...
#   Global: acc=75.72% loss=0.6446 gbest=78.45% (7.9s)
#   New best! 75.72%
#
# ============================================================ ROUND 15/100 (β=0.925)
#   client1 training... val=41.67%
#   client2 training... val=43.60%
#   client3 training... val=76.79%
#   QPSO aggregating (β=0.925)...
#   Global: acc=63.72% loss=0.8589 gbest=78.45% (8.0s)
#
# ============================================================ ROUND 16/100 (β=0.920)
#   client1 training... val=33.33%
#   client2 training... val=60.93%
#   client3 training... val=75.71%
#   QPSO aggregating (β=0.920)...
#   Global: acc=73.98% loss=0.6532 gbest=78.45% (8.1s)
#
# ============================================================ ROUND 17/100 (β=0.915)
#   client1 training... val=26.25%
#   client2 training... val=42.13%
#   client3 training... val=56.43%
#   QPSO aggregating (β=0.915)...
#   Global: acc=63.67% loss=0.8694 gbest=78.45% (7.9s)
#
# ============================================================ ROUND 18/100 (β=0.910)
#   client1 training... val=47.50%
#   client2 training... val=60.93%
#   client3 training... val=78.57%
#   QPSO aggregating (β=0.910)...
#   client3: pbest 78.57%
#   client3: gbest 78.57%
#   Global: acc=72.29% loss=0.6943 gbest=78.57% (7.8s)
#
# ============================================================ ROUND 19/100 (β=0.905)
#   client1 training... val=35.00%
#   client2 training... val=59.07%
#   client3 training... val=72.62%
#   QPSO aggregating (β=0.905)...
#   Global: acc=68.69% loss=0.7322 gbest=78.57% (8.0s)
#
# ============================================================ ROUND 20/100 (β=0.900)
#   client1 training... val=41.67%
#   client2 training... val=49.07%
#   client3 training... val=80.12%
#   QPSO aggregating (β=0.900)...
#   client3: pbest 80.12%
#   client3: gbest 80.12%
#   Global: acc=73.60% loss=0.6720 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 21/100 (β=0.895)
#   client1 training... val=45.83%
#   client2 training... val=42.27%
#   client3 training... val=67.74%
#   QPSO aggregating (β=0.895)...
#   Global: acc=64.81% loss=0.7959 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 22/100 (β=0.890)
#   client1 training... val=46.67%
#   client2 training... val=63.47%
#   client3 training... val=68.21%
#   QPSO aggregating (β=0.890)...
#   Global: acc=70.98% loss=0.7684 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 23/100 (β=0.885)
#   client1 training... val=32.08%
#   client2 training... val=52.40%
#   client3 training... val=72.98%
#   QPSO aggregating (β=0.885)...
#   Global: acc=66.61% loss=0.7680 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 24/100 (β=0.880)
#   client1 training... val=43.33%
#   client2 training... val=59.33%
#   client3 training... val=52.14%
#   QPSO aggregating (β=0.880)...
#   Global: acc=68.14% loss=0.7640 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 25/100 (β=0.875)
#   client1 training... val=42.08%
#   client2 training... val=51.07%
#   client3 training... val=78.45%
#   QPSO aggregating (β=0.875)...
#   Global: acc=66.50% loss=0.8267 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 26/100 (β=0.870)
#   client1 training... val=44.58%
#   client2 training... val=57.60%
#   client3 training... val=68.81%
#   QPSO aggregating (β=0.870)...
#   Global: acc=70.21% loss=0.7278 gbest=80.12% (8.5s)
#
# ============================================================ ROUND 27/100 (β=0.865)
#   client1 training... val=43.75%
#   client2 training... val=65.33%
#   client3 training... val=72.50%
#   QPSO aggregating (β=0.865)...
#   Global: acc=69.78% loss=0.7207 gbest=80.12% (8.4s)
#
# ============================================================ ROUND 28/100 (β=0.860)
#   client1 training... val=43.75%
#   client2 training... val=63.87%
#   client3 training... val=55.36%
#   QPSO aggregating (β=0.860)...
#   Global: acc=68.30% loss=0.7822 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 29/100 (β=0.855)
#   client1 training... val=39.17%
#   client2 training... val=62.00%
#   client3 training... val=28.81%
#   QPSO aggregating (β=0.855)...
#   Global: acc=64.27% loss=0.8742 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 30/100 (β=0.850)
#   client1 training... val=28.75%
#   client2 training... val=55.87%
#   client3 training... val=76.67%
#   QPSO aggregating (β=0.850)...
#   Global: acc=58.16% loss=1.0663 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 31/100 (β=0.845)
#   client1 training... val=52.50%
#   client2 training... val=58.80%
#   client3 training... val=72.14%
#   QPSO aggregating (β=0.845)...
#   Global: acc=76.05% loss=0.6516 gbest=80.12% (7.9s)
#   New best! 76.05%
#
# ============================================================ ROUND 32/100 (β=0.840)
#   client1 training... val=59.58%
#   client2 training... val=60.67%
#   client3 training... val=79.05%
#   QPSO aggregating (β=0.840)...
#   client1: pbest 59.58%
#   Global: acc=26.13% loss=2.7863 gbest=80.12% (7.8s)
#
# ============================================================ ROUND 33/100 (β=0.835)
#   client1 training... val=57.50%
#   client2 training... val=65.73%
#   client3 training... val=75.83%
#   QPSO aggregating (β=0.835)...
#   Global: acc=73.76% loss=0.7090 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 34/100 (β=0.830)
#   client1 training... val=40.42%
#   client2 training... val=64.13%
#   client3 training... val=66.79%
#   QPSO aggregating (β=0.830)...
#   Global: acc=60.56% loss=0.9167 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 35/100 (β=0.825)
#   client1 training... val=51.67%
#   client2 training... val=60.93%
#   client3 training... val=75.24%
#   QPSO aggregating (β=0.825)...
#   Global: acc=74.96% loss=0.7238 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 36/100 (β=0.820)
#   client1 training... val=35.00%
#   client2 training... val=67.07%
#   client3 training... val=65.36%
#   QPSO aggregating (β=0.820)...
#   Global: acc=56.74% loss=1.0838 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 37/100 (β=0.815)
#   client1 training... val=40.42%
#   client2 training... val=55.07%
#   client3 training... val=78.10%
#   QPSO aggregating (β=0.815)...
#   Global: acc=71.41% loss=0.7261 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 38/100 (β=0.810)
#   client1 training... val=57.50%
#   client2 training... val=61.60%
#   client3 training... val=46.07%
#   QPSO aggregating (β=0.810)...
#   Global: acc=74.58% loss=0.6563 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 39/100 (β=0.805)
#   client1 training... val=55.42%
#   client2 training... val=58.93%
#   client3 training... val=77.02%
#   QPSO aggregating (β=0.805)...
#   Global: acc=72.07% loss=0.6890 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 40/100 (β=0.800)
#   client1 training... val=50.00%
#   client2 training... val=63.07%
#   client3 training... val=50.36%
#   QPSO aggregating (β=0.800)...
#   Global: acc=71.36% loss=0.7155 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 41/100 (β=0.795)
#   client1 training... val=38.75%
#   client2 training... val=60.13%
#   client3 training... val=73.21%
#   QPSO aggregating (β=0.795)...
#   Global: acc=73.00% loss=0.6467 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 42/100 (β=0.790)
#   client1 training... val=45.83%
#   client2 training... val=58.80%
#   client3 training... val=79.40%
#   QPSO aggregating (β=0.790)...
#   Global: acc=60.77% loss=0.9231 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 43/100 (β=0.785)
#   client1 training... val=42.92%
#   client2 training... val=63.33%
#   client3 training... val=64.76%
#   QPSO aggregating (β=0.785)...
#   Global: acc=73.05% loss=0.6501 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 44/100 (β=0.780)
#   client1 training... val=52.08%
#   client2 training... val=46.27%
#   client3 training... val=65.83%
#   QPSO aggregating (β=0.780)...
#   Global: acc=65.08% loss=0.8302 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 45/100 (β=0.775)
#   client1 training... val=34.58%
#   client2 training... val=60.80%
#   client3 training... val=59.88%
#   QPSO aggregating (β=0.775)...
#   Global: acc=63.56% loss=0.8925 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 46/100 (β=0.770)
#   client1 training... val=47.08%
#   client2 training... val=61.33%
#   client3 training... val=77.14%
#   QPSO aggregating (β=0.770)...
#   Global: acc=73.05% loss=0.6690 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 47/100 (β=0.765)
#   client1 training... val=43.33%
#   client2 training... val=63.20%
#   client3 training... val=77.62%
#   QPSO aggregating (β=0.765)...
#   Global: acc=61.65% loss=0.8740 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 48/100 (β=0.760)
#   client1 training... val=47.92%
#   client2 training... val=55.07%
#   client3 training... val=73.81%
#   QPSO aggregating (β=0.760)...
#   Global: acc=73.87% loss=0.6726 gbest=80.12% (8.0s)
#
# ============================================================ ROUND 49/100 (β=0.755)
#   client1 training... val=47.08%
#   client2 training... val=58.67%
#   client3 training... val=72.74%
#   QPSO aggregating (β=0.755)...
#   Global: acc=56.57% loss=1.0373 gbest=80.12% (7.9s)
#
# ============================================================ ROUND 50/100 (β=0.750)
#   client1 training... val=55.00%
#   client2 training... val=61.47%
#   client3 training... val=80.71%
#   QPSO aggregating (β=0.750)...
#   client3: pbest 80.71%
#   client3: gbest 80.71%
#   Global: acc=73.81% loss=0.6532 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 51/100 (β=0.745)
#   client1 training... val=48.33%
#   client2 training... val=51.87%
#   client3 training... val=60.95%
#   QPSO aggregating (β=0.745)...
#   Global: acc=67.54% loss=0.7863 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 52/100 (β=0.740)
#   client1 training... val=57.92%
#   client2 training... val=56.00%
#   client3 training... val=71.43%
#   QPSO aggregating (β=0.740)...
#   Global: acc=70.27% loss=0.7220 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 53/100 (β=0.735)
#   client1 training... val=55.00%
#   client2 training... val=52.67%
#   client3 training... val=66.07%
#   QPSO aggregating (β=0.735)...
#   Global: acc=67.92% loss=0.7047 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 54/100 (β=0.730)
#   client1 training... val=47.50%
#   client2 training... val=42.67%
#   client3 training... val=75.36%
#   QPSO aggregating (β=0.730)...
#   Global: acc=74.52% loss=0.6686 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 55/100 (β=0.725)
#   client1 training... val=51.67%
#   client2 training... val=63.60%
#   client3 training... val=69.05%
#   QPSO aggregating (β=0.725)...
#   Global: acc=70.27% loss=0.7139 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 56/100 (β=0.720)
#   client1 training... val=60.00%
#   client2 training... val=54.93%
#   client3 training... val=64.40%
#   QPSO aggregating (β=0.720)...
#   client1: pbest 60.00%
#   Global: acc=62.68% loss=0.8515 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 57/100 (β=0.715)
#   client1 training... val=66.25%
#   client2 training... val=66.13%
#   client3 training... val=73.33%
#   QPSO aggregating (β=0.715)...
#   client1: pbest 66.25%
#   Global: acc=67.65% loss=0.7283 gbest=80.71% (7.8s)
#
# ============================================================ ROUND 58/100 (β=0.710)
#   client1 training... val=55.83%
#   client2 training... val=50.80%
#   client3 training... val=76.43%
#   QPSO aggregating (β=0.710)...
#   Global: acc=72.29% loss=0.6959 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 59/100 (β=0.705)
#   client1 training... val=62.92%
#   client2 training... val=52.13%
#   client3 training... val=75.60%
#   QPSO aggregating (β=0.705)...
#   Global: acc=74.80% loss=0.6773 gbest=80.71% (8.1s)
#
# ============================================================ ROUND 60/100 (β=0.700)
#   client1 training... val=37.50%
#   client2 training... val=50.13%
#   client3 training... val=68.69%
#   QPSO aggregating (β=0.700)...
#   Global: acc=74.20% loss=0.6140 gbest=80.71% (8.2s)
#
# ============================================================ ROUND 61/100 (β=0.695)
#   client1 training... val=36.67%
#   client2 training... val=48.00%
#   client3 training... val=78.93%
#   QPSO aggregating (β=0.695)...
#   Global: acc=74.36% loss=0.6190 gbest=80.71% (7.8s)
#
# ============================================================ ROUND 62/100 (β=0.690)
#   client1 training... val=51.25%
#   client2 training... val=55.87%
#   client3 training... val=75.48%
#   QPSO aggregating (β=0.690)...
#   Global: acc=68.19% loss=0.7531 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 63/100 (β=0.685)
#   client1 training... val=60.00%
#   client2 training... val=67.07%
#   client3 training... val=72.14%
#   QPSO aggregating (β=0.685)...
#   Global: acc=70.10% loss=0.6582 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 64/100 (β=0.680)
#   client1 training... val=50.42%
#   client2 training... val=64.13%
#   client3 training... val=76.90%
#   QPSO aggregating (β=0.680)...
#   Global: acc=72.45% loss=0.6573 gbest=80.71% (8.3s)
#
# ============================================================ ROUND 65/100 (β=0.675)
#   client1 training... val=64.17%
#   client2 training... val=63.07%
#   client3 training... val=72.50%
#   QPSO aggregating (β=0.675)...
#   Global: acc=70.81% loss=0.7254 gbest=80.71% (8.1s)
#
# ============================================================ ROUND 66/100 (β=0.670)
#   client1 training... val=51.67%
#   client2 training... val=62.40%
#   client3 training... val=48.93%
#   QPSO aggregating (β=0.670)...
#   Global: acc=63.83% loss=0.8908 gbest=80.71% (8.3s)
#
# ============================================================ ROUND 67/100 (β=0.665)
#   client1 training... val=44.58%
#   client2 training... val=68.27%
#   client3 training... val=77.86%
#   QPSO aggregating (β=0.665)...
#   Global: acc=67.43% loss=0.7870 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 68/100 (β=0.660)
#   client1 training... val=52.92%
#   client2 training... val=64.67%
#   client3 training... val=75.95%
#   QPSO aggregating (β=0.660)...
#   Global: acc=72.83% loss=0.6676 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 69/100 (β=0.655)
#   client1 training... val=50.00%
#   client2 training... val=49.47%
#   client3 training... val=78.21%
#   QPSO aggregating (β=0.655)...
#   Global: acc=73.16% loss=0.6602 gbest=80.71% (8.1s)
#
# ============================================================ ROUND 70/100 (β=0.650)
#   client1 training... val=35.00%
#   client2 training... val=65.20%
#   client3 training... val=72.86%
#   QPSO aggregating (β=0.650)...
#   Global: acc=72.29% loss=0.6214 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 71/100 (β=0.645)
#   client1 training... val=57.08%
#   client2 training... val=52.67%
#   client3 training... val=69.76%
#   QPSO aggregating (β=0.645)...
#   Global: acc=74.25% loss=0.6555 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 72/100 (β=0.640)
#   client1 training... val=42.50%
#   client2 training... val=66.67%
#   client3 training... val=55.83%
#   QPSO aggregating (β=0.640)...
#   Global: acc=73.60% loss=0.6350 gbest=80.71% (8.1s)
#
# ============================================================ ROUND 73/100 (β=0.635)
#   client1 training... val=56.67%
#   client2 training... val=58.80%
#   client3 training... val=57.86%
#   QPSO aggregating (β=0.635)...
#   Global: acc=69.01% loss=0.7365 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 74/100 (β=0.630)
#   client1 training... val=59.58%
#   client2 training... val=56.13%
#   client3 training... val=68.57%
#   QPSO aggregating (β=0.630)...
#   Global: acc=61.54% loss=0.9343 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 75/100 (β=0.625)
#   client1 training... val=47.50%
#   client2 training... val=64.27%
#   client3 training... val=78.93%
#   QPSO aggregating (β=0.625)...
#   Global: acc=72.50% loss=0.6563 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 76/100 (β=0.620)
#   client1 training... val=61.67%
#   client2 training... val=53.87%
#   client3 training... val=64.64%
#   QPSO aggregating (β=0.620)...
#   Global: acc=71.41% loss=0.6560 gbest=80.71% (8.0s)
#
# ============================================================ ROUND 77/100 (β=0.615)
#   client1 training... val=39.17%
#   client2 training... val=59.47%
#   client3 training... val=80.24%
#   QPSO aggregating (β=0.615)...
#   Global: acc=73.00% loss=0.6810 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 78/100 (β=0.610)
#   client1 training... val=50.42%
#   client2 training... val=61.60%
#   client3 training... val=66.67%
#   QPSO aggregating (β=0.610)...
#   Global: acc=71.96% loss=0.6864 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 79/100 (β=0.605)
#   client1 training... val=63.33%
#   client2 training... val=65.20%
#   client3 training... val=77.86%
#   QPSO aggregating (β=0.605)...
#   Global: acc=77.30% loss=0.6046 gbest=80.71% (7.8s)
#   New best! 77.30%
#
# ============================================================ ROUND 80/100 (β=0.600)
#   client1 training... val=48.33%
#   client2 training... val=60.00%
#   client3 training... val=77.50%
#   QPSO aggregating (β=0.600)...
#   Global: acc=70.49% loss=0.7233 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 81/100 (β=0.595)
#   client1 training... val=50.83%
#   client2 training... val=52.80%
#   client3 training... val=76.31%
#   QPSO aggregating (β=0.595)...
#   Global: acc=76.98% loss=0.5842 gbest=80.71% (7.9s)
#
# ============================================================ ROUND 82/100 (β=0.590)
#   client1 training... val=37.92%
#   client2 training... val=56.13%
#   client3 training... val=81.07%
#   QPSO aggregating (β=0.590)...
#   client3: pbest 81.07%
#   client3: gbest 81.07%
#   Global: acc=61.10% loss=0.8687 gbest=81.07% (7.9s)
#
# ============================================================ ROUND 83/100 (β=0.585)
#   client1 training... val=66.67%
#   client2 training... val=50.27%
#   client3 training... val=67.86%
#   QPSO aggregating (β=0.585)...
#   client1: pbest 66.67%
#   Global: acc=74.80% loss=0.6733 gbest=81.07% (7.9s)
#
# ============================================================ ROUND 84/100 (β=0.580)
#   client1 training... val=60.42%
#   client2 training... val=43.20%
#   client3 training... val=55.60%
#   QPSO aggregating (β=0.580)...
#   Global: acc=70.70% loss=0.6737 gbest=81.07% (7.9s)
#
# ============================================================ ROUND 85/100 (β=0.575)
#   client1 training... val=47.08%
#   client2 training... val=66.27%
#   client3 training... val=73.21%
#   QPSO aggregating (β=0.575)...
#   Global: acc=46.59% loss=1.2423 gbest=81.07% (7.9s)
#
# ============================================================ ROUND 86/100 (β=0.570)
#   client1 training... val=56.25%
#   client2 training... val=60.40%
#   client3 training... val=71.79%
#   QPSO aggregating (β=0.570)...
#   Global: acc=54.23% loss=1.0957 gbest=81.07% (7.8s)
#
# ============================================================ ROUND 87/100 (β=0.565)
#   client1 training... val=46.25%
#   client2 training... val=31.60%
#   client3 training... val=65.00%
#   QPSO aggregating (β=0.565)...
#   Global: acc=69.01% loss=0.6955 gbest=81.07% (7.7s)
#
# ============================================================ ROUND 88/100 (β=0.560)
#   client1 training... val=42.08%
#   client2 training... val=58.67%
#   client3 training... val=74.40%
#   QPSO aggregating (β=0.560)...
#   Global: acc=55.54% loss=1.0485 gbest=81.07% (7.8s)
#
# ============================================================ ROUND 89/100 (β=0.555)
#   client1 training... val=49.17%
#   client2 training... val=64.40%
#   client3 training... val=73.69%
#   QPSO aggregating (β=0.555)...
#   Global: acc=73.00% loss=0.6911 gbest=81.07% (7.7s)
#
# ============================================================ ROUND 90/100 (β=0.550)
#   client1 training... val=49.17%
#   client2 training... val=55.33%
#   client3 training... val=59.40%
#   QPSO aggregating (β=0.550)...
#   Global: acc=73.43% loss=0.6447 gbest=81.07% (7.9s)
#
# ============================================================ ROUND 91/100 (β=0.545)
#   client1 training... val=47.08%
#   client2 training... val=60.67%
#   client3 training... val=76.79%
#   QPSO aggregating (β=0.545)...
#   Global: acc=73.92% loss=0.6671 gbest=81.07% (8.0s)
#
# ============================================================ ROUND 92/100 (β=0.540)
#   client1 training... val=57.08%
#   client2 training... val=56.93%
#   client3 training... val=80.95%
#   QPSO aggregating (β=0.540)...
#   Global: acc=65.41% loss=0.8239 gbest=81.07% (8.0s)
#
# ============================================================ ROUND 93/100 (β=0.535)
#   client1 training... val=45.83%
#   client2 training... val=52.40%
#   client3 training... val=77.02%
#   QPSO aggregating (β=0.535)...
#   Global: acc=70.98% loss=0.7299 gbest=81.07% (8.1s)
#
# ============================================================ ROUND 94/100 (β=0.530)
#   client1 training... val=49.58%
#   client2 training... val=59.20%
#   client3 training... val=74.17%
#   QPSO aggregating (β=0.530)...
#   Global: acc=74.85% loss=0.6410 gbest=81.07% (8.0s)
#
# ============================================================ ROUND 95/100 (β=0.525)
#   client1 training... val=45.00%
#   client2 training... val=60.80%
#   client3 training... val=79.64%
#   QPSO aggregating (β=0.525)...
#   Global: acc=68.85% loss=0.7720 gbest=81.07% (8.1s)
#
# ============================================================ ROUND 96/100 (β=0.520)
#   client1 training... val=45.42%
#   client2 training... val=64.80%
#   client3 training... val=40.95%
#   QPSO aggregating (β=0.520)...
#   Global: acc=76.32% loss=0.6142 gbest=81.07% (8.1s)
#
# ============================================================ ROUND 97/100 (β=0.515)
#   client1 training... val=61.25%
#   client2 training... val=65.20%
#   client3 training... val=75.48%
#   QPSO aggregating (β=0.515)...
#   Global: acc=67.21% loss=0.7499 gbest=81.07% (8.1s)
#
# ============================================================ ROUND 98/100 (β=0.510)
#   client1 training... val=58.33%
#   client2 training... val=63.73%
#   client3 training... val=64.76%
#   QPSO aggregating (β=0.510)...
#   Global: acc=62.08% loss=0.8498 gbest=81.07% (8.0s)
#
# ============================================================ ROUND 99/100 (β=0.505)
#   client1 training... val=59.17%
#   client2 training... val=60.27%
#   client3 training... val=65.36%
#   QPSO aggregating (β=0.505)...
#   Global: acc=74.58% loss=0.6596 gbest=81.07% (8.0s)
#
# ============================================================ ROUND 100/100 (β=0.500)
#   client1 training... val=47.50%
#   client2 training... val=70.40%
#   client3 training... val=58.69%
#   QPSO aggregating (β=0.500)...
#   Global: acc=72.67% loss=0.6621 gbest=81.07% (8.2s)
#
# ================================================================================
#   QPSO-FL DONE best 77.30% gbest 81.07%
# ================================================================================
#
# All Phase 3 training complete!

# %% [markdown]
# ## Evaluation & Plots

# %%
def plot_accuracy_comparison(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(2, max(n,2), figsize=(8*max(n,2), 12))
    fig.suptitle("Phase 3: FL Aggregation Comparison (SimpleCNN)", fontsize=16, fontweight="bold")
    colors = ['#1f77b4','#ff7f0e','#2ca02c']
    ax = axes[0,0]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_acc"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Acc (%)", title="Global Test Accuracy", ylim=[0,100]); ax.legend(); ax.grid(alpha=0.3)
    ax = axes[0,1]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_loss"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Loss", title="Global Test Loss"); ax.legend(); ax.grid(alpha=0.3)
    for idx, (df, name) in enumerate(zip(dfs, names)):
        ax = axes[1, idx]
        for i in range(1,4): ax.plot(df["round"], df[f"client{i}_val_acc"], label=f"Client {i}", lw=2)
        ax.set(xlabel="Round", ylabel="Val Acc (%)", title=f"{name}: Per-Client"); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Saved -> {save_path}")

def generate_confusion_matrix(mp, tl, mname, device="cuda", save_path=None):
    model = SimpleCNN(NUM_CLASSES).to(device)
    model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
    model.eval(); preds, labels = [], []
    with torch.no_grad():
        for imgs, labs in tl:
            _, pred = model(imgs.to(device)).max(1)
            preds.extend(pred.cpu().numpy()); labels.extend(labs.numpy())
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix - {mname} (SimpleCNN)", fontsize=14, fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted"); plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"\n{mname}:"); print(classification_report(labels, preds, target_names=CLASS_NAMES, digits=4))

def plot_roc_auc(mps, mnames, tl, device="cuda", save_path=None):
    n = len(mps)
    fig, axes = plt.subplots(1, n, figsize=(7*n, 6))
    if n == 1: axes = [axes]
    cc = ['#e74c3c', '#3498db', '#2ecc71', '#9b59b6']
    for ax, mp, mn in zip(axes, mps, mnames):
        model = SimpleCNN(NUM_CLASSES).to(device)
        model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
        model.eval(); probs, labs = [], []
        with torch.no_grad():
            for imgs, lb in tl:
                out = model(imgs.to(device)); probs.append(torch.softmax(out, dim=1).cpu().numpy()); labs.extend(lb.numpy())
        yp = np.vstack(probs); yt = np.array(labs)
        if np.isnan(yp).any():
            print(f"  WARNING: {mn} has NaN outputs, replacing with uniform")
            yp = np.nan_to_num(yp, nan=1.0/NUM_CLASSES)
        yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
        for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
            try:
                fpr, tpr, _ = roc_curve(yb[:, i], yp[:, i]); a = auc(fpr, tpr)
                ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.4f})")
            except: ax.plot([0,1],[0,1], color=c, lw=2, label=f"{cls} (N/A)")
        try:
            fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
            ax.plot(fpr_m, tpr_m, 'k--', lw=2, label=f"Micro ({auc(fpr_m,tpr_m):.4f})")
        except: pass
        ax.plot([0,1],[0,1],'gray',ls=':',lw=1)
        ax.set(xlabel="FPR", ylabel="TPR", title=f"ROC - {mn}"); ax.legend(loc="lower right", fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show(); print(f"ROC-AUC saved -> {save_path}")

def plot_client_fairness(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(1, n, figsize=(6*n, 5)); cc = ["#FF6B6B","#4ECDC4","#45B7D1"]
    if n == 1: axes = [axes]
    for ax, df, t in zip(axes, dfs, names):
        accs = [df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)]
        ax.bar(["C1","C2","C3"], accs, color=cc, edgecolor="black")
        ax.axhline(np.mean(accs), color="red", ls="--", lw=2, label="Mean")
        ax.set(ylabel="Final Val Acc (%)", ylim=[0,100])
        ax.set_title(f"{t} (std={np.std(accs):.2f}%)", fontsize=13, fontweight="bold"); ax.legend(); ax.grid(axis="y", alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()

def plot_beta_decay(df_qpso, save_path):
    # Phase 3 extra plot: visualize how beta decays and its effect on accuracy
    if 'current_beta' not in df_qpso.columns: print("No beta column found"); return
    fig, ax1 = plt.subplots(figsize=(10, 5))
    ax1.plot(df_qpso["round"], df_qpso["global_test_acc"], 'b-', lw=2, label="QPSO Accuracy")
    ax1.set(xlabel="Round", ylabel="Accuracy (%)")
    ax1.tick_params(axis='y', labelcolor='b')
    ax2 = ax1.twinx()
    ax2.plot(df_qpso["round"], df_qpso["current_beta"], 'r--', lw=2, label="β (decay)")
    ax2.set(ylabel="β value")
    ax2.tick_params(axis='y', labelcolor='r')
    fig.suptitle("QPSO: Dynamic β Decay vs Accuracy", fontsize=14, fontweight="bold")
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    lines_2, labels_2 = ax2.get_legend_handles_labels()
    ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc="center right"); ax1.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Beta decay plot saved -> {save_path}")

def convergence_metrics(df, target=80.0):
    r = df[df["global_test_acc"]>=target]
    return {"final_acc": round(df["global_test_acc"].iloc[-1],2), "best_acc": round(df["global_test_acc"].max(),2),
            "round_to_target": int(r["round"].min()) if len(r) else None,
            "avg_round_time_s": round(df["round_time"].mean(),2), "total_time_min": round(df["round_time"].sum()/60,2)}

def statistical_analysis(dfa, dfb):
    a, b = dfa["global_test_acc"].values, dfb["global_test_acc"].values
    n = min(len(a),len(b)); a, b = a[:n], b[:n]
    t_stat, p_val = stats.ttest_rel(b, a); d = (b-a).mean()/((b-a).std(ddof=1)+1e-8)
    return {"t_stat": round(float(t_stat),4), "p_value": float(p_val), "cohens_d": round(float(d),4), "significant": bool(p_val<0.05)}

def build_comparison_df(*pairs):
    cols = ["Metric"] + [n for _, n in pairs]
    ml = []
    for df, n in pairs:
        m = convergence_metrics(df)
        m["client_std"] = round(float(np.std([df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)])),2)
        ml.append(m)
    keys = [("Final Acc (%)","final_acc"),("Best Acc (%)","best_acc"),("Rounds to 80%","round_to_target"),
            ("Avg Round (s)","avg_round_time_s"),("Total Time (min)","total_time_min"),("Client Std Dev","client_std")]
    rows = [[l]+[m[k] if m[k] is not None else "N/A" for m in ml] for l, k in keys]
    return pd.DataFrame(rows, columns=cols)
print("Phase 3 evaluation functions loaded")
# Out:
# Phase 3 evaluation functions loaded

# %%
df_fa = pd.read_csv('/kaggle/working/results/fedavg/metrics.csv')
df_fp = pd.read_csv('/kaggle/working/results/fedprox/metrics.csv')
df_qp = pd.read_csv('/kaggle/working/results/qpso/metrics.csv')
comp = build_comparison_df((df_fa,"FedAvg"),(df_fp,"FedProx"),(df_qp,"QPSO-FL"))
print(comp.to_string(index=False))
comp.to_csv('/kaggle/working/results/final_comparison.csv', index=False)
# Out:
#           Metric  FedAvg  FedProx QPSO-FL
#    Final Acc (%)   88.16    91.82   72.67
#     Best Acc (%)   90.56    93.02    77.3
#    Rounds to 80%   35.00    17.00     N/A
#    Avg Round (s)    7.90     8.02    7.97
# Total Time (min)   13.16    13.36   13.28
#   Client Std Dev   12.82     6.05    9.35

# %%
plot_accuracy_comparison([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/comparison.png')
for m, n in [('fedavg','FedAvg'),('fedprox','FedProx'),('qpso','QPSO-FL')]:
    generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth', data_loaders['global_test'], n, device=device, save_path=f'/kaggle/working/results/plots/cm_{m}.png')
plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/fairness.png')
plot_roc_auc(['/kaggle/working/models/fedavg_best.pth','/kaggle/working/models/fedprox_best.pth','/kaggle/working/models/qpso_best.pth'],
    ['FedAvg','FedProx','QPSO-FL'], data_loaders['global_test'], device=device, save_path='/kaggle/working/results/plots/roc_auc.png')
plot_beta_decay(df_qp, '/kaggle/working/results/plots/beta_decay.png')
# Out:
# Saved -> /kaggle/working/results/plots/comparison.png
#
# FedAvg:
#               precision    recall  f1-score   support
#
#       Glioma     0.9367    0.8371    0.8841       442
#   Meningioma     0.8134    0.8809    0.8458       470
#     No Tumor     0.9404    0.9491    0.9447       432
#    Pituitary     0.9452    0.9530    0.9491       489
#
#     accuracy                         0.9056      1833
#    macro avg     0.9089    0.9050    0.9059      1833
# weighted avg     0.9082    0.9056    0.9059      1833
#
#
# FedProx:
#               precision    recall  f1-score   support
#
#       Glioma     0.9501    0.8620    0.9039       442
#   Meningioma     0.8555    0.9319    0.8921       470
#     No Tumor     0.9436    0.9676    0.9554       432
#    Pituitary     0.9811    0.9571    0.9689       489
#
#     accuracy                         0.9302      1833
#    macro avg     0.9326    0.9296    0.9301      1833
# weighted avg     0.9326    0.9302    0.9304      1833
#
#
# QPSO-FL:
#               precision    recall  f1-score   support
#
#       Glioma     0.6694    0.7421    0.7039       442
#   Meningioma     0.7301    0.5064    0.5980       470
#     No Tumor     0.8117    0.9282    0.8661       432
#    Pituitary     0.8604    0.9202    0.8893       489
#
#     accuracy                         0.7730      1833
#    macro avg     0.7679    0.7742    0.7643      1833
# weighted avg     0.7695    0.7730    0.7644      1833
#
# ROC-AUC saved -> /kaggle/working/results/plots/roc_auc.png
# Beta decay plot saved -> /kaggle/working/results/plots/beta_decay.png

# %% [markdown]
# ## Statistical Analysis & Summary

# %%
s1 = statistical_analysis(df_fa, df_qp)
s2 = statistical_analysis(df_fa, df_fp)
print("FedAvg vs QPSO:", json.dumps(s1, indent=2))
print("FedAvg vs FedProx:", json.dumps(s2, indent=2))
summary = {"fedavg": convergence_metrics(df_fa), "fedprox": convergence_metrics(df_fp),
           "qpso": convergence_metrics(df_qp), "stats_fa_qp": s1, "stats_fa_fp": s2,
           "phase3_config": {"model": "SimpleCNN (~120K params)", "img_size": IMG_SIZE,
                            "local_epochs": LOCAL_EPOCHS, "lr": LR, "batch_size": BATCH_SIZE,
                            "beta_start": BETA_START, "beta_end": BETA_END, "beta_schedule": "linear_decay",
                            "fedprox_mu": FEDPROX_MU, "perturbation_clamp": "[-0.5, 0.5]",
                            "u_clamp": "[0.1, 1.0]"}}
with open('/kaggle/working/results/executive_summary.json','w') as f: json.dump(summary, f, indent=2)
print("Phase 3 summary saved")
print("\nLaTeX Table:")
print(comp.to_latex(index=False, float_format="%.2f", caption="Phase 3: FedAvg vs FedProx vs QPSO-FL (SimpleCNN)", label="tab:phase3_comparison"))
print("\nPhase 3 notebook complete!")
# Out:
# FedAvg vs QPSO: {
#   "t_stat": -8.3464,
#   "p_value": 4.3213745718204546e-13,
#   "cohens_d": -0.8346,
#   "significant": true
# }
# FedAvg vs FedProx: {
#   "t_stat": 13.3946,
#   "p_value": 5.857362777648649e-24,
#   "cohens_d": 1.3395,
#   "significant": true
# }
# Phase 3 summary saved
#
# LaTeX Table:
# \begin{table}
# \caption{Phase 3: FedAvg vs FedProx vs QPSO-FL (SimpleCNN)}
# \label{tab:phase3_comparison}
# \begin{tabular}{lrrl}
# \toprule
# Metric & FedAvg & FedProx & QPSO-FL \\
# \midrule
# Final Acc (%) & 88.16 & 91.82 & 72.67 \\
# Best Acc (%) & 90.56 & 93.02 & 77.30 \\
# Rounds to 80% & 35.00 & 17.00 & N/A \\
# Avg Round (s) & 7.90 & 8.02 & 7.97 \\
# Total Time (min) & 13.16 & 13.36 & 13.28 \\
# Client Std Dev & 12.82 & 6.05 & 9.35 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# Phase 3 notebook complete!
