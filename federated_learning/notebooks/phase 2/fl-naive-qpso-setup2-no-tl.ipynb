# %% [markdown]
# # Setup 2: Moderate Label Skew (70/10/10/10)
# **Settings:** GPU P100 · Persistence: Files only · Internet: ON
# **Add Inputs:** Brain Tumor MRI Dataset (masoudnickparvar) + BRISC 2025 (briscdataset)
# All-in-one: Data prep → Training (FedAvg + FedProx + QPSO) → Evaluation

# %%
import os, sys, copy, time, random, json, shutil
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
import torchvision.models as models, torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import stats
try:
    from tqdm.notebook import tqdm
except ImportError:
    from tqdm import tqdm

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42); device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu"); print("CPU only")
torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False

NUM_CLASSES = 4
CLASS_NAMES = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
VALID_CLASSES = {"glioma": 0, "meningioma": 1, "notumor": 2, "no_tumor": 2, "pituitary": 3}

for d in ['data/processed/client1','data/processed/client2','data/processed/client3',
          'data/test_set','models','results/fedavg','results/fedprox','results/qpso','results/plots','logs']:
    os.makedirs(f'/kaggle/working/{d}', exist_ok=True)
print("Directories created")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Directories created

# %% [markdown]
# ## Preprocessor

# %%
class Preprocessor:
    def __init__(self, size=(224,224)): self.size = size
    def load_image(self, path):
        try:
            img = Image.open(path)
            if img.mode != "RGB": img = img.convert("RGB")
            return np.array(img.resize(self.size, Image.LANCZOS), dtype=np.float32) / 255.0
        except: return None

    def process_dataset(self, dataset_path, client_name, save_dir="/kaggle/working/data/processed",
                        train_r=0.70, val_r=0.15):
        print(f"\n{'='*60}\nProcessing {client_name} <- {dataset_path}\n{'='*60}")
        images, labels = [], []
        for cls_name in sorted(os.listdir(dataset_path)):
            cls_path = os.path.join(dataset_path, cls_name)
            if not os.path.isdir(cls_path): continue
            key = cls_name.lower().replace(" ","")
            if key not in VALID_CLASSES: print(f"  Skipping: {cls_name}"); continue
            label = VALID_CLASSES[key]
            files = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))]
            print(f"  {cls_name}: {len(files)} images (label={label})")
            for fname in tqdm(files, desc=f"    {cls_name}", leave=False):
                arr = self.load_image(os.path.join(cls_path, fname))
                if arr is not None: images.append(arr); labels.append(label)
        X, y = np.array(images), np.array(labels)
        print(f"  Total: {len(X)} | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
        test_r = 1.0 - train_r - val_r
        X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=test_r, stratify=y, random_state=42)
        val_adj = val_r / (train_r + val_r)
        X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=val_adj, stratify=y_tmp, random_state=42)
        print(f"  Train:{len(X_train)} Val:{len(X_val)} Test:{len(X_test)}")
        out = os.path.join(save_dir, client_name); os.makedirs(out, exist_ok=True)
        for name, arr in [("X_train",X_train),("y_train",y_train),("X_val",X_val),("y_val",y_val),("X_test",X_test),("y_test",y_test)]:
            np.save(os.path.join(out, f"{name}.npy"), arr)
        print(f"  Saved -> {out}")

    @staticmethod
    def create_global_test(pdir="/kaggle/working/data/processed", sdir="/kaggle/working/data/test_set"):
        Xs, ys = [], []
        for i in range(1, 4):
            d = os.path.join(pdir, f"client{i}")
            Xs.append(np.load(os.path.join(d, "X_test.npy")))
            ys.append(np.load(os.path.join(d, "y_test.npy")))
        X, y = np.concatenate(Xs), np.concatenate(ys)
        os.makedirs(sdir, exist_ok=True)
        np.save(os.path.join(sdir, "X_test.npy"), X)
        np.save(os.path.join(sdir, "y_test.npy"), y)
        print(f"Global test: {len(X)} images | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
print("Preprocessor ready")
# Out:
# Preprocessor ready

# %% [markdown]
# ## Model & FL Components

# %%
class BrainTumorDataset(Dataset):
    _DEFAULT = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
    def __init__(self, X, y, transform=None):
        self.X, self.y = X, y; self.transform = transform or self._DEFAULT
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        img = Image.fromarray((self.X[idx]*255).astype(np.uint8))
        return self.transform(img), torch.tensor(self.y[idx], dtype=torch.long)

TRAIN_TF = transforms.Compose([transforms.RandomHorizontalFlip(0.5),
    transforms.RandomRotation(15), transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
TEST_TF = transforms.Compose([transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

def create_data_loaders(pdir="/kaggle/working/data/processed", tdir="/kaggle/working/data/test_set", bs=32, nw=2):
    loaders = {}
    for i in range(1, 4):
        d = f"{pdir}/client{i}"
        ds_tr = BrainTumorDataset(np.load(f"{d}/X_train.npy"), np.load(f"{d}/y_train.npy"), TRAIN_TF)
        ds_va = BrainTumorDataset(np.load(f"{d}/X_val.npy"), np.load(f"{d}/y_val.npy"), TEST_TF)
        ds_te = BrainTumorDataset(np.load(f"{d}/X_test.npy"), np.load(f"{d}/y_test.npy"), TEST_TF)
        loaders[f"client{i}"] = {"train": DataLoader(ds_tr, bs, shuffle=True, num_workers=nw, pin_memory=True),
            "val": DataLoader(ds_va, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "test": DataLoader(ds_te, bs, shuffle=False, num_workers=nw, pin_memory=True), "train_size": len(ds_tr)}
        print(f"client{i}: Train={len(ds_tr)} Val={len(ds_va)} Test={len(ds_te)}")
    gds = BrainTumorDataset(np.load(f"{tdir}/X_test.npy"), np.load(f"{tdir}/y_test.npy"), TEST_TF)
    loaders["global_test"] = DataLoader(gds, bs, shuffle=False, num_workers=nw, pin_memory=True)
    print(f"Global test: {len(gds)}"); return loaders

class BrainTumorResNet(nn.Module):
    def __init__(self, n=4):
        super().__init__()
        self.model = models.resnet18(weights=None)  # NO pretrained weights — from scratch
        self.model.fc = nn.Linear(self.model.fc.in_features, n)
    def forward(self, x): return self.model(x)

def create_model(n=4, device="cuda"):
    m = BrainTumorResNet(n).to(device)
    print(f"Model: ResNet-18 (from scratch) | Params: {sum(p.numel() for p in m.parameters()):,} | Classes: {n}"); return m

class FederatedClient:
    def __init__(self, cid, train_loader, val_loader, device="cuda"):
        self.client_id = cid; self.train_loader = train_loader
        self.val_loader = val_loader; self.device = device
        self.model = None; self.optimizer = None
        self.criterion = nn.CrossEntropyLoss(); self.dataset_size = len(train_loader.dataset)
    def set_model(self, gm): self.model = copy.deepcopy(gm).to(self.device)
    def set_optimizer(self, lr=0.001): self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
    def train_local(self, epochs=5, verbose=False):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs); loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea
    def validate(self):
        self.model.eval(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.model(imgs); ls += self.criterion(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return ls/len(self.val_loader), 100.*c/t
    def get_dataset_size(self): return self.dataset_size

class FedProxClient(FederatedClient):
    def train_local(self, epochs=5, verbose=False, mu=0.01, global_params=None):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs)
                if global_params is not None:
                    prox = sum(torch.norm(pl - pg.detach())**2 for pl, pg in zip(self.model.parameters(), global_params))
                    loss = loss + (mu / 2.0) * prox
                loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea

class FedAvgServer:
    def __init__(self, gm, clients, device="cuda"):
        self.global_model = gm; self.clients = clients; self.device = device
        self.total_samples = sum(c.get_dataset_size() for c in clients)
        print(f"FedAvg Server | clients={len(clients)} total={self.total_samples}")
    def aggregate_weights(self, cw):
        first = cw[0][0]; agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for sd, nk in cw: acc = acc + sd[k].float() * (nk / self.total_samples)
                agg[k] = acc.to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)

class QPSOServer:
    def __init__(self, gm, clients, device="cuda", beta=0.7):
        self.global_model = gm; self.clients = clients; self.device = device; self.beta = beta
        self.personal_best = {}; self.personal_best_scores = {}
        self.global_best = None; self.global_best_score = 0.0; self.mean_best = None
        print(f"QPSO Server | clients={len(clients)} beta={beta}")
    def initialize_particles(self):
        s = copy.deepcopy(self.global_model.state_dict())
        for c in self.clients: self.personal_best[c.client_id] = copy.deepcopy(s); self.personal_best_scores[c.client_id] = 0.0
        self.global_best = copy.deepcopy(s); self.global_best_score = 0.0; print("QPSO particles initialised")
    def update_personal_best(self, cid, w, acc):
        if acc > self.personal_best_scores[cid]: self.personal_best[cid] = copy.deepcopy(w); self.personal_best_scores[cid] = acc; return True
        return False
    def update_global_best(self, cid, acc):
        if acc > self.global_best_score: self.global_best = copy.deepcopy(self.personal_best[cid]); self.global_best_score = acc; return True
        return False
    def calculate_mean_best(self):
        fid = self.clients[0].client_id
        self.mean_best = {k: torch.zeros_like(v, dtype=torch.float32) for k, v in self.personal_best[fid].items()}
        for c in self.clients:
            for k in self.mean_best: self.mean_best[k] += self.personal_best[c.client_id][k].float()
        for k in self.mean_best: self.mean_best[k] /= len(self.clients)
    def qpso_aggregate(self, cwl):
        for cid, w, acc in cwl:
            pb = self.update_personal_best(cid, w, acc); gb = self.update_global_best(cid, acc)
            if pb: print(f"  {cid}: pbest {acc:.2f}%")
            if gb: print(f"  {cid}: gbest {acc:.2f}%")
        self.calculate_mean_best(); agg = copy.deepcopy(self.global_best)
        for k in agg:
            if not agg[k].is_floating_point(): continue
            ps = torch.zeros_like(agg[k], dtype=torch.float32)
            for c in self.clients: ps += self.personal_best[c.client_id][k].float()
            phi = torch.rand_like(agg[k].float())
            u = torch.rand_like(agg[k].float()).clamp(min=0.3, max=1.0)
            p = phi*(ps/len(self.clients)) + (1-phi)*self.global_best[k].float()
            sign = torch.where(torch.rand_like(agg[k].float())<0.5, torch.ones_like(agg[k].float()), -torch.ones_like(agg[k].float()))
            pert = self.beta * torch.abs(self.mean_best[k].float() - agg[k].float()) * torch.log(1.0/u)
            pert = pert.clamp(-0.1, 0.1)
            agg[k] = (p + sign * pert).to(self.global_best[k].dtype)
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)
print("All classes loaded")
# Out:
# All classes loaded

# %% [markdown]
# ## Data Preparation

# %%
# Setup 2: Moderate Label Skew (70/10/10/10)
# Each client keeps its OWN data but we subsample to create class imbalance
# Then augment back to original size

CLIENT1_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
CLIENT2_PATH = '/kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train'
CLIENT3_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

# First, process normally to get all images
prep = Preprocessor()
prep.process_dataset(CLIENT1_PATH, 'client1')
prep.process_dataset(CLIENT2_PATH, 'client2')
prep.process_dataset(CLIENT3_PATH, 'client3')

# Now apply label skew: Client1->Glioma dominant, Client2->Meningioma, Client3->NoTumor
DOMINANT = {1: 0, 2: 1, 3: 2}  # client_id -> dominant class label
DOMINANT_RATIO = 0.70
MINORITY_RATIO = 0.10

def augment_image(img):
    from PIL import ImageEnhance, ImageFilter
    pil = Image.fromarray((img*255).astype(np.uint8))
    if random.random() < 0.5: pil = pil.transpose(Image.FLIP_LEFT_RIGHT)
    if random.random() < 0.5: pil = pil.rotate(random.uniform(-30, 30), fillcolor=(0,0,0))
    if random.random() < 0.3: pil = ImageEnhance.Brightness(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.3: pil = ImageEnhance.Contrast(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.2: pil = pil.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1.5)))
    return np.array(pil, dtype=np.float32) / 255.0

for cid in range(1, 4):
    d = f"/kaggle/working/data/processed/client{cid}"
    X_train = np.load(f"{d}/X_train.npy"); y_train = np.load(f"{d}/y_train.npy")
    dom_cls = DOMINANT[cid]
    total = len(X_train)
    target_dom = int(total * DOMINANT_RATIO)
    target_min = int(total * MINORITY_RATIO)

    new_X, new_y = [], []
    for cls in range(NUM_CLASSES):
        mask = y_train == cls
        X_cls = X_train[mask]
        target = target_dom if cls == dom_cls else target_min
        if len(X_cls) >= target:
            idx = np.random.choice(len(X_cls), target, replace=False)
            new_X.append(X_cls[idx]); new_y.extend([cls]*target)
        else:
            new_X.append(X_cls); new_y.extend([cls]*len(X_cls))
            need = target - len(X_cls)
            for _ in range(need):
                src = X_cls[random.randint(0, len(X_cls)-1)]
                new_X.append(augment_image(src)[np.newaxis]); new_y.append(cls)

    X_new = np.concatenate(new_X); y_new = np.array(new_y)
    perm = np.random.permutation(len(X_new)); X_new = X_new[perm]; y_new = y_new[perm]
    np.save(f"{d}/X_train.npy", X_new); np.save(f"{d}/y_train.npy", y_new)
    print(f"client{cid}: dominant=class{dom_cls} | dist={np.bincount(y_new, minlength=NUM_CLASSES)} | total={len(X_new)}")

Preprocessor.create_global_test()
data_loaders = create_data_loaders()
print("\nSetup 2 data ready!")
# Out:
# ============================================================
# Processing client1 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
# ============================================================
#   glioma: 400 images (label=0)
#     glioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   meningioma: 400 images (label=1)
#     meningioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   notumor: 400 images (label=2)
#     notumor:   0%|          | 0/400 [00:00<?, ?it/s]
#   pituitary: 400 images (label=3)
#     pituitary:   0%|          | 0/400 [00:00<?, ?it/s]
#   Total: 1600 | Classes: [400 400 400 400]
#   Train:1119 Val:240 Test:241
#   Saved -> /kaggle/working/data/processed/client1
#
# ============================================================
# Processing client2 <- /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
# ============================================================
#   glioma: 1147 images (label=0)
#     glioma:   0%|          | 0/1147 [00:00<?, ?it/s]
#   meningioma: 1329 images (label=1)
#     meningioma:   0%|          | 0/1329 [00:00<?, ?it/s]
#   no_tumor: 1067 images (label=2)
#     no_tumor:   0%|          | 0/1067 [00:00<?, ?it/s]
#   pituitary: 1457 images (label=3)
#     pituitary:   0%|          | 0/1457 [00:00<?, ?it/s]
#   Total: 5000 | Classes: [1147 1329 1067 1457]
#   Train:3499 Val:750 Test:751
#   Saved -> /kaggle/working/data/processed/client2
#
# ============================================================
# Processing client3 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# ============================================================
#   glioma: 1400 images (label=0)
#     glioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   meningioma: 1400 images (label=1)
#     meningioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   notumor: 1400 images (label=2)
#     notumor:   0%|          | 0/1400 [00:00<?, ?it/s]
#   pituitary: 1400 images (label=3)
#     pituitary:   0%|          | 0/1400 [00:00<?, ?it/s]
#   Total: 5600 | Classes: [1400 1400 1400 1400]
#   Train:3919 Val:840 Test:841
#   Saved -> /kaggle/working/data/processed/client3
# client1: dominant=class0 | dist=[783 111 111 111] | total=1116
# client2: dominant=class1 | dist=[ 349 2449  349  349] | total=3496
# client3: dominant=class2 | dist=[ 391  391 2743  391] | total=3916
# Global test: 1833 images | Classes: [442 470 432 489]
# client1: Train=1116 Val=240 Test=241
# client2: Train=3496 Val=750 Test=751
# client3: Train=3916 Val=840 Test=841
# Global test: 1833
#
# Setup 2 data ready!

# %% [markdown]
# ## Training Functions

# %%
def train_fedavg(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDAVG TRAINING START\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedavg/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDAVG DONE best {best:.2f}%\n{'='*80}"); return h

def train_fedprox(server, clients, gtl, nr=100, le=5, lr=0.001, mu=0.01, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDPROX TRAINING START (mu="+str(mu)+")\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        gp = list(server.global_model.parameters())
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose, mu=mu, global_params=gp)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedprox/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDPROX DONE best {best:.2f}%\n{'='*80}"); return h

def train_qpso(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  QPSO-FL TRAINING START\n"+"="*80); server.initialize_particles()
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"global_best_score":[],
         "client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],
         "client1_pbest":[],"client2_pbest":[],"client3_pbest":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((cl.client_id, w, va))
        print("  QPSO aggregating..."); agg = server.qpso_aggregate(cw)
        server.global_model.load_state_dict(agg)
        for c in clients: h[f"{c.client_id}_pbest"].append(server.personal_best_scores[c.client_id])
        h["global_best_score"].append(server.global_best_score)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} gbest={server.global_best_score:.2f}% ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/qpso/metrics.csv", index=False)
    print(f"\n{'='*80}\n  QPSO-FL DONE best {best:.2f}% gbest {server.global_best_score:.2f}%\n{'='*80}"); return h
print("Trainers loaded")
# Out:
# Trainers loaded

# %% [markdown]
# ## FedAvg Training
# ⚠️ Set `nr=5` for a quick test first!

# %%
fedavg_model = create_model(NUM_CLASSES, device)
fedavg_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                  data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedavg_server = FedAvgServer(fedavg_model, fedavg_clients, device=device)
fedavg_history = train_fedavg(fedavg_server, fedavg_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
# Out:
# Model: ResNet-18 (from scratch) | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8528
# ================================================================================
#   FEDAVG TRAINING START
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=60.42%
#   client2 training... val=28.53%
#   client3 training... val=76.55%
#   Global: acc=23.57% loss=2.5890 (98.5s)
#   New best! 23.57%
#
# ============================================================ ROUND 2/100
#   client1 training... val=60.42%
#   client2 training... val=85.73%
#   client3 training... val=83.10%
#   Global: acc=25.37% loss=1.7706 (98.4s)
#   New best! 25.37%
#
# ============================================================ ROUND 3/100
#   client1 training... val=64.58%
#   client2 training... val=87.87%
#   client3 training... val=71.67%
#   Global: acc=79.32% loss=0.5890 (96.3s)
#   New best! 79.32%
#
# ============================================================ ROUND 4/100
#   client1 training... val=76.67%
#   client2 training... val=87.87%
#   client3 training... val=89.17%
#   Global: acc=92.42% loss=0.2419 (98.7s)
#   New best! 92.42%
#
# ============================================================ ROUND 5/100
#   client1 training... val=78.75%
#   client2 training... val=94.80%
#   client3 training... val=94.40%
#   Global: acc=92.85% loss=0.2340 (97.5s)
#   New best! 92.85%
#
# ============================================================ ROUND 6/100
#   client1 training... val=83.75%
#   client2 training... val=91.87%
#   client3 training... val=93.33%
#   Global: acc=95.36% loss=0.1697 (96.8s)
#   New best! 95.36%
#
# ============================================================ ROUND 7/100
#   client1 training... val=90.00%
#   client2 training... val=90.67%
#   client3 training... val=95.12%
#   Global: acc=94.33% loss=0.2243 (96.7s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=83.33%
#   client2 training... val=92.67%
#   client3 training... val=95.48%
#   Global: acc=96.78% loss=0.1415 (98.1s)
#   New best! 96.78%
#
# ============================================================ ROUND 9/100
#   client1 training... val=93.75%
#   client2 training... val=95.73%
#   client3 training... val=94.76%
#   Global: acc=97.05% loss=0.1514 (97.8s)
#   New best! 97.05%
#
# ============================================================ ROUND 10/100
#   client1 training... val=94.58%
#   client2 training... val=97.07%
#   client3 training... val=90.00%
#   Global: acc=97.11% loss=0.1701 (96.5s)
#   New best! 97.11%
#
# ============================================================ ROUND 11/100
#   client1 training... val=91.25%
#   client2 training... val=97.33%
#   client3 training... val=95.95%
#   Global: acc=97.33% loss=0.1710 (97.4s)
#   New best! 97.33%
#
# ============================================================ ROUND 12/100
#   client1 training... val=94.58%
#   client2 training... val=96.53%
#   client3 training... val=96.79%
#   Global: acc=97.65% loss=0.1405 (97.2s)
#   New best! 97.65%
#
# ============================================================ ROUND 13/100
#   client1 training... val=94.17%
#   client2 training... val=97.20%
#   client3 training... val=95.12%
#   Global: acc=96.84% loss=0.1668 (96.1s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=95.00%
#   client2 training... val=91.87%
#   client3 training... val=96.19%
#   Global: acc=96.78% loss=0.1838 (97.2s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=92.08%
#   client2 training... val=93.73%
#   client3 training... val=96.43%
#   Global: acc=96.89% loss=0.1696 (97.4s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=96.25%
#   client2 training... val=97.20%
#   client3 training... val=96.79%
#   Global: acc=96.78% loss=0.1709 (96.0s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=95.42%
#   client2 training... val=96.27%
#   client3 training... val=97.62%
#   Global: acc=97.82% loss=0.1391 (96.6s)
#   New best! 97.82%
#
# ============================================================ ROUND 18/100
#   client1 training... val=92.92%
#   client2 training... val=96.80%
#   client3 training... val=96.67%
#   Global: acc=96.94% loss=0.1759 (97.5s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=94.58%
#   client2 training... val=85.33%
#   client3 training... val=97.02%
#   Global: acc=96.89% loss=0.1846 (97.0s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=95.00%
#   client2 training... val=93.73%
#   client3 training... val=97.50%
#   Global: acc=97.82% loss=0.1569 (96.6s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=92.50%
#   client2 training... val=98.67%
#   client3 training... val=96.79%
#   Global: acc=97.71% loss=0.1554 (97.7s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=95.42%
#   client2 training... val=97.20%
#   client3 training... val=96.55%
#   Global: acc=97.05% loss=0.1835 (95.2s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=95.83%
#   client2 training... val=98.13%
#   client3 training... val=97.50%
#   Global: acc=97.65% loss=0.1637 (97.4s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=92.92%
#   client2 training... val=98.80%
#   client3 training... val=97.86%
#   Global: acc=97.44% loss=0.1881 (96.3s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=95.00%
#   client2 training... val=98.00%
#   client3 training... val=94.64%
#   Global: acc=97.55% loss=0.2102 (97.7s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=93.33%
#   client2 training... val=97.33%
#   client3 training... val=97.02%
#   Global: acc=97.98% loss=0.1752 (97.2s)
#   New best! 97.98%
#
# ============================================================ ROUND 27/100
#   client1 training... val=96.67%
#   client2 training... val=96.00%
#   client3 training... val=97.38%
#   Global: acc=97.93% loss=0.1777 (96.5s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=96.25%
#   client2 training... val=98.13%
#   client3 training... val=98.21%
#   Global: acc=97.49% loss=0.1979 (96.8s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=95.42%
#   client2 training... val=97.73%
#   client3 training... val=97.98%
#   Global: acc=98.04% loss=0.1721 (97.2s)
#   New best! 98.04%
#
# ============================================================ ROUND 30/100
#   client1 training... val=95.42%
#   client2 training... val=98.40%
#   client3 training... val=96.90%
#   Global: acc=97.87% loss=0.1837 (98.8s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=96.25%
#   client2 training... val=98.13%
#   client3 training... val=94.05%
#   Global: acc=97.76% loss=0.1817 (98.3s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=94.58%
#   client2 training... val=94.27%
#   client3 training... val=98.81%
#   Global: acc=97.87% loss=0.1815 (98.4s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=94.58%
#   client2 training... val=98.27%
#   client3 training... val=97.98%
#   Global: acc=97.55% loss=0.1964 (97.5s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=96.25%
#   client2 training... val=98.13%
#   client3 training... val=95.83%
#   Global: acc=97.44% loss=0.1842 (98.3s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=95.83%
#   client2 training... val=98.53%
#   client3 training... val=98.21%
#   Global: acc=98.04% loss=0.1746 (97.9s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=92.92%
#   client2 training... val=98.13%
#   client3 training... val=94.17%
#   Global: acc=97.82% loss=0.2077 (96.8s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=95.42%
#   client2 training... val=98.67%
#   client3 training... val=98.57%
#   Global: acc=98.09% loss=0.1855 (98.0s)
#   New best! 98.09%
#
# ============================================================ ROUND 38/100
#   client1 training... val=94.17%
#   client2 training... val=98.53%
#   client3 training... val=97.98%
#   Global: acc=97.82% loss=0.1851 (98.6s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=95.83%
#   client2 training... val=97.87%
#   client3 training... val=98.45%
#   Global: acc=98.09% loss=0.1856 (99.0s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=94.58%
#   client2 training... val=98.80%
#   client3 training... val=98.10%
#   Global: acc=97.76% loss=0.1934 (96.7s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=93.33%
#   client2 training... val=98.27%
#   client3 training... val=98.21%
#   Global: acc=97.98% loss=0.2035 (98.3s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=93.75%
#   client2 training... val=98.40%
#   client3 training... val=98.21%
#   Global: acc=97.98% loss=0.2086 (97.5s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=92.08%
#   client2 training... val=98.27%
#   client3 training... val=98.33%
#   Global: acc=98.25% loss=0.1713 (97.1s)
#   New best! 98.25%
#
# ============================================================ ROUND 44/100
#   client1 training... val=95.00%
#   client2 training... val=97.07%
#   client3 training... val=96.55%
#   Global: acc=97.82% loss=0.1893 (98.8s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=95.00%
#   client2 training... val=95.07%
#   client3 training... val=97.26%
#   Global: acc=97.87% loss=0.1904 (97.4s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=95.42%
#   client2 training... val=97.33%
#   client3 training... val=97.50%
#   Global: acc=97.49% loss=0.2010 (99.1s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=95.00%
#   client2 training... val=97.87%
#   client3 training... val=97.98%
#   Global: acc=97.93% loss=0.2031 (98.6s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=95.42%
#   client2 training... val=98.13%
#   client3 training... val=98.33%
#   Global: acc=97.49% loss=0.2321 (98.5s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=95.83%
#   client2 training... val=98.13%
#   client3 training... val=97.62%
#   Global: acc=97.87% loss=0.2096 (99.5s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=95.00%
#   client2 training... val=97.07%
#   client3 training... val=98.45%
#   Global: acc=97.65% loss=0.2309 (98.5s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=94.58%
#   client2 training... val=96.80%
#   client3 training... val=98.57%
#   Global: acc=97.87% loss=0.1994 (100.5s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=95.83%
#   client2 training... val=98.40%
#   client3 training... val=98.45%
#   Global: acc=97.76% loss=0.1694 (98.6s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=94.17%
#   client2 training... val=97.73%
#   client3 training... val=98.33%
#   Global: acc=97.87% loss=0.2092 (98.7s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=95.00%
#   client2 training... val=97.07%
#   client3 training... val=97.86%
#   Global: acc=97.65% loss=0.2568 (98.6s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=96.25%
#   client2 training... val=97.73%
#   client3 training... val=96.90%
#   Global: acc=98.04% loss=0.2144 (99.8s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=95.00%
#   client2 training... val=98.40%
#   client3 training... val=98.33%
#   Global: acc=97.65% loss=0.2138 (98.0s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=95.83%
#   client2 training... val=98.13%
#   client3 training... val=97.86%
#   Global: acc=98.15% loss=0.2276 (97.4s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=95.00%
#   client2 training... val=98.00%
#   client3 training... val=97.38%
#   Global: acc=97.49% loss=0.1877 (98.8s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=94.17%
#   client2 training... val=98.27%
#   client3 training... val=97.02%
#   Global: acc=97.65% loss=0.1988 (97.9s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=94.58%
#   client2 training... val=94.27%
#   client3 training... val=98.33%
#   Global: acc=97.60% loss=0.2152 (98.1s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=95.00%
#   client2 training... val=98.53%
#   client3 training... val=98.10%
#   Global: acc=97.76% loss=0.1934 (98.0s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=94.58%
#   client2 training... val=98.00%
#   client3 training... val=97.98%
#   Global: acc=97.38% loss=0.2278 (97.4s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=93.75%
#   client2 training... val=97.60%
#   client3 training... val=98.33%
#   Global: acc=97.49% loss=0.1901 (98.4s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=95.00%
#   client2 training... val=96.67%
#   client3 training... val=98.69%
#   Global: acc=97.60% loss=0.2217 (98.4s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=94.58%
#   client2 training... val=98.13%
#   client3 training... val=98.33%
#   Global: acc=97.49% loss=0.2310 (99.1s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=92.08%
#   client2 training... val=96.67%
#   client3 training... val=97.50%
#   Global: acc=97.44% loss=0.2446 (99.4s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=95.00%
#   client2 training... val=98.53%
#   client3 training... val=98.33%
#   Global: acc=97.98% loss=0.2269 (98.6s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=96.67%
#   client2 training... val=98.27%
#   client3 training... val=97.86%
#   Global: acc=97.76% loss=0.2410 (97.7s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=95.00%
#   client2 training... val=98.00%
#   client3 training... val=98.69%
#   Global: acc=97.60% loss=0.2204 (97.5s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=95.83%
#   client2 training... val=96.67%
#   client3 training... val=98.21%
#   Global: acc=97.49% loss=0.2433 (97.4s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=92.92%
#   client2 training... val=98.40%
#   client3 training... val=98.33%
#   Global: acc=97.55% loss=0.2344 (98.8s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=92.50%
#   client2 training... val=98.00%
#   client3 training... val=98.57%
#   Global: acc=98.09% loss=0.2233 (97.5s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=94.58%
#   client2 training... val=97.33%
#   client3 training... val=98.21%
#   Global: acc=97.22% loss=0.2805 (97.9s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=94.17%
#   client2 training... val=98.40%
#   client3 training... val=95.00%
#   Global: acc=97.38% loss=0.2739 (95.1s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=95.00%
#   client2 training... val=97.73%
#   client3 training... val=98.69%
#   Global: acc=97.82% loss=0.2520 (97.6s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=93.33%
#   client2 training... val=97.20%
#   client3 training... val=97.02%
#   Global: acc=97.22% loss=0.2763 (97.1s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=92.92%
#   client2 training... val=97.20%
#   client3 training... val=98.33%
#   Global: acc=97.55% loss=0.2419 (97.4s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=94.17%
#   client2 training... val=97.73%
#   client3 training... val=97.74%
#   Global: acc=97.38% loss=0.2865 (97.8s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=92.92%
#   client2 training... val=98.93%
#   client3 training... val=96.43%
#   Global: acc=97.16% loss=0.2986 (97.1s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=94.58%
#   client2 training... val=98.40%
#   client3 training... val=98.33%
#   Global: acc=97.44% loss=0.2260 (96.5s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=93.75%
#   client2 training... val=98.80%
#   client3 training... val=98.57%
#   Global: acc=97.65% loss=0.2386 (98.8s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=95.00%
#   client2 training... val=98.53%
#   client3 training... val=97.74%
#   Global: acc=97.65% loss=0.2190 (97.7s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=95.83%
#   client2 training... val=96.93%
#   client3 training... val=99.05%
#   Global: acc=97.71% loss=0.2584 (97.9s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=95.00%
#   client2 training... val=98.00%
#   client3 training... val=98.33%
#   Global: acc=97.44% loss=0.2605 (97.2s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=94.58%
#   client2 training... val=98.53%
#   client3 training... val=97.14%
#   Global: acc=97.49% loss=0.2371 (98.1s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=94.17%
#   client2 training... val=97.87%
#   client3 training... val=98.33%
#   Global: acc=97.87% loss=0.2742 (96.8s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=94.17%
#   client2 training... val=98.27%
#   client3 training... val=98.81%
#   Global: acc=97.82% loss=0.2402 (97.7s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=92.50%
#   client2 training... val=98.80%
#   client3 training... val=97.86%
#   Global: acc=97.98% loss=0.2137 (97.0s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=96.25%
#   client2 training... val=97.60%
#   client3 training... val=97.74%
#   Global: acc=97.98% loss=0.2441 (100.2s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=94.17%
#   client2 training... val=97.73%
#   client3 training... val=98.57%
#   Global: acc=97.49% loss=0.2383 (97.2s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=94.17%
#   client2 training... val=98.40%
#   client3 training... val=98.45%
#   Global: acc=97.87% loss=0.2469 (96.4s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=92.92%
#   client2 training... val=98.80%
#   client3 training... val=97.62%
#   Global: acc=97.49% loss=0.2397 (97.1s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=94.17%
#   client2 training... val=97.73%
#   client3 training... val=97.14%
#   Global: acc=97.00% loss=0.3079 (97.4s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=90.83%
#   client2 training... val=96.93%
#   client3 training... val=94.17%
#   Global: acc=97.55% loss=0.2828 (97.1s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=95.00%
#   client2 training... val=98.27%
#   client3 training... val=98.45%
#   Global: acc=97.87% loss=0.2739 (98.6s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=94.17%
#   client2 training... val=98.53%
#   client3 training... val=98.10%
#   Global: acc=97.71% loss=0.2548 (96.9s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=95.42%
#   client2 training... val=98.40%
#   client3 training... val=98.33%
#   Global: acc=97.60% loss=0.2430 (97.8s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=93.75%
#   client2 training... val=97.60%
#   client3 training... val=98.45%
#   Global: acc=97.76% loss=0.2637 (96.2s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=94.58%
#   client2 training... val=98.27%
#   client3 training... val=98.33%
#   Global: acc=97.38% loss=0.2728 (98.3s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=95.42%
#   client2 training... val=98.53%
#   client3 training... val=98.45%
#   Global: acc=97.27% loss=0.3094 (96.8s)
#
# ================================================================================
#   FEDAVG DONE best 98.25%
# ================================================================================

# %% [markdown]
# ## FedProx Training

# %%
torch.cuda.empty_cache()
fedprox_model = create_model(NUM_CLASSES, device)
fedprox_clients = [FedProxClient(f'client{i}', data_loaders[f'client{i}']['train'],
                   data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedprox_server = FedAvgServer(fedprox_model, fedprox_clients, device=device)
fedprox_history = train_fedprox(fedprox_server, fedprox_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, mu=0.01, se=10, verbose=False)
# Out:
# Model: ResNet-18 (from scratch) | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8528
# ================================================================================
#   FEDPROX TRAINING START (mu=0.01)
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=25.42%
#   client2 training... val=22.27%
#   client3 training... val=53.57%
#   Global: acc=23.57% loss=1.5534 (107.6s)
#   New best! 23.57%
#
# ============================================================ ROUND 2/100
#   client1 training... val=35.00%
#   client2 training... val=42.93%
#   client3 training... val=47.14%
#   Global: acc=64.38% loss=1.0719 (106.5s)
#   New best! 64.38%
#
# ============================================================ ROUND 3/100
#   client1 training... val=58.75%
#   client2 training... val=46.80%
#   client3 training... val=55.83%
#   Global: acc=60.61% loss=0.8866 (107.5s)
#
# ============================================================ ROUND 4/100
#   client1 training... val=30.83%
#   client2 training... val=68.13%
#   client3 training... val=32.02%
#   Global: acc=68.85% loss=0.7600 (107.7s)
#   New best! 68.85%
#
# ============================================================ ROUND 5/100
#   client1 training... val=55.00%
#   client2 training... val=66.53%
#   client3 training... val=68.69%
#   Global: acc=78.72% loss=0.5809 (108.7s)
#   New best! 78.72%
#
# ============================================================ ROUND 6/100
#   client1 training... val=78.33%
#   client2 training... val=81.87%
#   client3 training... val=80.71%
#   Global: acc=87.02% loss=0.4153 (108.2s)
#   New best! 87.02%
#
# ============================================================ ROUND 7/100
#   client1 training... val=71.25%
#   client2 training... val=48.93%
#   client3 training... val=83.57%
#   Global: acc=86.25% loss=0.4559 (106.0s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=67.50%
#   client2 training... val=80.13%
#   client3 training... val=87.14%
#   Global: acc=89.69% loss=0.3335 (105.9s)
#   New best! 89.69%
#
# ============================================================ ROUND 9/100
#   client1 training... val=64.17%
#   client2 training... val=70.13%
#   client3 training... val=40.36%
#   Global: acc=82.05% loss=0.5184 (106.6s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=75.42%
#   client2 training... val=72.80%
#   client3 training... val=81.31%
#   Global: acc=82.87% loss=0.4621 (106.2s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=81.67%
#   client2 training... val=84.67%
#   client3 training... val=83.21%
#   Global: acc=91.49% loss=0.2723 (107.2s)
#   New best! 91.49%
#
# ============================================================ ROUND 12/100
#   client1 training... val=75.00%
#   client2 training... val=71.33%
#   client3 training... val=84.52%
#   Global: acc=91.60% loss=0.2955 (107.3s)
#   New best! 91.60%
#
# ============================================================ ROUND 13/100
#   client1 training... val=83.75%
#   client2 training... val=79.87%
#   client3 training... val=89.05%
#   Global: acc=88.76% loss=0.3649 (106.8s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=79.17%
#   client2 training... val=88.93%
#   client3 training... val=65.36%
#   Global: acc=92.25% loss=0.2611 (105.6s)
#   New best! 92.25%
#
# ============================================================ ROUND 15/100
#   client1 training... val=85.42%
#   client2 training... val=89.87%
#   client3 training... val=88.57%
#   Global: acc=93.45% loss=0.2284 (106.4s)
#   New best! 93.45%
#
# ============================================================ ROUND 16/100
#   client1 training... val=82.50%
#   client2 training... val=91.87%
#   client3 training... val=90.71%
#   Global: acc=93.02% loss=0.2309 (107.0s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=80.00%
#   client2 training... val=90.27%
#   client3 training... val=88.69%
#   Global: acc=92.31% loss=0.2738 (107.0s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=56.67%
#   client2 training... val=90.67%
#   client3 training... val=91.07%
#   Global: acc=94.82% loss=0.2036 (107.0s)
#   New best! 94.82%
#
# ============================================================ ROUND 19/100
#   client1 training... val=76.67%
#   client2 training... val=89.20%
#   client3 training... val=89.88%
#   Global: acc=92.36% loss=0.2367 (106.4s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=67.50%
#   client2 training... val=88.13%
#   client3 training... val=76.07%
#   Global: acc=87.56% loss=0.4164 (106.4s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=84.17%
#   client2 training... val=89.47%
#   client3 training... val=91.67%
#   Global: acc=93.89% loss=0.2323 (106.6s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=67.50%
#   client2 training... val=80.27%
#   client3 training... val=87.14%
#   Global: acc=94.27% loss=0.2111 (107.2s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=76.25%
#   client2 training... val=91.07%
#   client3 training... val=82.26%
#   Global: acc=94.76% loss=0.2074 (106.3s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=90.00%
#   client2 training... val=89.73%
#   client3 training... val=81.90%
#   Global: acc=92.80% loss=0.2634 (106.3s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=85.83%
#   client2 training... val=88.80%
#   client3 training... val=93.33%
#   Global: acc=95.25% loss=0.1812 (106.7s)
#   New best! 95.25%
#
# ============================================================ ROUND 26/100
#   client1 training... val=86.67%
#   client2 training... val=92.27%
#   client3 training... val=94.52%
#   Global: acc=95.85% loss=0.1728 (106.3s)
#   New best! 95.85%
#
# ============================================================ ROUND 27/100
#   client1 training... val=92.92%
#   client2 training... val=88.27%
#   client3 training... val=93.69%
#   Global: acc=94.93% loss=0.2003 (104.9s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=82.92%
#   client2 training... val=96.00%
#   client3 training... val=81.67%
#   Global: acc=94.60% loss=0.2200 (105.5s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=86.25%
#   client2 training... val=77.07%
#   client3 training... val=86.90%
#   Global: acc=93.84% loss=0.2221 (106.4s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=85.42%
#   client2 training... val=88.53%
#   client3 training... val=91.67%
#   Global: acc=95.64% loss=0.1741 (106.0s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=88.33%
#   client2 training... val=93.20%
#   client3 training... val=96.31%
#   Global: acc=96.18% loss=0.1571 (106.7s)
#   New best! 96.18%
#
# ============================================================ ROUND 32/100
#   client1 training... val=65.42%
#   client2 training... val=94.80%
#   client3 training... val=86.79%
#   Global: acc=94.71% loss=0.1883 (106.7s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=88.33%
#   client2 training... val=91.07%
#   client3 training... val=96.07%
#   Global: acc=95.64% loss=0.1906 (108.0s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=87.08%
#   client2 training... val=90.67%
#   client3 training... val=94.05%
#   Global: acc=94.16% loss=0.2269 (107.0s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=86.25%
#   client2 training... val=90.13%
#   client3 training... val=96.19%
#   Global: acc=96.24% loss=0.1575 (107.6s)
#   New best! 96.24%
#
# ============================================================ ROUND 36/100
#   client1 training... val=81.67%
#   client2 training... val=88.93%
#   client3 training... val=93.57%
#   Global: acc=96.51% loss=0.1519 (106.8s)
#   New best! 96.51%
#
# ============================================================ ROUND 37/100
#   client1 training... val=80.83%
#   client2 training... val=96.27%
#   client3 training... val=95.60%
#   Global: acc=96.56% loss=0.1543 (107.0s)
#   New best! 96.56%
#
# ============================================================ ROUND 38/100
#   client1 training... val=87.92%
#   client2 training... val=93.73%
#   client3 training... val=95.60%
#   Global: acc=96.78% loss=0.1617 (106.9s)
#   New best! 96.78%
#
# ============================================================ ROUND 39/100
#   client1 training... val=83.33%
#   client2 training... val=94.40%
#   client3 training... val=96.19%
#   Global: acc=96.73% loss=0.1615 (107.6s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=91.25%
#   client2 training... val=90.13%
#   client3 training... val=96.90%
#   Global: acc=96.62% loss=0.1745 (107.6s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=85.42%
#   client2 training... val=87.07%
#   client3 training... val=94.52%
#   Global: acc=97.22% loss=0.1478 (106.0s)
#   New best! 97.22%
#
# ============================================================ ROUND 42/100
#   client1 training... val=89.17%
#   client2 training... val=96.40%
#   client3 training... val=95.48%
#   Global: acc=97.16% loss=0.1590 (106.0s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=92.50%
#   client2 training... val=96.00%
#   client3 training... val=88.21%
#   Global: acc=94.54% loss=0.2022 (106.6s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=92.08%
#   client2 training... val=87.47%
#   client3 training... val=96.67%
#   Global: acc=96.78% loss=0.1729 (106.3s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=60.42%
#   client2 training... val=92.27%
#   client3 training... val=93.33%
#   Global: acc=97.22% loss=0.1318 (106.0s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=95.83%
#   client2 training... val=96.00%
#   client3 training... val=89.17%
#   Global: acc=95.91% loss=0.1791 (106.8s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=83.75%
#   client2 training... val=96.80%
#   client3 training... val=93.33%
#   Global: acc=97.33% loss=0.1570 (106.1s)
#   New best! 97.33%
#
# ============================================================ ROUND 48/100
#   client1 training... val=91.25%
#   client2 training... val=93.47%
#   client3 training... val=95.71%
#   Global: acc=96.56% loss=0.1897 (105.8s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=88.33%
#   client2 training... val=95.07%
#   client3 training... val=95.24%
#   Global: acc=97.76% loss=0.1353 (108.6s)
#   New best! 97.76%
#
# ============================================================ ROUND 50/100
#   client1 training... val=93.75%
#   client2 training... val=92.53%
#   client3 training... val=97.02%
#   Global: acc=96.84% loss=0.1760 (109.0s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=72.92%
#   client2 training... val=95.73%
#   client3 training... val=90.24%
#   Global: acc=96.73% loss=0.1676 (107.7s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=85.83%
#   client2 training... val=95.60%
#   client3 training... val=96.07%
#   Global: acc=97.60% loss=0.1484 (108.5s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=94.58%
#   client2 training... val=96.40%
#   client3 training... val=90.24%
#   Global: acc=96.78% loss=0.1712 (107.7s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=87.08%
#   client2 training... val=96.00%
#   client3 training... val=95.12%
#   Global: acc=97.49% loss=0.1444 (107.2s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=77.92%
#   client2 training... val=97.20%
#   client3 training... val=92.50%
#   Global: acc=97.00% loss=0.1592 (108.0s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=93.75%
#   client2 training... val=95.60%
#   client3 training... val=96.43%
#   Global: acc=96.94% loss=0.1607 (108.0s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=88.75%
#   client2 training... val=93.60%
#   client3 training... val=87.62%
#   Global: acc=96.34% loss=0.1799 (109.1s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=92.50%
#   client2 training... val=96.27%
#   client3 training... val=94.76%
#   Global: acc=96.84% loss=0.1550 (108.9s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=91.25%
#   client2 training... val=96.80%
#   client3 training... val=97.38%
#   Global: acc=97.98% loss=0.1399 (107.6s)
#   New best! 97.98%
#
# ============================================================ ROUND 60/100
#   client1 training... val=92.92%
#   client2 training... val=95.60%
#   client3 training... val=95.95%
#   Global: acc=97.76% loss=0.1416 (108.1s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=89.17%
#   client2 training... val=96.53%
#   client3 training... val=97.62%
#   Global: acc=97.05% loss=0.1360 (108.0s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=90.83%
#   client2 training... val=87.07%
#   client3 training... val=97.86%
#   Global: acc=97.27% loss=0.1620 (106.3s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=92.92%
#   client2 training... val=90.13%
#   client3 training... val=97.50%
#   Global: acc=97.55% loss=0.1657 (106.2s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=91.67%
#   client2 training... val=94.27%
#   client3 training... val=87.86%
#   Global: acc=94.82% loss=0.2196 (106.4s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=86.25%
#   client2 training... val=96.67%
#   client3 training... val=88.93%
#   Global: acc=97.44% loss=0.1417 (105.3s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=87.08%
#   client2 training... val=95.73%
#   client3 training... val=95.24%
#   Global: acc=97.27% loss=0.1640 (106.4s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=92.92%
#   client2 training... val=94.67%
#   client3 training... val=94.88%
#   Global: acc=98.15% loss=0.1443 (106.2s)
#   New best! 98.15%
#
# ============================================================ ROUND 68/100
#   client1 training... val=92.92%
#   client2 training... val=96.27%
#   client3 training... val=94.29%
#   Global: acc=97.22% loss=0.1623 (106.4s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=92.50%
#   client2 training... val=92.13%
#   client3 training... val=98.69%
#   Global: acc=97.82% loss=0.1370 (106.7s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=91.67%
#   client2 training... val=96.00%
#   client3 training... val=97.86%
#   Global: acc=97.76% loss=0.1557 (108.6s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=95.00%
#   client2 training... val=96.80%
#   client3 training... val=95.24%
#   Global: acc=97.33% loss=0.1649 (108.4s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=94.58%
#   client2 training... val=97.07%
#   client3 training... val=96.19%
#   Global: acc=97.60% loss=0.1567 (108.0s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=91.67%
#   client2 training... val=94.80%
#   client3 training... val=97.98%
#   Global: acc=97.93% loss=0.1617 (107.5s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=93.33%
#   client2 training... val=96.80%
#   client3 training... val=83.81%
#   Global: acc=96.62% loss=0.1640 (109.1s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=91.25%
#   client2 training... val=98.13%
#   client3 training... val=86.55%
#   Global: acc=96.78% loss=0.2079 (107.9s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=92.92%
#   client2 training... val=96.40%
#   client3 training... val=97.14%
#   Global: acc=97.44% loss=0.1595 (107.3s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=89.58%
#   client2 training... val=97.20%
#   client3 training... val=95.83%
#   Global: acc=96.51% loss=0.1846 (107.4s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=92.50%
#   client2 training... val=96.13%
#   client3 training... val=98.57%
#   Global: acc=97.87% loss=0.1547 (107.4s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=94.17%
#   client2 training... val=97.60%
#   client3 training... val=98.45%
#   Global: acc=97.38% loss=0.1634 (106.1s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=94.17%
#   client2 training... val=89.07%
#   client3 training... val=95.24%
#   Global: acc=97.33% loss=0.1965 (106.1s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=89.17%
#   client2 training... val=95.60%
#   client3 training... val=98.21%
#   Global: acc=97.33% loss=0.1857 (107.0s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=91.67%
#   client2 training... val=98.00%
#   client3 training... val=98.69%
#   Global: acc=97.82% loss=0.1541 (106.6s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=92.92%
#   client2 training... val=96.13%
#   client3 training... val=88.10%
#   Global: acc=95.85% loss=0.2011 (106.0s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=90.00%
#   client2 training... val=98.27%
#   client3 training... val=97.50%
#   Global: acc=97.60% loss=0.1450 (106.0s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=91.25%
#   client2 training... val=97.07%
#   client3 training... val=97.62%
#   Global: acc=97.76% loss=0.1583 (108.0s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=90.00%
#   client2 training... val=96.67%
#   client3 training... val=93.33%
#   Global: acc=97.60% loss=0.1472 (108.3s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=92.92%
#   client2 training... val=97.73%
#   client3 training... val=97.14%
#   Global: acc=97.49% loss=0.1571 (108.1s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=92.92%
#   client2 training... val=95.60%
#   client3 training... val=97.02%
#   Global: acc=97.82% loss=0.1409 (107.6s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=77.50%
#   client2 training... val=96.13%
#   client3 training... val=96.90%
#   Global: acc=97.49% loss=0.1520 (107.1s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=93.33%
#   client2 training... val=96.00%
#   client3 training... val=98.33%
#   Global: acc=97.55% loss=0.1741 (106.0s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=86.67%
#   client2 training... val=88.27%
#   client3 training... val=91.19%
#   Global: acc=97.33% loss=0.1479 (105.7s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=91.67%
#   client2 training... val=96.53%
#   client3 training... val=98.57%
#   Global: acc=97.76% loss=0.1558 (106.8s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=93.33%
#   client2 training... val=95.47%
#   client3 training... val=94.64%
#   Global: acc=97.27% loss=0.1643 (106.3s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=92.08%
#   client2 training... val=97.60%
#   client3 training... val=95.48%
#   Global: acc=97.71% loss=0.1686 (106.3s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=84.17%
#   client2 training... val=98.27%
#   client3 training... val=98.45%
#   Global: acc=97.87% loss=0.1456 (106.5s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=93.33%
#   client2 training... val=97.20%
#   client3 training... val=97.14%
#   Global: acc=97.98% loss=0.1385 (105.5s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=93.75%
#   client2 training... val=97.60%
#   client3 training... val=98.45%
#   Global: acc=97.71% loss=0.1433 (106.1s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=93.75%
#   client2 training... val=98.00%
#   client3 training... val=96.07%
#   Global: acc=97.44% loss=0.1438 (105.8s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=92.92%
#   client2 training... val=90.93%
#   client3 training... val=98.69%
#   Global: acc=96.84% loss=0.1693 (105.7s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=90.83%
#   client2 training... val=96.53%
#   client3 training... val=97.74%
#   Global: acc=97.65% loss=0.1572 (106.0s)
#
# ================================================================================
#   FEDPROX DONE best 98.15%
# ================================================================================

# %% [markdown]
# ## QPSO Training

# %%
torch.cuda.empty_cache()
qpso_model = create_model(NUM_CLASSES, device)
qpso_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
qpso_server = QPSOServer(qpso_model, qpso_clients, device=device, beta=0.7)
qpso_history = train_qpso(qpso_server, qpso_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
print("\nAll training complete!")
# Out:
# Model: ResNet-18 (from scratch) | Params: 11,178,564 | Classes: 4
# QPSO Server | clients=3 beta=0.7
# ================================================================================
#   QPSO-FL TRAINING START
# ================================================================================
# QPSO particles initialised
#
# ============================================================ ROUND 1/100
#   client1 training... val=57.50%
#   client2 training... val=84.00%
#   client3 training... val=43.69%
#   QPSO aggregating...
#   client1: pbest 57.50%
#   client1: gbest 57.50%
#   client2: pbest 84.00%
#   client2: gbest 84.00%
#   client3: pbest 43.69%
#   Global: acc=23.24% loss=2.2638 gbest=84.00% (97.2s)
#   New best! 23.24%
#
# ============================================================ ROUND 2/100
#   client1 training... val=71.67%
#   client2 training... val=88.80%
#   client3 training... val=89.76%
#   QPSO aggregating...
#   client1: pbest 71.67%
#   client2: pbest 88.80%
#   client2: gbest 88.80%
#   client3: pbest 89.76%
#   client3: gbest 89.76%
#   Global: acc=85.60% loss=0.4168 gbest=89.76% (96.9s)
#   New best! 85.60%
#
# ============================================================ ROUND 3/100
#   client1 training... val=86.25%
#   client2 training... val=82.80%
#   client3 training... val=85.95%
#   QPSO aggregating...
#   client1: pbest 86.25%
#   Global: acc=88.98% loss=0.3356 gbest=89.76% (97.8s)
#   New best! 88.98%
#
# ============================================================ ROUND 4/100
#   client1 training... val=72.50%
#   client2 training... val=92.40%
#   client3 training... val=80.95%
#   QPSO aggregating...
#   client2: pbest 92.40%
#   client2: gbest 92.40%
#   Global: acc=91.76% loss=0.2487 gbest=92.40% (97.5s)
#   New best! 91.76%
#
# ============================================================ ROUND 5/100
#   client1 training... val=82.92%
#   client2 training... val=94.93%
#   client3 training... val=71.55%
#   QPSO aggregating...
#   client2: pbest 94.93%
#   client2: gbest 94.93%
#   Global: acc=92.58% loss=0.2306 gbest=94.93% (97.1s)
#   New best! 92.58%
#
# ============================================================ ROUND 6/100
#   client1 training... val=82.08%
#   client2 training... val=92.93%
#   client3 training... val=94.17%
#   QPSO aggregating...
#   client3: pbest 94.17%
#   Global: acc=94.44% loss=0.1921 gbest=94.93% (98.3s)
#   New best! 94.44%
#
# ============================================================ ROUND 7/100
#   client1 training... val=88.33%
#   client2 training... val=82.53%
#   client3 training... val=92.86%
#   QPSO aggregating...
#   client1: pbest 88.33%
#   Global: acc=94.60% loss=0.1894 gbest=94.93% (97.1s)
#   New best! 94.60%
#
# ============================================================ ROUND 8/100
#   client1 training... val=90.83%
#   client2 training... val=87.73%
#   client3 training... val=94.40%
#   QPSO aggregating...
#   client1: pbest 90.83%
#   client3: pbest 94.40%
#   Global: acc=95.36% loss=0.1751 gbest=94.93% (98.0s)
#   New best! 95.36%
#
# ============================================================ ROUND 9/100
#   client1 training... val=89.17%
#   client2 training... val=87.33%
#   client3 training... val=93.45%
#   QPSO aggregating...
#   Global: acc=95.85% loss=0.1619 gbest=94.93% (97.2s)
#   New best! 95.85%
#
# ============================================================ ROUND 10/100
#   client1 training... val=87.08%
#   client2 training... val=94.93%
#   client3 training... val=95.24%
#   QPSO aggregating...
#   client3: pbest 95.24%
#   client3: gbest 95.24%
#   Global: acc=95.64% loss=0.1722 gbest=95.24% (97.8s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=92.50%
#   client2 training... val=92.93%
#   client3 training... val=91.31%
#   QPSO aggregating...
#   client1: pbest 92.50%
#   Global: acc=95.96% loss=0.1649 gbest=95.24% (96.2s)
#   New best! 95.96%
#
# ============================================================ ROUND 12/100
#   client1 training... val=93.33%
#   client2 training... val=78.13%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   client1: pbest 93.33%
#   client3: pbest 95.83%
#   client3: gbest 95.83%
#   Global: acc=95.14% loss=0.1918 gbest=95.83% (96.8s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=90.42%
#   client2 training... val=95.47%
#   client3 training... val=94.05%
#   QPSO aggregating...
#   client2: pbest 95.47%
#   Global: acc=95.53% loss=0.1716 gbest=95.83% (97.4s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=90.83%
#   client2 training... val=94.67%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   Global: acc=95.36% loss=0.1743 gbest=95.83% (96.7s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=90.83%
#   client2 training... val=95.20%
#   client3 training... val=95.36%
#   QPSO aggregating...
#   Global: acc=95.53% loss=0.1771 gbest=95.83% (97.7s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=93.75%
#   client2 training... val=91.87%
#   client3 training... val=95.48%
#   QPSO aggregating...
#   client1: pbest 93.75%
#   Global: acc=96.07% loss=0.1641 gbest=95.83% (98.2s)
#   New best! 96.07%
#
# ============================================================ ROUND 17/100
#   client1 training... val=92.50%
#   client2 training... val=94.80%
#   client3 training... val=92.50%
#   QPSO aggregating...
#   Global: acc=95.80% loss=0.1787 gbest=95.83% (97.6s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=90.00%
#   client2 training... val=94.67%
#   client3 training... val=94.29%
#   QPSO aggregating...
#   Global: acc=95.91% loss=0.1634 gbest=95.83% (96.4s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=95.42%
#   client2 training... val=95.33%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   client1: pbest 95.42%
#   Global: acc=95.85% loss=0.1659 gbest=95.83% (97.4s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=95.42%
#   client2 training... val=96.53%
#   client3 training... val=95.00%
#   QPSO aggregating...
#   client2: pbest 96.53%
#   client2: gbest 96.53%
#   Global: acc=96.18% loss=0.1515 gbest=96.53% (97.2s)
#   New best! 96.18%
#
# ============================================================ ROUND 21/100
#   client1 training... val=92.08%
#   client2 training... val=97.60%
#   client3 training... val=93.93%
#   QPSO aggregating...
#   client2: pbest 97.60%
#   client2: gbest 97.60%
#   Global: acc=97.22% loss=0.1431 gbest=97.60% (98.9s)
#   New best! 97.22%
#
# ============================================================ ROUND 22/100
#   client1 training... val=92.92%
#   client2 training... val=96.00%
#   client3 training... val=96.19%
#   QPSO aggregating...
#   client3: pbest 96.19%
#   Global: acc=97.05% loss=0.1494 gbest=97.60% (98.0s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=91.25%
#   client2 training... val=95.73%
#   client3 training... val=96.55%
#   QPSO aggregating...
#   client3: pbest 96.55%
#   Global: acc=96.67% loss=0.1535 gbest=97.60% (96.3s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=96.67%
#   client2 training... val=94.93%
#   client3 training... val=96.31%
#   QPSO aggregating...
#   client1: pbest 96.67%
#   Global: acc=97.11% loss=0.1416 gbest=97.60% (96.8s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=92.50%
#   client2 training... val=94.67%
#   client3 training... val=94.17%
#   QPSO aggregating...
#   Global: acc=97.27% loss=0.1417 gbest=97.60% (98.0s)
#   New best! 97.27%
#
# ============================================================ ROUND 26/100
#   client1 training... val=90.83%
#   client2 training... val=92.80%
#   client3 training... val=96.31%
#   QPSO aggregating...
#   Global: acc=97.05% loss=0.1442 gbest=97.60% (97.5s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=91.25%
#   client2 training... val=97.47%
#   client3 training... val=95.60%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1371 gbest=97.60% (97.3s)
#   New best! 97.44%
#
# ============================================================ ROUND 28/100
#   client1 training... val=91.25%
#   client2 training... val=96.40%
#   client3 training... val=86.19%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1412 gbest=97.60% (99.1s)
#   New best! 97.55%
#
# ============================================================ ROUND 29/100
#   client1 training... val=95.00%
#   client2 training... val=96.80%
#   client3 training... val=93.57%
#   QPSO aggregating...
#   Global: acc=97.05% loss=0.1445 gbest=97.60% (98.9s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=94.58%
#   client2 training... val=94.93%
#   client3 training... val=96.67%
#   QPSO aggregating...
#   client3: pbest 96.67%
#   Global: acc=97.38% loss=0.1359 gbest=97.60% (97.3s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=91.67%
#   client2 training... val=96.13%
#   client3 training... val=96.67%
#   QPSO aggregating...
#   Global: acc=96.94% loss=0.1446 gbest=97.60% (97.5s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=93.33%
#   client2 training... val=96.00%
#   client3 training... val=96.55%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1330 gbest=97.60% (97.0s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=89.17%
#   client2 training... val=94.93%
#   client3 training... val=94.88%
#   QPSO aggregating...
#   Global: acc=97.16% loss=0.1370 gbest=97.60% (98.1s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=91.25%
#   client2 training... val=96.27%
#   client3 training... val=96.67%
#   QPSO aggregating...
#   Global: acc=97.27% loss=0.1367 gbest=97.60% (97.9s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=94.17%
#   client2 training... val=97.07%
#   client3 training... val=96.90%
#   QPSO aggregating...
#   client3: pbest 96.90%
#   Global: acc=97.33% loss=0.1432 gbest=97.60% (97.4s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=96.67%
#   client2 training... val=96.53%
#   client3 training... val=95.95%
#   QPSO aggregating...
#   Global: acc=97.33% loss=0.1431 gbest=97.60% (97.6s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=94.58%
#   client2 training... val=95.87%
#   client3 training... val=96.55%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1475 gbest=97.60% (97.6s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=90.83%
#   client2 training... val=95.47%
#   client3 training... val=96.90%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1437 gbest=97.60% (97.6s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=96.25%
#   client2 training... val=88.40%
#   client3 training... val=96.31%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1435 gbest=97.60% (97.1s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=88.75%
#   client2 training... val=94.93%
#   client3 training... val=96.31%
#   QPSO aggregating...
#   Global: acc=97.27% loss=0.1469 gbest=97.60% (96.9s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=80.42%
#   client2 training... val=96.13%
#   client3 training... val=94.29%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1437 gbest=97.60% (97.1s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=92.08%
#   client2 training... val=98.13%
#   client3 training... val=93.21%
#   QPSO aggregating...
#   client2: pbest 98.13%
#   client2: gbest 98.13%
#   Global: acc=96.18% loss=0.1701 gbest=98.13% (98.9s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=82.08%
#   client2 training... val=97.07%
#   client3 training... val=96.07%
#   QPSO aggregating...
#   Global: acc=96.13% loss=0.1732 gbest=98.13% (95.9s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=89.58%
#   client2 training... val=95.87%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=96.02% loss=0.1758 gbest=98.13% (97.0s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=94.58%
#   client2 training... val=93.73%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   Global: acc=95.64% loss=0.1793 gbest=98.13% (98.3s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=91.67%
#   client2 training... val=94.80%
#   client3 training... val=96.90%
#   QPSO aggregating...
#   Global: acc=95.74% loss=0.1783 gbest=98.13% (98.6s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=93.75%
#   client2 training... val=95.20%
#   client3 training... val=96.79%
#   QPSO aggregating...
#   Global: acc=95.58% loss=0.1832 gbest=98.13% (96.2s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=93.75%
#   client2 training... val=79.87%
#   client3 training... val=96.07%
#   QPSO aggregating...
#   Global: acc=95.69% loss=0.1765 gbest=98.13% (96.7s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=90.00%
#   client2 training... val=78.27%
#   client3 training... val=96.31%
#   QPSO aggregating...
#   Global: acc=95.91% loss=0.1756 gbest=98.13% (96.8s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=90.00%
#   client2 training... val=97.73%
#   client3 training... val=95.95%
#   QPSO aggregating...
#   Global: acc=95.85% loss=0.1705 gbest=98.13% (96.7s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=93.75%
#   client2 training... val=97.20%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   client3: pbest 97.50%
#   Global: acc=95.85% loss=0.1770 gbest=98.13% (99.5s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=90.00%
#   client2 training... val=94.40%
#   client3 training... val=97.74%
#   QPSO aggregating...
#   client3: pbest 97.74%
#   Global: acc=96.18% loss=0.1752 gbest=98.13% (99.2s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=91.67%
#   client2 training... val=95.87%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   Global: acc=96.34% loss=0.1606 gbest=98.13% (99.5s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=92.50%
#   client2 training... val=94.27%
#   client3 training... val=94.29%
#   QPSO aggregating...
#   Global: acc=96.18% loss=0.1672 gbest=98.13% (98.4s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=92.08%
#   client2 training... val=96.67%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   client3: pbest 98.33%
#   client3: gbest 98.33%
#   Global: acc=97.44% loss=0.1464 gbest=98.33% (98.8s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=88.75%
#   client2 training... val=97.20%
#   client3 training... val=95.00%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1481 gbest=98.33% (99.9s)
#   New best! 97.60%
#
# ============================================================ ROUND 57/100
#   client1 training... val=89.58%
#   client2 training... val=97.07%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1467 gbest=98.33% (101.2s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=95.42%
#   client2 training... val=93.73%
#   client3 training... val=95.48%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1418 gbest=98.33% (98.7s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=93.75%
#   client2 training... val=96.40%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1433 gbest=98.33% (100.5s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=95.00%
#   client2 training... val=93.73%
#   client3 training... val=96.67%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1503 gbest=98.33% (100.2s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=95.00%
#   client2 training... val=94.13%
#   client3 training... val=96.07%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1534 gbest=98.33% (100.2s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=94.17%
#   client2 training... val=97.33%
#   client3 training... val=94.05%
#   QPSO aggregating...
#   Global: acc=97.49% loss=0.1461 gbest=98.33% (100.7s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=95.83%
#   client2 training... val=98.13%
#   client3 training... val=95.60%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1446 gbest=98.33% (99.7s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=94.17%
#   client2 training... val=95.33%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1486 gbest=98.33% (100.0s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=92.08%
#   client2 training... val=97.60%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1427 gbest=98.33% (100.3s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=94.17%
#   client2 training... val=97.20%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1504 gbest=98.33% (100.7s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=90.83%
#   client2 training... val=96.00%
#   client3 training... val=94.88%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1468 gbest=98.33% (99.5s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=90.42%
#   client2 training... val=96.27%
#   client3 training... val=92.74%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1518 gbest=98.33% (99.4s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=92.08%
#   client2 training... val=96.80%
#   client3 training... val=96.07%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1440 gbest=98.33% (99.0s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=92.08%
#   client2 training... val=94.67%
#   client3 training... val=96.07%
#   QPSO aggregating...
#   Global: acc=97.33% loss=0.1479 gbest=98.33% (101.0s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=91.67%
#   client2 training... val=96.93%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=97.49% loss=0.1451 gbest=98.33% (100.0s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=87.08%
#   client2 training... val=98.00%
#   client3 training... val=92.50%
#   QPSO aggregating...
#   Global: acc=97.33% loss=0.1534 gbest=98.33% (98.9s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=92.92%
#   client2 training... val=96.93%
#   client3 training... val=91.19%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1492 gbest=98.33% (99.7s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=95.00%
#   client2 training... val=89.20%
#   client3 training... val=96.90%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1518 gbest=98.33% (100.0s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=92.50%
#   client2 training... val=97.73%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=97.49% loss=0.1505 gbest=98.33% (100.8s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=93.75%
#   client2 training... val=96.27%
#   client3 training... val=95.48%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1473 gbest=98.33% (99.7s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=93.75%
#   client2 training... val=94.00%
#   client3 training... val=95.60%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1493 gbest=98.33% (100.1s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=92.92%
#   client2 training... val=94.80%
#   client3 training... val=90.48%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1477 gbest=98.33% (99.3s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=95.42%
#   client2 training... val=94.67%
#   client3 training... val=95.24%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1514 gbest=98.33% (99.7s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=91.25%
#   client2 training... val=94.53%
#   client3 training... val=95.60%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1453 gbest=98.33% (99.7s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=93.33%
#   client2 training... val=97.73%
#   client3 training... val=95.95%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1472 gbest=98.33% (97.5s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=94.58%
#   client2 training... val=97.60%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   Global: acc=97.65% loss=0.1455 gbest=98.33% (98.2s)
#   New best! 97.65%
#
# ============================================================ ROUND 83/100
#   client1 training... val=80.00%
#   client2 training... val=94.80%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1491 gbest=98.33% (98.1s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=95.00%
#   client2 training... val=93.60%
#   client3 training... val=96.79%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1446 gbest=98.33% (97.5s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=91.25%
#   client2 training... val=97.73%
#   client3 training... val=95.36%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1466 gbest=98.33% (98.4s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=95.00%
#   client2 training... val=96.40%
#   client3 training... val=95.95%
#   QPSO aggregating...
#   Global: acc=97.49% loss=0.1470 gbest=98.33% (97.8s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=92.50%
#   client2 training... val=97.07%
#   client3 training... val=95.00%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1477 gbest=98.33% (98.4s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=93.75%
#   client2 training... val=95.60%
#   client3 training... val=94.88%
#   QPSO aggregating...
#   Global: acc=97.27% loss=0.1547 gbest=98.33% (98.1s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=96.25%
#   client2 training... val=85.73%
#   client3 training... val=97.62%
#   QPSO aggregating...
#   Global: acc=97.71% loss=0.1443 gbest=98.33% (97.7s)
#   New best! 97.71%
#
# ============================================================ ROUND 90/100
#   client1 training... val=89.17%
#   client2 training... val=94.53%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=97.44% loss=0.1492 gbest=98.33% (97.5s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=92.50%
#   client2 training... val=98.13%
#   client3 training... val=91.90%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1449 gbest=98.33% (98.6s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=95.00%
#   client2 training... val=95.87%
#   client3 training... val=87.98%
#   QPSO aggregating...
#   Global: acc=97.49% loss=0.1467 gbest=98.33% (98.9s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=93.75%
#   client2 training... val=94.80%
#   client3 training... val=95.48%
#   QPSO aggregating...
#   Global: acc=97.33% loss=0.1462 gbest=98.33% (98.2s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=95.83%
#   client2 training... val=97.60%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1454 gbest=98.33% (99.4s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=95.83%
#   client2 training... val=92.53%
#   client3 training... val=89.17%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1551 gbest=98.33% (98.3s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=88.33%
#   client2 training... val=84.00%
#   client3 training... val=95.95%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1535 gbest=98.33% (98.8s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=93.33%
#   client2 training... val=92.13%
#   client3 training... val=94.17%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1471 gbest=98.33% (96.5s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=93.75%
#   client2 training... val=95.87%
#   client3 training... val=95.71%
#   QPSO aggregating...
#   Global: acc=97.65% loss=0.1442 gbest=98.33% (97.7s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=87.92%
#   client2 training... val=94.53%
#   client3 training... val=97.02%
#   QPSO aggregating...
#   Global: acc=97.60% loss=0.1470 gbest=98.33% (99.1s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=94.17%
#   client2 training... val=97.60%
#   client3 training... val=97.26%
#   QPSO aggregating...
#   Global: acc=97.55% loss=0.1457 gbest=98.33% (98.2s)
#
# ================================================================================
#   QPSO-FL DONE best 97.71% gbest 98.33%
# ================================================================================
#
# All training complete!

# %% [markdown]
# ## Evaluation & Plots

# %%
def plot_accuracy_comparison(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(2, max(n,2), figsize=(8*max(n,2), 12))
    fig.suptitle("FL Aggregation Comparison", fontsize=16, fontweight="bold")
    colors = ['#1f77b4','#ff7f0e','#2ca02c']
    ax = axes[0,0]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_acc"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Acc (%)", title="Global Test Accuracy", ylim=[0,100]); ax.legend(); ax.grid(alpha=0.3)
    ax = axes[0,1]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_loss"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Loss", title="Global Test Loss"); ax.legend(); ax.grid(alpha=0.3)
    for idx, (df, name) in enumerate(zip(dfs, names)):
        ax = axes[1, idx]
        for i in range(1,4): ax.plot(df["round"], df[f"client{i}_val_acc"], label=f"Client {i}", lw=2)
        ax.set(xlabel="Round", ylabel="Val Acc (%)", title=f"{name}: Per-Client"); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Saved -> {save_path}")

def generate_confusion_matrix(mp, tl, mname, device="cuda", save_path=None):
    model = BrainTumorResNet(NUM_CLASSES).to(device)
    model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
    model.eval(); preds, labels = [], []
    with torch.no_grad():
        for imgs, labs in tl:
            _, pred = model(imgs.to(device)).max(1)
            preds.extend(pred.cpu().numpy()); labels.extend(labs.numpy())
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix - {mname}", fontsize=14, fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted"); plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"\n{mname}:"); print(classification_report(labels, preds, target_names=CLASS_NAMES, digits=4))

def plot_roc_auc(mps, mnames, tl, device="cuda", save_path=None):
    n = len(mps)
    fig, axes = plt.subplots(1, n, figsize=(7*n, 6))
    if n == 1: axes = [axes]
    cc = ['#e74c3c', '#3498db', '#2ecc71', '#9b59b6']
    for ax, mp, mn in zip(axes, mps, mnames):
        model = BrainTumorResNet(NUM_CLASSES).to(device)
        model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
        model.eval(); probs, labs = [], []
        with torch.no_grad():
            for imgs, lb in tl:
                out = model(imgs.to(device)); probs.append(torch.softmax(out, dim=1).cpu().numpy()); labs.extend(lb.numpy())
        yp = np.vstack(probs); yt = np.array(labs)
        # Handle NaN from poorly trained models
        if np.isnan(yp).any():
            print(f"  WARNING: {mn} has NaN outputs, replacing with uniform")
            yp = np.nan_to_num(yp, nan=1.0/NUM_CLASSES)
        yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
        for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
            try:
                fpr, tpr, _ = roc_curve(yb[:, i], yp[:, i]); a = auc(fpr, tpr)
                ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.4f})")
            except: ax.plot([0,1],[0,1], color=c, lw=2, label=f"{cls} (N/A)")
        try:
            fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
            ax.plot(fpr_m, tpr_m, 'k--', lw=2, label=f"Micro ({auc(fpr_m,tpr_m):.4f})")
        except: pass
        ax.plot([0,1],[0,1],'gray',ls=':',lw=1)
        ax.set(xlabel="FPR", ylabel="TPR", title=f"ROC - {mn}"); ax.legend(loc="lower right", fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show(); print(f"ROC-AUC saved -> {save_path}")

def plot_client_fairness(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(1, n, figsize=(6*n, 5)); cc = ["#FF6B6B","#4ECDC4","#45B7D1"]
    if n == 1: axes = [axes]
    for ax, df, t in zip(axes, dfs, names):
        accs = [df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)]
        ax.bar(["C1","C2","C3"], accs, color=cc, edgecolor="black")
        ax.axhline(np.mean(accs), color="red", ls="--", lw=2, label="Mean")
        ax.set(ylabel="Final Val Acc (%)", ylim=[0,100])
        ax.set_title(f"{t} (std={np.std(accs):.2f}%)", fontsize=13, fontweight="bold"); ax.legend(); ax.grid(axis="y", alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()

def convergence_metrics(df, target=80.0):
    r = df[df["global_test_acc"]>=target]
    return {"final_acc": round(df["global_test_acc"].iloc[-1],2), "best_acc": round(df["global_test_acc"].max(),2),
            "round_to_target": int(r["round"].min()) if len(r) else None,
            "avg_round_time_s": round(df["round_time"].mean(),2), "total_time_min": round(df["round_time"].sum()/60,2)}

def statistical_analysis(dfa, dfb):
    a, b = dfa["global_test_acc"].values, dfb["global_test_acc"].values
    n = min(len(a),len(b)); a, b = a[:n], b[:n]
    t_stat, p_val = stats.ttest_rel(b, a); d = (b-a).mean()/((b-a).std(ddof=1)+1e-8)
    return {"t_stat": round(float(t_stat),4), "p_value": float(p_val), "cohens_d": round(float(d),4), "significant": bool(p_val<0.05)}

def build_comparison_df(*pairs):
    cols = ["Metric"] + [n for _, n in pairs]
    ml = []
    for df, n in pairs:
        m = convergence_metrics(df)
        m["client_std"] = round(float(np.std([df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)])),2)
        ml.append(m)
    keys = [("Final Acc (%)","final_acc"),("Best Acc (%)","best_acc"),("Rounds to 80%","round_to_target"),
            ("Avg Round (s)","avg_round_time_s"),("Total Time (min)","total_time_min"),("Client Std Dev","client_std")]
    rows = [[l]+[m[k] if m[k] is not None else "N/A" for m in ml] for l, k in keys]
    return pd.DataFrame(rows, columns=cols)
print("Evaluation functions loaded")
# Out:
# Evaluation functions loaded

# %%
df_fa = pd.read_csv('/kaggle/working/results/fedavg/metrics.csv')
df_fp = pd.read_csv('/kaggle/working/results/fedprox/metrics.csv')
df_qp = pd.read_csv('/kaggle/working/results/qpso/metrics.csv')
comp = build_comparison_df((df_fa,"FedAvg"),(df_fp,"FedProx"),(df_qp,"QPSO-FL"))
print(comp.to_string(index=False))
comp.to_csv('/kaggle/working/results/final_comparison.csv', index=False)
# Out:
#           Metric  FedAvg  FedProx  QPSO-FL
#    Final Acc (%)   97.27    97.65    97.55
#     Best Acc (%)   98.25    98.15    97.71
#    Rounds to 80%    4.00     6.00     2.00
#    Avg Round (s)   97.70   106.93    98.28
# Total Time (min)  162.83   178.21   163.81
#   Client Std Dev    1.45     3.01     1.54

# %%
plot_accuracy_comparison([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/comparison.png')
for m, n in [('fedavg','FedAvg'),('fedprox','FedProx'),('qpso','QPSO-FL')]:
    generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth', data_loaders['global_test'], n, device=device, save_path=f'/kaggle/working/results/plots/cm_{m}.png')
plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/fairness.png')
plot_roc_auc(['/kaggle/working/models/fedavg_best.pth','/kaggle/working/models/fedprox_best.pth','/kaggle/working/models/qpso_best.pth'],
    ['FedAvg','FedProx','QPSO-FL'], data_loaders['global_test'], device=device, save_path='/kaggle/working/results/plots/roc_auc.png')
# Out:
# Saved -> /kaggle/working/results/plots/comparison.png
#
# FedAvg:
#               precision    recall  f1-score   support
#
#       Glioma     0.9885    0.9683    0.9783       442
#   Meningioma     0.9787    0.9787    0.9787       470
#     No Tumor     0.9748    0.9861    0.9804       432
#    Pituitary     0.9878    0.9959    0.9919       489
#
#     accuracy                         0.9825      1833
#    macro avg     0.9825    0.9823    0.9823      1833
# weighted avg     0.9826    0.9825    0.9825      1833
#
#
# FedProx:
#               precision    recall  f1-score   support
#
#       Glioma     0.9885    0.9751    0.9818       442
#   Meningioma     0.9646    0.9851    0.9747       470
#     No Tumor     0.9816    0.9861    0.9838       432
#    Pituitary     0.9917    0.9796    0.9856       489
#
#     accuracy                         0.9815      1833
#    macro avg     0.9816    0.9815    0.9815      1833
# weighted avg     0.9816    0.9815    0.9815      1833
#
#
# QPSO-FL:
#               precision    recall  f1-score   support
#
#       Glioma     0.9705    0.9683    0.9694       442
#   Meningioma     0.9762    0.9617    0.9689       470
#     No Tumor     0.9815    0.9838    0.9827       432
#    Pituitary     0.9798    0.9939    0.9868       489
#
#     accuracy                         0.9771      1833
#    macro avg     0.9770    0.9769    0.9770      1833
# weighted avg     0.9771    0.9771    0.9770      1833
#
# ROC-AUC saved -> /kaggle/working/results/plots/roc_auc.png

# %% [markdown]
# ## Statistical Analysis & Summary

# %%
s1 = statistical_analysis(df_fa, df_qp)
s2 = statistical_analysis(df_fa, df_fp)
print("FedAvg vs QPSO:", json.dumps(s1, indent=2))
print("FedAvg vs FedProx:", json.dumps(s2, indent=2))
summary = {"fedavg": convergence_metrics(df_fa), "fedprox": convergence_metrics(df_fp),
           "qpso": convergence_metrics(df_qp), "stats_fa_qp": s1, "stats_fa_fp": s2}
with open('/kaggle/working/results/executive_summary.json','w') as f: json.dump(summary, f, indent=2)
print("Summary saved")
print("\nLaTeX Table:")
print(comp.to_latex(index=False, float_format="%.2f", caption="FedAvg vs FedProx vs QPSO-FL", label="tab:comparison"))
print("\nNotebook complete!")
# Out:
# FedAvg vs QPSO: {
#   "t_stat": 0.1381,
#   "p_value": 0.890447262922104,
#   "cohens_d": 0.0138,
#   "significant": false
# }
# FedAvg vs FedProx: {
#   "t_stat": -3.4081,
#   "p_value": 0.0009471645316786733,
#   "cohens_d": -0.3408,
#   "significant": true
# }
# Summary saved
#
# LaTeX Table:
# \begin{table}
# \caption{FedAvg vs FedProx vs QPSO-FL}
# \label{tab:comparison}
# \begin{tabular}{lrrr}
# \toprule
# Metric & FedAvg & FedProx & QPSO-FL \\
# \midrule
# Final Acc (%) & 97.27 & 97.65 & 97.55 \\
# Best Acc (%) & 98.25 & 98.15 & 97.71 \\
# Rounds to 80% & 4.00 & 6.00 & 2.00 \\
# Avg Round (s) & 97.70 & 106.93 & 98.28 \\
# Total Time (min) & 162.83 & 178.21 & 163.81 \\
# Client Std Dev & 1.45 & 3.01 & 1.54 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# Notebook complete!
