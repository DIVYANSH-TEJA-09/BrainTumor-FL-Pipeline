# %% [markdown]
# # Phase 4 — Setup 2: Moderate Label Skew (70/10/10/10)
#
# FedAvg · FedProx · Layer-by-Layer QPSO-FL

# %%
import os, sys, copy, time, random, json, shutil
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from PIL import Image
import pandas as pd
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import stats
try:
    from tqdm.notebook import tqdm
except ImportError:
    from tqdm import tqdm

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42); device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu"); print("CPU only")
torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False

NUM_CLASSES = 4
CLASS_NAMES = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
VALID_CLASSES = {"glioma": 0, "meningioma": 1, "notumor": 2, "no_tumor": 2, "pituitary": 3}

# ╔══════════════════════════════════════════════════════╗
# ║  Phase 4 Hyperparameters                            ║
# ╚══════════════════════════════════════════════════════╝
IMG_SIZE     = 112
LOCAL_EPOCHS = 1
LR           = 0.01
BATCH_SIZE   = 64
NUM_ROUNDS   = 100
FEDPROX_MU   = 0.01

# QPSO — faithful port from MNIST reference notebook
QPSO_BETA        = 0.6   # static contraction-expansion coefficient (same as MNIST)
QPSO_ITERS       = 5     # optimization iterations per layer per round (same default as MNIST)
QPSO_VAL_BATCHES = 4     # mini-batches used for each fitness evaluation (speed/quality tradeoff)

# Early Stopping (applies to all three methods independently)
PATIENCE   = 15     # stop if best accuracy does not improve for this many rounds
MIN_ROUNDS = 30     # always run at least this many rounds
TARGET_ACC = 95.0   # once this accuracy is reached, begin counting patience

print(f"Phase 4 | SimpleCNN | img={IMG_SIZE} | E={LOCAL_EPOCHS} | lr={LR} | bs={BATCH_SIZE} | max_rounds={NUM_ROUNDS}")
print(f"QPSO: beta={QPSO_BETA} (static) | iters/layer={QPSO_ITERS} | val_batches={QPSO_VAL_BATCHES}")
print(f"FedProx mu={FEDPROX_MU}")
print(f"Early Stopping: patience={PATIENCE} | min_rounds={MIN_ROUNDS} | target={TARGET_ACC}%")

for d in ['data/processed/client1','data/processed/client2','data/processed/client3',
          'data/test_set','models',
          'results_phase4/fedavg','results_phase4/fedprox','results_phase4/qpso',
          'results_phase4/plots','logs']:
    os.makedirs(f'/kaggle/working/{d}', exist_ok=True)
print("Directories created")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Phase 4 | SimpleCNN | img=112 | E=1 | lr=0.01 | bs=64 | max_rounds=100
# QPSO: beta=0.6 (static) | iters/layer=5 | val_batches=4
# FedProx mu=0.01
# Early Stopping: patience=15 | min_rounds=30 | target=95.0%
# Directories created

# %%
class Preprocessor:
    def __init__(self, size=None):
        self.size = size or (IMG_SIZE, IMG_SIZE)

    def load_image(self, path):
        try:
            img = Image.open(path)
            if img.mode != "RGB": img = img.convert("RGB")
            return np.array(img.resize(self.size, Image.LANCZOS), dtype=np.float32) / 255.0
        except: return None

    def process_dataset(self, dataset_path, client_name,
                        save_dir="/kaggle/working/data/processed",
                        train_r=0.70, val_r=0.15):
        print(f"\n{'='*60}\nProcessing {client_name} <- {dataset_path}\n{'='*60}")
        images, labels = [], []
        for cls_name in sorted(os.listdir(dataset_path)):
            cls_path = os.path.join(dataset_path, cls_name)
            if not os.path.isdir(cls_path): continue
            key = cls_name.lower().replace(" ", "")
            if key not in VALID_CLASSES: print(f"  Skipping: {cls_name}"); continue
            label = VALID_CLASSES[key]
            files = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))]
            print(f"  {cls_name}: {len(files)} images (label={label})")
            for fname in tqdm(files, desc=f"    {cls_name}", leave=False):
                arr = self.load_image(os.path.join(cls_path, fname))
                if arr is not None: images.append(arr); labels.append(label)
        X, y = np.array(images), np.array(labels)
        print(f"  Total: {len(X)} | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
        test_r = 1.0 - train_r - val_r
        X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=test_r, stratify=y, random_state=42)
        val_adj = val_r / (train_r + val_r)
        X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=val_adj, stratify=y_tmp, random_state=42)
        print(f"  Train:{len(X_train)} Val:{len(X_val)} Test:{len(X_test)}")
        out = os.path.join(save_dir, client_name); os.makedirs(out, exist_ok=True)
        for name, arr in [("X_train",X_train),("y_train",y_train),("X_val",X_val),
                          ("y_val",y_val),("X_test",X_test),("y_test",y_test)]:
            np.save(os.path.join(out, f"{name}.npy"), arr)
        print(f"  Saved -> {out}")

    @staticmethod
    def create_global_test(pdir="/kaggle/working/data/processed", sdir="/kaggle/working/data/test_set"):
        Xs, ys = [], []
        for i in range(1, 4):
            d = os.path.join(pdir, f"client{i}")
            Xs.append(np.load(os.path.join(d, "X_test.npy")))
            ys.append(np.load(os.path.join(d, "y_test.npy")))
        X, y = np.concatenate(Xs), np.concatenate(ys)
        os.makedirs(sdir, exist_ok=True)
        np.save(os.path.join(sdir, "X_test.npy"), X); np.save(os.path.join(sdir, "y_test.npy"), y)
        print(f"Global test: {len(X)} images | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")

print("Preprocessor ready")
# Out:
# Preprocessor ready

# %%
class BrainTumorDataset(Dataset):
    _DEFAULT = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
    def __init__(self, X, y, transform=None):
        self.X, self.y = X, y; self.transform = transform or self._DEFAULT
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        img = Image.fromarray((self.X[idx]*255).astype(np.uint8))
        return self.transform(img), torch.tensor(self.y[idx], dtype=torch.long)

TRAIN_TF = transforms.Compose([
    transforms.RandomHorizontalFlip(0.5), transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
TEST_TF = transforms.Compose([
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

def create_data_loaders(pdir="/kaggle/working/data/processed",
                        tdir="/kaggle/working/data/test_set", bs=None, nw=2):
    bs = bs or BATCH_SIZE; loaders = {}
    for i in range(1, 4):
        d = f"{pdir}/client{i}"
        ds_tr = BrainTumorDataset(np.load(f"{d}/X_train.npy"), np.load(f"{d}/y_train.npy"), TRAIN_TF)
        ds_va = BrainTumorDataset(np.load(f"{d}/X_val.npy"),   np.load(f"{d}/y_val.npy"),   TEST_TF)
        ds_te = BrainTumorDataset(np.load(f"{d}/X_test.npy"),  np.load(f"{d}/y_test.npy"),  TEST_TF)
        loaders[f"client{i}"] = {
            "train": DataLoader(ds_tr, bs, shuffle=True,  num_workers=nw, pin_memory=True),
            "val":   DataLoader(ds_va, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "test":  DataLoader(ds_te, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "train_size": len(ds_tr)}
        print(f"client{i}: Train={len(ds_tr)} Val={len(ds_va)} Test={len(ds_te)}")
    gds = BrainTumorDataset(np.load(f"{tdir}/X_test.npy"), np.load(f"{tdir}/y_test.npy"), TEST_TF)
    loaders["global_test"] = DataLoader(gds, bs, shuffle=False, num_workers=nw, pin_memory=True)
    print(f"Global test: {len(gds)}"); return loaders

# ═══════════════════════════════════════════════════════════════
# SimpleCNN — identical to Phase 3 (~120K params)
# ═══════════════════════════════════════════════════════════════
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3,  16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64), nn.ReLU(), nn.AdaptiveAvgPool2d(4),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(0.3), nn.Linear(64*4*4, 128), nn.ReLU(),
            nn.Dropout(0.3), nn.Linear(128, num_classes),
        )
    def forward(self, x):
        return self.classifier(self.features(x).view(x.size(0), -1))

def create_model(n=4, dev=None):
    dev = dev or device; m = SimpleCNN(n).to(dev)
    total = sum(p.numel() for p in m.parameters())
    print(f"SimpleCNN | params={total:,} | classes={n}"); return m

print("Dataset / model definitions ready")
# Out:
# Dataset / model definitions ready

# %%
# ═══════════════════════════════════════════════════════════════
# Federated Learning Clients & FedAvg Server
# ═══════════════════════════════════════════════════════════════
class FederatedClient:
    def __init__(self, cid, train_loader, val_loader, device="cuda"):
        self.client_id = cid; self.train_loader = train_loader
        self.val_loader = val_loader; self.device = device
        self.model = None; self.optimizer = None
        self.criterion = nn.CrossEntropyLoss()
        self.dataset_size = len(train_loader.dataset)

    def set_model(self, gm):      self.model = copy.deepcopy(gm).to(self.device)
    def set_optimizer(self, lr=None): self.optimizer = optim.Adam(self.model.parameters(), lr=lr or LR)
    def get_dataset_size(self):   return self.dataset_size

    def train_local(self, epochs=None, verbose=False, mu=None, global_params=None):
        epochs = epochs or LOCAL_EPOCHS; self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs)
                if mu is not None and global_params is not None:
                    prox = sum(torch.norm(pl - pg.detach())**2
                               for pl, pg in zip(self.model.parameters(), global_params))
                    loss = loss + (mu / 2.0) * prox
                loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1)
                t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea

    def validate(self):
        self.model.eval(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.model(imgs); ls += self.criterion(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return ls/len(self.val_loader), 100.*c/t

class FedProxClient(FederatedClient): pass   # train_local already handles mu/global_params

class FedAvgServer:
    def __init__(self, gm, clients, device="cuda"):
        self.global_model = gm; self.clients = clients; self.device = device
        self.total_samples = sum(c.get_dataset_size() for c in clients)
        print(f"FedAvg Server | clients={len(clients)} total_samples={self.total_samples}")

    def aggregate_weights(self, cw):
        first = cw[0][0]; total = sum(n for _, n in cw); agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for sd, nk in cw: acc += sd[k].float() * (nk / total)
                agg[k] = acc.to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg

    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)

    def get_global_model(self): return copy.deepcopy(self.global_model)

print("FL client / FedAvg server classes loaded")
# Out:
# FL client / FedAvg server classes loaded

# %%
# ═══════════════════════════════════════════════════════════════
# Phase 4 QPSOServer — Layer-by-Layer QPSO
#
# Faithfully ported from the MNIST IID reference notebook.
#
# Algorithm (per round):
#   1. Collect client state_dicts (particles).
#   2. Compute FedAvg baseline (used for BN buffers + initial context).
#   3. For each trainable parameter tensor (layer) independently:
#        a. Positions = client weights for that layer, flattened.
#        b. Evaluate initial fitness (val LOSS) for each particle.
#        c. Run QPSO_ITERS update steps:
#             mbest = mean of personal bests
#             For each particle i:
#               phi  = rand(dim)
#               u    = rand(dim) + epsilon          (no hard clamp, raw random)
#               sign = random ±1 per dimension
#               p    = phi*pbest_i + (1-phi)*gbest  (attractor)
#               step = beta * |mbest - x_i| * log(1/u) * sign
#               new_pos = p + step                  (matches MNIST formula exactly)
#               Evaluate fitness; update pbest/gbest if loss improved.
#        d. Set this layer = gbest.
#   4. Assembled model = all layers from step 3d.
# ═══════════════════════════════════════════════════════════════
class QPSOServer:
    def __init__(self, gm, clients, device="cuda",
                 beta=None, q_iters=None, val_loader=None, val_batches=None):
        self.global_model = gm
        self.clients      = clients
        self.device       = device
        self.beta         = beta       or QPSO_BETA
        self.q_iters      = q_iters    or QPSO_ITERS
        self.val_loader   = val_loader
        self.val_batches  = val_batches or QPSO_VAL_BATCHES
        self._param_names = {n for n, _ in gm.named_parameters()}
        print(f"QPSOServer | clients={len(clients)} | beta={self.beta} | "
              f"iters/layer={self.q_iters} | trainable_tensors={len(self._param_names)}")
        if val_loader is None:
            print("  WARNING: val_loader not set — call set_val_loader() before training")

    def set_val_loader(self, loader): self.val_loader = loader

    # ── Fitness: validation loss with one layer substituted ──────────────────
    # Minimise loss — lower is better (matches MNIST reference).
    def _eval_loss(self, base_sd, layer_key, candidate_flat, layer_shape):
        sd = copy.deepcopy(base_sd)
        sd[layer_key] = candidate_flat.reshape(layer_shape).to(base_sd[layer_key].dtype)
        self.global_model.load_state_dict(sd)
        self.global_model.eval()
        crit = nn.CrossEntropyLoss(); total = 0.0; nb = 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                total += crit(self.global_model(imgs), labs).item()
                nb += 1
                if nb >= self.val_batches: break
        return total / max(nb, 1)

    # ── FedAvg helper — baseline for non-trainable buffers ───────────────────
    def _fedavg(self, client_weights):
        first = client_weights[0]; n = len(client_weights); agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for w in client_weights: acc += w[k].float()
                agg[k] = (acc / n).to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg

    # ── Main layer-by-layer aggregation ──────────────────────────────────────
    def qpso_aggregate(self, client_weights, rnd=1):
        assert self.val_loader is not None, "val_loader must be set before qpso_aggregate()"
        n_particles = len(client_weights)

        # FedAvg baseline — valid state for the whole model at all times
        base_sd      = self._fedavg(client_weights)
        optimized_sd = copy.deepcopy(base_sd)   # will be updated layer by layer

        for k in base_sd:
            if k not in self._param_names or not base_sd[k].is_floating_point():
                continue   # skip BN running_mean / running_var / num_batches_tracked

            shape = base_sd[k].shape

            # Initialise particle positions from client weights for this layer
            positions = torch.stack(
                [w[k].float().cpu().flatten() for w in client_weights])  # (n_particles, dim)
            dim = positions.shape[1]

            pbest        = positions.clone()
            pbest_scores = torch.zeros(n_particles)

            # Evaluate initial fitness for each particle
            for i in range(n_particles):
                pbest_scores[i] = self._eval_loss(optimized_sd, k, pbest[i], shape)

            gbest_idx   = int(pbest_scores.argmin())
            gbest       = pbest[gbest_idx].clone()
            gbest_score = pbest_scores[gbest_idx].item()

            print(f"  [Layer {k}] dim={dim:,}  init_best_loss={gbest_score:.4f}")

            # QPSO iterations for this layer
            for it in range(self.q_iters):
                mbest = pbest.mean(dim=0)    # mean best position
                for i in range(n_particles):
                    phi  = torch.rand(dim)
                    # u: raw random in (0,1], no hard clamp — matches MNIST reference
                    u    = torch.rand(dim).clamp(min=1e-9)
                    sign = torch.where(torch.rand(dim) > 0.5,
                                       torch.ones(dim), -torch.ones(dim))

                    # Attractor: convex combination of pbest_i and gbest
                    p = phi * pbest[i] + (1.0 - phi) * gbest

                    # Quantum step (no perturbation clamp — matches MNIST reference)
                    step    = self.beta * torch.abs(mbest - positions[i]) * torch.log(1.0 / u) * sign
                    new_pos = p + step        # MNIST formula: new_pos = p + step

                    positions[i] = new_pos
                    score = self._eval_loss(optimized_sd, k, new_pos, shape)

                    if score < pbest_scores[i]:   # minimise loss
                        pbest_scores[i] = score
                        pbest[i]        = new_pos.clone()

                    if score < gbest_score:
                        gbest_score = score
                        gbest       = new_pos.clone()

                print(f"    iter {it+1}/{self.q_iters}  best_loss={gbest_score:.4f}")

            # Commit gbest for this layer into the running optimized state
            optimized_sd[k] = gbest.reshape(shape).to(base_sd[k].dtype)

        self.global_model.load_state_dict(optimized_sd)
        print("  QPSO aggregation complete")
        return optimized_sd

    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)

    def get_global_model(self): return copy.deepcopy(self.global_model)

print("QPSOServer (layer-by-layer, Phase 4) loaded")
# Out:
# QPSOServer (layer-by-layer, Phase 4) loaded

# %%
# ═══════════════════════════════════════════════════════════════
# Training loops with Early Stopping
#
# Early stopping applies to all three methods identically:
#   - Always run at least MIN_ROUNDS rounds.
#   - Once global test accuracy >= TARGET_ACC, start patience countdown.
#   - Stop when best accuracy hasn't improved for PATIENCE consecutive rounds.
# ═══════════════════════════════════════════════════════════════

def _early_stop_check(rnd, best_acc, acc, no_improve_streak):
    # Returns (updated_best, updated_streak, should_stop).
    if acc > best_acc:
        return acc, 0, False
    if rnd < MIN_ROUNDS:
        return best_acc, no_improve_streak + 1, False
    if best_acc >= TARGET_ACC:
        streak = no_improve_streak + 1
        if streak >= PATIENCE:
            return best_acc, streak, True
        return best_acc, streak, False
    return best_acc, no_improve_streak + 1, False


def train_fedavg(server, clients, gtl, nr=None, le=None, lr=None,
                 se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR
    print("="*80 + f"\n  FEDAVG  rounds={nr} | epochs={le} | lr={lr}\n" + "="*80)
    h = {k:[] for k in ["round","global_test_acc","global_test_loss",
                         "client1_val_acc","client2_val_acc","client3_val_acc","round_time"]}
    best = 0.0; streak = 0
    for rnd in range(1, nr+1):
        t0 = time.time(); cw = []
        for cl in clients:
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            _, va = cl.validate()
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga)
        h["global_test_loss"].append(gl); h["round_time"].append(dt)
        tag = ""
        if ga > best: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_best.pth"); tag = " *** best"
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results_phase4/fedavg/metrics.csv", index=False)
        print(f"  R{rnd:3d} | acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s){tag}")
        best, streak, stop = _early_stop_check(rnd, best, ga, streak)
        if stop: print(f"  Early stop at round {rnd} (patience={PATIENCE}, best={best:.2f}%)"); break
    print(f"  FedAvg done — best {best:.2f}%"); return h


def train_fedprox(server, clients, gtl, nr=None, le=None, lr=None, mu=None,
                  se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR; mu = mu or FEDPROX_MU
    print("="*80 + f"\n  FEDPROX  rounds={nr} | epochs={le} | lr={lr} | mu={mu}\n" + "="*80)
    h = {k:[] for k in ["round","global_test_acc","global_test_loss",
                         "client1_val_acc","client2_val_acc","client3_val_acc","round_time"]}
    best = 0.0; streak = 0
    for rnd in range(1, nr+1):
        t0 = time.time(); cw = []; gp = list(server.global_model.parameters())
        for cl in clients:
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose, mu=mu, global_params=gp)
            _, va = cl.validate()
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga)
        h["global_test_loss"].append(gl); h["round_time"].append(dt)
        tag = ""
        if ga > best: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_best.pth"); tag = " *** best"
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results_phase4/fedprox/metrics.csv", index=False)
        print(f"  R{rnd:3d} | acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s){tag}")
        best, streak, stop = _early_stop_check(rnd, best, ga, streak)
        if stop: print(f"  Early stop at round {rnd} (patience={PATIENCE}, best={best:.2f}%)"); break
    print(f"  FedProx done — best {best:.2f}%"); return h


def train_qpso(server, clients, gtl, nr=None, le=None, lr=None,
               se=10, sd="/kaggle/working", verbose=False):
    nr = nr or NUM_ROUNDS; le = le or LOCAL_EPOCHS; lr = lr or LR
    print("="*80 + f"\n  QPSO-FL (layer-by-layer)  rounds={nr} | beta={server.beta} | iters/layer={server.q_iters}\n" + "="*80)
    h = {k:[] for k in ["round","global_test_acc","global_test_loss",
                         "client1_val_acc","client2_val_acc","client3_val_acc","round_time"]}
    best = 0.0; streak = 0
    for rnd in range(1, nr+1):
        t0 = time.time()
        print(f"\n{'='*60} ROUND {rnd}/{nr}")
        cws = []
        for cl in clients:
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            _, va = cl.validate(); print(f"  {cl.client_id} val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cws.append(w)
        print(f"  QPSO aggregating (beta={server.beta}, iters/layer={server.q_iters})...")
        agg = server.qpso_aggregate(cws, rnd)
        server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga)
        h["global_test_loss"].append(gl); h["round_time"].append(dt)
        tag = ""
        if ga > best: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_best.pth"); tag = " *** best"
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results_phase4/qpso/metrics.csv", index=False)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s){tag}")
        best, streak, stop = _early_stop_check(rnd, best, ga, streak)
        if stop: print(f"  Early stop at round {rnd} (patience={PATIENCE}, best={best:.2f}%)"); break
    print(f"  QPSO-FL done — best {best:.2f}%"); return h

print("Training functions loaded")
# Out:
# Training functions loaded

# %%
def plot_accuracy_comparison(dfs, names, save_path):
    colors = ['#1f77b4','#ff7f0e','#2ca02c']; n = len(dfs)
    fig, axes = plt.subplots(2, max(n,2), figsize=(8*max(n,2), 12))
    fig.suptitle("Phase 4: FL Aggregation Comparison (SimpleCNN)", fontsize=16, fontweight="bold")
    ax = axes[0,0]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_acc"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Acc (%)", title="Global Test Accuracy", ylim=[0,100]); ax.legend(); ax.grid(alpha=0.3)
    ax = axes[0,1]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_loss"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Loss", title="Global Test Loss"); ax.legend(); ax.grid(alpha=0.3)
    for idx, (df, name) in enumerate(zip(dfs, names)):
        ax = axes[1, idx]
        for i in range(1,4): ax.plot(df["round"], df[f"client{i}_val_acc"], label=f"Client {i}", lw=2)
        ax.set(xlabel="Round", ylabel="Val Acc (%)", title=f"{name}: Per-Client Val"); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Saved -> {save_path}")

def generate_confusion_matrix(mp, tl, mname, dev=None, save_path=None):
    dev = dev or device; model = SimpleCNN(NUM_CLASSES).to(dev)
    model.load_state_dict(torch.load(mp, map_location=dev, weights_only=True))
    model.eval(); preds, labels = [], []
    with torch.no_grad():
        for imgs, labs in tl:
            _, pred = model(imgs.to(dev)).max(1)
            preds.extend(pred.cpu().numpy()); labels.extend(labs.numpy())
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix — {mname}", fontsize=14, fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted"); plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"\n{mname}:"); print(classification_report(labels, preds, target_names=CLASS_NAMES, digits=4))

def plot_roc_auc(mps, mnames, tl, dev=None, save_path=None):
    dev = dev or device; n = len(mps)
    fig, axes = plt.subplots(1, n, figsize=(7*n, 6))
    if n == 1: axes = [axes]
    cc = ['#e74c3c','#3498db','#2ecc71','#9b59b6']
    for ax, mp, mn in zip(axes, mps, mnames):
        model = SimpleCNN(NUM_CLASSES).to(dev)
        model.load_state_dict(torch.load(mp, map_location=dev, weights_only=True))
        model.eval(); probs, labs = [], []
        with torch.no_grad():
            for imgs, lb in tl:
                out = model(imgs.to(dev))
                probs.append(torch.softmax(out,1).cpu().numpy()); labs.extend(lb.numpy())
        yp = np.vstack(probs); yt = np.array(labs)
        if np.isnan(yp).any(): yp = np.nan_to_num(yp, nan=1.0/NUM_CLASSES)
        yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
        for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
            try:
                fpr, tpr, _ = roc_curve(yb[:,i], yp[:,i]); a = auc(fpr,tpr)
                ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.3f})")
            except: ax.plot([0,1],[0,1], color=c, lw=2, label=f"{cls} (N/A)")
        try:
            fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
            ax.plot(fpr_m, tpr_m, 'k--', lw=2, label=f"Micro ({auc(fpr_m,tpr_m):.3f})")
        except: pass
        ax.plot([0,1],[0,1],'gray',ls=':',lw=1)
        ax.set(xlabel="FPR", ylabel="TPR", title=f"ROC — {mn}"); ax.legend(loc="lower right", fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()

def plot_client_fairness(dfs, names, save_path):
    n = len(dfs); cc = ["#FF6B6B","#4ECDC4","#45B7D1"]
    fig, axes = plt.subplots(1, n, figsize=(6*n, 5))
    if n == 1: axes = [axes]
    for ax, df, t in zip(axes, dfs, names):
        accs = [df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)]
        ax.bar(["C1","C2","C3"], accs, color=cc, edgecolor="black")
        ax.axhline(np.mean(accs), color="red", ls="--", lw=2, label="Mean")
        ax.set(ylabel="Final Val Acc (%)", ylim=[0,100])
        ax.set_title(f"{t} (std={np.std(accs):.2f}%)", fontsize=13, fontweight="bold")
        ax.legend(); ax.grid(axis="y", alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()

def convergence_metrics(df, target=80.0):
    r = df[df["global_test_acc"] >= target]
    return {"final_acc":        round(df["global_test_acc"].iloc[-1], 2),
            "best_acc":         round(df["global_test_acc"].max(), 2),
            "rounds_run":       int(df["round"].max()),
            "round_to_target":  int(r["round"].min()) if len(r) else None,
            "avg_round_time_s": round(df["round_time"].mean(), 2),
            "total_time_min":   round(df["round_time"].sum() / 60, 2)}

def statistical_analysis(dfa, dfb):
    a, b = dfa["global_test_acc"].values, dfb["global_test_acc"].values
    n = min(len(a), len(b)); a, b = a[:n], b[:n]
    t_stat, p_val = stats.ttest_rel(b, a)
    d = (b-a).mean() / ((b-a).std(ddof=1) + 1e-8)
    return {"t_stat": round(float(t_stat),4), "p_value": float(p_val),
            "cohens_d": round(float(d),4), "significant": bool(p_val < 0.05)}

def build_comparison_df(*pairs):
    cols = ["Metric"] + [n for _, n in pairs]; ml = []
    for df, n in pairs:
        m = convergence_metrics(df)
        m["client_std"] = round(float(np.std([df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)])), 2)
        ml.append(m)
    keys = [("Final Acc (%)","final_acc"),("Best Acc (%)","best_acc"),
            ("Rounds Run","rounds_run"),("Rounds to 80%","round_to_target"),
            ("Avg Round (s)","avg_round_time_s"),("Total Time (min)","total_time_min"),
            ("Client Std Dev","client_std")]
    rows = [[l]+[m[k] if m[k] is not None else "N/A" for m in ml] for l, k in keys]
    return pd.DataFrame(rows, columns=cols)

print("Evaluation helpers loaded")
# Out:
# Evaluation helpers loaded

# %%
# ── Setup 2: Moderate Label Skew (70/10/10/10) ─────────────────────────────
CLIENT1_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
CLIENT2_PATH = '/kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train'
CLIENT3_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

prep = Preprocessor()
prep.process_dataset(CLIENT1_PATH, 'client1')
prep.process_dataset(CLIENT2_PATH, 'client2')
prep.process_dataset(CLIENT3_PATH, 'client3')

DOMINANT       = {1: 0, 2: 1, 3: 2}
DOMINANT_RATIO = 0.70
MINORITY_RATIO = 0.10

def augment_image(img):
    from PIL import ImageEnhance, ImageFilter
    pil = Image.fromarray((img*255).astype(np.uint8))
    if random.random() < 0.5: pil = pil.transpose(Image.FLIP_LEFT_RIGHT)
    if random.random() < 0.5: pil = pil.rotate(random.uniform(-30,30), fillcolor=(0,0,0))
    if random.random() < 0.3: pil = ImageEnhance.Brightness(pil).enhance(random.uniform(0.7,1.3))
    if random.random() < 0.3: pil = ImageEnhance.Contrast(pil).enhance(random.uniform(0.7,1.3))
    if random.random() < 0.2: pil = pil.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5,1.5)))
    return np.array(pil, dtype=np.float32) / 255.0

for cid in range(1, 4):
    d = f"/kaggle/working/data/processed/client{cid}"
    X_train = np.load(f"{d}/X_train.npy"); y_train = np.load(f"{d}/y_train.npy")
    dom_cls = DOMINANT[cid]; total = len(X_train)
    target_dom = int(total * DOMINANT_RATIO); target_min = int(total * MINORITY_RATIO)
    new_X, new_y = [], []
    for cls in range(NUM_CLASSES):
        mask = y_train == cls; X_cls = X_train[mask]
        target = target_dom if cls == dom_cls else target_min
        if len(X_cls) >= target:
            idx = np.random.choice(len(X_cls), target, replace=False)
            new_X.append(X_cls[idx]); new_y.extend([cls]*target)
        else:
            new_X.append(X_cls); new_y.extend([cls]*len(X_cls))
            for _ in range(target - len(X_cls)):
                src = X_cls[random.randint(0, len(X_cls)-1)]
                new_X.append(augment_image(src)[np.newaxis]); new_y.append(cls)
    X_new = np.concatenate(new_X); y_new = np.array(new_y)
    perm = np.random.permutation(len(X_new)); X_new = X_new[perm]; y_new = y_new[perm]
    np.save(f"{d}/X_train.npy", X_new); np.save(f"{d}/y_train.npy", y_new)
    print(f"client{cid}: dom=class{dom_cls} | dist={np.bincount(y_new, minlength=NUM_CLASSES)} | total={len(X_new)}")

Preprocessor.create_global_test()
data_loaders = create_data_loaders()

_val_ds = ConcatDataset([data_loaders[f"client{i}"]["val"].dataset for i in range(1,4)])
qpso_val_loader = DataLoader(_val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
print(f"QPSO val loader: {len(_val_ds)} samples")
print("Setup 2 data ready!")
# Out:
# ============================================================
# Processing client1 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
# ============================================================
#   glioma: 400 images (label=0)
#     glioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   meningioma: 400 images (label=1)
#     meningioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   notumor: 400 images (label=2)
#     notumor:   0%|          | 0/400 [00:00<?, ?it/s]
#   pituitary: 400 images (label=3)
#     pituitary:   0%|          | 0/400 [00:00<?, ?it/s]
#   Total: 1600 | Classes: [400 400 400 400]
#   Train:1119 Val:240 Test:241
#   Saved -> /kaggle/working/data/processed/client1
#
# ============================================================
# Processing client2 <- /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
# ============================================================
#   glioma: 1147 images (label=0)
#     glioma:   0%|          | 0/1147 [00:00<?, ?it/s]
#   meningioma: 1329 images (label=1)
#     meningioma:   0%|          | 0/1329 [00:00<?, ?it/s]
#   no_tumor: 1067 images (label=2)
#     no_tumor:   0%|          | 0/1067 [00:00<?, ?it/s]
#   pituitary: 1457 images (label=3)
#     pituitary:   0%|          | 0/1457 [00:00<?, ?it/s]
#   Total: 5000 | Classes: [1147 1329 1067 1457]
#   Train:3499 Val:750 Test:751
#   Saved -> /kaggle/working/data/processed/client2
#
# ============================================================
# Processing client3 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# ============================================================
#   glioma: 1400 images (label=0)
#     glioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   meningioma: 1400 images (label=1)
#     meningioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   notumor: 1400 images (label=2)
#     notumor:   0%|          | 0/1400 [00:00<?, ?it/s]
#   pituitary: 1400 images (label=3)
#     pituitary:   0%|          | 0/1400 [00:00<?, ?it/s]
#   Total: 5600 | Classes: [1400 1400 1400 1400]
#   Train:3919 Val:840 Test:841
#   Saved -> /kaggle/working/data/processed/client3
# client1: dom=class0 | dist=[783 111 111 111] | total=1116
# client2: dom=class1 | dist=[ 349 2449  349  349] | total=3496
# client3: dom=class2 | dist=[ 391  391 2743  391] | total=3916
# Global test: 1833 images | Classes: [442 470 432 489]
# client1: Train=1116 Val=240 Test=241
# client2: Train=3496 Val=750 Test=751
# client3: Train=3916 Val=840 Test=841
# Global test: 1833
# QPSO val loader: 1830 samples
# Setup 2 data ready!

# %%
# FedAvg
fedavg_model   = create_model(NUM_CLASSES, device)
fedavg_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                  data_loaders[f'client{i}']['val'], device=device) for i in range(1,4)]
fedavg_server  = FedAvgServer(fedavg_model, fedavg_clients, device=device)
fedavg_history = train_fedavg(fedavg_server, fedavg_clients, data_loaders['global_test'],
                               nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, se=10)
torch.cuda.empty_cache()

# FedProx
fedprox_model   = create_model(NUM_CLASSES, device)
fedprox_clients = [FedProxClient(f'client{i}', data_loaders[f'client{i}']['train'],
                   data_loaders[f'client{i}']['val'], device=device) for i in range(1,4)]
fedprox_server  = FedAvgServer(fedprox_model, fedprox_clients, device=device)
fedprox_history = train_fedprox(fedprox_server, fedprox_clients, data_loaders['global_test'],
                                 nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, mu=FEDPROX_MU, se=10)
torch.cuda.empty_cache()

# QPSO-FL (layer-by-layer, loss-minimizing)
qpso_model   = create_model(NUM_CLASSES, device)
qpso_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                data_loaders[f'client{i}']['val'], device=device) for i in range(1,4)]
qpso_server  = QPSOServer(qpso_model, qpso_clients, device=device,
                           beta=QPSO_BETA, q_iters=QPSO_ITERS,
                           val_loader=qpso_val_loader, val_batches=QPSO_VAL_BATCHES)
qpso_history = train_qpso(qpso_server, qpso_clients, data_loaders['global_test'],
                           nr=NUM_ROUNDS, le=LOCAL_EPOCHS, lr=LR, se=10)
torch.cuda.empty_cache()

print("\nAll Phase 4 Setup 1 training complete!")
# Out:
# SimpleCNN | params=155,524 | classes=4
# FedAvg Server | clients=3 total_samples=8528
# ================================================================================
#   FEDAVG  rounds=100 | epochs=1 | lr=0.01
# ================================================================================
#   R  1 | acc=23.24% loss=1.3777 (9.0s) *** best
#   R  2 | acc=26.57% loss=1.3049 (8.0s) *** best
#   R  3 | acc=35.62% loss=1.2247 (8.1s) *** best
#   R  4 | acc=46.43% loss=1.1734 (8.6s) *** best
#   R  5 | acc=57.72% loss=1.1046 (8.7s) *** best
#   R  6 | acc=54.39% loss=1.1086 (8.2s)
#   R  7 | acc=53.41% loss=1.1406 (8.3s)
#   R  8 | acc=57.94% loss=1.0364 (8.1s) *** best
#   R  9 | acc=57.72% loss=0.9451 (8.0s)
#   R 10 | acc=68.96% loss=0.8695 (8.1s) *** best
#   R 11 | acc=64.43% loss=0.8449 (8.1s)
#   R 12 | acc=59.74% loss=0.9066 (8.0s)
#   R 13 | acc=64.70% loss=0.8414 (8.0s)
#   R 14 | acc=62.36% loss=0.7970 (8.0s)
#   R 15 | acc=60.67% loss=0.8218 (8.0s)
#   R 16 | acc=67.48% loss=0.7267 (8.0s)
#   R 17 | acc=68.30% loss=0.7243 (7.8s)
#   R 18 | acc=61.87% loss=0.7753 (8.0s)
#   R 19 | acc=65.25% loss=0.7728 (7.8s)
#   R 20 | acc=69.39% loss=0.7664 (7.8s) *** best
#   R 21 | acc=73.00% loss=0.6874 (7.8s) *** best
#   R 22 | acc=65.85% loss=0.6883 (7.8s)
#   R 23 | acc=67.70% loss=0.7035 (7.9s)
#   R 24 | acc=65.41% loss=0.6871 (7.8s)
#   R 25 | acc=75.29% loss=0.6714 (7.8s) *** best
#   R 26 | acc=70.27% loss=0.7338 (7.9s)
#   R 27 | acc=74.74% loss=0.7219 (8.0s)
#   R 28 | acc=71.47% loss=0.6961 (8.0s)
#   R 29 | acc=75.61% loss=0.6654 (7.8s) *** best
#   R 30 | acc=79.49% loss=0.5971 (7.9s) *** best
#   R 31 | acc=73.76% loss=0.6954 (7.8s)
#   R 32 | acc=77.03% loss=0.6277 (7.9s)
#   R 33 | acc=75.40% loss=0.6195 (7.9s)
#   R 34 | acc=78.45% loss=0.5979 (7.8s)
#   R 35 | acc=80.03% loss=0.5712 (7.8s) *** best
#   R 36 | acc=76.81% loss=0.6299 (7.8s)
#   R 37 | acc=79.92% loss=0.5780 (7.9s)
#   R 38 | acc=81.94% loss=0.5741 (7.8s) *** best
#   R 39 | acc=79.81% loss=0.5646 (7.8s)
#   R 40 | acc=75.29% loss=0.6168 (7.8s)
#   R 41 | acc=80.63% loss=0.5466 (7.8s)
#   R 42 | acc=79.81% loss=0.6025 (7.9s)
#   R 43 | acc=76.98% loss=0.6405 (7.9s)
#   R 44 | acc=84.02% loss=0.5274 (7.9s) *** best
#   R 45 | acc=82.43% loss=0.5146 (8.0s)
#   R 46 | acc=80.69% loss=0.6067 (8.0s)
#   R 47 | acc=82.21% loss=0.5536 (8.6s)
#   R 48 | acc=67.43% loss=0.7211 (8.2s)
#   R 49 | acc=77.58% loss=0.5901 (8.2s)
#   R 50 | acc=83.74% loss=0.5144 (8.1s)
#   R 51 | acc=83.36% loss=0.5184 (8.1s)
#   R 52 | acc=83.31% loss=0.5144 (8.2s)
#   R 53 | acc=84.72% loss=0.4903 (8.1s) *** best
#   R 54 | acc=80.14% loss=0.5514 (8.6s)
#   R 55 | acc=86.09% loss=0.4773 (8.3s) *** best
#   R 56 | acc=85.82% loss=0.4902 (8.2s)
#   R 57 | acc=84.40% loss=0.4949 (8.2s)
#   R 58 | acc=85.16% loss=0.4581 (8.0s)
#   R 59 | acc=86.58% loss=0.4745 (8.1s) *** best
#   R 60 | acc=85.11% loss=0.4680 (8.3s)
#   R 61 | acc=84.34% loss=0.4819 (8.1s)
#   R 62 | acc=85.32% loss=0.4581 (8.1s)
#   R 63 | acc=86.63% loss=0.4694 (8.0s) *** best
#   R 64 | acc=85.38% loss=0.4783 (7.9s)
#   R 65 | acc=85.38% loss=0.4655 (8.0s)
#   R 66 | acc=84.67% loss=0.4597 (7.9s)
#   R 67 | acc=85.60% loss=0.4594 (7.9s)
#   R 68 | acc=86.31% loss=0.4500 (8.1s)
#   R 69 | acc=85.60% loss=0.4512 (7.9s)
#   R 70 | acc=85.82% loss=0.4724 (8.0s)
#   R 71 | acc=88.22% loss=0.4497 (8.0s) *** best
#   R 72 | acc=87.67% loss=0.4275 (8.1s)
#   R 73 | acc=86.52% loss=0.4161 (8.0s)
#   R 74 | acc=87.56% loss=0.4261 (7.8s)
#   R 75 | acc=87.83% loss=0.4113 (7.9s)
#   R 76 | acc=87.07% loss=0.4264 (8.1s)
#   R 77 | acc=86.80% loss=0.4207 (8.0s)
#   R 78 | acc=86.47% loss=0.4054 (8.0s)
#   R 79 | acc=87.40% loss=0.3807 (7.8s)
#   R 80 | acc=87.67% loss=0.4133 (8.0s)
#   R 81 | acc=88.16% loss=0.3865 (7.9s)
#   R 82 | acc=88.71% loss=0.3838 (7.8s) *** best
#   R 83 | acc=89.96% loss=0.3902 (7.9s) *** best
#   R 84 | acc=88.71% loss=0.3682 (8.0s)
#   R 85 | acc=86.58% loss=0.4148 (8.1s)
#   R 86 | acc=87.94% loss=0.3668 (7.8s)
#   R 87 | acc=87.07% loss=0.4172 (7.9s)
#   R 88 | acc=88.98% loss=0.3577 (8.0s)
#   R 89 | acc=88.87% loss=0.3793 (8.0s)
#   R 90 | acc=87.83% loss=0.4054 (7.9s)
#   R 91 | acc=90.18% loss=0.3476 (8.1s) *** best
#   R 92 | acc=88.71% loss=0.3672 (8.0s)
#   R 93 | acc=88.05% loss=0.3650 (8.1s)
#   R 94 | acc=90.56% loss=0.3006 (8.1s) *** best
#   R 95 | acc=85.92% loss=0.4073 (8.1s)
#   R 96 | acc=89.47% loss=0.3439 (8.2s)
#   R 97 | acc=87.02% loss=0.3694 (8.2s)
#   R 98 | acc=89.80% loss=0.3233 (8.4s)
#   R 99 | acc=90.13% loss=0.3406 (8.2s)
#   R100 | acc=88.16% loss=0.3624 (8.1s)
#   FedAvg done — best 90.56%
# SimpleCNN | params=155,524 | classes=4
# FedAvg Server | clients=3 total_samples=8528
# ================================================================================
#   FEDPROX  rounds=100 | epochs=1 | lr=0.01 | mu=0.01
# ================================================================================
#   R  1 | acc=23.02% loss=1.3901 (8.4s) *** best
#   R  2 | acc=55.21% loss=1.1548 (8.4s) *** best
#   R  3 | acc=60.07% loss=1.0164 (8.4s) *** best
#   R  4 | acc=68.36% loss=0.8732 (8.4s) *** best
#   R  5 | acc=68.47% loss=0.7901 (8.2s) *** best
#   R  6 | acc=71.96% loss=0.7483 (8.3s) *** best
#   R  7 | acc=70.65% loss=0.6912 (8.3s)
#   R  8 | acc=75.01% loss=0.6412 (8.2s) *** best
#   R  9 | acc=69.12% loss=0.7039 (8.3s)
#   R 10 | acc=71.30% loss=0.6650 (8.3s)
#   R 11 | acc=72.01% loss=0.6632 (8.4s)
#   R 12 | acc=76.32% loss=0.6202 (8.3s) *** best
#   R 13 | acc=73.98% loss=0.6285 (8.3s)
#   R 14 | acc=79.98% loss=0.5554 (8.1s) *** best
#   R 15 | acc=78.83% loss=0.5570 (8.4s)
#   R 16 | acc=79.81% loss=0.5625 (8.3s)
#   R 17 | acc=83.03% loss=0.4571 (8.3s) *** best
#   R 18 | acc=82.27% loss=0.5048 (8.1s)
#   R 19 | acc=72.34% loss=0.5919 (8.1s)
#   R 20 | acc=81.51% loss=0.4731 (8.2s)
#   R 21 | acc=85.32% loss=0.4616 (8.1s) *** best
#   R 22 | acc=80.80% loss=0.4790 (8.0s)
#   R 23 | acc=79.92% loss=0.4959 (8.0s)
#   R 24 | acc=85.65% loss=0.4304 (8.1s) *** best
#   R 25 | acc=84.94% loss=0.4122 (8.0s)
#   R 26 | acc=84.67% loss=0.4240 (8.2s)
#   R 27 | acc=86.69% loss=0.3808 (8.4s) *** best
#   R 28 | acc=83.03% loss=0.4357 (8.1s)
#   R 29 | acc=84.40% loss=0.4077 (8.1s)
#   R 30 | acc=84.40% loss=0.4206 (8.0s)
#   R 31 | acc=83.63% loss=0.4232 (8.2s)
#   R 32 | acc=85.92% loss=0.3845 (8.2s)
#   R 33 | acc=84.56% loss=0.4019 (8.1s)
#   R 34 | acc=87.02% loss=0.3458 (8.0s) *** best
#   R 35 | acc=83.85% loss=0.4170 (8.2s)
#   R 36 | acc=86.25% loss=0.3515 (8.1s)
#   R 37 | acc=85.22% loss=0.3764 (8.2s)
#   R 38 | acc=87.51% loss=0.3501 (8.2s) *** best
#   R 39 | acc=87.34% loss=0.3297 (8.1s)
#   R 40 | acc=88.16% loss=0.3193 (8.2s) *** best
#   R 41 | acc=88.33% loss=0.3062 (8.1s) *** best
#   R 42 | acc=84.78% loss=0.4009 (8.1s)
#   R 43 | acc=88.60% loss=0.3125 (8.1s) *** best
#   R 44 | acc=85.54% loss=0.3921 (8.2s)
#   R 45 | acc=90.02% loss=0.3006 (8.1s) *** best
#   R 46 | acc=88.98% loss=0.3158 (8.1s)
#   R 47 | acc=89.69% loss=0.3010 (8.2s)
#   R 48 | acc=89.03% loss=0.2998 (8.1s)
#   R 49 | acc=87.67% loss=0.3291 (8.2s)
#   R 50 | acc=86.74% loss=0.3692 (8.1s)
#   R 51 | acc=89.96% loss=0.3094 (8.1s)
#   R 52 | acc=89.80% loss=0.2839 (8.1s)
#   R 53 | acc=87.73% loss=0.3223 (8.1s)
#   R 54 | acc=88.87% loss=0.3007 (8.1s)
#   R 55 | acc=86.03% loss=0.3573 (8.1s)
#   R 56 | acc=89.74% loss=0.2865 (8.1s)
#   R 57 | acc=90.56% loss=0.2723 (8.2s) *** best
#   R 58 | acc=89.91% loss=0.2790 (8.3s)
#   R 59 | acc=91.27% loss=0.2685 (8.1s) *** best
#   R 60 | acc=89.03% loss=0.3083 (8.1s)
#   R 61 | acc=88.82% loss=0.3002 (8.2s)
#   R 62 | acc=90.34% loss=0.2667 (8.2s)
#   R 63 | acc=89.36% loss=0.2792 (8.1s)
#   R 64 | acc=91.87% loss=0.2574 (8.2s) *** best
#   R 65 | acc=88.65% loss=0.2924 (8.1s)
#   R 66 | acc=91.22% loss=0.2680 (8.2s)
#   R 67 | acc=90.94% loss=0.2711 (8.1s)
#   R 68 | acc=89.74% loss=0.2940 (8.1s)
#   R 69 | acc=91.05% loss=0.2634 (8.2s)
#   R 70 | acc=90.83% loss=0.2577 (8.2s)
#   R 71 | acc=91.76% loss=0.2312 (8.1s)
#   R 72 | acc=89.03% loss=0.2885 (8.1s)
#   R 73 | acc=92.09% loss=0.2356 (8.1s) *** best
#   R 74 | acc=87.02% loss=0.3556 (8.2s)
#   R 75 | acc=91.49% loss=0.2520 (8.2s)
#   R 76 | acc=92.20% loss=0.2393 (8.0s) *** best
#   R 77 | acc=92.64% loss=0.2289 (8.1s) *** best
#   R 78 | acc=92.42% loss=0.2420 (8.1s)
#   R 79 | acc=92.20% loss=0.2344 (8.1s)
#   R 80 | acc=90.73% loss=0.2601 (8.1s)
#   R 81 | acc=91.65% loss=0.2504 (8.1s)
#   R 82 | acc=90.18% loss=0.2680 (8.0s)
#   R 83 | acc=92.91% loss=0.2309 (8.1s) *** best
#   R 84 | acc=92.53% loss=0.2345 (8.1s)
#   R 85 | acc=91.38% loss=0.2633 (8.1s)
#   R 86 | acc=91.98% loss=0.2262 (8.2s)
#   R 87 | acc=90.51% loss=0.2731 (8.2s)
#   R 88 | acc=92.74% loss=0.2208 (8.1s)
#   R 89 | acc=93.02% loss=0.2155 (8.0s) *** best
#   R 90 | acc=91.87% loss=0.2471 (8.2s)
#   R 91 | acc=92.25% loss=0.2355 (8.2s)
#   R 92 | acc=92.14% loss=0.2219 (8.2s)
#   R 93 | acc=90.94% loss=0.2403 (8.2s)
#   R 94 | acc=92.91% loss=0.2223 (8.1s)
#   R 95 | acc=92.74% loss=0.2189 (8.2s)
#   R 96 | acc=92.80% loss=0.2181 (8.1s)
#   R 97 | acc=91.93% loss=0.2326 (8.1s)
#   R 98 | acc=92.42% loss=0.2165 (8.1s)
#   R 99 | acc=92.74% loss=0.2130 (8.2s)
#   R100 | acc=91.82% loss=0.2264 (8.1s)
#   FedProx done — best 93.02%
# SimpleCNN | params=155,524 | classes=4
# QPSOServer | clients=3 | beta=0.6 | iters/layer=5 | trainable_tensors=16
# ================================================================================
#   QPSO-FL (layer-by-layer)  rounds=100 | beta=0.6 | iters/layer=5
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 val=25.00%
#   client2 val=51.60%
#   client3 val=25.00%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.3813
#     iter 1/5  best_loss=1.3807
#     iter 2/5  best_loss=1.3807
#     iter 3/5  best_loss=1.3806
#     iter 4/5  best_loss=1.3802
#     iter 5/5  best_loss=1.3801
#   [Layer features.0.bias] dim=16  init_best_loss=1.3801
#     iter 1/5  best_loss=1.3801
#     iter 2/5  best_loss=1.3800
#     iter 3/5  best_loss=1.3800
#     iter 4/5  best_loss=1.3800
#     iter 5/5  best_loss=1.3800
#   [Layer features.1.weight] dim=16  init_best_loss=1.3798
#     iter 1/5  best_loss=1.3794
#     iter 2/5  best_loss=1.3794
#     iter 3/5  best_loss=1.3794
#     iter 4/5  best_loss=1.3794
#     iter 5/5  best_loss=1.3788
#   [Layer features.1.bias] dim=16  init_best_loss=1.3784
#     iter 1/5  best_loss=1.3781
#     iter 2/5  best_loss=1.3781
#     iter 3/5  best_loss=1.3781
#     iter 4/5  best_loss=1.3781
#     iter 5/5  best_loss=1.3781
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.3710
#     iter 1/5  best_loss=1.3704
#     iter 2/5  best_loss=1.3697
#     iter 3/5  best_loss=1.3685
#     iter 4/5  best_loss=1.3669
#     iter 5/5  best_loss=1.3669
#   [Layer features.4.bias] dim=32  init_best_loss=1.3669
#     iter 1/5  best_loss=1.3669
#     iter 2/5  best_loss=1.3669
#     iter 3/5  best_loss=1.3669
#     iter 4/5  best_loss=1.3668
#     iter 5/5  best_loss=1.3668
#   [Layer features.5.weight] dim=32  init_best_loss=1.3660
#     iter 1/5  best_loss=1.3660
#     iter 2/5  best_loss=1.3658
#     iter 3/5  best_loss=1.3658
#     iter 4/5  best_loss=1.3647
#     iter 5/5  best_loss=1.3646
#   [Layer features.5.bias] dim=32  init_best_loss=1.3645
#     iter 1/5  best_loss=1.3641
#     iter 2/5  best_loss=1.3641
#     iter 3/5  best_loss=1.3640
#     iter 4/5  best_loss=1.3640
#     iter 5/5  best_loss=1.3639
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.3479
#     iter 1/5  best_loss=1.3479
#     iter 2/5  best_loss=1.3438
#     iter 3/5  best_loss=1.3438
#     iter 4/5  best_loss=1.3438
#     iter 5/5  best_loss=1.3423
#   [Layer features.8.bias] dim=64  init_best_loss=1.3423
#     iter 1/5  best_loss=1.3422
#     iter 2/5  best_loss=1.3422
#     iter 3/5  best_loss=1.3422
#     iter 4/5  best_loss=1.3422
#     iter 5/5  best_loss=1.3422
#   [Layer features.9.weight] dim=64  init_best_loss=1.3412
#     iter 1/5  best_loss=1.3402
#     iter 2/5  best_loss=1.3402
#     iter 3/5  best_loss=1.3402
#     iter 4/5  best_loss=1.3393
#     iter 5/5  best_loss=1.3386
#   [Layer features.9.bias] dim=64  init_best_loss=1.3384
#     iter 1/5  best_loss=1.3384
#     iter 2/5  best_loss=1.3383
#     iter 3/5  best_loss=1.3382
#     iter 4/5  best_loss=1.3380
#     iter 5/5  best_loss=1.3380
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=3.4954
#     iter 1/5  best_loss=1.2778
#     iter 2/5  best_loss=1.2778
#     iter 3/5  best_loss=1.2690
#     iter 4/5  best_loss=1.2686
#     iter 5/5  best_loss=1.2686
#   [Layer classifier.1.bias] dim=128  init_best_loss=1.2685
#     iter 1/5  best_loss=1.2685
#     iter 2/5  best_loss=1.2685
#     iter 3/5  best_loss=1.2683
#     iter 4/5  best_loss=1.2683
#     iter 5/5  best_loss=1.2683
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.2681
#     iter 1/5  best_loss=1.2681
#     iter 2/5  best_loss=1.2681
#     iter 3/5  best_loss=1.2681
#     iter 4/5  best_loss=1.2638
#     iter 5/5  best_loss=1.2638
#   [Layer classifier.4.bias] dim=4  init_best_loss=1.2532
#     iter 1/5  best_loss=1.2520
#     iter 2/5  best_loss=1.2520
#     iter 3/5  best_loss=1.2518
#     iter 4/5  best_loss=1.2514
#     iter 5/5  best_loss=1.2512
#   QPSO aggregation complete
#   Global: acc=43.43% loss=1.2622 (74.7s) *** best
#
# ============================================================ ROUND 2/100
#   client1 val=25.00%
#   client2 val=26.53%
#   client3 val=25.00%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.3665
#     iter 1/5  best_loss=1.3658
#     iter 2/5  best_loss=1.3658
#     iter 3/5  best_loss=1.3638
#     iter 4/5  best_loss=1.3638
#     iter 5/5  best_loss=1.3638
#   [Layer features.0.bias] dim=16  init_best_loss=1.3636
#     iter 1/5  best_loss=1.3636
#     iter 2/5  best_loss=1.3636
#     iter 3/5  best_loss=1.3636
#     iter 4/5  best_loss=1.3636
#     iter 5/5  best_loss=1.3636
#   [Layer features.1.weight] dim=16  init_best_loss=1.3630
#     iter 1/5  best_loss=1.3629
#     iter 2/5  best_loss=1.3629
#     iter 3/5  best_loss=1.3627
#     iter 4/5  best_loss=1.3623
#     iter 5/5  best_loss=1.3622
#   [Layer features.1.bias] dim=16  init_best_loss=1.3619
#     iter 1/5  best_loss=1.3611
#     iter 2/5  best_loss=1.3604
#     iter 3/5  best_loss=1.3602
#     iter 4/5  best_loss=1.3601
#     iter 5/5  best_loss=1.3601
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.3455
#     iter 1/5  best_loss=1.3455
#     iter 2/5  best_loss=1.3455
#     iter 3/5  best_loss=1.3435
#     iter 4/5  best_loss=1.3421
#     iter 5/5  best_loss=1.3415
#   [Layer features.4.bias] dim=32  init_best_loss=1.3415
#     iter 1/5  best_loss=1.3414
#     iter 2/5  best_loss=1.3414
#     iter 3/5  best_loss=1.3414
#     iter 4/5  best_loss=1.3414
#     iter 5/5  best_loss=1.3414
#   [Layer features.5.weight] dim=32  init_best_loss=1.3408
#     iter 1/5  best_loss=1.3400
#     iter 2/5  best_loss=1.3389
#     iter 3/5  best_loss=1.3389
#     iter 4/5  best_loss=1.3389
#     iter 5/5  best_loss=1.3385
#   [Layer features.5.bias] dim=32  init_best_loss=1.3362
#     iter 1/5  best_loss=1.3362
#     iter 2/5  best_loss=1.3358
#     iter 3/5  best_loss=1.3358
#     iter 4/5  best_loss=1.3358
#     iter 5/5  best_loss=1.3344
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.3004
#     iter 1/5  best_loss=1.2882
#     iter 2/5  best_loss=1.2882
#     iter 3/5  best_loss=1.2882
#     iter 4/5  best_loss=1.2882
#     iter 5/5  best_loss=1.2847
#   [Layer features.8.bias] dim=64  init_best_loss=1.2847
#     iter 1/5  best_loss=1.2847
#     iter 2/5  best_loss=1.2847
#     iter 3/5  best_loss=1.2847
#     iter 4/5  best_loss=1.2847
#     iter 5/5  best_loss=1.2847
#   [Layer features.9.weight] dim=64  init_best_loss=1.2831
#     iter 1/5  best_loss=1.2821
#     iter 2/5  best_loss=1.2821
#     iter 3/5  best_loss=1.2821
#     iter 4/5  best_loss=1.2814
#     iter 5/5  best_loss=1.2813
#   [Layer features.9.bias] dim=64  init_best_loss=1.2790
#     iter 1/5  best_loss=1.2785
#     iter 2/5  best_loss=1.2778
#     iter 3/5  best_loss=1.2778
#     iter 4/5  best_loss=1.2778
#     iter 5/5  best_loss=1.2768
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=1.2764
#     iter 1/5  best_loss=1.2612
#     iter 2/5  best_loss=1.2361
#     iter 3/5  best_loss=1.2361
#     iter 4/5  best_loss=1.2307
#     iter 5/5  best_loss=1.2307
#   [Layer classifier.1.bias] dim=128  init_best_loss=1.2304
#     iter 1/5  best_loss=1.2304
#     iter 2/5  best_loss=1.2301
#     iter 3/5  best_loss=1.2300
#     iter 4/5  best_loss=1.2296
#     iter 5/5  best_loss=1.2291
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.2919
#     iter 1/5  best_loss=1.2795
#     iter 2/5  best_loss=1.2525
#     iter 3/5  best_loss=1.2360
#     iter 4/5  best_loss=1.2312
#     iter 5/5  best_loss=1.2312
#   [Layer classifier.4.bias] dim=4  init_best_loss=1.2282
#     iter 1/5  best_loss=1.2282
#     iter 2/5  best_loss=1.2275
#     iter 3/5  best_loss=1.2145
#     iter 4/5  best_loss=1.2064
#     iter 5/5  best_loss=1.2048
#   QPSO aggregation complete
#   Global: acc=52.21% loss=1.2289 (75.8s) *** best
#
# ============================================================ ROUND 3/100
#   client1 val=25.00%
#   client2 val=26.53%
#   client3 val=52.26%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.3921
#     iter 1/5  best_loss=1.3069
#     iter 2/5  best_loss=1.3069
#     iter 3/5  best_loss=1.3069
#     iter 4/5  best_loss=1.3036
#     iter 5/5  best_loss=1.3036
#   [Layer features.0.bias] dim=16  init_best_loss=1.3036
#     iter 1/5  best_loss=1.3034
#     iter 2/5  best_loss=1.3030
#     iter 3/5  best_loss=1.3030
#     iter 4/5  best_loss=1.3030
#     iter 5/5  best_loss=1.3030
#   [Layer features.1.weight] dim=16  init_best_loss=1.2984
#     iter 1/5  best_loss=1.2971
#     iter 2/5  best_loss=1.2960
#     iter 3/5  best_loss=1.2953
#     iter 4/5  best_loss=1.2953
#     iter 5/5  best_loss=1.2952
#   [Layer features.1.bias] dim=16  init_best_loss=1.2947
#     iter 1/5  best_loss=1.2943
#     iter 2/5  best_loss=1.2932
#     iter 3/5  best_loss=1.2931
#     iter 4/5  best_loss=1.2931
#     iter 5/5  best_loss=1.2931
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.3081
#     iter 1/5  best_loss=1.2754
#     iter 2/5  best_loss=1.2709
#     iter 3/5  best_loss=1.2678
#     iter 4/5  best_loss=1.2672
#     iter 5/5  best_loss=1.2655
#   [Layer features.4.bias] dim=32  init_best_loss=1.2655
#     iter 1/5  best_loss=1.2654
#     iter 2/5  best_loss=1.2654
#     iter 3/5  best_loss=1.2654
#     iter 4/5  best_loss=1.2654
#     iter 5/5  best_loss=1.2654
#   [Layer features.5.weight] dim=32  init_best_loss=1.2628
#     iter 1/5  best_loss=1.2628
#     iter 2/5  best_loss=1.2605
#     iter 3/5  best_loss=1.2605
#     iter 4/5  best_loss=1.2598
#     iter 5/5  best_loss=1.2577
#   [Layer features.5.bias] dim=32  init_best_loss=1.2568
#     iter 1/5  best_loss=1.2563
#     iter 2/5  best_loss=1.2553
#     iter 3/5  best_loss=1.2548
#     iter 4/5  best_loss=1.2548
#     iter 5/5  best_loss=1.2544
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.2560
#     iter 1/5  best_loss=1.2355
#     iter 2/5  best_loss=1.2267
#     iter 3/5  best_loss=1.2213
#     iter 4/5  best_loss=1.2213
#     iter 5/5  best_loss=1.2182
#   [Layer features.8.bias] dim=64  init_best_loss=1.2182
#     iter 1/5  best_loss=1.2182
#     iter 2/5  best_loss=1.2182
#     iter 3/5  best_loss=1.2182
#     iter 4/5  best_loss=1.2182
#     iter 5/5  best_loss=1.2182
#   [Layer features.9.weight] dim=64  init_best_loss=1.2173
#     iter 1/5  best_loss=1.2160
#     iter 2/5  best_loss=1.2160
#     iter 3/5  best_loss=1.2148
#     iter 4/5  best_loss=1.2148
#     iter 5/5  best_loss=1.2137
#   [Layer features.9.bias] dim=64  init_best_loss=1.2124
#     iter 1/5  best_loss=1.2124
#     iter 2/5  best_loss=1.2124
#     iter 3/5  best_loss=1.2124
#     iter 4/5  best_loss=1.2121
#     iter 5/5  best_loss=1.2113
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=1.2741
#     iter 1/5  best_loss=1.2301
#     iter 2/5  best_loss=1.2301
#     iter 3/5  best_loss=1.2144
#     iter 4/5  best_loss=1.2125
#     iter 5/5  best_loss=1.2125
#   [Layer classifier.1.bias] dim=128  init_best_loss=1.2121
#     iter 1/5  best_loss=1.2121
#     iter 2/5  best_loss=1.2119
#     iter 3/5  best_loss=1.2115
#     iter 4/5  best_loss=1.2115
#     iter 5/5  best_loss=1.2115
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.3289
#     iter 1/5  best_loss=1.2624
#     iter 2/5  best_loss=1.2400
#     iter 3/5  best_loss=1.2400
#     iter 4/5  best_loss=1.2400
#     iter 5/5  best_loss=1.2092
#   [Layer classifier.4.bias] dim=4  init_best_loss=1.2038
#     iter 1/5  best_loss=1.2038
#     iter 2/5  best_loss=1.1945
#     iter 3/5  best_loss=1.1945
#     iter 4/5  best_loss=1.1945
#     iter 5/5  best_loss=1.1941
#   QPSO aggregation complete
#   Global: acc=48.88% loss=1.2017 (76.3s)
#
# ============================================================ ROUND 4/100
#   client1 val=29.17%
#   client2 val=34.67%
#   client3 val=63.93%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.2246
#     iter 1/5  best_loss=1.2246
#     iter 2/5  best_loss=1.2094
#     iter 3/5  best_loss=1.2092
#     iter 4/5  best_loss=1.2092
#     iter 5/5  best_loss=1.2092
#   [Layer features.0.bias] dim=16  init_best_loss=1.2091
#     iter 1/5  best_loss=1.2091
#     iter 2/5  best_loss=1.2091
#     iter 3/5  best_loss=1.2090
#     iter 4/5  best_loss=1.2089
#     iter 5/5  best_loss=1.2088
#   [Layer features.1.weight] dim=16  init_best_loss=1.2067
#     iter 1/5  best_loss=1.2064
#     iter 2/5  best_loss=1.2064
#     iter 3/5  best_loss=1.2058
#     iter 4/5  best_loss=1.2048
#     iter 5/5  best_loss=1.2048
#   [Layer features.1.bias] dim=16  init_best_loss=1.2039
#     iter 1/5  best_loss=1.2023
#     iter 2/5  best_loss=1.2022
#     iter 3/5  best_loss=1.2018
#     iter 4/5  best_loss=1.2018
#     iter 5/5  best_loss=1.2016
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.2429
#     iter 1/5  best_loss=1.2022
#     iter 2/5  best_loss=1.2002
#     iter 3/5  best_loss=1.1985
#     iter 4/5  best_loss=1.1924
#     iter 5/5  best_loss=1.1923
#   [Layer features.4.bias] dim=32  init_best_loss=1.1923
#     iter 1/5  best_loss=1.1923
#     iter 2/5  best_loss=1.1923
#     iter 3/5  best_loss=1.1923
#     iter 4/5  best_loss=1.1923
#     iter 5/5  best_loss=1.1923
#   [Layer features.5.weight] dim=32  init_best_loss=1.1880
#     iter 1/5  best_loss=1.1880
#     iter 2/5  best_loss=1.1877
#     iter 3/5  best_loss=1.1875
#     iter 4/5  best_loss=1.1872
#     iter 5/5  best_loss=1.1871
#   [Layer features.5.bias] dim=32  init_best_loss=1.1857
#     iter 1/5  best_loss=1.1857
#     iter 2/5  best_loss=1.1857
#     iter 3/5  best_loss=1.1855
#     iter 4/5  best_loss=1.1854
#     iter 5/5  best_loss=1.1849
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.1755
#     iter 1/5  best_loss=1.1751
#     iter 2/5  best_loss=1.1701
#     iter 3/5  best_loss=1.1677
#     iter 4/5  best_loss=1.1667
#     iter 5/5  best_loss=1.1666
#   [Layer features.8.bias] dim=64  init_best_loss=1.1666
#     iter 1/5  best_loss=1.1666
#     iter 2/5  best_loss=1.1666
#     iter 3/5  best_loss=1.1666
#     iter 4/5  best_loss=1.1666
#     iter 5/5  best_loss=1.1666
#   [Layer features.9.weight] dim=64  init_best_loss=1.1659
#     iter 1/5  best_loss=1.1658
#     iter 2/5  best_loss=1.1657
#     iter 3/5  best_loss=1.1651
#     iter 4/5  best_loss=1.1649
#     iter 5/5  best_loss=1.1642
#   [Layer features.9.bias] dim=64  init_best_loss=1.1630
#     iter 1/5  best_loss=1.1630
#     iter 2/5  best_loss=1.1620
#     iter 3/5  best_loss=1.1617
#     iter 4/5  best_loss=1.1616
#     iter 5/5  best_loss=1.1613
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=1.1310
#     iter 1/5  best_loss=1.1310
#     iter 2/5  best_loss=1.1205
#     iter 3/5  best_loss=1.1196
#     iter 4/5  best_loss=1.1190
#     iter 5/5  best_loss=1.1167
#   [Layer classifier.1.bias] dim=128  init_best_loss=1.1163
#     iter 1/5  best_loss=1.1163
#     iter 2/5  best_loss=1.1163
#     iter 3/5  best_loss=1.1161
#     iter 4/5  best_loss=1.1161
#     iter 5/5  best_loss=1.1161
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.3032
#     iter 1/5  best_loss=1.2339
#     iter 2/5  best_loss=1.0882
#     iter 3/5  best_loss=1.0799
#     iter 4/5  best_loss=1.0799
#     iter 5/5  best_loss=1.0713
#   [Layer classifier.4.bias] dim=4  init_best_loss=1.0691
#     iter 1/5  best_loss=1.0568
#     iter 2/5  best_loss=1.0527
#     iter 3/5  best_loss=1.0507
#     iter 4/5  best_loss=1.0506
#     iter 5/5  best_loss=1.0505
#   QPSO aggregation complete
#   Global: acc=64.05% loss=1.0234 (76.6s) *** best
#
# ============================================================ ROUND 5/100
#   client1 val=44.17%
#   client2 val=45.07%
#   client3 val=54.88%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.0632
#     iter 1/5  best_loss=1.0632
#     iter 2/5  best_loss=1.0510
#     iter 3/5  best_loss=1.0459
#     iter 4/5  best_loss=1.0445
#     iter 5/5  best_loss=1.0445
#   [Layer features.0.bias] dim=16  init_best_loss=1.0444
#     iter 1/5  best_loss=1.0444
#     iter 2/5  best_loss=1.0444
#     iter 3/5  best_loss=1.0444
#     iter 4/5  best_loss=1.0444
#     iter 5/5  best_loss=1.0443
#   [Layer features.1.weight] dim=16  init_best_loss=1.0426
#     iter 1/5  best_loss=1.0415
#     iter 2/5  best_loss=1.0415
#     iter 3/5  best_loss=1.0414
#     iter 4/5  best_loss=1.0409
#     iter 5/5  best_loss=1.0398
#   [Layer features.1.bias] dim=16  init_best_loss=1.0359
#     iter 1/5  best_loss=1.0351
#     iter 2/5  best_loss=1.0346
#     iter 3/5  best_loss=1.0346
#     iter 4/5  best_loss=1.0341
#     iter 5/5  best_loss=1.0327
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.0540
#     iter 1/5  best_loss=1.0378
#     iter 2/5  best_loss=1.0309
#     iter 3/5  best_loss=1.0286
#     iter 4/5  best_loss=1.0271
#     iter 5/5  best_loss=1.0264
#   [Layer features.4.bias] dim=32  init_best_loss=1.0264
#     iter 1/5  best_loss=1.0264
#     iter 2/5  best_loss=1.0264
#     iter 3/5  best_loss=1.0264
#     iter 4/5  best_loss=1.0264
#     iter 5/5  best_loss=1.0264
#   [Layer features.5.weight] dim=32  init_best_loss=1.0254
#     iter 1/5  best_loss=1.0244
#     iter 2/5  best_loss=1.0244
#     iter 3/5  best_loss=1.0239
#     iter 4/5  best_loss=1.0239
#     iter 5/5  best_loss=1.0236
#   [Layer features.5.bias] dim=32  init_best_loss=1.0235
#     iter 1/5  best_loss=1.0235
#     iter 2/5  best_loss=1.0220
#     iter 3/5  best_loss=1.0220
#     iter 4/5  best_loss=1.0218
#     iter 5/5  best_loss=1.0211
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.0238
#     iter 1/5  best_loss=1.0238
#     iter 2/5  best_loss=1.0138
#     iter 3/5  best_loss=1.0119
#     iter 4/5  best_loss=1.0101
#     iter 5/5  best_loss=1.0101
#   [Layer features.8.bias] dim=64  init_best_loss=1.0100
#     iter 1/5  best_loss=1.0100
#     iter 2/5  best_loss=1.0100
#     iter 3/5  best_loss=1.0100
#     iter 4/5  best_loss=1.0100
#     iter 5/5  best_loss=1.0100
#   [Layer features.9.weight] dim=64  init_best_loss=1.0091
#     iter 1/5  best_loss=1.0071
#     iter 2/5  best_loss=1.0069
#     iter 3/5  best_loss=1.0058
#     iter 4/5  best_loss=1.0050
#     iter 5/5  best_loss=1.0050
#   [Layer features.9.bias] dim=64  init_best_loss=1.0041
#     iter 1/5  best_loss=1.0040
#     iter 2/5  best_loss=1.0040
#     iter 3/5  best_loss=1.0034
#     iter 4/5  best_loss=1.0029
#     iter 5/5  best_loss=1.0029
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=1.0504
#     iter 1/5  best_loss=1.0152
#     iter 2/5  best_loss=1.0010
#     iter 3/5  best_loss=1.0010
#     iter 4/5  best_loss=1.0010
#     iter 5/5  best_loss=1.0010
#   [Layer classifier.1.bias] dim=128  init_best_loss=1.0007
#     iter 1/5  best_loss=1.0007
#     iter 2/5  best_loss=1.0007
#     iter 3/5  best_loss=1.0007
#     iter 4/5  best_loss=1.0007
#     iter 5/5  best_loss=1.0007
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.1648
#     iter 1/5  best_loss=1.1181
#     iter 2/5  best_loss=1.0263
#     iter 3/5  best_loss=1.0263
#     iter 4/5  best_loss=1.0213
#     iter 5/5  best_loss=1.0213
#   [Layer classifier.4.bias] dim=4  init_best_loss=1.0282
#     iter 1/5  best_loss=1.0059
#     iter 2/5  best_loss=1.0057
#     iter 3/5  best_loss=0.9986
#     iter 4/5  best_loss=0.9986
#     iter 5/5  best_loss=0.9986
#   QPSO aggregation complete
#   Global: acc=66.61% loss=0.9223 (73.1s) *** best
#
# ============================================================ ROUND 6/100
#   client1 val=28.75%
#   client2 val=54.80%
#   client3 val=57.14%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.0802
#     iter 1/5  best_loss=0.9953
#     iter 2/5  best_loss=0.9953
#     iter 3/5  best_loss=0.9867
#     iter 4/5  best_loss=0.9819
#     iter 5/5  best_loss=0.9813
#   [Layer features.0.bias] dim=16  init_best_loss=0.9810
#     iter 1/5  best_loss=0.9810
#     iter 2/5  best_loss=0.9809
#     iter 3/5  best_loss=0.9809
#     iter 4/5  best_loss=0.9807
#     iter 5/5  best_loss=0.9807
#   [Layer features.1.weight] dim=16  init_best_loss=0.9818
#     iter 1/5  best_loss=0.9795
#     iter 2/5  best_loss=0.9792
#     iter 3/5  best_loss=0.9777
#     iter 4/5  best_loss=0.9764
#     iter 5/5  best_loss=0.9764
#   [Layer features.1.bias] dim=16  init_best_loss=0.9752
#     iter 1/5  best_loss=0.9745
#     iter 2/5  best_loss=0.9745
#     iter 3/5  best_loss=0.9743
#     iter 4/5  best_loss=0.9739
#     iter 5/5  best_loss=0.9738
#   [Layer features.4.weight] dim=4,608  init_best_loss=1.0027
#     iter 1/5  best_loss=0.9760
#     iter 2/5  best_loss=0.9716
#     iter 3/5  best_loss=0.9709
#     iter 4/5  best_loss=0.9708
#     iter 5/5  best_loss=0.9680
#   [Layer features.4.bias] dim=32  init_best_loss=0.9680
#     iter 1/5  best_loss=0.9680
#     iter 2/5  best_loss=0.9680
#     iter 3/5  best_loss=0.9680
#     iter 4/5  best_loss=0.9680
#     iter 5/5  best_loss=0.9680
#   [Layer features.5.weight] dim=32  init_best_loss=0.9676
#     iter 1/5  best_loss=0.9669
#     iter 2/5  best_loss=0.9668
#     iter 3/5  best_loss=0.9665
#     iter 4/5  best_loss=0.9665
#     iter 5/5  best_loss=0.9663
#   [Layer features.5.bias] dim=32  init_best_loss=0.9651
#     iter 1/5  best_loss=0.9651
#     iter 2/5  best_loss=0.9649
#     iter 3/5  best_loss=0.9643
#     iter 4/5  best_loss=0.9643
#     iter 5/5  best_loss=0.9643
#   [Layer features.8.weight] dim=18,432  init_best_loss=1.0300
#     iter 1/5  best_loss=0.9718
#     iter 2/5  best_loss=0.9644
#     iter 3/5  best_loss=0.9640
#     iter 4/5  best_loss=0.9635
#     iter 5/5  best_loss=0.9633
#   [Layer features.8.bias] dim=64  init_best_loss=0.9633
#     iter 1/5  best_loss=0.9633
#     iter 2/5  best_loss=0.9633
#     iter 3/5  best_loss=0.9633
#     iter 4/5  best_loss=0.9633
#     iter 5/5  best_loss=0.9633
#   [Layer features.9.weight] dim=64  init_best_loss=0.9623
#     iter 1/5  best_loss=0.9611
#     iter 2/5  best_loss=0.9609
#     iter 3/5  best_loss=0.9607
#     iter 4/5  best_loss=0.9602
#     iter 5/5  best_loss=0.9594
#   [Layer features.9.bias] dim=64  init_best_loss=0.9607
#     iter 1/5  best_loss=0.9576
#     iter 2/5  best_loss=0.9576
#     iter 3/5  best_loss=0.9574
#     iter 4/5  best_loss=0.9564
#     iter 5/5  best_loss=0.9563
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=1.0006
#     iter 1/5  best_loss=0.9594
#     iter 2/5  best_loss=0.9572
#     iter 3/5  best_loss=0.9538
#     iter 4/5  best_loss=0.9493
#     iter 5/5  best_loss=0.9493
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.9492
#     iter 1/5  best_loss=0.9492
#     iter 2/5  best_loss=0.9490
#     iter 3/5  best_loss=0.9488
#     iter 4/5  best_loss=0.9487
#     iter 5/5  best_loss=0.9487
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.0750
#     iter 1/5  best_loss=0.9778
#     iter 2/5  best_loss=0.9745
#     iter 3/5  best_loss=0.9745
#     iter 4/5  best_loss=0.9670
#     iter 5/5  best_loss=0.9561
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.9555
#     iter 1/5  best_loss=0.9494
#     iter 2/5  best_loss=0.9459
#     iter 3/5  best_loss=0.9459
#     iter 4/5  best_loss=0.9454
#     iter 5/5  best_loss=0.9445
#   QPSO aggregation complete
#   Global: acc=70.05% loss=0.8577 (72.5s) *** best
#
# ============================================================ ROUND 7/100
#   client1 val=25.42%
#   client2 val=56.40%
#   client3 val=31.90%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=1.0393
#     iter 1/5  best_loss=0.9529
#     iter 2/5  best_loss=0.9529
#     iter 3/5  best_loss=0.9529
#     iter 4/5  best_loss=0.9529
#     iter 5/5  best_loss=0.9529
#   [Layer features.0.bias] dim=16  init_best_loss=0.9516
#     iter 1/5  best_loss=0.9508
#     iter 2/5  best_loss=0.9507
#     iter 3/5  best_loss=0.9500
#     iter 4/5  best_loss=0.9497
#     iter 5/5  best_loss=0.9496
#   [Layer features.1.weight] dim=16  init_best_loss=0.9459
#     iter 1/5  best_loss=0.9445
#     iter 2/5  best_loss=0.9404
#     iter 3/5  best_loss=0.9384
#     iter 4/5  best_loss=0.9376
#     iter 5/5  best_loss=0.9376
#   [Layer features.1.bias] dim=16  init_best_loss=0.9400
#     iter 1/5  best_loss=0.9391
#     iter 2/5  best_loss=0.9376
#     iter 3/5  best_loss=0.9376
#     iter 4/5  best_loss=0.9364
#     iter 5/5  best_loss=0.9359
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.9335
#     iter 1/5  best_loss=0.9335
#     iter 2/5  best_loss=0.9301
#     iter 3/5  best_loss=0.9256
#     iter 4/5  best_loss=0.9245
#     iter 5/5  best_loss=0.9231
#   [Layer features.4.bias] dim=32  init_best_loss=0.9231
#     iter 1/5  best_loss=0.9231
#     iter 2/5  best_loss=0.9231
#     iter 3/5  best_loss=0.9231
#     iter 4/5  best_loss=0.9230
#     iter 5/5  best_loss=0.9230
#   [Layer features.5.weight] dim=32  init_best_loss=0.9250
#     iter 1/5  best_loss=0.9236
#     iter 2/5  best_loss=0.9202
#     iter 3/5  best_loss=0.9194
#     iter 4/5  best_loss=0.9193
#     iter 5/5  best_loss=0.9189
#   [Layer features.5.bias] dim=32  init_best_loss=0.9200
#     iter 1/5  best_loss=0.9193
#     iter 2/5  best_loss=0.9193
#     iter 3/5  best_loss=0.9193
#     iter 4/5  best_loss=0.9192
#     iter 5/5  best_loss=0.9186
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.9312
#     iter 1/5  best_loss=0.9206
#     iter 2/5  best_loss=0.9206
#     iter 3/5  best_loss=0.9185
#     iter 4/5  best_loss=0.9178
#     iter 5/5  best_loss=0.9174
#   [Layer features.8.bias] dim=64  init_best_loss=0.9174
#     iter 1/5  best_loss=0.9174
#     iter 2/5  best_loss=0.9174
#     iter 3/5  best_loss=0.9174
#     iter 4/5  best_loss=0.9174
#     iter 5/5  best_loss=0.9174
#   [Layer features.9.weight] dim=64  init_best_loss=0.9157
#     iter 1/5  best_loss=0.9157
#     iter 2/5  best_loss=0.9157
#     iter 3/5  best_loss=0.9157
#     iter 4/5  best_loss=0.9154
#     iter 5/5  best_loss=0.9153
#   [Layer features.9.bias] dim=64  init_best_loss=0.9152
#     iter 1/5  best_loss=0.9152
#     iter 2/5  best_loss=0.9144
#     iter 3/5  best_loss=0.9132
#     iter 4/5  best_loss=0.9132
#     iter 5/5  best_loss=0.9132
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.9614
#     iter 1/5  best_loss=0.9204
#     iter 2/5  best_loss=0.9046
#     iter 3/5  best_loss=0.9007
#     iter 4/5  best_loss=0.8999
#     iter 5/5  best_loss=0.8999
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.8997
#     iter 1/5  best_loss=0.8995
#     iter 2/5  best_loss=0.8995
#     iter 3/5  best_loss=0.8995
#     iter 4/5  best_loss=0.8995
#     iter 5/5  best_loss=0.8995
#   [Layer classifier.4.weight] dim=512  init_best_loss=1.0258
#     iter 1/5  best_loss=0.8842
#     iter 2/5  best_loss=0.8842
#     iter 3/5  best_loss=0.8842
#     iter 4/5  best_loss=0.8842
#     iter 5/5  best_loss=0.8842
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.8875
#     iter 1/5  best_loss=0.8855
#     iter 2/5  best_loss=0.8855
#     iter 3/5  best_loss=0.8773
#     iter 4/5  best_loss=0.8773
#     iter 5/5  best_loss=0.8773
#   QPSO aggregation complete
#   Global: acc=73.38% loss=0.8057 (71.8s) *** best
#
# ============================================================ ROUND 8/100
#   client1 val=33.33%
#   client2 val=29.20%
#   client3 val=47.74%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.9150
#     iter 1/5  best_loss=0.9125
#     iter 2/5  best_loss=0.8608
#     iter 3/5  best_loss=0.8608
#     iter 4/5  best_loss=0.8608
#     iter 5/5  best_loss=0.8543
#   [Layer features.0.bias] dim=16  init_best_loss=0.8529
#     iter 1/5  best_loss=0.8523
#     iter 2/5  best_loss=0.8504
#     iter 3/5  best_loss=0.8504
#     iter 4/5  best_loss=0.8504
#     iter 5/5  best_loss=0.8504
#   [Layer features.1.weight] dim=16  init_best_loss=0.8453
#     iter 1/5  best_loss=0.8453
#     iter 2/5  best_loss=0.8424
#     iter 3/5  best_loss=0.8418
#     iter 4/5  best_loss=0.8418
#     iter 5/5  best_loss=0.8410
#   [Layer features.1.bias] dim=16  init_best_loss=0.8393
#     iter 1/5  best_loss=0.8380
#     iter 2/5  best_loss=0.8374
#     iter 3/5  best_loss=0.8363
#     iter 4/5  best_loss=0.8358
#     iter 5/5  best_loss=0.8354
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.8511
#     iter 1/5  best_loss=0.8273
#     iter 2/5  best_loss=0.8211
#     iter 3/5  best_loss=0.8211
#     iter 4/5  best_loss=0.8207
#     iter 5/5  best_loss=0.8207
#   [Layer features.4.bias] dim=32  init_best_loss=0.8207
#     iter 1/5  best_loss=0.8207
#     iter 2/5  best_loss=0.8207
#     iter 3/5  best_loss=0.8207
#     iter 4/5  best_loss=0.8207
#     iter 5/5  best_loss=0.8207
#   [Layer features.5.weight] dim=32  init_best_loss=0.8217
#     iter 1/5  best_loss=0.8217
#     iter 2/5  best_loss=0.8217
#     iter 3/5  best_loss=0.8216
#     iter 4/5  best_loss=0.8216
#     iter 5/5  best_loss=0.8214
#   [Layer features.5.bias] dim=32  init_best_loss=0.8230
#     iter 1/5  best_loss=0.8225
#     iter 2/5  best_loss=0.8222
#     iter 3/5  best_loss=0.8222
#     iter 4/5  best_loss=0.8213
#     iter 5/5  best_loss=0.8212
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.8399
#     iter 1/5  best_loss=0.8399
#     iter 2/5  best_loss=0.8236
#     iter 3/5  best_loss=0.8236
#     iter 4/5  best_loss=0.8217
#     iter 5/5  best_loss=0.8210
#   [Layer features.8.bias] dim=64  init_best_loss=0.8210
#     iter 1/5  best_loss=0.8210
#     iter 2/5  best_loss=0.8210
#     iter 3/5  best_loss=0.8210
#     iter 4/5  best_loss=0.8210
#     iter 5/5  best_loss=0.8210
#   [Layer features.9.weight] dim=64  init_best_loss=0.8227
#     iter 1/5  best_loss=0.8212
#     iter 2/5  best_loss=0.8194
#     iter 3/5  best_loss=0.8193
#     iter 4/5  best_loss=0.8187
#     iter 5/5  best_loss=0.8181
#   [Layer features.9.bias] dim=64  init_best_loss=0.8174
#     iter 1/5  best_loss=0.8174
#     iter 2/5  best_loss=0.8174
#     iter 3/5  best_loss=0.8174
#     iter 4/5  best_loss=0.8165
#     iter 5/5  best_loss=0.8159
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.8545
#     iter 1/5  best_loss=0.8545
#     iter 2/5  best_loss=0.8172
#     iter 3/5  best_loss=0.8172
#     iter 4/5  best_loss=0.8172
#     iter 5/5  best_loss=0.8127
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.8122
#     iter 1/5  best_loss=0.8120
#     iter 2/5  best_loss=0.8120
#     iter 3/5  best_loss=0.8120
#     iter 4/5  best_loss=0.8120
#     iter 5/5  best_loss=0.8118
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.8559
#     iter 1/5  best_loss=0.8289
#     iter 2/5  best_loss=0.8200
#     iter 3/5  best_loss=0.8139
#     iter 4/5  best_loss=0.8108
#     iter 5/5  best_loss=0.8067
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.8062
#     iter 1/5  best_loss=0.7932
#     iter 2/5  best_loss=0.7894
#     iter 3/5  best_loss=0.7842
#     iter 4/5  best_loss=0.7842
#     iter 5/5  best_loss=0.7842
#   QPSO aggregation complete
#   Global: acc=72.07% loss=0.7467 (73.9s)
#
# ============================================================ ROUND 9/100
#   client1 val=48.33%
#   client2 val=53.87%
#   client3 val=73.57%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.8636
#     iter 1/5  best_loss=0.8636
#     iter 2/5  best_loss=0.8636
#     iter 3/5  best_loss=0.8636
#     iter 4/5  best_loss=0.8389
#     iter 5/5  best_loss=0.8389
#   [Layer features.0.bias] dim=16  init_best_loss=0.8381
#     iter 1/5  best_loss=0.8381
#     iter 2/5  best_loss=0.8348
#     iter 3/5  best_loss=0.8326
#     iter 4/5  best_loss=0.8316
#     iter 5/5  best_loss=0.8309
#   [Layer features.1.weight] dim=16  init_best_loss=0.8129
#     iter 1/5  best_loss=0.8129
#     iter 2/5  best_loss=0.8129
#     iter 3/5  best_loss=0.8125
#     iter 4/5  best_loss=0.8113
#     iter 5/5  best_loss=0.8113
#   [Layer features.1.bias] dim=16  init_best_loss=0.8022
#     iter 1/5  best_loss=0.8022
#     iter 2/5  best_loss=0.8022
#     iter 3/5  best_loss=0.8022
#     iter 4/5  best_loss=0.7998
#     iter 5/5  best_loss=0.7998
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.8426
#     iter 1/5  best_loss=0.7562
#     iter 2/5  best_loss=0.7544
#     iter 3/5  best_loss=0.7544
#     iter 4/5  best_loss=0.7523
#     iter 5/5  best_loss=0.7523
#   [Layer features.4.bias] dim=32  init_best_loss=0.7522
#     iter 1/5  best_loss=0.7522
#     iter 2/5  best_loss=0.7522
#     iter 3/5  best_loss=0.7522
#     iter 4/5  best_loss=0.7522
#     iter 5/5  best_loss=0.7522
#   [Layer features.5.weight] dim=32  init_best_loss=0.7519
#     iter 1/5  best_loss=0.7506
#     iter 2/5  best_loss=0.7445
#     iter 3/5  best_loss=0.7440
#     iter 4/5  best_loss=0.7436
#     iter 5/5  best_loss=0.7434
#   [Layer features.5.bias] dim=32  init_best_loss=0.7436
#     iter 1/5  best_loss=0.7436
#     iter 2/5  best_loss=0.7436
#     iter 3/5  best_loss=0.7436
#     iter 4/5  best_loss=0.7436
#     iter 5/5  best_loss=0.7435
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.7521
#     iter 1/5  best_loss=0.7521
#     iter 2/5  best_loss=0.7428
#     iter 3/5  best_loss=0.7376
#     iter 4/5  best_loss=0.7376
#     iter 5/5  best_loss=0.7376
#   [Layer features.8.bias] dim=64  init_best_loss=0.7376
#     iter 1/5  best_loss=0.7376
#     iter 2/5  best_loss=0.7376
#     iter 3/5  best_loss=0.7376
#     iter 4/5  best_loss=0.7376
#     iter 5/5  best_loss=0.7376
#   [Layer features.9.weight] dim=64  init_best_loss=0.7353
#     iter 1/5  best_loss=0.7353
#     iter 2/5  best_loss=0.7353
#     iter 3/5  best_loss=0.7346
#     iter 4/5  best_loss=0.7346
#     iter 5/5  best_loss=0.7346
#   [Layer features.9.bias] dim=64  init_best_loss=0.7350
#     iter 1/5  best_loss=0.7347
#     iter 2/5  best_loss=0.7347
#     iter 3/5  best_loss=0.7344
#     iter 4/5  best_loss=0.7337
#     iter 5/5  best_loss=0.7337
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.7495
#     iter 1/5  best_loss=0.7476
#     iter 2/5  best_loss=0.7435
#     iter 3/5  best_loss=0.7334
#     iter 4/5  best_loss=0.7334
#     iter 5/5  best_loss=0.7295
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.7294
#     iter 1/5  best_loss=0.7292
#     iter 2/5  best_loss=0.7292
#     iter 3/5  best_loss=0.7292
#     iter 4/5  best_loss=0.7292
#     iter 5/5  best_loss=0.7292
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.7500
#     iter 1/5  best_loss=0.7500
#     iter 2/5  best_loss=0.7500
#     iter 3/5  best_loss=0.7371
#     iter 4/5  best_loss=0.7271
#     iter 5/5  best_loss=0.7073
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.6942
#     iter 1/5  best_loss=0.6911
#     iter 2/5  best_loss=0.6906
#     iter 3/5  best_loss=0.6831
#     iter 4/5  best_loss=0.6807
#     iter 5/5  best_loss=0.6793
#   QPSO aggregation complete
#   Global: acc=73.27% loss=0.6613 (75.1s)
#
# ============================================================ ROUND 10/100
#   client1 val=40.00%
#   client2 val=57.47%
#   client3 val=66.43%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.8567
#     iter 1/5  best_loss=0.7994
#     iter 2/5  best_loss=0.7830
#     iter 3/5  best_loss=0.7820
#     iter 4/5  best_loss=0.7783
#     iter 5/5  best_loss=0.7660
#   [Layer features.0.bias] dim=16  init_best_loss=0.7656
#     iter 1/5  best_loss=0.7645
#     iter 2/5  best_loss=0.7644
#     iter 3/5  best_loss=0.7638
#     iter 4/5  best_loss=0.7638
#     iter 5/5  best_loss=0.7626
#   [Layer features.1.weight] dim=16  init_best_loss=0.7629
#     iter 1/5  best_loss=0.7611
#     iter 2/5  best_loss=0.7602
#     iter 3/5  best_loss=0.7602
#     iter 4/5  best_loss=0.7599
#     iter 5/5  best_loss=0.7598
#   [Layer features.1.bias] dim=16  init_best_loss=0.7607
#     iter 1/5  best_loss=0.7598
#     iter 2/5  best_loss=0.7598
#     iter 3/5  best_loss=0.7584
#     iter 4/5  best_loss=0.7578
#     iter 5/5  best_loss=0.7572
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.7520
#     iter 1/5  best_loss=0.7520
#     iter 2/5  best_loss=0.7520
#     iter 3/5  best_loss=0.7510
#     iter 4/5  best_loss=0.7506
#     iter 5/5  best_loss=0.7497
#   [Layer features.4.bias] dim=32  init_best_loss=0.7497
#     iter 1/5  best_loss=0.7497
#     iter 2/5  best_loss=0.7497
#     iter 3/5  best_loss=0.7497
#     iter 4/5  best_loss=0.7497
#     iter 5/5  best_loss=0.7497
#   [Layer features.5.weight] dim=32  init_best_loss=0.7557
#     iter 1/5  best_loss=0.7536
#     iter 2/5  best_loss=0.7512
#     iter 3/5  best_loss=0.7512
#     iter 4/5  best_loss=0.7499
#     iter 5/5  best_loss=0.7495
#   [Layer features.5.bias] dim=32  init_best_loss=0.7481
#     iter 1/5  best_loss=0.7481
#     iter 2/5  best_loss=0.7476
#     iter 3/5  best_loss=0.7462
#     iter 4/5  best_loss=0.7455
#     iter 5/5  best_loss=0.7453
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.7748
#     iter 1/5  best_loss=0.7748
#     iter 2/5  best_loss=0.7544
#     iter 3/5  best_loss=0.7544
#     iter 4/5  best_loss=0.7544
#     iter 5/5  best_loss=0.7534
#   [Layer features.8.bias] dim=64  init_best_loss=0.7534
#     iter 1/5  best_loss=0.7534
#     iter 2/5  best_loss=0.7534
#     iter 3/5  best_loss=0.7534
#     iter 4/5  best_loss=0.7534
#     iter 5/5  best_loss=0.7534
#   [Layer features.9.weight] dim=64  init_best_loss=0.7520
#     iter 1/5  best_loss=0.7491
#     iter 2/5  best_loss=0.7468
#     iter 3/5  best_loss=0.7468
#     iter 4/5  best_loss=0.7454
#     iter 5/5  best_loss=0.7454
#   [Layer features.9.bias] dim=64  init_best_loss=0.7430
#     iter 1/5  best_loss=0.7430
#     iter 2/5  best_loss=0.7430
#     iter 3/5  best_loss=0.7430
#     iter 4/5  best_loss=0.7422
#     iter 5/5  best_loss=0.7419
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.8253
#     iter 1/5  best_loss=0.7287
#     iter 2/5  best_loss=0.7270
#     iter 3/5  best_loss=0.7180
#     iter 4/5  best_loss=0.7135
#     iter 5/5  best_loss=0.7129
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.7116
#     iter 1/5  best_loss=0.7110
#     iter 2/5  best_loss=0.7100
#     iter 3/5  best_loss=0.7093
#     iter 4/5  best_loss=0.7093
#     iter 5/5  best_loss=0.7093
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.7884
#     iter 1/5  best_loss=0.7884
#     iter 2/5  best_loss=0.7626
#     iter 3/5  best_loss=0.7433
#     iter 4/5  best_loss=0.7433
#     iter 5/5  best_loss=0.7431
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.7351
#     iter 1/5  best_loss=0.7302
#     iter 2/5  best_loss=0.7302
#     iter 3/5  best_loss=0.7293
#     iter 4/5  best_loss=0.7271
#     iter 5/5  best_loss=0.7269
#   QPSO aggregation complete
#   Global: acc=73.00% loss=0.6956 (74.9s)
#
# ============================================================ ROUND 11/100
#   client1 val=43.75%
#   client2 val=49.20%
#   client3 val=75.36%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.7981
#     iter 1/5  best_loss=0.7187
#     iter 2/5  best_loss=0.7173
#     iter 3/5  best_loss=0.7173
#     iter 4/5  best_loss=0.7173
#     iter 5/5  best_loss=0.7149
#   [Layer features.0.bias] dim=16  init_best_loss=0.7138
#     iter 1/5  best_loss=0.7122
#     iter 2/5  best_loss=0.7114
#     iter 3/5  best_loss=0.7113
#     iter 4/5  best_loss=0.7113
#     iter 5/5  best_loss=0.7113
#   [Layer features.1.weight] dim=16  init_best_loss=0.7081
#     iter 1/5  best_loss=0.7081
#     iter 2/5  best_loss=0.7081
#     iter 3/5  best_loss=0.7081
#     iter 4/5  best_loss=0.7081
#     iter 5/5  best_loss=0.7081
#   [Layer features.1.bias] dim=16  init_best_loss=0.7077
#     iter 1/5  best_loss=0.7059
#     iter 2/5  best_loss=0.7059
#     iter 3/5  best_loss=0.7056
#     iter 4/5  best_loss=0.7056
#     iter 5/5  best_loss=0.7056
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.7329
#     iter 1/5  best_loss=0.7329
#     iter 2/5  best_loss=0.7119
#     iter 3/5  best_loss=0.7076
#     iter 4/5  best_loss=0.7051
#     iter 5/5  best_loss=0.7039
#   [Layer features.4.bias] dim=32  init_best_loss=0.7039
#     iter 1/5  best_loss=0.7039
#     iter 2/5  best_loss=0.7039
#     iter 3/5  best_loss=0.7039
#     iter 4/5  best_loss=0.7039
#     iter 5/5  best_loss=0.7039
#   [Layer features.5.weight] dim=32  init_best_loss=0.7032
#     iter 1/5  best_loss=0.7031
#     iter 2/5  best_loss=0.7027
#     iter 3/5  best_loss=0.7021
#     iter 4/5  best_loss=0.7019
#     iter 5/5  best_loss=0.7011
#   [Layer features.5.bias] dim=32  init_best_loss=0.7009
#     iter 1/5  best_loss=0.6992
#     iter 2/5  best_loss=0.6982
#     iter 3/5  best_loss=0.6974
#     iter 4/5  best_loss=0.6973
#     iter 5/5  best_loss=0.6973
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.7208
#     iter 1/5  best_loss=0.6940
#     iter 2/5  best_loss=0.6932
# ...
#     iter 3/5  best_loss=0.2571
#     iter 4/5  best_loss=0.2569
#     iter 5/5  best_loss=0.2559
#   [Layer features.9.bias] dim=64  init_best_loss=0.2553
#     iter 1/5  best_loss=0.2546
#     iter 2/5  best_loss=0.2524
#     iter 3/5  best_loss=0.2523
#     iter 4/5  best_loss=0.2515
#     iter 5/5  best_loss=0.2515
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.2896
#     iter 1/5  best_loss=0.2575
#     iter 2/5  best_loss=0.2517
#     iter 3/5  best_loss=0.2495
#     iter 4/5  best_loss=0.2495
#     iter 5/5  best_loss=0.2495
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.2496
#     iter 1/5  best_loss=0.2474
#     iter 2/5  best_loss=0.2474
#     iter 3/5  best_loss=0.2474
#     iter 4/5  best_loss=0.2474
#     iter 5/5  best_loss=0.2474
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.2525
#     iter 1/5  best_loss=0.2474
#     iter 2/5  best_loss=0.2446
#     iter 3/5  best_loss=0.2446
#     iter 4/5  best_loss=0.2446
#     iter 5/5  best_loss=0.2436
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.2422
#     iter 1/5  best_loss=0.2422
#     iter 2/5  best_loss=0.2422
#     iter 3/5  best_loss=0.2421
#     iter 4/5  best_loss=0.2421
#     iter 5/5  best_loss=0.2421
#   QPSO aggregation complete
#   Global: acc=91.82% loss=0.2381 (74.9s)
#
# ============================================================ ROUND 97/100
#   client1 val=75.83%
#   client2 val=83.07%
#   client3 val=88.21%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.3405
#     iter 1/5  best_loss=0.3087
#     iter 2/5  best_loss=0.3068
#     iter 3/5  best_loss=0.3053
#     iter 4/5  best_loss=0.3053
#     iter 5/5  best_loss=0.3049
#   [Layer features.0.bias] dim=16  init_best_loss=0.3029
#     iter 1/5  best_loss=0.3029
#     iter 2/5  best_loss=0.3029
#     iter 3/5  best_loss=0.3025
#     iter 4/5  best_loss=0.3023
#     iter 5/5  best_loss=0.3023
#   [Layer features.1.weight] dim=16  init_best_loss=0.3016
#     iter 1/5  best_loss=0.2992
#     iter 2/5  best_loss=0.2988
#     iter 3/5  best_loss=0.2988
#     iter 4/5  best_loss=0.2984
#     iter 5/5  best_loss=0.2984
#   [Layer features.1.bias] dim=16  init_best_loss=0.2929
#     iter 1/5  best_loss=0.2913
#     iter 2/5  best_loss=0.2902
#     iter 3/5  best_loss=0.2897
#     iter 4/5  best_loss=0.2891
#     iter 5/5  best_loss=0.2891
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.2973
#     iter 1/5  best_loss=0.2931
#     iter 2/5  best_loss=0.2881
#     iter 3/5  best_loss=0.2881
#     iter 4/5  best_loss=0.2881
#     iter 5/5  best_loss=0.2881
#   [Layer features.4.bias] dim=32  init_best_loss=0.2881
#     iter 1/5  best_loss=0.2881
#     iter 2/5  best_loss=0.2880
#     iter 3/5  best_loss=0.2880
#     iter 4/5  best_loss=0.2880
#     iter 5/5  best_loss=0.2880
#   [Layer features.5.weight] dim=32  init_best_loss=0.2880
#     iter 1/5  best_loss=0.2861
#     iter 2/5  best_loss=0.2858
#     iter 3/5  best_loss=0.2858
#     iter 4/5  best_loss=0.2857
#     iter 5/5  best_loss=0.2857
#   [Layer features.5.bias] dim=32  init_best_loss=0.2843
#     iter 1/5  best_loss=0.2814
#     iter 2/5  best_loss=0.2814
#     iter 3/5  best_loss=0.2812
#     iter 4/5  best_loss=0.2812
#     iter 5/5  best_loss=0.2807
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.2824
#     iter 1/5  best_loss=0.2812
#     iter 2/5  best_loss=0.2735
#     iter 3/5  best_loss=0.2724
#     iter 4/5  best_loss=0.2722
#     iter 5/5  best_loss=0.2722
#   [Layer features.8.bias] dim=64  init_best_loss=0.2722
#     iter 1/5  best_loss=0.2721
#     iter 2/5  best_loss=0.2721
#     iter 3/5  best_loss=0.2721
#     iter 4/5  best_loss=0.2721
#     iter 5/5  best_loss=0.2721
#   [Layer features.9.weight] dim=64  init_best_loss=0.2689
#     iter 1/5  best_loss=0.2689
#     iter 2/5  best_loss=0.2683
#     iter 3/5  best_loss=0.2682
#     iter 4/5  best_loss=0.2670
#     iter 5/5  best_loss=0.2664
#   [Layer features.9.bias] dim=64  init_best_loss=0.2640
#     iter 1/5  best_loss=0.2640
#     iter 2/5  best_loss=0.2637
#     iter 3/5  best_loss=0.2635
#     iter 4/5  best_loss=0.2635
#     iter 5/5  best_loss=0.2635
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.3094
#     iter 1/5  best_loss=0.2693
#     iter 2/5  best_loss=0.2619
#     iter 3/5  best_loss=0.2617
#     iter 4/5  best_loss=0.2610
#     iter 5/5  best_loss=0.2610
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.2601
#     iter 1/5  best_loss=0.2588
#     iter 2/5  best_loss=0.2588
#     iter 3/5  best_loss=0.2585
#     iter 4/5  best_loss=0.2576
#     iter 5/5  best_loss=0.2576
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.2642
#     iter 1/5  best_loss=0.2599
#     iter 2/5  best_loss=0.2584
#     iter 3/5  best_loss=0.2559
#     iter 4/5  best_loss=0.2551
#     iter 5/5  best_loss=0.2551
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.2544
#     iter 1/5  best_loss=0.2542
#     iter 2/5  best_loss=0.2541
#     iter 3/5  best_loss=0.2541
#     iter 4/5  best_loss=0.2541
#     iter 5/5  best_loss=0.2541
#   QPSO aggregation complete
#   Global: acc=91.82% loss=0.2352 (75.4s)
#
# ============================================================ ROUND 98/100
#   client1 val=80.83%
#   client2 val=84.53%
#   client3 val=91.07%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.3407
#     iter 1/5  best_loss=0.3086
#     iter 2/5  best_loss=0.3058
#     iter 3/5  best_loss=0.3058
#     iter 4/5  best_loss=0.3043
#     iter 5/5  best_loss=0.3011
#   [Layer features.0.bias] dim=16  init_best_loss=0.3004
#     iter 1/5  best_loss=0.2994
#     iter 2/5  best_loss=0.2986
#     iter 3/5  best_loss=0.2981
#     iter 4/5  best_loss=0.2981
#     iter 5/5  best_loss=0.2978
#   [Layer features.1.weight] dim=16  init_best_loss=0.2969
#     iter 1/5  best_loss=0.2934
#     iter 2/5  best_loss=0.2931
#     iter 3/5  best_loss=0.2927
#     iter 4/5  best_loss=0.2915
#     iter 5/5  best_loss=0.2901
#   [Layer features.1.bias] dim=16  init_best_loss=0.2894
#     iter 1/5  best_loss=0.2886
#     iter 2/5  best_loss=0.2877
#     iter 3/5  best_loss=0.2877
#     iter 4/5  best_loss=0.2875
#     iter 5/5  best_loss=0.2875
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.2942
#     iter 1/5  best_loss=0.2830
#     iter 2/5  best_loss=0.2818
#     iter 3/5  best_loss=0.2805
#     iter 4/5  best_loss=0.2805
#     iter 5/5  best_loss=0.2778
#   [Layer features.4.bias] dim=32  init_best_loss=0.2778
#     iter 1/5  best_loss=0.2778
#     iter 2/5  best_loss=0.2778
#     iter 3/5  best_loss=0.2778
#     iter 4/5  best_loss=0.2778
#     iter 5/5  best_loss=0.2778
#   [Layer features.5.weight] dim=32  init_best_loss=0.2753
#     iter 1/5  best_loss=0.2753
#     iter 2/5  best_loss=0.2753
#     iter 3/5  best_loss=0.2753
#     iter 4/5  best_loss=0.2752
#     iter 5/5  best_loss=0.2752
#   [Layer features.5.bias] dim=32  init_best_loss=0.2757
#     iter 1/5  best_loss=0.2750
#     iter 2/5  best_loss=0.2748
#     iter 3/5  best_loss=0.2742
#     iter 4/5  best_loss=0.2742
#     iter 5/5  best_loss=0.2742
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.2795
#     iter 1/5  best_loss=0.2779
#     iter 2/5  best_loss=0.2727
#     iter 3/5  best_loss=0.2724
#     iter 4/5  best_loss=0.2724
#     iter 5/5  best_loss=0.2712
#   [Layer features.8.bias] dim=64  init_best_loss=0.2712
#     iter 1/5  best_loss=0.2712
#     iter 2/5  best_loss=0.2712
#     iter 3/5  best_loss=0.2712
#     iter 4/5  best_loss=0.2712
#     iter 5/5  best_loss=0.2712
#   [Layer features.9.weight] dim=64  init_best_loss=0.2738
#     iter 1/5  best_loss=0.2722
#     iter 2/5  best_loss=0.2719
#     iter 3/5  best_loss=0.2700
#     iter 4/5  best_loss=0.2699
#     iter 5/5  best_loss=0.2671
#   [Layer features.9.bias] dim=64  init_best_loss=0.2672
#     iter 1/5  best_loss=0.2672
#     iter 2/5  best_loss=0.2672
#     iter 3/5  best_loss=0.2672
#     iter 4/5  best_loss=0.2648
#     iter 5/5  best_loss=0.2648
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.2849
#     iter 1/5  best_loss=0.2710
#     iter 2/5  best_loss=0.2581
#     iter 3/5  best_loss=0.2560
#     iter 4/5  best_loss=0.2560
#     iter 5/5  best_loss=0.2560
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.2558
#     iter 1/5  best_loss=0.2533
#     iter 2/5  best_loss=0.2524
#     iter 3/5  best_loss=0.2519
#     iter 4/5  best_loss=0.2514
#     iter 5/5  best_loss=0.2514
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.2611
#     iter 1/5  best_loss=0.2493
#     iter 2/5  best_loss=0.2493
#     iter 3/5  best_loss=0.2484
#     iter 4/5  best_loss=0.2482
#     iter 5/5  best_loss=0.2479
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.2469
#     iter 1/5  best_loss=0.2464
#     iter 2/5  best_loss=0.2462
#     iter 3/5  best_loss=0.2462
#     iter 4/5  best_loss=0.2452
#     iter 5/5  best_loss=0.2452
#   QPSO aggregation complete
#   Global: acc=92.09% loss=0.2375 (74.9s) *** best
#
# ============================================================ ROUND 99/100
#   client1 val=82.50%
#   client2 val=85.60%
#   client3 val=90.36%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.2973
#     iter 1/5  best_loss=0.2904
#     iter 2/5  best_loss=0.2874
#     iter 3/5  best_loss=0.2872
#     iter 4/5  best_loss=0.2872
#     iter 5/5  best_loss=0.2858
#   [Layer features.0.bias] dim=16  init_best_loss=0.2848
#     iter 1/5  best_loss=0.2846
#     iter 2/5  best_loss=0.2846
#     iter 3/5  best_loss=0.2846
#     iter 4/5  best_loss=0.2846
#     iter 5/5  best_loss=0.2845
#   [Layer features.1.weight] dim=16  init_best_loss=0.2832
#     iter 1/5  best_loss=0.2820
#     iter 2/5  best_loss=0.2816
#     iter 3/5  best_loss=0.2816
#     iter 4/5  best_loss=0.2809
#     iter 5/5  best_loss=0.2804
#   [Layer features.1.bias] dim=16  init_best_loss=0.2792
#     iter 1/5  best_loss=0.2790
#     iter 2/5  best_loss=0.2784
#     iter 3/5  best_loss=0.2781
#     iter 4/5  best_loss=0.2776
#     iter 5/5  best_loss=0.2776
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.2917
#     iter 1/5  best_loss=0.2790
#     iter 2/5  best_loss=0.2747
#     iter 3/5  best_loss=0.2747
#     iter 4/5  best_loss=0.2734
#     iter 5/5  best_loss=0.2734
#   [Layer features.4.bias] dim=32  init_best_loss=0.2734
#     iter 1/5  best_loss=0.2734
#     iter 2/5  best_loss=0.2734
#     iter 3/5  best_loss=0.2734
#     iter 4/5  best_loss=0.2734
#     iter 5/5  best_loss=0.2734
#   [Layer features.5.weight] dim=32  init_best_loss=0.2724
#     iter 1/5  best_loss=0.2707
#     iter 2/5  best_loss=0.2705
#     iter 3/5  best_loss=0.2696
#     iter 4/5  best_loss=0.2696
#     iter 5/5  best_loss=0.2696
#   [Layer features.5.bias] dim=32  init_best_loss=0.2689
#     iter 1/5  best_loss=0.2687
#     iter 2/5  best_loss=0.2675
#     iter 3/5  best_loss=0.2675
#     iter 4/5  best_loss=0.2674
#     iter 5/5  best_loss=0.2674
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.2695
#     iter 1/5  best_loss=0.2695
#     iter 2/5  best_loss=0.2669
#     iter 3/5  best_loss=0.2648
#     iter 4/5  best_loss=0.2626
#     iter 5/5  best_loss=0.2625
#   [Layer features.8.bias] dim=64  init_best_loss=0.2624
#     iter 1/5  best_loss=0.2624
#     iter 2/5  best_loss=0.2624
#     iter 3/5  best_loss=0.2624
#     iter 4/5  best_loss=0.2624
#     iter 5/5  best_loss=0.2624
#   [Layer features.9.weight] dim=64  init_best_loss=0.2566
#     iter 1/5  best_loss=0.2554
#     iter 2/5  best_loss=0.2554
#     iter 3/5  best_loss=0.2524
#     iter 4/5  best_loss=0.2523
#     iter 5/5  best_loss=0.2523
#   [Layer features.9.bias] dim=64  init_best_loss=0.2506
#     iter 1/5  best_loss=0.2506
#     iter 2/5  best_loss=0.2506
#     iter 3/5  best_loss=0.2500
#     iter 4/5  best_loss=0.2496
#     iter 5/5  best_loss=0.2494
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.2878
#     iter 1/5  best_loss=0.2485
#     iter 2/5  best_loss=0.2467
#     iter 3/5  best_loss=0.2455
#     iter 4/5  best_loss=0.2451
#     iter 5/5  best_loss=0.2428
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.2430
#     iter 1/5  best_loss=0.2425
#     iter 2/5  best_loss=0.2425
#     iter 3/5  best_loss=0.2425
#     iter 4/5  best_loss=0.2425
#     iter 5/5  best_loss=0.2421
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.2460
#     iter 1/5  best_loss=0.2460
#     iter 2/5  best_loss=0.2449
#     iter 3/5  best_loss=0.2445
#     iter 4/5  best_loss=0.2417
#     iter 5/5  best_loss=0.2408
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.2404
#     iter 1/5  best_loss=0.2404
#     iter 2/5  best_loss=0.2404
#     iter 3/5  best_loss=0.2402
#     iter 4/5  best_loss=0.2402
#     iter 5/5  best_loss=0.2401
#   QPSO aggregation complete
#   Global: acc=91.49% loss=0.2467 (73.2s)
#
# ============================================================ ROUND 100/100
#   client1 val=80.00%
#   client2 val=87.33%
#   client3 val=88.10%
#   QPSO aggregating (beta=0.6, iters/layer=5)...
#   [Layer features.0.weight] dim=432  init_best_loss=0.3411
#     iter 1/5  best_loss=0.3225
#     iter 2/5  best_loss=0.3225
#     iter 3/5  best_loss=0.3208
#     iter 4/5  best_loss=0.3208
#     iter 5/5  best_loss=0.3206
#   [Layer features.0.bias] dim=16  init_best_loss=0.3200
#     iter 1/5  best_loss=0.3200
#     iter 2/5  best_loss=0.3198
#     iter 3/5  best_loss=0.3197
#     iter 4/5  best_loss=0.3197
#     iter 5/5  best_loss=0.3196
#   [Layer features.1.weight] dim=16  init_best_loss=0.3159
#     iter 1/5  best_loss=0.3159
#     iter 2/5  best_loss=0.3143
#     iter 3/5  best_loss=0.3143
#     iter 4/5  best_loss=0.3130
#     iter 5/5  best_loss=0.3130
#   [Layer features.1.bias] dim=16  init_best_loss=0.3130
#     iter 1/5  best_loss=0.3121
#     iter 2/5  best_loss=0.3102
#     iter 3/5  best_loss=0.3102
#     iter 4/5  best_loss=0.3102
#     iter 5/5  best_loss=0.3098
#   [Layer features.4.weight] dim=4,608  init_best_loss=0.2972
#     iter 1/5  best_loss=0.2972
#     iter 2/5  best_loss=0.2965
#     iter 3/5  best_loss=0.2965
#     iter 4/5  best_loss=0.2959
#     iter 5/5  best_loss=0.2959
#   [Layer features.4.bias] dim=32  init_best_loss=0.2959
#     iter 1/5  best_loss=0.2959
#     iter 2/5  best_loss=0.2959
#     iter 3/5  best_loss=0.2959
#     iter 4/5  best_loss=0.2959
#     iter 5/5  best_loss=0.2959
#   [Layer features.5.weight] dim=32  init_best_loss=0.2952
#     iter 1/5  best_loss=0.2943
#     iter 2/5  best_loss=0.2943
#     iter 3/5  best_loss=0.2943
#     iter 4/5  best_loss=0.2934
#     iter 5/5  best_loss=0.2928
#   [Layer features.5.bias] dim=32  init_best_loss=0.2897
#     iter 1/5  best_loss=0.2896
#     iter 2/5  best_loss=0.2892
#     iter 3/5  best_loss=0.2892
#     iter 4/5  best_loss=0.2891
#     iter 5/5  best_loss=0.2884
#   [Layer features.8.weight] dim=18,432  init_best_loss=0.3053
#     iter 1/5  best_loss=0.2951
#     iter 2/5  best_loss=0.2879
#     iter 3/5  best_loss=0.2859
#     iter 4/5  best_loss=0.2859
#     iter 5/5  best_loss=0.2824
#   [Layer features.8.bias] dim=64  init_best_loss=0.2824
#     iter 1/5  best_loss=0.2824
#     iter 2/5  best_loss=0.2824
#     iter 3/5  best_loss=0.2824
#     iter 4/5  best_loss=0.2824
#     iter 5/5  best_loss=0.2824
#   [Layer features.9.weight] dim=64  init_best_loss=0.2793
#     iter 1/5  best_loss=0.2771
#     iter 2/5  best_loss=0.2771
#     iter 3/5  best_loss=0.2751
#     iter 4/5  best_loss=0.2751
#     iter 5/5  best_loss=0.2751
#   [Layer features.9.bias] dim=64  init_best_loss=0.2745
#     iter 1/5  best_loss=0.2745
#     iter 2/5  best_loss=0.2740
#     iter 3/5  best_loss=0.2735
#     iter 4/5  best_loss=0.2735
#     iter 5/5  best_loss=0.2735
#   [Layer classifier.1.weight] dim=131,072  init_best_loss=0.3197
#     iter 1/5  best_loss=0.2757
#     iter 2/5  best_loss=0.2730
#     iter 3/5  best_loss=0.2730
#     iter 4/5  best_loss=0.2729
#     iter 5/5  best_loss=0.2728
#   [Layer classifier.1.bias] dim=128  init_best_loss=0.2709
#     iter 1/5  best_loss=0.2708
#     iter 2/5  best_loss=0.2705
#     iter 3/5  best_loss=0.2699
#     iter 4/5  best_loss=0.2699
#     iter 5/5  best_loss=0.2691
#   [Layer classifier.4.weight] dim=512  init_best_loss=0.2821
#     iter 1/5  best_loss=0.2758
#     iter 2/5  best_loss=0.2706
#     iter 3/5  best_loss=0.2706
#     iter 4/5  best_loss=0.2703
#     iter 5/5  best_loss=0.2703
#   [Layer classifier.4.bias] dim=4  init_best_loss=0.2660
#     iter 1/5  best_loss=0.2646
#     iter 2/5  best_loss=0.2642
#     iter 3/5  best_loss=0.2641
#     iter 4/5  best_loss=0.2640
#     iter 5/5  best_loss=0.2638
#   QPSO aggregation complete
#   Global: acc=91.43% loss=0.2475 (75.9s)
#   QPSO-FL done — best 92.09%
#
# All Phase 4 Setup 1 training complete!

# %%
df_fa = pd.read_csv('/kaggle/working/results_phase4/fedavg/metrics.csv')
df_fp = pd.read_csv('/kaggle/working/results_phase4/fedprox/metrics.csv')
df_qp = pd.read_csv('/kaggle/working/results_phase4/qpso/metrics.csv')

comp = build_comparison_df((df_fa,"FedAvg"),(df_fp,"FedProx"),(df_qp,"QPSO-FL"))
print(comp.to_string(index=False))
comp.to_csv('/kaggle/working/results_phase4/final_comparison.csv', index=False)

plot_accuracy_comparison([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'],
                         '/kaggle/working/results_phase4/plots/comparison.png')

for m, n in [('fedavg','FedAvg'),('fedprox','FedProx'),('qpso','QPSO-FL')]:
    generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth',
                              data_loaders['global_test'], n,
                              save_path=f'/kaggle/working/results_phase4/plots/cm_{m}.png')

plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'],
                     '/kaggle/working/results_phase4/plots/fairness.png')

plot_roc_auc([f'/kaggle/working/models/{m}_best.pth' for m in ('fedavg','fedprox','qpso')],
             ['FedAvg','FedProx','QPSO-FL'],
             data_loaders['global_test'],
             save_path='/kaggle/working/results_phase4/plots/roc_auc.png')

s1 = statistical_analysis(df_fa, df_qp)
s2 = statistical_analysis(df_fa, df_fp)
print("FedAvg vs QPSO:",    json.dumps(s1, indent=2))
print("FedAvg vs FedProx:", json.dumps(s2, indent=2))

summary = {
    "phase": "Phase 4",
    "fedavg":  convergence_metrics(df_fa),
    "fedprox": convergence_metrics(df_fp),
    "qpso":    convergence_metrics(df_qp),
    "stats_fedavg_vs_qpso":   s1,
    "stats_fedavg_vs_fedprox": s2,
    "config": {
        "model": "SimpleCNN (~120K params)", "img_size": IMG_SIZE,
        "local_epochs": LOCAL_EPOCHS, "lr": LR, "batch_size": BATCH_SIZE,
        "num_rounds": NUM_ROUNDS, "fedprox_mu": FEDPROX_MU,
        "qpso_beta": QPSO_BETA, "qpso_iters_per_layer": QPSO_ITERS,
        "qpso_val_batches": QPSO_VAL_BATCHES,
        "early_stopping": {"patience": PATIENCE, "min_rounds": MIN_ROUNDS, "target_acc": TARGET_ACC},
        "qpso_type": "layer-by-layer, loss-minimizing, ported from MNIST IID reference"
    }
}
with open('/kaggle/working/results_phase4/executive_summary.json','w') as f:
    json.dump(summary, f, indent=2)
print("Summary saved")

print("\nLaTeX Table:")
print(comp.to_latex(index=False, float_format="%.2f",
      caption="Phase 4: FedAvg vs FedProx vs QPSO-FL (SimpleCNN, layer-by-layer)",
      label="tab:phase4_comparison"))
print("\nNotebook complete!")
# Out:
#           Metric  FedAvg  FedProx  QPSO-FL
#    Final Acc (%)   88.16    91.82    91.43
#     Best Acc (%)   90.56    93.02    92.09
#       Rounds Run  100.00   100.00   100.00
#    Rounds to 80%   35.00    17.00    19.00
#    Avg Round (s)    8.03     8.16    74.92
# Total Time (min)   13.38    13.60   124.87
#   Client Std Dev   12.82     6.05     3.65
# Saved -> /kaggle/working/results_phase4/plots/comparison.png
#
# FedAvg:
#               precision    recall  f1-score   support
#
#       Glioma     0.9367    0.8371    0.8841       442
#   Meningioma     0.8134    0.8809    0.8458       470
#     No Tumor     0.9404    0.9491    0.9447       432
#    Pituitary     0.9452    0.9530    0.9491       489
#
#     accuracy                         0.9056      1833
#    macro avg     0.9089    0.9050    0.9059      1833
# weighted avg     0.9082    0.9056    0.9059      1833
#
#
# FedProx:
#               precision    recall  f1-score   support
#
#       Glioma     0.9501    0.8620    0.9039       442
#   Meningioma     0.8555    0.9319    0.8921       470
#     No Tumor     0.9436    0.9676    0.9554       432
#    Pituitary     0.9811    0.9571    0.9689       489
#
#     accuracy                         0.9302      1833
#    macro avg     0.9326    0.9296    0.9301      1833
# weighted avg     0.9326    0.9302    0.9304      1833
#
#
# QPSO-FL:
#               precision    recall  f1-score   support
#
#       Glioma     0.9271    0.8914    0.9089       442
#   Meningioma     0.8566    0.8894    0.8727       470
#     No Tumor     0.9712    0.9352    0.9528       432
#    Pituitary     0.9365    0.9652    0.9507       489
#
#     accuracy                         0.9209      1833
#    macro avg     0.9228    0.9203    0.9213      1833
# weighted avg     0.9219    0.9209    0.9211      1833
#
# FedAvg vs QPSO: {
#   "t_stat": 12.5859,
#   "p_value": 2.9116109479752896e-22,
#   "cohens_d": 1.2586,
#   "significant": true
# }
# FedAvg vs FedProx: {
#   "t_stat": 13.3946,
#   "p_value": 5.857362777648649e-24,
#   "cohens_d": 1.3395,
#   "significant": true
# }
# Summary saved
#
# LaTeX Table:
# \begin{table}
# \caption{Phase 4: FedAvg vs FedProx vs QPSO-FL (SimpleCNN, layer-by-layer)}
# \label{tab:phase4_comparison}
# \begin{tabular}{lrrr}
# \toprule
# Metric & FedAvg & FedProx & QPSO-FL \\
# \midrule
# Final Acc (%) & 88.16 & 91.82 & 91.43 \\
# Best Acc (%) & 90.56 & 93.02 & 92.09 \\
# Rounds Run & 100.00 & 100.00 & 100.00 \\
# Rounds to 80% & 35.00 & 17.00 & 19.00 \\
# Avg Round (s) & 8.03 & 8.16 & 74.92 \\
# Total Time (min) & 13.38 & 13.60 & 124.87 \\
# Client Std Dev & 12.82 & 6.05 & 3.65 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# Notebook complete!
