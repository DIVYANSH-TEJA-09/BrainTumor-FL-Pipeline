# %% [markdown]
# # Setup 3: Extreme Label Skew (single class per client)
# **Settings:** GPU P100 · Persistence: Files only · Internet: ON
# **Add Inputs:** Brain Tumor MRI Dataset (masoudnickparvar) + BRISC 2025 (briscdataset)
# All-in-one: Data prep → Training (FedAvg + FedProx + QPSO) → Evaluation

# %%
import os, sys, copy, time, random, json, shutil
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
import torchvision.models as models, torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import stats
try:
    from tqdm.notebook import tqdm
except ImportError:
    from tqdm import tqdm

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42); device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu"); print("CPU only")
torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False

NUM_CLASSES = 4
CLASS_NAMES = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
VALID_CLASSES = {"glioma": 0, "meningioma": 1, "notumor": 2, "no_tumor": 2, "pituitary": 3}

for d in ['data/processed/client1','data/processed/client2','data/processed/client3',
          'data/test_set','models','results/fedavg','results/fedprox','results/qpso','results/plots','logs']:
    os.makedirs(f'/kaggle/working/{d}', exist_ok=True)
print("Directories created")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Directories created

# %% [markdown]
# ## Preprocessor

# %%
class Preprocessor:
    def __init__(self, size=(224,224)): self.size = size
    def load_image(self, path):
        try:
            img = Image.open(path)
            if img.mode != "RGB": img = img.convert("RGB")
            return np.array(img.resize(self.size, Image.LANCZOS), dtype=np.float32) / 255.0
        except: return None

    def process_dataset(self, dataset_path, client_name, save_dir="/kaggle/working/data/processed",
                        train_r=0.70, val_r=0.15):
        print(f"\n{'='*60}\nProcessing {client_name} <- {dataset_path}\n{'='*60}")
        images, labels = [], []
        for cls_name in sorted(os.listdir(dataset_path)):
            cls_path = os.path.join(dataset_path, cls_name)
            if not os.path.isdir(cls_path): continue
            key = cls_name.lower().replace(" ","")
            if key not in VALID_CLASSES: print(f"  Skipping: {cls_name}"); continue
            label = VALID_CLASSES[key]
            files = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))]
            print(f"  {cls_name}: {len(files)} images (label={label})")
            for fname in tqdm(files, desc=f"    {cls_name}", leave=False):
                arr = self.load_image(os.path.join(cls_path, fname))
                if arr is not None: images.append(arr); labels.append(label)
        X, y = np.array(images), np.array(labels)
        print(f"  Total: {len(X)} | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
        test_r = 1.0 - train_r - val_r
        X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=test_r, stratify=y, random_state=42)
        val_adj = val_r / (train_r + val_r)
        X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=val_adj, stratify=y_tmp, random_state=42)
        print(f"  Train:{len(X_train)} Val:{len(X_val)} Test:{len(X_test)}")
        out = os.path.join(save_dir, client_name); os.makedirs(out, exist_ok=True)
        for name, arr in [("X_train",X_train),("y_train",y_train),("X_val",X_val),("y_val",y_val),("X_test",X_test),("y_test",y_test)]:
            np.save(os.path.join(out, f"{name}.npy"), arr)
        print(f"  Saved -> {out}")

    @staticmethod
    def create_global_test(pdir="/kaggle/working/data/processed", sdir="/kaggle/working/data/test_set"):
        Xs, ys = [], []
        for i in range(1, 4):
            d = os.path.join(pdir, f"client{i}")
            Xs.append(np.load(os.path.join(d, "X_test.npy")))
            ys.append(np.load(os.path.join(d, "y_test.npy")))
        X, y = np.concatenate(Xs), np.concatenate(ys)
        os.makedirs(sdir, exist_ok=True)
        np.save(os.path.join(sdir, "X_test.npy"), X)
        np.save(os.path.join(sdir, "y_test.npy"), y)
        print(f"Global test: {len(X)} images | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
print("Preprocessor ready")
# Out:
# Preprocessor ready

# %% [markdown]
# ## Model & FL Components

# %%
class BrainTumorDataset(Dataset):
    _DEFAULT = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
    def __init__(self, X, y, transform=None):
        self.X, self.y = X, y; self.transform = transform or self._DEFAULT
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        img = Image.fromarray((self.X[idx]*255).astype(np.uint8))
        return self.transform(img), torch.tensor(self.y[idx], dtype=torch.long)

TRAIN_TF = transforms.Compose([transforms.RandomHorizontalFlip(0.5),
    transforms.RandomRotation(15), transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
TEST_TF = transforms.Compose([transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

def create_data_loaders(pdir="/kaggle/working/data/processed", tdir="/kaggle/working/data/test_set", bs=32, nw=2):
    loaders = {}
    for i in range(1, 4):
        d = f"{pdir}/client{i}"
        ds_tr = BrainTumorDataset(np.load(f"{d}/X_train.npy"), np.load(f"{d}/y_train.npy"), TRAIN_TF)
        ds_va = BrainTumorDataset(np.load(f"{d}/X_val.npy"), np.load(f"{d}/y_val.npy"), TEST_TF)
        ds_te = BrainTumorDataset(np.load(f"{d}/X_test.npy"), np.load(f"{d}/y_test.npy"), TEST_TF)
        loaders[f"client{i}"] = {"train": DataLoader(ds_tr, bs, shuffle=True, num_workers=nw, pin_memory=True),
            "val": DataLoader(ds_va, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "test": DataLoader(ds_te, bs, shuffle=False, num_workers=nw, pin_memory=True), "train_size": len(ds_tr)}
        print(f"client{i}: Train={len(ds_tr)} Val={len(ds_va)} Test={len(ds_te)}")
    gds = BrainTumorDataset(np.load(f"{tdir}/X_test.npy"), np.load(f"{tdir}/y_test.npy"), TEST_TF)
    loaders["global_test"] = DataLoader(gds, bs, shuffle=False, num_workers=nw, pin_memory=True)
    print(f"Global test: {len(gds)}"); return loaders

class BrainTumorResNet(nn.Module):
    def __init__(self, n=4, pretrained=True):
        super().__init__()
        w = models.ResNet18_Weights.DEFAULT if pretrained else None
        self.model = models.resnet18(weights=w); self.model.fc = nn.Linear(self.model.fc.in_features, n)
    def forward(self, x): return self.model(x)

def create_model(n=4, device="cuda"):
    m = BrainTumorResNet(n).to(device)
    print(f"Model: ResNet-18 | Params: {sum(p.numel() for p in m.parameters()):,} | Classes: {n}"); return m

class FederatedClient:
    def __init__(self, cid, train_loader, val_loader, device="cuda"):
        self.client_id = cid; self.train_loader = train_loader
        self.val_loader = val_loader; self.device = device
        self.model = None; self.optimizer = None
        self.criterion = nn.CrossEntropyLoss(); self.dataset_size = len(train_loader.dataset)
    def set_model(self, gm): self.model = copy.deepcopy(gm).to(self.device)
    def set_optimizer(self, lr=0.001): self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
    def train_local(self, epochs=5, verbose=False):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs); loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea
    def validate(self):
        self.model.eval(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.model(imgs); ls += self.criterion(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return ls/len(self.val_loader), 100.*c/t
    def get_dataset_size(self): return self.dataset_size

class FedProxClient(FederatedClient):
    def train_local(self, epochs=5, verbose=False, mu=0.01, global_params=None):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs)
                if global_params is not None:
                    prox = sum(torch.norm(pl - pg.detach())**2 for pl, pg in zip(self.model.parameters(), global_params))
                    loss = loss + (mu / 2.0) * prox
                loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea

class FedAvgServer:
    def __init__(self, gm, clients, device="cuda"):
        self.global_model = gm; self.clients = clients; self.device = device
        self.total_samples = sum(c.get_dataset_size() for c in clients)
        print(f"FedAvg Server | clients={len(clients)} total={self.total_samples}")
    def aggregate_weights(self, cw):
        first = cw[0][0]; agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for sd, nk in cw: acc = acc + sd[k].float() * (nk / self.total_samples)
                agg[k] = acc.to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)

class QPSOServer:
    def __init__(self, gm, clients, device="cuda", beta=0.7):
        self.global_model = gm; self.clients = clients; self.device = device; self.beta = beta
        self.personal_best = {}; self.personal_best_scores = {}
        self.global_best = None; self.global_best_score = 0.0; self.mean_best = None
        print(f"QPSO Server | clients={len(clients)} beta={beta}")
    def initialize_particles(self):
        s = copy.deepcopy(self.global_model.state_dict())
        for c in self.clients: self.personal_best[c.client_id] = copy.deepcopy(s); self.personal_best_scores[c.client_id] = 0.0
        self.global_best = copy.deepcopy(s); self.global_best_score = 0.0; print("QPSO particles initialised")
    def update_personal_best(self, cid, w, acc):
        if acc > self.personal_best_scores[cid]: self.personal_best[cid] = copy.deepcopy(w); self.personal_best_scores[cid] = acc; return True
        return False
    def update_global_best(self, cid, acc):
        if acc > self.global_best_score: self.global_best = copy.deepcopy(self.personal_best[cid]); self.global_best_score = acc; return True
        return False
    def calculate_mean_best(self):
        fid = self.clients[0].client_id
        self.mean_best = {k: torch.zeros_like(v, dtype=torch.float32) for k, v in self.personal_best[fid].items()}
        for c in self.clients:
            for k in self.mean_best: self.mean_best[k] += self.personal_best[c.client_id][k].float()
        for k in self.mean_best: self.mean_best[k] /= len(self.clients)
    def qpso_aggregate(self, cwl):
        for cid, w, acc in cwl:
            pb = self.update_personal_best(cid, w, acc); gb = self.update_global_best(cid, acc)
            if pb: print(f"  {cid}: pbest {acc:.2f}%")
            if gb: print(f"  {cid}: gbest {acc:.2f}%")
        self.calculate_mean_best(); agg = copy.deepcopy(self.global_best)
        for k in agg:
            if not agg[k].is_floating_point(): continue
            ps = torch.zeros_like(agg[k], dtype=torch.float32)
            for c in self.clients: ps += self.personal_best[c.client_id][k].float()
            phi = torch.rand_like(agg[k].float())
            u = torch.rand_like(agg[k].float()).clamp(min=0.3, max=1.0)
            p = phi*(ps/len(self.clients)) + (1-phi)*self.global_best[k].float()
            sign = torch.where(torch.rand_like(agg[k].float())<0.5, torch.ones_like(agg[k].float()), -torch.ones_like(agg[k].float()))
            pert = self.beta * torch.abs(self.mean_best[k].float() - agg[k].float()) * torch.log(1.0/u)
            pert = pert.clamp(-0.1, 0.1)
            agg[k] = (p + sign * pert).to(self.global_best[k].dtype)
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)
print("All classes loaded")
# Out:
# All classes loaded

# %% [markdown]
# ## Data Preparation

# %%
# Setup 3: Extreme Label Skew (single class per client)
# Client1 -> Only Glioma, Client2 -> Only Meningioma, Client3 -> Only Pituitary
# No Tumor is ONLY in test set (tests generalization)

CLIENT1_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
CLIENT2_PATH = '/kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train'
CLIENT3_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

# First, process normally
prep = Preprocessor()
prep.process_dataset(CLIENT1_PATH, 'client1')
prep.process_dataset(CLIENT2_PATH, 'client2')
prep.process_dataset(CLIENT3_PATH, 'client3')

# Now keep only one class per client
KEEP_CLASS = {1: 0, 2: 1, 3: 3}  # client -> keep class (0=glioma,1=menin,3=pituitary)

def augment_image(img):
    from PIL import ImageEnhance, ImageFilter
    pil = Image.fromarray((img*255).astype(np.uint8))
    if random.random() < 0.5: pil = pil.transpose(Image.FLIP_LEFT_RIGHT)
    if random.random() < 0.5: pil = pil.rotate(random.uniform(-30, 30), fillcolor=(0,0,0))
    if random.random() < 0.3: pil = ImageEnhance.Brightness(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.3: pil = ImageEnhance.Contrast(pil).enhance(random.uniform(0.7, 1.3))
    if random.random() < 0.2: pil = pil.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1.5)))
    return np.array(pil, dtype=np.float32) / 255.0

for cid in range(1, 4):
    d = f"/kaggle/working/data/processed/client{cid}"
    for split in ['train', 'val']:
        X = np.load(f"{d}/X_{split}.npy"); y = np.load(f"{d}/y_{split}.npy")
        keep = KEEP_CLASS[cid]
        mask = y == keep
        X_keep = X[mask]; y_keep = y[mask]
        original_size = len(X)

        # Augment to restore size (train only)
        if split == 'train' and len(X_keep) < original_size:
            extras_X, extras_y = [], []
            need = original_size - len(X_keep)
            for _ in range(need):
                src = X_keep[random.randint(0, len(X_keep)-1)]
                extras_X.append(augment_image(src)); extras_y.append(keep)
            X_keep = np.concatenate([X_keep, np.array(extras_X)])
            y_keep = np.concatenate([y_keep, np.array(extras_y)])

        perm = np.random.permutation(len(X_keep)); X_keep = X_keep[perm]; y_keep = y_keep[perm]
        np.save(f"{d}/X_{split}.npy", X_keep); np.save(f"{d}/y_{split}.npy", y_keep)
        print(f"client{cid} {split}: class={keep} | count={len(X_keep)}")

Preprocessor.create_global_test()
data_loaders = create_data_loaders()
print("\nSetup 3 data ready!")
# Out:
# ============================================================
# Processing client1 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
# ============================================================
#   glioma: 400 images (label=0)
#     glioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   meningioma: 400 images (label=1)
#     meningioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   notumor: 400 images (label=2)
#     notumor:   0%|          | 0/400 [00:00<?, ?it/s]
#   pituitary: 400 images (label=3)
#     pituitary:   0%|          | 0/400 [00:00<?, ?it/s]
#   Total: 1600 | Classes: [400 400 400 400]
#   Train:1119 Val:240 Test:241
#   Saved -> /kaggle/working/data/processed/client1
#
# ============================================================
# Processing client2 <- /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
# ============================================================
#   glioma: 1147 images (label=0)
#     glioma:   0%|          | 0/1147 [00:00<?, ?it/s]
#   meningioma: 1329 images (label=1)
#     meningioma:   0%|          | 0/1329 [00:00<?, ?it/s]
#   no_tumor: 1067 images (label=2)
#     no_tumor:   0%|          | 0/1067 [00:00<?, ?it/s]
#   pituitary: 1457 images (label=3)
#     pituitary:   0%|          | 0/1457 [00:00<?, ?it/s]
#   Total: 5000 | Classes: [1147 1329 1067 1457]
#   Train:3499 Val:750 Test:751
#   Saved -> /kaggle/working/data/processed/client2
#
# ============================================================
# Processing client3 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# ============================================================
#   glioma: 1400 images (label=0)
#     glioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   meningioma: 1400 images (label=1)
#     meningioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   notumor: 1400 images (label=2)
#     notumor:   0%|          | 0/1400 [00:00<?, ?it/s]
#   pituitary: 1400 images (label=3)
#     pituitary:   0%|          | 0/1400 [00:00<?, ?it/s]
#   Total: 5600 | Classes: [1400 1400 1400 1400]
#   Train:3919 Val:840 Test:841
#   Saved -> /kaggle/working/data/processed/client3
# client1 train: class=0 | count=1119
# client1 val: class=0 | count=60
# client2 train: class=1 | count=3499
# client2 val: class=1 | count=199
# client3 train: class=3 | count=3919
# client3 val: class=3 | count=210
# Global test: 1833 images | Classes: [442 470 432 489]
# client1: Train=1119 Val=60 Test=241
# client2: Train=3499 Val=199 Test=751
# client3: Train=3919 Val=210 Test=841
# Global test: 1833
#
# Setup 3 data ready!

# %% [markdown]
# ## Training Functions

# %%
def train_fedavg(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDAVG TRAINING START\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedavg/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDAVG DONE best {best:.2f}%\n{'='*80}"); return h

def train_fedprox(server, clients, gtl, nr=100, le=5, lr=0.001, mu=0.01, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDPROX TRAINING START (mu="+str(mu)+")\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        gp = list(server.global_model.parameters())
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose, mu=mu, global_params=gp)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedprox/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDPROX DONE best {best:.2f}%\n{'='*80}"); return h

def train_qpso(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  QPSO-FL TRAINING START\n"+"="*80); server.initialize_particles()
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"global_best_score":[],
         "client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],
         "client1_pbest":[],"client2_pbest":[],"client3_pbest":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((cl.client_id, w, va))
        print("  QPSO aggregating..."); agg = server.qpso_aggregate(cw)
        server.global_model.load_state_dict(agg)
        for c in clients: h[f"{c.client_id}_pbest"].append(server.personal_best_scores[c.client_id])
        h["global_best_score"].append(server.global_best_score)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} gbest={server.global_best_score:.2f}% ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/qpso/metrics.csv", index=False)
    print(f"\n{'='*80}\n  QPSO-FL DONE best {best:.2f}% gbest {server.global_best_score:.2f}%\n{'='*80}"); return h
print("Trainers loaded")
# Out:
# Trainers loaded

# %% [markdown]
# ## FedAvg Training
# ⚠️ Set `nr=5` for a quick test first!

# %%
fedavg_model = create_model(NUM_CLASSES, device)
fedavg_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                  data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedavg_server = FedAvgServer(fedavg_model, fedavg_clients, device=device)
fedavg_history = train_fedavg(fedavg_server, fedavg_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 205MB/s]
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8537
# ================================================================================
#   FEDAVG TRAINING START
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.80% loss=2.4765 (96.9s)
#   New best! 25.80%
#
# ============================================================ ROUND 2/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=2.7276 (97.0s)
#   New best! 26.68%
#
# ============================================================ ROUND 3/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=2.9828 (94.8s)
#
# ============================================================ ROUND 4/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.4251 (97.3s)
#
# ============================================================ ROUND 5/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=3.2392 (96.2s)
#
# ============================================================ ROUND 6/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.0699 (95.8s)
#
# ============================================================ ROUND 7/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.1982 (95.2s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.1229 (96.1s)
#
# ============================================================ ROUND 9/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.0748 (96.3s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.1067 (95.1s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.2819 (95.7s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.9250 (96.4s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=24.28% loss=3.4221 (94.8s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.0267 (96.3s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.7171 (96.6s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.5962 (94.9s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.9792 (95.6s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=2.8940 (95.2s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.6504 (96.5s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=33.82% loss=4.6559 (95.2s)
#   New best! 33.82%
#
# ============================================================ ROUND 21/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.6695 (97.6s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.0176 (96.0s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.4453 (95.3s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.5920 (96.2s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.7071 (96.6s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.5692 (95.8s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.3747 (96.0s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=7.2802 (97.1s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.22% loss=5.6460 (96.8s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.9108 (96.0s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.9227 (96.5s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.6676 (96.5s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=22.75% loss=4.7121 (96.1s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.3401 (95.3s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.8752 (95.3s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.2065 (96.5s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.9178 (95.1s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.6748 (96.2s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.1993 (98.4s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.5555 (95.9s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.1661 (95.0s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.8147 (95.8s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.7073 (94.7s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.6505 (95.9s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.8701 (95.5s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.6083 (97.0s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.8849 (96.3s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.79% loss=5.2530 (96.2s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.2059 (96.2s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.3786 (96.4s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.4836 (95.7s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.2750 (95.6s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=17.02% loss=5.0057 (96.8s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.7099 (95.5s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.4564 (95.1s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.4963 (95.4s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.4592 (96.4s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=39.50% loss=4.8745 (95.5s)
#   New best! 39.50%
#
# ============================================================ ROUND 59/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.9988 (95.8s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.5100 (96.4s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.9502 (96.5s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.6405 (95.4s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.8382 (95.5s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.2078 (96.9s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.9506 (96.3s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=5.0106 (95.3s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.1144 (95.6s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.6067 (95.3s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.5065 (96.1s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.2254 (95.8s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.8689 (94.5s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.5894 (94.6s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.2886 (97.6s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.0210 (96.1s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.97% loss=5.0774 (95.1s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.4524 (96.5s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.0365 (95.9s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.1882 (95.8s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.0786 (95.5s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.9397 (95.4s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.1197 (95.6s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.1188 (94.7s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=7.1113 (94.7s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.8579 (94.8s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.7970 (95.8s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.4009 (95.9s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.3477 (94.5s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.11% loss=4.7005 (95.7s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.2161 (95.1s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.6793 (97.0s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=4.9403 (95.6s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=7.7059 (95.3s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.2080 (95.4s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=14.95% loss=4.2894 (95.0s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.4691 (95.4s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.9286 (95.0s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=5.3516 (95.8s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.2138 (95.7s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.9664 (95.0s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=6.6989 (95.7s)
#
# ================================================================================
#   FEDAVG DONE best 39.50%
# ================================================================================

# %% [markdown]
# ## FedProx Training

# %%
torch.cuda.empty_cache()
fedprox_model = create_model(NUM_CLASSES, device)
fedprox_clients = [FedProxClient(f'client{i}', data_loaders[f'client{i}']['train'],
                   data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedprox_server = FedAvgServer(fedprox_model, fedprox_clients, device=device)
fedprox_history = train_fedprox(fedprox_server, fedprox_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, mu=0.01, se=10, verbose=False)
# Out:
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8537
# ================================================================================
#   FEDPROX TRAINING START (mu=0.01)
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=29.41% loss=2.5126 (103.3s)
#   New best! 29.41%
#
# ============================================================ ROUND 2/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.77% loss=2.8418 (103.2s)
#
# ============================================================ ROUND 3/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.06% loss=2.9972 (104.1s)
#
# ============================================================ ROUND 4/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.22% loss=3.0280 (104.2s)
#
# ============================================================ ROUND 5/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.79% loss=3.1311 (103.7s)
#
# ============================================================ ROUND 6/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=27.39% loss=3.1348 (104.0s)
#
# ============================================================ ROUND 7/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.79% loss=3.1596 (103.3s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.1459 (103.0s)
#
# ============================================================ ROUND 9/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.90% loss=3.1915 (105.1s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.1679 (106.3s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.95% loss=3.1861 (105.5s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.2048 (103.7s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1898 (103.7s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1922 (103.6s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.79% loss=3.1607 (104.1s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.57% loss=3.2037 (105.1s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.79% loss=3.2010 (104.7s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.2153 (105.6s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.2159 (105.3s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1892 (105.2s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.2211 (105.7s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.2137 (105.1s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.1881 (105.5s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.84% loss=3.2077 (105.2s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.2094 (104.7s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.2169 (103.9s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1822 (105.7s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.1957 (104.2s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1726 (103.9s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.1937 (104.3s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.1591 (104.8s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1789 (104.2s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1895 (104.2s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1892 (104.1s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.1908 (104.2s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.2549 (104.0s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.3464 (104.3s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.3623 (104.7s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.5498 (104.3s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.5504 (103.9s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.7707 (104.5s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.7432 (104.0s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.0200 (103.8s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.9877 (104.8s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.0594 (104.1s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.3056 (104.6s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.3569 (105.1s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.0948 (104.7s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.7208 (104.0s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.35% loss=3.6323 (103.5s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.40% loss=3.6178 (103.9s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.6236 (104.8s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.6282 (104.4s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.73% loss=3.6672 (103.7s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.5456 (103.9s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.6123 (104.1s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.57% loss=3.6142 (103.9s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.5985 (104.8s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.5935 (103.3s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.5806 (104.2s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.7022 (105.4s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.6261 (104.0s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.4626 (105.3s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.6362 (104.5s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.40% loss=3.5795 (105.0s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.6147 (104.6s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.4697 (104.8s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.51% loss=3.7910 (105.2s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.6628 (103.9s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=3.7301 (106.2s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=20.68% loss=2.5529 (105.6s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=24.50% loss=3.0869 (103.6s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=24.44% loss=3.2090 (104.1s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=21.88% loss=3.0555 (103.3s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.64% loss=2.4871 (104.0s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.40% loss=3.7058 (103.9s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.42% loss=2.9385 (105.2s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.35% loss=2.9559 (106.2s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.46% loss=3.0090 (102.9s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.13% loss=2.9416 (103.8s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.46% loss=3.0600 (104.2s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.24% loss=3.0309 (103.9s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.40% loss=3.1832 (104.3s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.57% loss=3.2609 (103.1s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.46% loss=3.5012 (102.6s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.35% loss=3.3174 (103.6s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=4.1335 (104.3s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.30% loss=3.5306 (103.6s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.62% loss=4.4052 (104.4s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=19.31% loss=2.7544 (103.8s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.40% loss=3.6164 (104.1s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=22.80% loss=3.1882 (104.2s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.19% loss=3.5868 (103.6s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.80% loss=3.5757 (104.3s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.30% loss=3.0747 (103.8s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.30% loss=3.4489 (104.3s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=23.73% loss=3.0195 (104.2s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=25.97% loss=3.1730 (104.9s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.68% loss=3.4103 (104.6s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   Global: acc=26.30% loss=2.8641 (104.5s)
#
# ================================================================================
#   FEDPROX DONE best 29.41%
# ================================================================================

# %% [markdown]
# ## QPSO Training

# %%
torch.cuda.empty_cache()
qpso_model = create_model(NUM_CLASSES, device)
qpso_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
qpso_server = QPSOServer(qpso_model, qpso_clients, device=device, beta=0.7)
qpso_history = train_qpso(qpso_server, qpso_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
print("\nAll training complete!")
# Out:
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# QPSO Server | clients=3 beta=0.7
# ================================================================================
#   QPSO-FL TRAINING START
# ================================================================================
# QPSO particles initialised
#
# ============================================================ ROUND 1/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   client1: pbest 100.00%
#   client1: gbest 100.00%
#   client2: pbest 100.00%
#   client3: pbest 100.00%
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#   New best! 24.11%
#
# ============================================================ ROUND 2/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 3/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.2s)
#
# ============================================================ ROUND 4/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 5/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.8s)
#
# ============================================================ ROUND 6/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 7/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.7s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 9/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=4.0579 gbest=100.00% (96.4s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.3s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.6s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.0s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.9s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.6s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.7s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.8s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.8s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.4s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.2s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.1s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (99.1s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.5s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.4s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.2s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.2s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.6s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.1s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.7s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.8s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=4.4741 gbest=100.00% (96.8s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.2s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.6s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.2s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.6s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.6s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.3s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.2s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.7s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.1s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.4s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.6s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.5s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.1s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.6s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.3s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.3s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.8s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.2s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.0s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.6s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.6s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.8s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.1s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (98.7s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.8s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.3s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=4.5995 gbest=100.00% (96.4s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=4.0968 gbest=100.00% (97.0s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.8s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.5s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.5s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.9s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.7s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.7s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.4s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (97.4s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.7s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (96.9s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.9s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.6s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (95.5s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=100.00%
#   client2 training... val=100.00%
#   client3 training... val=100.00%
#   QPSO aggregating...
#   Global: acc=24.11% loss=nan gbest=100.00% (94.8s)
#
# ================================================================================
#   QPSO-FL DONE best 24.11% gbest 100.00%
# ================================================================================
#
# All training complete!

# %% [markdown]
# ## Evaluation & Plots

# %%
def plot_accuracy_comparison(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(2, max(n,2), figsize=(8*max(n,2), 12))
    fig.suptitle("FL Aggregation Comparison", fontsize=16, fontweight="bold")
    colors = ['#1f77b4','#ff7f0e','#2ca02c']
    ax = axes[0,0]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_acc"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Acc (%)", title="Global Test Accuracy", ylim=[0,100]); ax.legend(); ax.grid(alpha=0.3)
    ax = axes[0,1]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_loss"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Loss", title="Global Test Loss"); ax.legend(); ax.grid(alpha=0.3)
    for idx, (df, name) in enumerate(zip(dfs, names)):
        ax = axes[1, idx]
        for i in range(1,4): ax.plot(df["round"], df[f"client{i}_val_acc"], label=f"Client {i}", lw=2)
        ax.set(xlabel="Round", ylabel="Val Acc (%)", title=f"{name}: Per-Client"); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Saved -> {save_path}")

def generate_confusion_matrix(mp, tl, mname, device="cuda", save_path=None):
    model = BrainTumorResNet(NUM_CLASSES, pretrained=False).to(device)
    model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
    model.eval(); preds, labels = [], []
    with torch.no_grad():
        for imgs, labs in tl:
            _, pred = model(imgs.to(device)).max(1)
            preds.extend(pred.cpu().numpy()); labels.extend(labs.numpy())
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix - {mname}", fontsize=14, fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted"); plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"\n{mname}:"); print(classification_report(labels, preds, target_names=CLASS_NAMES, digits=4))

def plot_roc_auc(mps, mnames, tl, device="cuda", save_path=None):
    n = len(mps)
    fig, axes = plt.subplots(1, n, figsize=(7*n, 6))
    if n == 1: axes = [axes]
    cc = ['#e74c3c', '#3498db', '#2ecc71', '#9b59b6']
    for ax, mp, mn in zip(axes, mps, mnames):
        model = BrainTumorResNet(NUM_CLASSES, pretrained=False).to(device)
        model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
        model.eval(); probs, labs = [], []
        with torch.no_grad():
            for imgs, lb in tl:
                out = model(imgs.to(device)); probs.append(torch.softmax(out, dim=1).cpu().numpy()); labs.extend(lb.numpy())
        yp = np.vstack(probs); yt = np.array(labs)
        yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
        for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
            fpr, tpr, _ = roc_curve(yb[:, i], yp[:, i]); a = auc(fpr, tpr)
            ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.4f})")
        fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
        ax.plot(fpr_m, tpr_m, 'k--', lw=2, label=f"Micro ({auc(fpr_m,tpr_m):.4f})")
        ax.plot([0,1],[0,1],'gray',ls=':',lw=1)
        ax.set(xlabel="FPR", ylabel="TPR", title=f"ROC - {mn}"); ax.legend(loc="lower right", fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show(); print(f"ROC-AUC saved -> {save_path}")

def plot_client_fairness(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(1, n, figsize=(6*n, 5)); cc = ["#FF6B6B","#4ECDC4","#45B7D1"]
    if n == 1: axes = [axes]
    for ax, df, t in zip(axes, dfs, names):
        accs = [df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)]
        ax.bar(["C1","C2","C3"], accs, color=cc, edgecolor="black")
        ax.axhline(np.mean(accs), color="red", ls="--", lw=2, label="Mean")
        ax.set(ylabel="Final Val Acc (%)", ylim=[0,100])
        ax.set_title(f"{t} (std={np.std(accs):.2f}%)", fontsize=13, fontweight="bold"); ax.legend(); ax.grid(axis="y", alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()

def convergence_metrics(df, target=80.0):
    r = df[df["global_test_acc"]>=target]
    return {"final_acc": round(df["global_test_acc"].iloc[-1],2), "best_acc": round(df["global_test_acc"].max(),2),
            "round_to_target": int(r["round"].min()) if len(r) else None,
            "avg_round_time_s": round(df["round_time"].mean(),2), "total_time_min": round(df["round_time"].sum()/60,2)}

def statistical_analysis(dfa, dfb):
    a, b = dfa["global_test_acc"].values, dfb["global_test_acc"].values
    n = min(len(a),len(b)); a, b = a[:n], b[:n]
    t_stat, p_val = stats.ttest_rel(b, a); d = (b-a).mean()/((b-a).std(ddof=1)+1e-8)
    return {"t_stat": round(float(t_stat),4), "p_value": float(p_val), "cohens_d": round(float(d),4), "significant": bool(p_val<0.05)}

def build_comparison_df(*pairs):
    cols = ["Metric"] + [n for _, n in pairs]
    ml = []
    for df, n in pairs:
        m = convergence_metrics(df)
        m["client_std"] = round(float(np.std([df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)])),2)
        ml.append(m)
    keys = [("Final Acc (%)","final_acc"),("Best Acc (%)","best_acc"),("Rounds to 80%","round_to_target"),
            ("Avg Round (s)","avg_round_time_s"),("Total Time (min)","total_time_min"),("Client Std Dev","client_std")]
    rows = [[l]+[m[k] if m[k] is not None else "N/A" for m in ml] for l, k in keys]
    return pd.DataFrame(rows, columns=cols)
print("Evaluation functions loaded")
# Out:
# Evaluation functions loaded

# %%
df_fa = pd.read_csv('/kaggle/working/results/fedavg/metrics.csv')
df_fp = pd.read_csv('/kaggle/working/results/fedprox/metrics.csv')
df_qp = pd.read_csv('/kaggle/working/results/qpso/metrics.csv')
comp = build_comparison_df((df_fa,"FedAvg"),(df_fp,"FedProx"),(df_qp,"QPSO-FL"))
print(comp.to_string(index=False))
comp.to_csv('/kaggle/working/results/final_comparison.csv', index=False)
# Out:
#           Metric  FedAvg FedProx QPSO-FL
#    Final Acc (%)   25.64    26.3   24.11
#     Best Acc (%)    39.5   29.41   24.11
#    Rounds to 80%     N/A     N/A     N/A
#    Avg Round (s)   95.84  104.33   96.26
# Total Time (min)  159.74  173.89  160.43
#   Client Std Dev     0.0     0.0     0.0

# %%
plot_accuracy_comparison([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/comparison.png')
for m, n in [('fedavg','FedAvg'),('fedprox','FedProx'),('qpso','QPSO-FL')]:
    generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth', data_loaders['global_test'], n, device=device, save_path=f'/kaggle/working/results/plots/cm_{m}.png')
plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/fairness.png')
plot_roc_auc(['/kaggle/working/models/fedavg_best.pth','/kaggle/working/models/fedprox_best.pth','/kaggle/working/models/qpso_best.pth'],
    ['FedAvg','FedProx','QPSO-FL'], data_loaders['global_test'], device=device, save_path='/kaggle/working/results/plots/roc_auc.png')
# Out:
# Saved -> /kaggle/working/results/plots/comparison.png
#
# FedAvg:
#               precision    recall  f1-score   support
#
#       Glioma     0.0000    0.0000    0.0000       442
#   Meningioma     0.3641    0.6638    0.4702       470
#     No Tumor     0.0000    0.0000    0.0000       432
#    Pituitary     0.4221    0.8425    0.5625       489
#
#     accuracy                         0.3950      1833
#    macro avg     0.1965    0.3766    0.2582      1833
# weighted avg     0.2060    0.3950    0.2706      1833
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# FedProx:
#               precision    recall  f1-score   support
#
#       Glioma     0.0000    0.0000    0.0000       442
#   Meningioma     0.3478    0.2383    0.2828       470
#     No Tumor     0.0000    0.0000    0.0000       432
#    Pituitary     0.2826    0.8732    0.4270       489
#
#     accuracy                         0.2941      1833
#    macro avg     0.1576    0.2779    0.1775      1833
# weighted avg     0.1646    0.2941    0.1864      1833
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# QPSO-FL:
#               precision    recall  f1-score   support
#
#       Glioma     0.2411    1.0000    0.3886       442
#   Meningioma     0.0000    0.0000    0.0000       470
#     No Tumor     0.0000    0.0000    0.0000       432
#    Pituitary     0.0000    0.0000    0.0000       489
#
#     accuracy                         0.2411      1833
#    macro avg     0.0603    0.2500    0.0971      1833
# weighted avg     0.0581    0.2411    0.0937      1833
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_24/1481786757.py in <cell line: 0>()
#       3     generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth', data_loaders['global_test'], n, device=device, save_path=f'/kaggle/working/results/plots/cm_{m}.png')
#       4 plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/fairness.png')
# ----> 5 plot_roc_auc(['/kaggle/working/models/fedavg_best.pth','/kaggle/working/models/fedprox_best.pth','/kaggle/working/models/qpso_best.pth'],
#       6     ['FedAvg','FedProx','QPSO-FL'], data_loaders['global_test'], device=device, save_path='/kaggle/working/results/plots/roc_auc.png')
#
# /tmp/ipykernel_24/1285490335.py in plot_roc_auc(mps, mnames, tl, device, save_path)
#      51         yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
#      52         for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
# ---> 53             fpr, tpr, _ = roc_curve(yb[:, i], yp[:, i]); a = auc(fpr, tpr)
#      54             ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.4f})")
#      55         fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1148     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1149     """
# -> 1150     fps, tps, thresholds = _binary_clf_curve(
#    1151         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1152     )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     822     y_score = column_or_1d(y_score)
#     823     assert_all_finite(y_true)
# --> 824     assert_all_finite(y_score)
#     825
#     826     # Filter out zero-weighted samples, as they should not impact the result
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in assert_all_finite(X, allow_nan, estimator_name, input_name)
#     208     Test failed: Array contains non-finite values.
#     209     """
# --> 210     _assert_all_finite(
#     211         X.data if sp.issparse(X) else X,
#     212         allow_nan=allow_nan,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input contains NaN.

# %% [markdown]
# ## Statistical Analysis & Summary

# %%
s1 = statistical_analysis(df_fa, df_qp)
s2 = statistical_analysis(df_fa, df_fp)
print("FedAvg vs QPSO:", json.dumps(s1, indent=2))
print("FedAvg vs FedProx:", json.dumps(s2, indent=2))
summary = {"fedavg": convergence_metrics(df_fa), "fedprox": convergence_metrics(df_fp),
           "qpso": convergence_metrics(df_qp), "stats_fa_qp": s1, "stats_fa_fp": s2}
with open('/kaggle/working/results/executive_summary.json','w') as f: json.dump(summary, f, indent=2)
print("Summary saved")
print("\nLaTeX Table:")
print(comp.to_latex(index=False, float_format="%.2f", caption="FedAvg vs FedProx vs QPSO-FL", label="tab:comparison"))
print("\nNotebook complete!")
