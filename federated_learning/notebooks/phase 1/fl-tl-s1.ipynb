# %% [markdown]
# # Setup 1: Natural Heterogeneity (4-class, IID baseline)
# **Settings:** GPU P100 · Persistence: Files only · Internet: ON
# **Add Inputs:** Brain Tumor MRI Dataset (masoudnickparvar) + BRISC 2025 (briscdataset)
# All-in-one: Data prep → Training (FedAvg + FedProx + QPSO) → Evaluation

# %%
import os, sys, copy, time, random, json, shutil
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
import torchvision.models as models, torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import matplotlib; matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import stats
try:
    from tqdm.notebook import tqdm
except ImportError:
    from tqdm import tqdm

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42); device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu"); print("CPU only")
torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False

NUM_CLASSES = 4
CLASS_NAMES = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
VALID_CLASSES = {"glioma": 0, "meningioma": 1, "notumor": 2, "no_tumor": 2, "pituitary": 3}

for d in ['data/processed/client1','data/processed/client2','data/processed/client3',
          'data/test_set','models','results/fedavg','results/fedprox','results/qpso','results/plots','logs']:
    os.makedirs(f'/kaggle/working/{d}', exist_ok=True)
print("Directories created")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Directories created

# %% [markdown]
# ## Preprocessor

# %%
class Preprocessor:
    def __init__(self, size=(224,224)): self.size = size
    def load_image(self, path):
        try:
            img = Image.open(path)
            if img.mode != "RGB": img = img.convert("RGB")
            return np.array(img.resize(self.size, Image.LANCZOS), dtype=np.float32) / 255.0
        except: return None

    def process_dataset(self, dataset_path, client_name, save_dir="/kaggle/working/data/processed",
                        train_r=0.70, val_r=0.15):
        print(f"\n{'='*60}\nProcessing {client_name} <- {dataset_path}\n{'='*60}")
        images, labels = [], []
        for cls_name in sorted(os.listdir(dataset_path)):
            cls_path = os.path.join(dataset_path, cls_name)
            if not os.path.isdir(cls_path): continue
            key = cls_name.lower().replace(" ","")
            if key not in VALID_CLASSES: print(f"  Skipping: {cls_name}"); continue
            label = VALID_CLASSES[key]
            files = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))]
            print(f"  {cls_name}: {len(files)} images (label={label})")
            for fname in tqdm(files, desc=f"    {cls_name}", leave=False):
                arr = self.load_image(os.path.join(cls_path, fname))
                if arr is not None: images.append(arr); labels.append(label)
        X, y = np.array(images), np.array(labels)
        print(f"  Total: {len(X)} | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
        test_r = 1.0 - train_r - val_r
        X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size=test_r, stratify=y, random_state=42)
        val_adj = val_r / (train_r + val_r)
        X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size=val_adj, stratify=y_tmp, random_state=42)
        print(f"  Train:{len(X_train)} Val:{len(X_val)} Test:{len(X_test)}")
        out = os.path.join(save_dir, client_name); os.makedirs(out, exist_ok=True)
        for name, arr in [("X_train",X_train),("y_train",y_train),("X_val",X_val),("y_val",y_val),("X_test",X_test),("y_test",y_test)]:
            np.save(os.path.join(out, f"{name}.npy"), arr)
        print(f"  Saved -> {out}")

    @staticmethod
    def create_global_test(pdir="/kaggle/working/data/processed", sdir="/kaggle/working/data/test_set"):
        Xs, ys = [], []
        for i in range(1, 4):
            d = os.path.join(pdir, f"client{i}")
            Xs.append(np.load(os.path.join(d, "X_test.npy")))
            ys.append(np.load(os.path.join(d, "y_test.npy")))
        X, y = np.concatenate(Xs), np.concatenate(ys)
        os.makedirs(sdir, exist_ok=True)
        np.save(os.path.join(sdir, "X_test.npy"), X)
        np.save(os.path.join(sdir, "y_test.npy"), y)
        print(f"Global test: {len(X)} images | Classes: {np.bincount(y, minlength=NUM_CLASSES)}")
print("Preprocessor ready")
# Out:
# Preprocessor ready

# %% [markdown]
# ## Model & FL Components

# %%
class BrainTumorDataset(Dataset):
    _DEFAULT = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
    def __init__(self, X, y, transform=None):
        self.X, self.y = X, y; self.transform = transform or self._DEFAULT
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        img = Image.fromarray((self.X[idx]*255).astype(np.uint8))
        return self.transform(img), torch.tensor(self.y[idx], dtype=torch.long)

TRAIN_TF = transforms.Compose([transforms.RandomHorizontalFlip(0.5),
    transforms.RandomRotation(15), transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(), transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])
TEST_TF = transforms.Compose([transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])])

def create_data_loaders(pdir="/kaggle/working/data/processed", tdir="/kaggle/working/data/test_set", bs=32, nw=2):
    loaders = {}
    for i in range(1, 4):
        d = f"{pdir}/client{i}"
        ds_tr = BrainTumorDataset(np.load(f"{d}/X_train.npy"), np.load(f"{d}/y_train.npy"), TRAIN_TF)
        ds_va = BrainTumorDataset(np.load(f"{d}/X_val.npy"), np.load(f"{d}/y_val.npy"), TEST_TF)
        ds_te = BrainTumorDataset(np.load(f"{d}/X_test.npy"), np.load(f"{d}/y_test.npy"), TEST_TF)
        loaders[f"client{i}"] = {"train": DataLoader(ds_tr, bs, shuffle=True, num_workers=nw, pin_memory=True),
            "val": DataLoader(ds_va, bs, shuffle=False, num_workers=nw, pin_memory=True),
            "test": DataLoader(ds_te, bs, shuffle=False, num_workers=nw, pin_memory=True), "train_size": len(ds_tr)}
        print(f"client{i}: Train={len(ds_tr)} Val={len(ds_va)} Test={len(ds_te)}")
    gds = BrainTumorDataset(np.load(f"{tdir}/X_test.npy"), np.load(f"{tdir}/y_test.npy"), TEST_TF)
    loaders["global_test"] = DataLoader(gds, bs, shuffle=False, num_workers=nw, pin_memory=True)
    print(f"Global test: {len(gds)}"); return loaders

class BrainTumorResNet(nn.Module):
    def __init__(self, n=4, pretrained=True):
        super().__init__()
        w = models.ResNet18_Weights.DEFAULT if pretrained else None
        self.model = models.resnet18(weights=w); self.model.fc = nn.Linear(self.model.fc.in_features, n)
    def forward(self, x): return self.model(x)

def create_model(n=4, device="cuda"):
    m = BrainTumorResNet(n).to(device)
    print(f"Model: ResNet-18 | Params: {sum(p.numel() for p in m.parameters()):,} | Classes: {n}"); return m

class FederatedClient:
    def __init__(self, cid, train_loader, val_loader, device="cuda"):
        self.client_id = cid; self.train_loader = train_loader
        self.val_loader = val_loader; self.device = device
        self.model = None; self.optimizer = None
        self.criterion = nn.CrossEntropyLoss(); self.dataset_size = len(train_loader.dataset)
    def set_model(self, gm): self.model = copy.deepcopy(gm).to(self.device)
    def set_optimizer(self, lr=0.001): self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
    def train_local(self, epochs=5, verbose=False):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs); loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea
    def validate(self):
        self.model.eval(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in self.val_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.model(imgs); ls += self.criterion(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return ls/len(self.val_loader), 100.*c/t
    def get_dataset_size(self): return self.dataset_size

class FedProxClient(FederatedClient):
    def train_local(self, epochs=5, verbose=False, mu=0.01, global_params=None):
        self.model.train(); el, ea = [], []
        for ep in range(epochs):
            ls, c, t = 0.0, 0, 0
            for imgs, labs in self.train_loader:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                self.optimizer.zero_grad(); out = self.model(imgs)
                loss = self.criterion(out, labs)
                if global_params is not None:
                    prox = sum(torch.norm(pl - pg.detach())**2 for pl, pg in zip(self.model.parameters(), global_params))
                    loss = loss + (mu / 2.0) * prox
                loss.backward(); self.optimizer.step()
                ls += loss.item(); _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
            el.append(ls/len(self.train_loader)); ea.append(100.*c/t)
        return self.model.state_dict(), el, ea

class FedAvgServer:
    def __init__(self, gm, clients, device="cuda"):
        self.global_model = gm; self.clients = clients; self.device = device
        self.total_samples = sum(c.get_dataset_size() for c in clients)
        print(f"FedAvg Server | clients={len(clients)} total={self.total_samples}")
    def aggregate_weights(self, cw):
        first = cw[0][0]; agg = {}
        for k in first:
            if first[k].is_floating_point():
                acc = torch.zeros_like(first[k], dtype=torch.float32)
                for sd, nk in cw: acc = acc + sd[k].float() * (nk / self.total_samples)
                agg[k] = acc.to(first[k].dtype)
            else: agg[k] = first[k].clone()
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)

class QPSOServer:
    def __init__(self, gm, clients, device="cuda", beta=0.7):
        self.global_model = gm; self.clients = clients; self.device = device; self.beta = beta
        self.personal_best = {}; self.personal_best_scores = {}
        self.global_best = None; self.global_best_score = 0.0; self.mean_best = None
        print(f"QPSO Server | clients={len(clients)} beta={beta}")
    def initialize_particles(self):
        s = copy.deepcopy(self.global_model.state_dict())
        for c in self.clients: self.personal_best[c.client_id] = copy.deepcopy(s); self.personal_best_scores[c.client_id] = 0.0
        self.global_best = copy.deepcopy(s); self.global_best_score = 0.0; print("QPSO particles initialised")
    def update_personal_best(self, cid, w, acc):
        if acc > self.personal_best_scores[cid]: self.personal_best[cid] = copy.deepcopy(w); self.personal_best_scores[cid] = acc; return True
        return False
    def update_global_best(self, cid, acc):
        if acc > self.global_best_score: self.global_best = copy.deepcopy(self.personal_best[cid]); self.global_best_score = acc; return True
        return False
    def calculate_mean_best(self):
        fid = self.clients[0].client_id
        self.mean_best = {k: torch.zeros_like(v, dtype=torch.float32) for k, v in self.personal_best[fid].items()}
        for c in self.clients:
            for k in self.mean_best: self.mean_best[k] += self.personal_best[c.client_id][k].float()
        for k in self.mean_best: self.mean_best[k] /= len(self.clients)
    def qpso_aggregate(self, cwl):
        for cid, w, acc in cwl:
            pb = self.update_personal_best(cid, w, acc); gb = self.update_global_best(cid, acc)
            if pb: print(f"  {cid}: pbest {acc:.2f}%")
            if gb: print(f"  {cid}: gbest {acc:.2f}%")
        self.calculate_mean_best(); agg = copy.deepcopy(self.global_best)
        for k in agg:
            if not agg[k].is_floating_point(): continue
            ps = torch.zeros_like(agg[k], dtype=torch.float32)
            for c in self.clients: ps += self.personal_best[c.client_id][k].float()
            phi = torch.rand_like(agg[k].float())
            u = torch.rand_like(agg[k].float()).clamp(min=0.3, max=1.0)
            p = phi*(ps/len(self.clients)) + (1-phi)*self.global_best[k].float()
            sign = torch.where(torch.rand_like(agg[k].float())<0.5, torch.ones_like(agg[k].float()), -torch.ones_like(agg[k].float()))
            pert = self.beta * torch.abs(self.mean_best[k].float() - agg[k].float()) * torch.log(1.0/u)
            pert = pert.clamp(-0.1, 0.1)
            agg[k] = (p + sign * pert).to(self.global_best[k].dtype)
        return agg
    def evaluate_global_model(self, tl):
        self.global_model.eval(); crit = nn.CrossEntropyLoss(); ls, c, t = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labs in tl:
                imgs, labs = imgs.to(self.device), labs.to(self.device)
                out = self.global_model(imgs); ls += crit(out, labs).item()
                _, pred = out.max(1); t += labs.size(0); c += pred.eq(labs).sum().item()
        return 100.*c/t, ls/len(tl)
    def get_global_model(self): return copy.deepcopy(self.global_model)
print("All classes loaded")
# Out:
# All classes loaded

# %% [markdown]
# ## Data Preparation

# %%
# Setup 1: Natural Heterogeneity — use datasets as-is with all 4 classes
CLIENT1_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
CLIENT2_PATH = '/kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train'
CLIENT3_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'

# Verify paths
for name, path in [("Client1 (Masoud Test)", CLIENT1_PATH), ("Client2 (BRISC)", CLIENT2_PATH), ("Client3 (Masoud Train)", CLIENT3_PATH)]:
    print(f"\n{name}: {path}")
    if os.path.exists(path):
        for d in sorted(os.listdir(path)):
            full = os.path.join(path, d)
            if os.path.isdir(full): print(f"  {d}/ ({len(os.listdir(full))} files)")
    else: print("  PATH NOT FOUND!")

prep = Preprocessor()
prep.process_dataset(CLIENT1_PATH, 'client1')
prep.process_dataset(CLIENT2_PATH, 'client2')
prep.process_dataset(CLIENT3_PATH, 'client3')
Preprocessor.create_global_test()
data_loaders = create_data_loaders()
print("\nSetup 1 data ready!")
# Out:
# Client1 (Masoud Test): /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
#   glioma/ (400 files)
#   meningioma/ (400 files)
#   notumor/ (400 files)
#   pituitary/ (400 files)
#
# Client2 (BRISC): /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
#   glioma/ (1147 files)
#   meningioma/ (1329 files)
#   no_tumor/ (1067 files)
#   pituitary/ (1457 files)
#
# Client3 (Masoud Train): /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
#   glioma/ (1400 files)
#   meningioma/ (1400 files)
#   notumor/ (1400 files)
#   pituitary/ (1400 files)
#
# ============================================================
# Processing client1 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing
# ============================================================
#   glioma: 400 images (label=0)
#     glioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   meningioma: 400 images (label=1)
#     meningioma:   0%|          | 0/400 [00:00<?, ?it/s]
#   notumor: 400 images (label=2)
#     notumor:   0%|          | 0/400 [00:00<?, ?it/s]
#   pituitary: 400 images (label=3)
#     pituitary:   0%|          | 0/400 [00:00<?, ?it/s]
#   Total: 1600 | Classes: [400 400 400 400]
#   Train:1119 Val:240 Test:241
#   Saved -> /kaggle/working/data/processed/client1
#
# ============================================================
# Processing client2 <- /kaggle/input/datasets/briscdataset/brisc2025/brisc2025/classification_task/train
# ============================================================
#   glioma: 1147 images (label=0)
#     glioma:   0%|          | 0/1147 [00:00<?, ?it/s]
#   meningioma: 1329 images (label=1)
#     meningioma:   0%|          | 0/1329 [00:00<?, ?it/s]
#   no_tumor: 1067 images (label=2)
#     no_tumor:   0%|          | 0/1067 [00:00<?, ?it/s]
#   pituitary: 1457 images (label=3)
#     pituitary:   0%|          | 0/1457 [00:00<?, ?it/s]
#   Total: 5000 | Classes: [1147 1329 1067 1457]
#   Train:3499 Val:750 Test:751
#   Saved -> /kaggle/working/data/processed/client2
#
# ============================================================
# Processing client3 <- /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training
# ============================================================
#   glioma: 1400 images (label=0)
#     glioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   meningioma: 1400 images (label=1)
#     meningioma:   0%|          | 0/1400 [00:00<?, ?it/s]
#   notumor: 1400 images (label=2)
#     notumor:   0%|          | 0/1400 [00:00<?, ?it/s]
#   pituitary: 1400 images (label=3)
#     pituitary:   0%|          | 0/1400 [00:00<?, ?it/s]
#   Total: 5600 | Classes: [1400 1400 1400 1400]
#   Train:3919 Val:840 Test:841
#   Saved -> /kaggle/working/data/processed/client3
# Global test: 1833 images | Classes: [442 470 432 489]
# client1: Train=1119 Val=240 Test=241
# client2: Train=3499 Val=750 Test=751
# client3: Train=3919 Val=840 Test=841
# Global test: 1833
#
# Setup 1 data ready!

# %% [markdown]
# ## Training Functions

# %%
def train_fedavg(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDAVG TRAINING START\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedavg_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedavg/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDAVG DONE best {best:.2f}%\n{'='*80}"); return h

def train_fedprox(server, clients, gtl, nr=100, le=5, lr=0.001, mu=0.01, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  FEDPROX TRAINING START (mu="+str(mu)+")\n"+"="*80)
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        gp = list(server.global_model.parameters())
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose, mu=mu, global_params=gp)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((w, cl.get_dataset_size()))
        agg = server.aggregate_weights(cw); server.global_model.load_state_dict(agg)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/fedprox_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/fedprox/metrics.csv", index=False)
    print(f"\n{'='*80}\n  FEDPROX DONE best {best:.2f}%\n{'='*80}"); return h

def train_qpso(server, clients, gtl, nr=100, le=5, lr=0.001, se=10, sd="/kaggle/working", verbose=False):
    print("="*80+"\n  QPSO-FL TRAINING START\n"+"="*80); server.initialize_particles()
    h = {"round":[],"global_test_acc":[],"global_test_loss":[],"global_best_score":[],
         "client1_val_acc":[],"client2_val_acc":[],"client3_val_acc":[],
         "client1_pbest":[],"client2_pbest":[],"client3_pbest":[],"round_time":[]}
    best = 0.0
    for rnd in range(1, nr+1):
        t0 = time.time(); print(f"\n{'='*60} ROUND {rnd}/{nr}"); cw = []
        for cl in clients:
            print(f"  {cl.client_id} training...", end=" ")
            cl.set_model(server.get_global_model()); cl.set_optimizer(lr)
            w,_,_ = cl.train_local(le, verbose=verbose)
            vl, va = cl.validate(); print(f"val={va:.2f}%")
            h[f"{cl.client_id}_val_acc"].append(va); cw.append((cl.client_id, w, va))
        print("  QPSO aggregating..."); agg = server.qpso_aggregate(cw)
        server.global_model.load_state_dict(agg)
        for c in clients: h[f"{c.client_id}_pbest"].append(server.personal_best_scores[c.client_id])
        h["global_best_score"].append(server.global_best_score)
        ga, gl = server.evaluate_global_model(gtl); dt = time.time()-t0
        h["round"].append(rnd); h["global_test_acc"].append(ga); h["global_test_loss"].append(gl); h["round_time"].append(dt)
        print(f"  Global: acc={ga:.2f}% loss={gl:.4f} gbest={server.global_best_score:.2f}% ({dt:.1f}s)")
        if ga > best: best = ga; torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_best.pth"); print(f"  New best! {best:.2f}%")
        if rnd % se == 0: torch.save(server.global_model.state_dict(), f"{sd}/models/qpso_round_{rnd}.pth")
        pd.DataFrame(h).to_csv(f"{sd}/results/qpso/metrics.csv", index=False)
    print(f"\n{'='*80}\n  QPSO-FL DONE best {best:.2f}% gbest {server.global_best_score:.2f}%\n{'='*80}"); return h
print("Trainers loaded")
# Out:
# Trainers loaded

# %% [markdown]
# ## FedAvg Training
# ⚠️ Set `nr=5` for a quick test first!

# %%
fedavg_model = create_model(NUM_CLASSES, device)
fedavg_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                  data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedavg_server = FedAvgServer(fedavg_model, fedavg_clients, device=device)
fedavg_history = train_fedavg(fedavg_server, fedavg_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 194MB/s]
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8537
# ================================================================================
#   FEDAVG TRAINING START
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=77.92%
#   client2 training... val=90.40%
#   client3 training... val=96.43%
#   Global: acc=41.13% loss=1.1321 (97.5s)
#   New best! 41.13%
#
# ============================================================ ROUND 2/100
#   client1 training... val=67.92%
#   client2 training... val=96.40%
#   client3 training... val=94.76%
#   Global: acc=97.05% loss=0.1220 (96.4s)
#   New best! 97.05%
#
# ============================================================ ROUND 3/100
#   client1 training... val=83.33%
#   client2 training... val=96.67%
#   client3 training... val=97.74%
#   Global: acc=97.87% loss=0.0899 (95.9s)
#   New best! 97.87%
#
# ============================================================ ROUND 4/100
#   client1 training... val=81.25%
#   client2 training... val=95.87%
#   client3 training... val=98.33%
#   Global: acc=97.87% loss=0.1082 (97.7s)
#
# ============================================================ ROUND 5/100
#   client1 training... val=95.42%
#   client2 training... val=98.00%
#   client3 training... val=98.33%
#   Global: acc=98.64% loss=0.0832 (97.1s)
#   New best! 98.64%
#
# ============================================================ ROUND 6/100
#   client1 training... val=96.25%
#   client2 training... val=98.00%
#   client3 training... val=96.90%
#   Global: acc=98.64% loss=0.0859 (96.6s)
#
# ============================================================ ROUND 7/100
#   client1 training... val=96.67%
#   client2 training... val=96.40%
#   client3 training... val=98.21%
#   Global: acc=98.42% loss=0.0945 (96.7s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=95.83%
#   client2 training... val=97.07%
#   client3 training... val=98.57%
#   Global: acc=98.80% loss=0.0786 (96.0s)
#   New best! 98.80%
#
# ============================================================ ROUND 9/100
#   client1 training... val=96.67%
#   client2 training... val=98.40%
#   client3 training... val=98.93%
#   Global: acc=98.53% loss=0.0925 (94.6s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=97.50%
#   client2 training... val=99.33%
#   client3 training... val=97.50%
#   Global: acc=98.69% loss=0.0810 (97.0s)
#
# ============================================================ ROUND 11/100
#   client1 training... val=96.67%
#   client2 training... val=99.07%
#   client3 training... val=98.33%
#   Global: acc=98.42% loss=0.0904 (97.2s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=95.83%
#   client2 training... val=99.07%
#   client3 training... val=98.93%
#   Global: acc=98.64% loss=0.0839 (95.3s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=97.50%
#   client2 training... val=98.93%
#   client3 training... val=99.05%
#   Global: acc=98.80% loss=0.0903 (96.1s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=97.08%
#   client2 training... val=98.80%
#   client3 training... val=98.69%
#   Global: acc=98.53% loss=0.1020 (97.2s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=96.67%
#   client2 training... val=99.47%
#   client3 training... val=99.64%
#   Global: acc=98.64% loss=0.1100 (95.8s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=95.83%
#   client2 training... val=92.40%
#   client3 training... val=99.40%
#   Global: acc=98.80% loss=0.0932 (96.3s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=96.25%
#   client2 training... val=99.47%
#   client3 training... val=99.05%
#   Global: acc=98.47% loss=0.1001 (97.8s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=97.50%
#   client2 training... val=99.47%
#   client3 training... val=99.29%
#   Global: acc=98.75% loss=0.0957 (96.3s)
#
# ============================================================ ROUND 19/100
#   client1 training... val=95.83%
#   client2 training... val=99.33%
#   client3 training... val=99.40%
#   Global: acc=98.75% loss=0.1096 (96.1s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=96.67%
#   client2 training... val=99.20%
#   client3 training... val=99.05%
#   Global: acc=98.91% loss=0.1297 (97.0s)
#   New best! 98.91%
#
# ============================================================ ROUND 21/100
#   client1 training... val=97.08%
#   client2 training... val=99.20%
#   client3 training... val=99.52%
#   Global: acc=98.42% loss=0.1135 (97.4s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=96.67%
#   client2 training... val=99.47%
#   client3 training... val=99.29%
#   Global: acc=98.80% loss=0.1315 (97.0s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=96.67%
#   client2 training... val=98.93%
#   client3 training... val=99.29%
#   Global: acc=98.75% loss=0.1332 (95.5s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=96.67%
#   client2 training... val=98.67%
#   client3 training... val=99.40%
#   Global: acc=98.75% loss=0.1306 (95.8s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=97.92%
#   client2 training... val=99.60%
#   client3 training... val=99.40%
#   Global: acc=98.85% loss=0.1274 (96.2s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=97.50%
#   client2 training... val=99.07%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.1483 (95.5s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=95.83%
#   client2 training... val=99.73%
#   client3 training... val=99.17%
#   Global: acc=98.96% loss=0.1184 (96.7s)
#   New best! 98.96%
#
# ============================================================ ROUND 28/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.40%
#   Global: acc=98.91% loss=0.1112 (95.6s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=97.08%
#   client2 training... val=99.33%
#   client3 training... val=99.76%
#   Global: acc=98.75% loss=0.1202 (97.6s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=96.25%
#   client2 training... val=99.47%
#   client3 training... val=99.64%
#   Global: acc=98.85% loss=0.1084 (96.0s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=95.42%
#   client2 training... val=99.20%
#   client3 training... val=98.45%
#   Global: acc=98.53% loss=0.0996 (96.9s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.40%
#   Global: acc=98.75% loss=0.1240 (96.5s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.76%
#   Global: acc=98.69% loss=0.1792 (98.1s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=97.50%
#   client2 training... val=99.47%
#   client3 training... val=99.29%
#   Global: acc=98.85% loss=0.1316 (96.8s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.40%
#   Global: acc=98.96% loss=0.1530 (96.8s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=97.50%
#   client2 training... val=99.47%
#   client3 training... val=99.40%
#   Global: acc=98.80% loss=0.1805 (96.8s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=96.25%
#   client2 training... val=99.60%
#   client3 training... val=99.52%
#   Global: acc=98.75% loss=0.1848 (96.5s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=98.58% loss=0.1917 (98.2s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=98.33%
#   client2 training... val=98.00%
#   client3 training... val=99.40%
#   Global: acc=98.64% loss=0.1375 (97.5s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=96.67%
#   client2 training... val=99.33%
#   client3 training... val=98.93%
#   Global: acc=98.64% loss=0.1802 (96.2s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=97.08%
#   client2 training... val=99.60%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.2006 (95.5s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=97.92%
#   client2 training... val=99.47%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.2056 (97.0s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=98.33%
#   client2 training... val=99.60%
#   client3 training... val=99.52%
#   Global: acc=98.47% loss=0.1799 (97.8s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=96.25%
#   client2 training... val=99.73%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.1347 (96.5s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=96.67%
#   client2 training... val=95.87%
#   client3 training... val=99.52%
#   Global: acc=98.69% loss=0.1516 (96.7s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=97.08%
#   client2 training... val=99.33%
#   client3 training... val=99.17%
#   Global: acc=98.85% loss=0.1461 (95.7s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=97.50%
#   client2 training... val=99.73%
#   client3 training... val=99.05%
#   Global: acc=98.91% loss=0.1816 (95.2s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.29%
#   Global: acc=98.80% loss=0.1370 (95.4s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=97.50%
#   client2 training... val=99.47%
#   client3 training... val=99.52%
#   Global: acc=98.80% loss=0.1705 (96.1s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=97.08%
#   client2 training... val=99.47%
#   client3 training... val=99.52%
#   Global: acc=98.96% loss=0.1706 (96.3s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=99.29%
#   Global: acc=98.96% loss=0.1883 (96.6s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=95.83%
#   client2 training... val=99.60%
#   client3 training... val=99.17%
#   Global: acc=98.85% loss=0.2328 (95.8s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=96.25%
#   client2 training... val=99.47%
#   client3 training... val=99.29%
#   Global: acc=98.91% loss=0.1500 (96.3s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=97.92%
#   client2 training... val=99.20%
#   client3 training... val=99.05%
#   Global: acc=98.75% loss=0.1666 (96.5s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.64%
#   Global: acc=98.69% loss=0.1527 (97.4s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=97.50%
#   client2 training... val=99.47%
#   client3 training... val=99.29%
#   Global: acc=98.64% loss=0.1789 (96.4s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.40%
#   Global: acc=98.75% loss=0.1749 (95.2s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=96.67%
#   client2 training... val=99.33%
#   client3 training... val=99.52%
#   Global: acc=98.69% loss=0.1727 (96.0s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.52%
#   Global: acc=98.85% loss=0.2025 (97.2s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.17%
#   Global: acc=98.53% loss=0.1967 (95.8s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.64% loss=0.1707 (96.9s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=97.08%
#   client2 training... val=99.87%
#   client3 training... val=99.52%
#   Global: acc=98.96% loss=0.1533 (98.0s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=97.92%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.96% loss=0.1651 (96.5s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=96.25%
#   client2 training... val=99.47%
#   client3 training... val=99.76%
#   Global: acc=98.69% loss=0.1949 (96.4s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=96.25%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=98.96% loss=0.1538 (97.2s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.1954 (97.8s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=96.25%
#   client2 training... val=99.33%
#   client3 training... val=99.29%
#   Global: acc=98.53% loss=0.1724 (96.6s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=96.67%
#   client2 training... val=99.60%
#   client3 training... val=99.64%
#   Global: acc=98.69% loss=0.1957 (95.8s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.64%
#   Global: acc=98.75% loss=0.1861 (97.9s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=97.92%
#   client2 training... val=99.20%
#   client3 training... val=99.88%
#   Global: acc=98.64% loss=0.2266 (97.2s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=96.67%
#   client2 training... val=98.13%
#   client3 training... val=99.64%
#   Global: acc=98.69% loss=0.2110 (95.2s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=97.08%
#   client2 training... val=99.07%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.2540 (97.4s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=95.83%
#   client2 training... val=99.20%
#   client3 training... val=99.64%
#   Global: acc=98.64% loss=0.2049 (94.8s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=97.50%
#   client2 training... val=99.60%
#   client3 training... val=99.40%
#   Global: acc=98.69% loss=0.2318 (95.2s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=96.25%
#   client2 training... val=99.73%
#   client3 training... val=99.88%
#   Global: acc=98.75% loss=0.1750 (96.4s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=96.25%
#   client2 training... val=99.60%
#   client3 training... val=99.76%
#   Global: acc=98.69% loss=0.2013 (96.4s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=97.08%
#   client2 training... val=99.60%
#   client3 training... val=99.40%
#   Global: acc=98.80% loss=0.2205 (97.0s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.52%
#   Global: acc=98.80% loss=0.2489 (96.0s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=96.25%
#   client2 training... val=99.60%
#   client3 training... val=99.88%
#   Global: acc=98.80% loss=0.1622 (96.7s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=96.67%
#   client2 training... val=98.67%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.1907 (96.1s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=96.25%
#   client2 training... val=99.20%
#   client3 training... val=99.76%
#   Global: acc=98.64% loss=0.2069 (96.9s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=97.08%
#   client2 training... val=98.53%
#   client3 training... val=99.17%
#   Global: acc=98.47% loss=0.2888 (95.6s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=96.67%
#   client2 training... val=99.47%
#   client3 training... val=99.52%
#   Global: acc=98.69% loss=0.2057 (98.0s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=97.50%
#   client2 training... val=99.60%
#   client3 training... val=99.17%
#   Global: acc=98.58% loss=0.2474 (96.2s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.52%
#   Global: acc=98.69% loss=0.2417 (96.1s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=97.08%
#   client2 training... val=99.60%
#   client3 training... val=99.76%
#   Global: acc=98.69% loss=0.2757 (97.3s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.64% loss=0.1644 (96.4s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=97.08%
#   client2 training... val=99.07%
#   client3 training... val=99.17%
#   Global: acc=98.64% loss=0.2300 (97.1s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=96.67%
#   client2 training... val=99.33%
#   client3 training... val=99.52%
#   Global: acc=98.58% loss=0.2352 (96.8s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.29%
#   Global: acc=98.96% loss=0.2073 (96.1s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=97.50%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=98.96% loss=0.2839 (95.5s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=97.92%
#   client2 training... val=99.60%
#   client3 training... val=99.17%
#   Global: acc=98.80% loss=0.1966 (97.3s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=97.92%
#   client2 training... val=99.07%
#   client3 training... val=96.67%
#   Global: acc=98.64% loss=0.1861 (95.5s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=97.92%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.85% loss=0.1635 (96.2s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=97.92%
#   client2 training... val=98.80%
#   client3 training... val=99.40%
#   Global: acc=98.47% loss=0.2377 (96.3s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.40%
#   Global: acc=98.53% loss=0.2169 (96.9s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=97.92%
#   client2 training... val=99.73%
#   client3 training... val=98.33%
#   Global: acc=98.58% loss=0.2327 (96.8s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=96.25%
#   client2 training... val=99.47%
#   client3 training... val=99.64%
#   Global: acc=98.69% loss=0.2308 (95.4s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=96.67%
#   client2 training... val=99.60%
#   client3 training... val=99.88%
#   Global: acc=98.75% loss=0.2218 (97.6s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=97.50%
#   client2 training... val=99.60%
#   client3 training... val=99.88%
#   Global: acc=98.69% loss=0.2424 (96.3s)
#
# ================================================================================
#   FEDAVG DONE best 98.96%
# ================================================================================

# %% [markdown]
# ## FedProx Training

# %%
torch.cuda.empty_cache()
fedprox_model = create_model(NUM_CLASSES, device)
fedprox_clients = [FedProxClient(f'client{i}', data_loaders[f'client{i}']['train'],
                   data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
fedprox_server = FedAvgServer(fedprox_model, fedprox_clients, device=device)
fedprox_history = train_fedprox(fedprox_server, fedprox_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, mu=0.01, se=10, verbose=False)
# Out:
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# FedAvg Server | clients=3 total=8537
# ================================================================================
#   FEDPROX TRAINING START (mu=0.01)
# ================================================================================
#
# ============================================================ ROUND 1/100
#   client1 training... val=89.58%
#   client2 training... val=69.60%
#   client3 training... val=92.02%
#   Global: acc=89.85% loss=0.4236 (103.9s)
#   New best! 89.85%
#
# ============================================================ ROUND 2/100
#   client1 training... val=77.50%
#   client2 training... val=81.73%
#   client3 training... val=81.79%
#   Global: acc=95.31% loss=0.1671 (104.3s)
#   New best! 95.31%
#
# ============================================================ ROUND 3/100
#   client1 training... val=84.58%
#   client2 training... val=93.47%
#   client3 training... val=79.29%
#   Global: acc=95.25% loss=0.1677 (103.9s)
#
# ============================================================ ROUND 4/100
#   client1 training... val=92.08%
#   client2 training... val=55.20%
#   client3 training... val=95.12%
#   Global: acc=96.24% loss=0.1298 (103.9s)
#   New best! 96.24%
#
# ============================================================ ROUND 5/100
#   client1 training... val=84.17%
#   client2 training... val=92.67%
#   client3 training... val=94.17%
#   Global: acc=96.73% loss=0.1252 (105.4s)
#   New best! 96.73%
#
# ============================================================ ROUND 6/100
#   client1 training... val=89.17%
#   client2 training... val=96.93%
#   client3 training... val=97.38%
#   Global: acc=97.60% loss=0.1118 (104.4s)
#   New best! 97.60%
#
# ============================================================ ROUND 7/100
#   client1 training... val=94.58%
#   client2 training... val=96.93%
#   client3 training... val=96.67%
#   Global: acc=98.09% loss=0.0944 (104.7s)
#   New best! 98.09%
#
# ============================================================ ROUND 8/100
#   client1 training... val=84.58%
#   client2 training... val=97.07%
#   client3 training... val=95.83%
#   Global: acc=97.71% loss=0.1280 (104.2s)
#
# ============================================================ ROUND 9/100
#   client1 training... val=95.00%
#   client2 training... val=93.73%
#   client3 training... val=97.02%
#   Global: acc=98.09% loss=0.0751 (104.0s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=89.58%
#   client2 training... val=97.07%
#   client3 training... val=96.43%
#   Global: acc=98.31% loss=0.0823 (103.7s)
#   New best! 98.31%
#
# ============================================================ ROUND 11/100
#   client1 training... val=93.33%
#   client2 training... val=98.67%
#   client3 training... val=97.62%
#   Global: acc=98.36% loss=0.0744 (103.8s)
#   New best! 98.36%
#
# ============================================================ ROUND 12/100
#   client1 training... val=93.75%
#   client2 training... val=96.80%
#   client3 training... val=93.10%
#   Global: acc=97.87% loss=0.1009 (103.8s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=92.92%
#   client2 training... val=96.40%
#   client3 training... val=97.74%
#   Global: acc=98.47% loss=0.0762 (104.1s)
#   New best! 98.47%
#
# ============================================================ ROUND 14/100
#   client1 training... val=95.83%
#   client2 training... val=96.40%
#   client3 training... val=98.81%
#   Global: acc=98.31% loss=0.1016 (103.8s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=95.00%
#   client2 training... val=99.47%
#   client3 training... val=92.98%
#   Global: acc=98.47% loss=0.0727 (104.5s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=95.42%
#   client2 training... val=90.13%
#   client3 training... val=91.55%
#   Global: acc=96.94% loss=0.1406 (103.7s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=92.08%
#   client2 training... val=98.67%
#   client3 training... val=99.05%
#   Global: acc=98.53% loss=0.0889 (103.8s)
#   New best! 98.53%
#
# ============================================================ ROUND 18/100
#   client1 training... val=94.58%
#   client2 training... val=99.73%
#   client3 training... val=99.29%
#   Global: acc=98.69% loss=0.0753 (103.9s)
#   New best! 98.69%
#
# ============================================================ ROUND 19/100
#   client1 training... val=94.17%
#   client2 training... val=98.27%
#   client3 training... val=99.05%
#   Global: acc=98.69% loss=0.0787 (104.4s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=89.58%
#   client2 training... val=98.67%
#   client3 training... val=98.93%
#   Global: acc=98.80% loss=0.0679 (104.3s)
#   New best! 98.80%
#
# ============================================================ ROUND 21/100
#   client1 training... val=94.17%
#   client2 training... val=99.07%
#   client3 training... val=99.05%
#   Global: acc=98.69% loss=0.0755 (104.1s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=95.00%
#   client2 training... val=99.47%
#   client3 training... val=98.21%
#   Global: acc=98.91% loss=0.0738 (104.0s)
#   New best! 98.91%
#
# ============================================================ ROUND 23/100
#   client1 training... val=93.33%
#   client2 training... val=94.53%
#   client3 training... val=98.81%
#   Global: acc=98.53% loss=0.0890 (105.9s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=95.42%
#   client2 training... val=99.33%
#   client3 training... val=98.69%
#   Global: acc=98.58% loss=0.0889 (104.8s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=92.92%
#   client2 training... val=98.53%
#   client3 training... val=99.64%
#   Global: acc=98.75% loss=0.0931 (104.0s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=97.50%
#   client2 training... val=90.40%
#   client3 training... val=99.40%
#   Global: acc=98.64% loss=0.0913 (104.2s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=96.25%
#   client2 training... val=98.80%
#   client3 training... val=97.50%
#   Global: acc=98.25% loss=0.0975 (103.9s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=97.92%
#   client2 training... val=99.47%
#   client3 training... val=96.07%
#   Global: acc=98.64% loss=0.0813 (103.8s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=96.25%
#   client2 training... val=96.93%
#   client3 training... val=99.17%
#   Global: acc=98.80% loss=0.0679 (104.1s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=95.83%
#   client2 training... val=98.53%
#   client3 training... val=99.05%
#   Global: acc=98.69% loss=0.0734 (104.4s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=96.25%
#   client2 training... val=94.80%
#   client3 training... val=99.40%
#   Global: acc=98.58% loss=0.0980 (103.7s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=95.42%
#   client2 training... val=99.73%
#   client3 training... val=99.88%
#   Global: acc=98.80% loss=0.0812 (104.3s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=94.17%
#   client2 training... val=99.60%
#   client3 training... val=99.76%
#   Global: acc=98.80% loss=0.0743 (104.3s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=97.08%
#   client2 training... val=89.33%
#   client3 training... val=99.76%
#   Global: acc=98.80% loss=0.0758 (104.9s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.80% loss=0.0834 (103.9s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.91% loss=0.0747 (104.6s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=97.08%
#   client2 training... val=61.33%
#   client3 training... val=99.52%
#   Global: acc=98.69% loss=0.0882 (104.6s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=95.83%
#   client2 training... val=99.60%
#   client3 training... val=99.29%
#   Global: acc=98.53% loss=0.0859 (103.8s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=95.83%
#   client2 training... val=99.20%
#   client3 training... val=99.29%
#   Global: acc=98.75% loss=0.0806 (103.8s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=94.17%
#   client2 training... val=66.53%
#   client3 training... val=99.76%
#   Global: acc=98.36% loss=0.1139 (104.2s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=95.42%
#   client2 training... val=99.33%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.0798 (106.5s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=94.17%
#   client2 training... val=99.87%
#   client3 training... val=99.88%
#   Global: acc=99.02% loss=0.0718 (104.2s)
#   New best! 99.02%
#
# ============================================================ ROUND 43/100
#   client1 training... val=95.42%
#   client2 training... val=99.87%
#   client3 training... val=87.86%
#   Global: acc=98.58% loss=0.1126 (104.2s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=96.25%
#   client2 training... val=99.87%
#   client3 training... val=98.69%
#   Global: acc=98.85% loss=0.0890 (104.9s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=95.83%
#   client2 training... val=98.53%
#   client3 training... val=99.40%
#   Global: acc=98.85% loss=0.0839 (103.9s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=95.42%
#   client2 training... val=99.47%
#   client3 training... val=99.52%
#   Global: acc=98.80% loss=0.0870 (105.0s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=99.76%
#   Global: acc=98.91% loss=0.0830 (103.6s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=94.58%
#   client2 training... val=99.20%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.0786 (103.9s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=98.81%
#   Global: acc=98.64% loss=0.0766 (103.3s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=96.25%
#   client2 training... val=97.20%
#   client3 training... val=99.64%
#   Global: acc=98.64% loss=0.0681 (103.2s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.64%
#   Global: acc=98.91% loss=0.0756 (103.5s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=97.08%
#   client2 training... val=99.73%
#   client3 training... val=95.83%
#   Global: acc=98.42% loss=0.1019 (104.1s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.40%
#   Global: acc=98.85% loss=0.0781 (104.1s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=97.08%
#   client2 training... val=99.47%
#   client3 training... val=99.88%
#   Global: acc=98.96% loss=0.0850 (103.5s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.52%
#   Global: acc=99.07% loss=0.0762 (103.7s)
#   New best! 99.07%
#
# ============================================================ ROUND 56/100
#   client1 training... val=97.08%
#   client2 training... val=98.67%
#   client3 training... val=99.64%
#   Global: acc=98.91% loss=0.0913 (103.9s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.40%
#   Global: acc=99.13% loss=0.0605 (103.6s)
#   New best! 99.13%
#
# ============================================================ ROUND 58/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=98.93%
#   Global: acc=98.91% loss=0.0714 (104.8s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.40%
#   Global: acc=98.85% loss=0.0812 (103.7s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=93.75%
#   client2 training... val=100.00%
#   client3 training... val=99.05%
#   Global: acc=98.80% loss=0.0771 (103.6s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=97.08%
#   client2 training... val=99.87%
#   client3 training... val=99.52%
#   Global: acc=99.02% loss=0.0788 (104.2s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=96.67%
#   client2 training... val=99.73%
#   client3 training... val=99.76%
#   Global: acc=99.07% loss=0.0743 (103.3s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=95.42%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.96% loss=0.0807 (103.6s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=96.25%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=99.07% loss=0.0765 (104.3s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=95.42%
#   client2 training... val=99.73%
#   client3 training... val=99.52%
#   Global: acc=98.91% loss=0.0845 (105.1s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=98.91% loss=0.0737 (104.9s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.64%
#   Global: acc=98.91% loss=0.0838 (104.4s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=96.25%
#   client2 training... val=99.07%
#   client3 training... val=99.76%
#   Global: acc=98.96% loss=0.0991 (104.0s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=98.33%
#   client2 training... val=100.00%
#   client3 training... val=99.64%
#   Global: acc=98.85% loss=0.0985 (104.2s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.91% loss=0.0919 (104.1s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.91% loss=0.0868 (104.4s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.85% loss=0.0857 (104.5s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=97.50%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.0872 (104.8s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=97.08%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.0890 (103.8s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.64%
#   Global: acc=98.80% loss=0.0888 (104.2s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=97.50%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.0783 (106.2s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.96% loss=0.0748 (103.9s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=99.13% loss=0.0834 (103.5s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=94.17%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.85% loss=0.0806 (104.2s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=93.75%
#   client2 training... val=99.87%
#   client3 training... val=99.88%
#   Global: acc=98.96% loss=0.0885 (103.9s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=95.83%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=99.07% loss=0.0866 (103.5s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=98.33%
#   client2 training... val=100.00%
#   client3 training... val=99.64%
#   Global: acc=98.85% loss=0.0791 (103.4s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=94.17%
#   client2 training... val=99.87%
#   client3 training... val=99.52%
#   Global: acc=98.96% loss=0.0721 (103.5s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=90.42%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.85% loss=0.0813 (104.2s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=96.67%
#   client2 training... val=60.53%
#   client3 training... val=99.88%
#   Global: acc=98.42% loss=0.0877 (103.8s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=97.50%
#   client2 training... val=100.00%
#   client3 training... val=99.64%
#   Global: acc=98.91% loss=0.0731 (104.1s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=97.50%
#   client2 training... val=99.87%
#   client3 training... val=99.76%
#   Global: acc=98.80% loss=0.0749 (104.2s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=95.83%
#   client2 training... val=99.87%
#   client3 training... val=99.88%
#   Global: acc=99.02% loss=0.0664 (103.2s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=97.92%
#   client2 training... val=99.87%
#   client3 training... val=99.64%
#   Global: acc=99.02% loss=0.0877 (104.2s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.88%
#   Global: acc=98.80% loss=0.0842 (103.8s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=97.50%
#   client2 training... val=99.87%
#   client3 training... val=99.52%
#   Global: acc=98.91% loss=0.0760 (104.4s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=97.50%
#   client2 training... val=99.07%
#   client3 training... val=99.76%
#   Global: acc=98.80% loss=0.0810 (104.4s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=96.67%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.96% loss=0.0777 (106.1s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=96.67%
#   client2 training... val=99.87%
#   client3 training... val=99.88%
#   Global: acc=99.02% loss=0.0765 (105.5s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=97.92%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=99.07% loss=0.0825 (103.7s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=97.92%
#   client2 training... val=100.00%
#   client3 training... val=99.40%
#   Global: acc=98.91% loss=0.0699 (104.0s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=96.25%
#   client2 training... val=100.00%
#   client3 training... val=99.76%
#   Global: acc=98.96% loss=0.0800 (104.3s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=97.08%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.85% loss=0.0753 (104.2s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=96.25%
#   client2 training... val=99.87%
#   client3 training... val=99.52%
#   Global: acc=98.91% loss=0.0913 (103.6s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=97.50%
#   client2 training... val=100.00%
#   client3 training... val=99.88%
#   Global: acc=98.91% loss=0.0804 (103.9s)
#
# ================================================================================
#   FEDPROX DONE best 99.13%
# ================================================================================

# %% [markdown]
# ## QPSO Training

# %%
torch.cuda.empty_cache()
qpso_model = create_model(NUM_CLASSES, device)
qpso_clients = [FederatedClient(f'client{i}', data_loaders[f'client{i}']['train'],
                data_loaders[f'client{i}']['val'], device=device) for i in range(1, 4)]
qpso_server = QPSOServer(qpso_model, qpso_clients, device=device, beta=0.7)
qpso_history = train_qpso(qpso_server, qpso_clients, data_loaders['global_test'],
    nr=100, le=5, lr=0.001, se=10, verbose=False)
print("\nAll training complete!")
# Out:
# Model: ResNet-18 | Params: 11,178,564 | Classes: 4
# QPSO Server | clients=3 beta=0.7
# ================================================================================
#   QPSO-FL TRAINING START
# ================================================================================
# QPSO particles initialised
#
# ============================================================ ROUND 1/100
#   client1 training... val=82.92%
#   client2 training... val=95.20%
#   client3 training... val=95.60%
#   QPSO aggregating...
#   client1: pbest 82.92%
#   client1: gbest 82.92%
#   client2: pbest 95.20%
#   client2: gbest 95.20%
#   client3: pbest 95.60%
#   client3: gbest 95.60%
#   Global: acc=77.09% loss=0.5488 gbest=95.60% (95.8s)
#   New best! 77.09%
#
# ============================================================ ROUND 2/100
#   client1 training... val=90.83%
#   client2 training... val=96.80%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   client1: pbest 90.83%
#   client2: pbest 96.80%
#   client2: gbest 96.80%
#   client3: pbest 95.83%
#   Global: acc=93.84% loss=0.2537 gbest=96.80% (96.8s)
#   New best! 93.84%
#
# ============================================================ ROUND 3/100
#   client1 training... val=90.00%
#   client2 training... val=86.67%
#   client3 training... val=96.79%
#   QPSO aggregating...
#   client3: pbest 96.79%
#   Global: acc=95.64% loss=0.1775 gbest=96.80% (96.5s)
#   New best! 95.64%
#
# ============================================================ ROUND 4/100
#   client1 training... val=92.08%
#   client2 training... val=96.00%
#   client3 training... val=94.88%
#   QPSO aggregating...
#   client1: pbest 92.08%
#   Global: acc=96.78% loss=0.1169 gbest=96.80% (96.0s)
#   New best! 96.78%
#
# ============================================================ ROUND 5/100
#   client1 training... val=87.50%
#   client2 training... val=97.20%
#   client3 training... val=98.21%
#   QPSO aggregating...
#   client2: pbest 97.20%
#   client2: gbest 97.20%
#   client3: pbest 98.21%
#   client3: gbest 98.21%
#   Global: acc=97.55% loss=0.0955 gbest=98.21% (96.2s)
#   New best! 97.55%
#
# ============================================================ ROUND 6/100
#   client1 training... val=95.42%
#   client2 training... val=98.53%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   client1: pbest 95.42%
#   client2: pbest 98.53%
#   client2: gbest 98.53%
#   client3: pbest 98.33%
#   Global: acc=98.15% loss=0.0837 gbest=98.53% (96.2s)
#   New best! 98.15%
#
# ============================================================ ROUND 7/100
#   client1 training... val=95.42%
#   client2 training... val=96.13%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   Global: acc=97.22% loss=0.1320 gbest=98.53% (96.4s)
#
# ============================================================ ROUND 8/100
#   client1 training... val=94.58%
#   client2 training... val=98.67%
#   client3 training... val=97.74%
#   QPSO aggregating...
#   client2: pbest 98.67%
#   client2: gbest 98.67%
#   Global: acc=98.36% loss=0.0889 gbest=98.67% (97.4s)
#   New best! 98.36%
#
# ============================================================ ROUND 9/100
#   client1 training... val=95.00%
#   client2 training... val=97.60%
#   client3 training... val=97.38%
#   QPSO aggregating...
#   Global: acc=97.38% loss=0.1145 gbest=98.67% (97.4s)
#
# ============================================================ ROUND 10/100
#   client1 training... val=97.08%
#   client2 training... val=91.87%
#   client3 training... val=89.17%
#   QPSO aggregating...
#   client1: pbest 97.08%
#   Global: acc=98.47% loss=0.0814 gbest=98.67% (95.6s)
#   New best! 98.47%
#
# ============================================================ ROUND 11/100
#   client1 training... val=97.08%
#   client2 training... val=97.07%
#   client3 training... val=92.74%
#   QPSO aggregating...
#   Global: acc=97.87% loss=0.0977 gbest=98.67% (98.9s)
#
# ============================================================ ROUND 12/100
#   client1 training... val=93.75%
#   client2 training... val=98.80%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   client2: pbest 98.80%
#   client2: gbest 98.80%
#   Global: acc=98.20% loss=0.0961 gbest=98.80% (96.9s)
#
# ============================================================ ROUND 13/100
#   client1 training... val=94.58%
#   client2 training... val=98.13%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   client3: pbest 98.81%
#   client3: gbest 98.81%
#   Global: acc=97.82% loss=0.1115 gbest=98.81% (95.3s)
#
# ============================================================ ROUND 14/100
#   client1 training... val=93.75%
#   client2 training... val=98.67%
#   client3 training... val=95.71%
#   QPSO aggregating...
#   Global: acc=97.71% loss=0.1157 gbest=98.81% (98.1s)
#
# ============================================================ ROUND 15/100
#   client1 training... val=94.58%
#   client2 training... val=96.67%
#   client3 training... val=95.83%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0872 gbest=98.81% (96.5s)
#
# ============================================================ ROUND 16/100
#   client1 training... val=95.42%
#   client2 training... val=98.40%
#   client3 training... val=97.38%
#   QPSO aggregating...
#   Global: acc=97.87% loss=0.1008 gbest=98.81% (96.2s)
#
# ============================================================ ROUND 17/100
#   client1 training... val=95.83%
#   client2 training... val=96.27%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   client3: pbest 99.17%
#   client3: gbest 99.17%
#   Global: acc=98.42% loss=0.0919 gbest=99.17% (96.6s)
#
# ============================================================ ROUND 18/100
#   client1 training... val=96.67%
#   client2 training... val=99.20%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   client2: pbest 99.20%
#   client2: gbest 99.20%
#   Global: acc=98.80% loss=0.0785 gbest=99.20% (97.6s)
#   New best! 98.80%
#
# ============================================================ ROUND 19/100
#   client1 training... val=95.42%
#   client2 training... val=98.53%
#   client3 training... val=99.29%
#   QPSO aggregating...
#   client3: pbest 99.29%
#   client3: gbest 99.29%
#   Global: acc=97.98% loss=0.1126 gbest=99.29% (95.6s)
#
# ============================================================ ROUND 20/100
#   client1 training... val=96.67%
#   client2 training... val=99.60%
#   client3 training... val=94.76%
#   QPSO aggregating...
#   client2: pbest 99.60%
#   client2: gbest 99.60%
#   Global: acc=98.58% loss=0.0723 gbest=99.60% (96.9s)
#
# ============================================================ ROUND 21/100
#   client1 training... val=95.83%
#   client2 training... val=99.20%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0715 gbest=99.60% (96.9s)
#
# ============================================================ ROUND 22/100
#   client1 training... val=96.67%
#   client2 training... val=98.93%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0756 gbest=99.60% (96.4s)
#
# ============================================================ ROUND 23/100
#   client1 training... val=95.83%
#   client2 training... val=97.07%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0727 gbest=99.60% (97.3s)
#
# ============================================================ ROUND 24/100
#   client1 training... val=97.92%
#   client2 training... val=98.40%
#   client3 training... val=99.52%
#   QPSO aggregating...
#   client1: pbest 97.92%
#   client3: pbest 99.52%
#   Global: acc=98.53% loss=0.0837 gbest=99.60% (96.8s)
#
# ============================================================ ROUND 25/100
#   client1 training... val=95.83%
#   client2 training... val=99.60%
#   client3 training... val=99.29%
#   QPSO aggregating...
#   Global: acc=98.31% loss=0.0934 gbest=99.60% (96.9s)
#
# ============================================================ ROUND 26/100
#   client1 training... val=95.83%
#   client2 training... val=97.47%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0822 gbest=99.60% (97.7s)
#
# ============================================================ ROUND 27/100
#   client1 training... val=95.42%
#   client2 training... val=98.80%
#   client3 training... val=99.29%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0785 gbest=99.60% (98.0s)
#
# ============================================================ ROUND 28/100
#   client1 training... val=94.58%
#   client2 training... val=98.80%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0794 gbest=99.60% (97.6s)
#
# ============================================================ ROUND 29/100
#   client1 training... val=95.42%
#   client2 training... val=97.87%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0750 gbest=99.60% (96.2s)
#
# ============================================================ ROUND 30/100
#   client1 training... val=96.25%
#   client2 training... val=99.07%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0854 gbest=99.60% (97.6s)
#
# ============================================================ ROUND 31/100
#   client1 training... val=97.08%
#   client2 training... val=98.80%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0674 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 32/100
#   client1 training... val=96.25%
#   client2 training... val=98.67%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0744 gbest=99.60% (96.3s)
#
# ============================================================ ROUND 33/100
#   client1 training... val=95.42%
#   client2 training... val=97.20%
#   client3 training... val=99.40%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0685 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 34/100
#   client1 training... val=95.83%
#   client2 training... val=98.00%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0719 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 35/100
#   client1 training... val=95.00%
#   client2 training... val=98.67%
#   client3 training... val=97.86%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0783 gbest=99.60% (97.6s)
#
# ============================================================ ROUND 36/100
#   client1 training... val=95.00%
#   client2 training... val=99.20%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.25% loss=0.0938 gbest=99.60% (98.1s)
#
# ============================================================ ROUND 37/100
#   client1 training... val=95.83%
#   client2 training... val=98.80%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.36% loss=0.0862 gbest=99.60% (96.8s)
#
# ============================================================ ROUND 38/100
#   client1 training... val=95.42%
#   client2 training... val=93.33%
#   client3 training... val=99.29%
#   QPSO aggregating...
#   Global: acc=98.36% loss=0.0751 gbest=99.60% (97.0s)
#
# ============================================================ ROUND 39/100
#   client1 training... val=95.83%
#   client2 training... val=99.07%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0808 gbest=99.60% (97.0s)
#
# ============================================================ ROUND 40/100
#   client1 training... val=94.58%
#   client2 training... val=99.33%
#   client3 training... val=96.55%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0699 gbest=99.60% (95.7s)
#
# ============================================================ ROUND 41/100
#   client1 training... val=95.00%
#   client2 training... val=98.80%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0705 gbest=99.60% (97.0s)
#
# ============================================================ ROUND 42/100
#   client1 training... val=95.83%
#   client2 training... val=98.53%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0744 gbest=99.60% (95.8s)
#
# ============================================================ ROUND 43/100
#   client1 training... val=96.25%
#   client2 training... val=98.93%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0764 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 44/100
#   client1 training... val=90.83%
#   client2 training... val=98.27%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0754 gbest=99.60% (97.2s)
#
# ============================================================ ROUND 45/100
#   client1 training... val=95.42%
#   client2 training... val=98.93%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0810 gbest=99.60% (96.1s)
#
# ============================================================ ROUND 46/100
#   client1 training... val=95.42%
#   client2 training... val=97.87%
#   client3 training... val=94.76%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0696 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 47/100
#   client1 training... val=97.08%
#   client2 training... val=99.47%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0716 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 48/100
#   client1 training... val=95.83%
#   client2 training... val=97.20%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0943 gbest=99.60% (96.9s)
#
# ============================================================ ROUND 49/100
#   client1 training... val=95.00%
#   client2 training... val=99.20%
#   client3 training... val=99.29%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0818 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 50/100
#   client1 training... val=94.17%
#   client2 training... val=93.07%
#   client3 training... val=96.67%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0720 gbest=99.60% (98.2s)
#
# ============================================================ ROUND 51/100
#   client1 training... val=95.83%
#   client2 training... val=93.07%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0742 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 52/100
#   client1 training... val=95.00%
#   client2 training... val=99.20%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0788 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 53/100
#   client1 training... val=96.25%
#   client2 training... val=97.07%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0659 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 54/100
#   client1 training... val=97.50%
#   client2 training... val=99.20%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0696 gbest=99.60% (96.0s)
#
# ============================================================ ROUND 55/100
#   client1 training... val=96.67%
#   client2 training... val=99.07%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0857 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 56/100
#   client1 training... val=96.25%
#   client2 training... val=98.80%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0741 gbest=99.60% (97.3s)
#
# ============================================================ ROUND 57/100
#   client1 training... val=95.83%
#   client2 training... val=99.33%
#   client3 training... val=98.21%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0719 gbest=99.60% (97.0s)
#
# ============================================================ ROUND 58/100
#   client1 training... val=93.75%
#   client2 training... val=97.33%
#   client3 training... val=98.21%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0732 gbest=99.60% (95.8s)
#
# ============================================================ ROUND 59/100
#   client1 training... val=95.42%
#   client2 training... val=97.20%
#   client3 training... val=98.10%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0847 gbest=99.60% (97.5s)
#
# ============================================================ ROUND 60/100
#   client1 training... val=95.42%
#   client2 training... val=97.20%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0876 gbest=99.60% (97.2s)
#
# ============================================================ ROUND 61/100
#   client1 training... val=95.42%
#   client2 training... val=99.20%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0743 gbest=99.60% (98.2s)
#
# ============================================================ ROUND 62/100
#   client1 training... val=95.83%
#   client2 training... val=98.00%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0781 gbest=99.60% (95.4s)
#
# ============================================================ ROUND 63/100
#   client1 training... val=94.58%
#   client2 training... val=98.80%
#   client3 training... val=96.43%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0786 gbest=99.60% (95.7s)
#
# ============================================================ ROUND 64/100
#   client1 training... val=93.33%
#   client2 training... val=98.93%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0849 gbest=99.60% (96.3s)
#
# ============================================================ ROUND 65/100
#   client1 training... val=96.67%
#   client2 training... val=99.07%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0725 gbest=99.60% (97.9s)
#
# ============================================================ ROUND 66/100
#   client1 training... val=95.42%
#   client2 training... val=98.93%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0726 gbest=99.60% (96.3s)
#
# ============================================================ ROUND 67/100
#   client1 training... val=96.25%
#   client2 training... val=98.80%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0737 gbest=99.60% (96.2s)
#
# ============================================================ ROUND 68/100
#   client1 training... val=94.58%
#   client2 training... val=99.20%
#   client3 training... val=98.10%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0766 gbest=99.60% (96.4s)
#
# ============================================================ ROUND 69/100
#   client1 training... val=97.08%
#   client2 training... val=98.40%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0724 gbest=99.60% (96.4s)
#
# ============================================================ ROUND 70/100
#   client1 training... val=95.83%
#   client2 training... val=99.33%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0693 gbest=99.60% (96.8s)
#
# ============================================================ ROUND 71/100
#   client1 training... val=97.08%
#   client2 training... val=98.80%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.25% loss=0.0920 gbest=99.60% (95.4s)
#
# ============================================================ ROUND 72/100
#   client1 training... val=95.42%
#   client2 training... val=97.73%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0744 gbest=99.60% (95.2s)
#
# ============================================================ ROUND 73/100
#   client1 training... val=98.33%
#   client2 training... val=99.33%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   client1: pbest 98.33%
#   Global: acc=98.42% loss=0.0825 gbest=99.60% (97.1s)
#
# ============================================================ ROUND 74/100
#   client1 training... val=95.42%
#   client2 training... val=98.53%
#   client3 training... val=97.02%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0674 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 75/100
#   client1 training... val=95.83%
#   client2 training... val=99.33%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0678 gbest=99.60% (95.7s)
#
# ============================================================ ROUND 76/100
#   client1 training... val=97.08%
#   client2 training... val=97.33%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0690 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 77/100
#   client1 training... val=95.42%
#   client2 training... val=98.53%
#   client3 training... val=98.21%
#   QPSO aggregating...
#   Global: acc=98.09% loss=0.1027 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 78/100
#   client1 training... val=95.83%
#   client2 training... val=98.93%
#   client3 training... val=98.81%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0755 gbest=99.60% (97.1s)
#
# ============================================================ ROUND 79/100
#   client1 training... val=96.67%
#   client2 training... val=98.80%
#   client3 training... val=97.62%
#   QPSO aggregating...
#   Global: acc=98.80% loss=0.0707 gbest=99.60% (97.5s)
#
# ============================================================ ROUND 80/100
#   client1 training... val=95.42%
#   client2 training... val=96.13%
#   client3 training... val=97.62%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0690 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 81/100
#   client1 training... val=95.42%
#   client2 training... val=98.80%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0748 gbest=99.60% (96.0s)
#
# ============================================================ ROUND 82/100
#   client1 training... val=95.42%
#   client2 training... val=94.67%
#   client3 training... val=98.33%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0794 gbest=99.60% (95.9s)
#
# ============================================================ ROUND 83/100
#   client1 training... val=96.67%
#   client2 training... val=98.40%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0868 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 84/100
#   client1 training... val=96.25%
#   client2 training... val=97.33%
#   client3 training... val=99.52%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0752 gbest=99.60% (98.5s)
#
# ============================================================ ROUND 85/100
#   client1 training... val=95.83%
#   client2 training... val=97.73%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.36% loss=0.0824 gbest=99.60% (95.8s)
#
# ============================================================ ROUND 86/100
#   client1 training... val=95.42%
#   client2 training... val=98.40%
#   client3 training... val=98.45%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0895 gbest=99.60% (95.8s)
#
# ============================================================ ROUND 87/100
#   client1 training... val=96.67%
#   client2 training... val=99.07%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.64% loss=0.0812 gbest=99.60% (98.2s)
#
# ============================================================ ROUND 88/100
#   client1 training... val=95.00%
#   client2 training... val=98.93%
#   client3 training... val=98.21%
#   QPSO aggregating...
#   Global: acc=98.42% loss=0.0796 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 89/100
#   client1 training... val=95.42%
#   client2 training... val=98.40%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.53% loss=0.0806 gbest=99.60% (98.2s)
#
# ============================================================ ROUND 90/100
#   client1 training... val=95.42%
#   client2 training... val=99.20%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0715 gbest=99.60% (96.5s)
#
# ============================================================ ROUND 91/100
#   client1 training... val=95.00%
#   client2 training... val=97.87%
#   client3 training... val=98.57%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0718 gbest=99.60% (95.0s)
#
# ============================================================ ROUND 92/100
#   client1 training... val=95.83%
#   client2 training... val=99.07%
#   client3 training... val=99.17%
#   QPSO aggregating...
#   Global: acc=98.69% loss=0.0797 gbest=99.60% (97.0s)
#
# ============================================================ ROUND 93/100
#   client1 training... val=96.25%
#   client2 training... val=98.93%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0716 gbest=99.60% (96.6s)
#
# ============================================================ ROUND 94/100
#   client1 training... val=95.00%
#   client2 training... val=99.47%
#   client3 training... val=98.69%
#   QPSO aggregating...
#   Global: acc=98.80% loss=0.0684 gbest=99.60% (95.3s)
#
# ============================================================ ROUND 95/100
#   client1 training... val=86.67%
#   client2 training... val=99.20%
#   client3 training... val=99.05%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0813 gbest=99.60% (97.2s)
#
# ============================================================ ROUND 96/100
#   client1 training... val=96.25%
#   client2 training... val=98.27%
#   client3 training... val=95.71%
#   QPSO aggregating...
#   Global: acc=98.80% loss=0.0769 gbest=99.60% (96.7s)
#
# ============================================================ ROUND 97/100
#   client1 training... val=96.67%
#   client2 training... val=98.53%
#   client3 training... val=96.90%
#   QPSO aggregating...
#   Global: acc=98.75% loss=0.0697 gbest=99.60% (95.2s)
#
# ============================================================ ROUND 98/100
#   client1 training... val=95.00%
#   client2 training... val=98.53%
#   client3 training... val=95.12%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0710 gbest=99.60% (95.2s)
#
# ============================================================ ROUND 99/100
#   client1 training... val=96.67%
#   client2 training... val=98.27%
#   client3 training... val=97.50%
#   QPSO aggregating...
#   Global: acc=98.47% loss=0.0886 gbest=99.60% (96.8s)
#
# ============================================================ ROUND 100/100
#   client1 training... val=96.67%
#   client2 training... val=99.33%
#   client3 training... val=98.93%
#   QPSO aggregating...
#   Global: acc=98.58% loss=0.0672 gbest=99.60% (96.1s)
#
# ================================================================================
#   QPSO-FL DONE best 98.80% gbest 99.60%
# ================================================================================
#
# All training complete!

# %% [markdown]
# ## Evaluation & Plots

# %%
def plot_accuracy_comparison(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(2, max(n,2), figsize=(8*max(n,2), 12))
    fig.suptitle("FL Aggregation Comparison", fontsize=16, fontweight="bold")
    colors = ['#1f77b4','#ff7f0e','#2ca02c']
    ax = axes[0,0]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_acc"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Acc (%)", title="Global Test Accuracy", ylim=[0,100]); ax.legend(); ax.grid(alpha=0.3)
    ax = axes[0,1]
    for df, name, c in zip(dfs, names, colors):
        ax.plot(df["round"], df["global_test_loss"], label=name, lw=2, color=c)
    ax.set(xlabel="Round", ylabel="Loss", title="Global Test Loss"); ax.legend(); ax.grid(alpha=0.3)
    for idx, (df, name) in enumerate(zip(dfs, names)):
        ax = axes[1, idx]
        for i in range(1,4): ax.plot(df["round"], df[f"client{i}_val_acc"], label=f"Client {i}", lw=2)
        ax.set(xlabel="Round", ylabel="Val Acc (%)", title=f"{name}: Per-Client"); ax.legend(); ax.grid(alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()
    print(f"Saved -> {save_path}")

def generate_confusion_matrix(mp, tl, mname, device="cuda", save_path=None):
    model = BrainTumorResNet(NUM_CLASSES, pretrained=False).to(device)
    model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
    model.eval(); preds, labels = [], []
    with torch.no_grad():
        for imgs, labs in tl:
            _, pred = model(imgs.to(device)).max(1)
            preds.extend(pred.cpu().numpy()); labels.extend(labs.numpy())
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"Confusion Matrix - {mname}", fontsize=14, fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted"); plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"\n{mname}:"); print(classification_report(labels, preds, target_names=CLASS_NAMES, digits=4))

def plot_roc_auc(mps, mnames, tl, device="cuda", save_path=None):
    n = len(mps)
    fig, axes = plt.subplots(1, n, figsize=(7*n, 6))
    if n == 1: axes = [axes]
    cc = ['#e74c3c', '#3498db', '#2ecc71', '#9b59b6']
    for ax, mp, mn in zip(axes, mps, mnames):
        model = BrainTumorResNet(NUM_CLASSES, pretrained=False).to(device)
        model.load_state_dict(torch.load(mp, map_location=device, weights_only=True))
        model.eval(); probs, labs = [], []
        with torch.no_grad():
            for imgs, lb in tl:
                out = model(imgs.to(device)); probs.append(torch.softmax(out, dim=1).cpu().numpy()); labs.extend(lb.numpy())
        yp = np.vstack(probs); yt = np.array(labs)
        yb = label_binarize(yt, classes=list(range(NUM_CLASSES)))
        for i, (cls, c) in enumerate(zip(CLASS_NAMES, cc)):
            fpr, tpr, _ = roc_curve(yb[:, i], yp[:, i]); a = auc(fpr, tpr)
            ax.plot(fpr, tpr, color=c, lw=2, label=f"{cls} ({a:.4f})")
        fpr_m, tpr_m, _ = roc_curve(yb.ravel(), yp.ravel())
        ax.plot(fpr_m, tpr_m, 'k--', lw=2, label=f"Micro ({auc(fpr_m,tpr_m):.4f})")
        ax.plot([0,1],[0,1],'gray',ls=':',lw=1)
        ax.set(xlabel="FPR", ylabel="TPR", title=f"ROC - {mn}"); ax.legend(loc="lower right", fontsize=8); ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path: plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show(); print(f"ROC-AUC saved -> {save_path}")

def plot_client_fairness(dfs, names, save_path):
    n = len(dfs)
    fig, axes = plt.subplots(1, n, figsize=(6*n, 5)); cc = ["#FF6B6B","#4ECDC4","#45B7D1"]
    if n == 1: axes = [axes]
    for ax, df, t in zip(axes, dfs, names):
        accs = [df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)]
        ax.bar(["C1","C2","C3"], accs, color=cc, edgecolor="black")
        ax.axhline(np.mean(accs), color="red", ls="--", lw=2, label="Mean")
        ax.set(ylabel="Final Val Acc (%)", ylim=[0,100])
        ax.set_title(f"{t} (std={np.std(accs):.2f}%)", fontsize=13, fontweight="bold"); ax.legend(); ax.grid(axis="y", alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=300, bbox_inches="tight"); plt.show()

def convergence_metrics(df, target=80.0):
    r = df[df["global_test_acc"]>=target]
    return {"final_acc": round(df["global_test_acc"].iloc[-1],2), "best_acc": round(df["global_test_acc"].max(),2),
            "round_to_target": int(r["round"].min()) if len(r) else None,
            "avg_round_time_s": round(df["round_time"].mean(),2), "total_time_min": round(df["round_time"].sum()/60,2)}

def statistical_analysis(dfa, dfb):
    a, b = dfa["global_test_acc"].values, dfb["global_test_acc"].values
    n = min(len(a),len(b)); a, b = a[:n], b[:n]
    t_stat, p_val = stats.ttest_rel(b, a); d = (b-a).mean()/((b-a).std(ddof=1)+1e-8)
    return {"t_stat": round(float(t_stat),4), "p_value": float(p_val), "cohens_d": round(float(d),4), "significant": bool(p_val<0.05)}

def build_comparison_df(*pairs):
    cols = ["Metric"] + [n for _, n in pairs]
    ml = []
    for df, n in pairs:
        m = convergence_metrics(df)
        m["client_std"] = round(float(np.std([df[f"client{i}_val_acc"].iloc[-1] for i in range(1,4)])),2)
        ml.append(m)
    keys = [("Final Acc (%)","final_acc"),("Best Acc (%)","best_acc"),("Rounds to 80%","round_to_target"),
            ("Avg Round (s)","avg_round_time_s"),("Total Time (min)","total_time_min"),("Client Std Dev","client_std")]
    rows = [[l]+[m[k] if m[k] is not None else "N/A" for m in ml] for l, k in keys]
    return pd.DataFrame(rows, columns=cols)
print("Evaluation functions loaded")
# Out:
# Evaluation functions loaded

# %%
df_fa = pd.read_csv('/kaggle/working/results/fedavg/metrics.csv')
df_fp = pd.read_csv('/kaggle/working/results/fedprox/metrics.csv')
df_qp = pd.read_csv('/kaggle/working/results/qpso/metrics.csv')
comp = build_comparison_df((df_fa,"FedAvg"),(df_fp,"FedProx"),(df_qp,"QPSO-FL"))
print(comp.to_string(index=False))
comp.to_csv('/kaggle/working/results/final_comparison.csv', index=False)
# Out:
#           Metric  FedAvg  FedProx  QPSO-FL
#    Final Acc (%)   98.69    98.91    98.58
#     Best Acc (%)   98.96    99.13    98.80
#    Rounds to 80%    2.00     1.00     2.00
#    Avg Round (s)   96.52   104.17    96.64
# Total Time (min)  160.86   173.61   161.06
#   Client Std Dev    1.06     1.15     1.17

# %%
plot_accuracy_comparison([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/comparison.png')
for m, n in [('fedavg','FedAvg'),('fedprox','FedProx'),('qpso','QPSO-FL')]:
    generate_confusion_matrix(f'/kaggle/working/models/{m}_best.pth', data_loaders['global_test'], n, device=device, save_path=f'/kaggle/working/results/plots/cm_{m}.png')
plot_client_fairness([df_fa, df_fp, df_qp], ['FedAvg','FedProx','QPSO-FL'], '/kaggle/working/results/plots/fairness.png')
plot_roc_auc(['/kaggle/working/models/fedavg_best.pth','/kaggle/working/models/fedprox_best.pth','/kaggle/working/models/qpso_best.pth'],
    ['FedAvg','FedProx','QPSO-FL'], data_loaders['global_test'], device=device, save_path='/kaggle/working/results/plots/roc_auc.png')
# Out:
# Saved -> /kaggle/working/results/plots/comparison.png
#
# FedAvg:
#               precision    recall  f1-score   support
#
#       Glioma     1.0000    0.9706    0.9851       442
#   Meningioma     0.9894    0.9894    0.9894       470
#     No Tumor     0.9773    0.9977    0.9874       432
#    Pituitary     0.9919    1.0000    0.9959       489
#
#     accuracy                         0.9896      1833
#    macro avg     0.9896    0.9894    0.9894      1833
# weighted avg     0.9898    0.9896    0.9896      1833
#
#
# FedProx:
#               precision    recall  f1-score   support
#
#       Glioma     1.0000    0.9751    0.9874       442
#   Meningioma     0.9852    0.9936    0.9894       470
#     No Tumor     0.9885    0.9977    0.9931       432
#    Pituitary     0.9919    0.9980    0.9949       489
#
#     accuracy                         0.9913      1833
#    macro avg     0.9914    0.9911    0.9912      1833
# weighted avg     0.9913    0.9913    0.9913      1833
#
#
# QPSO-FL:
#               precision    recall  f1-score   support
#
#       Glioma     0.9977    0.9706    0.9839       442
#   Meningioma     0.9872    0.9830    0.9851       470
#     No Tumor     0.9840    0.9977    0.9908       432
#    Pituitary     0.9839    1.0000    0.9919       489
#
#     accuracy                         0.9880      1833
#    macro avg     0.9882    0.9878    0.9879      1833
# weighted avg     0.9881    0.9880    0.9880      1833
#
# ROC-AUC saved -> /kaggle/working/results/plots/roc_auc.png

# %% [markdown]
# ## Statistical Analysis & Summary

# %%
s1 = statistical_analysis(df_fa, df_qp)
s2 = statistical_analysis(df_fa, df_fp)
print("FedAvg vs QPSO:", json.dumps(s1, indent=2))
print("FedAvg vs FedProx:", json.dumps(s2, indent=2))
summary = {"fedavg": convergence_metrics(df_fa), "fedprox": convergence_metrics(df_fp),
           "qpso": convergence_metrics(df_qp), "stats_fa_qp": s1, "stats_fa_fp": s2}
with open('/kaggle/working/results/executive_summary.json','w') as f: json.dump(summary, f, indent=2)
print("Summary saved")
print("\nLaTeX Table:")
print(comp.to_latex(index=False, float_format="%.2f", caption="FedAvg vs FedProx vs QPSO-FL", label="tab:comparison"))
print("\nNotebook complete!")
# Out:
# FedAvg vs QPSO: {
#   "t_stat": 0.1642,
#   "p_value": 0.869891512368429,
#   "cohens_d": 0.0164,
#   "significant": false
# }
# FedAvg vs FedProx: {
#   "t_stat": 0.8482,
#   "p_value": 0.39834675584039214,
#   "cohens_d": 0.0848,
#   "significant": false
# }
# Summary saved
#
# LaTeX Table:
# \begin{table}
# \caption{FedAvg vs FedProx vs QPSO-FL}
# \label{tab:comparison}
# \begin{tabular}{lrrr}
# \toprule
# Metric & FedAvg & FedProx & QPSO-FL \\
# \midrule
# Final Acc (%) & 98.69 & 98.91 & 98.58 \\
# Best Acc (%) & 98.96 & 99.13 & 98.80 \\
# Rounds to 80% & 2.00 & 1.00 & 2.00 \\
# Avg Round (s) & 96.52 & 104.17 & 96.64 \\
# Total Time (min) & 160.86 & 173.61 & 161.06 \\
# Client Std Dev & 1.06 & 1.15 & 1.17 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# Notebook complete!
